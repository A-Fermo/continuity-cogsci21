# %%
import pandas as pd
import os

# %%
cd = os.getcwd()
data = pd.read_csv("{}/data.csv".format(cd))
display(data)
# Out:
#     subject_id          rt        stimulus  button_pressed  \
# 0            1    1367.000  img/inst_1.png             0.0
# 1            1         NaN             NaN             NaN
# 2            1         NaN             NaN             NaN
# 3            1         NaN             NaN             NaN
# 4            1         NaN             NaN             NaN
# 5            1     816.000  img/inst_6.png             0.0
# 6            1    4670.000             NaN             NaN
# 7            1    1217.000  img/inst_8.png             0.0
# 8            1    8562.000             NaN             NaN
# 9            1   13385.000             NaN             NaN
# 10           1    8398.000             NaN             NaN
# 11           1   14195.000             NaN             NaN
# 12           1   18570.000             NaN             NaN
# 13           1   12289.000             NaN             NaN
# 14           1   14525.000             NaN             NaN
# ...
