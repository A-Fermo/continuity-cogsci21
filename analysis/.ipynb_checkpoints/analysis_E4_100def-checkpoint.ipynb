# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from jupyterthemes import jtplot
jtplot.style(theme="chesterish")
pd.options.display.max_rows = 100

# %% [markdown]
# ## Data structuring

# %% [markdown]
# #### Importing data.csv

# %%
root_dir = os.path.dirname(os.getcwd())
data_clean = pd.read_csv("{}/data/data_E4_100def.csv".format(root_dir))
data_clean
# Out:
#       subject_id     stimulus           trial_type  time_elapsed  gender  age  \
# 0              1  instruction        causal-graph1         25008  female   35
# 1              1  instruction        causal-graph1         40025  female   35
# 2              1  instruction        causal-graph1         76214  female   35
# 3              1  instruction        causal-graph1        100212  female   35
# 4              1  instruction        causal-graph1        153979  female   35
# 5              1  instruction        causal-graph1        168998  female   35
# 6              1  instruction  survey-multi-choice        294778  female   35
# 7              1  instruction        causal-graph1        306920  female   35
# 8              1       UAS_LT        causal-graph1        386904  female   35
# 9              1     chainS_L        causal-graph1        429102  female   35
# 10             1      UAAS_LB        causal-graph1        459063  female   35
# 11             1      UBBS_LB        causal-graph1        494370  female   35
# 12             1       UBS_LT        causal-graph1        513288  female   35
# 13             1      UBAS_LB        causal-graph1        532059  female   35
# 14             1      UABS_LT        causal-graph1        555482  female   35
# 15             1  instruction        causal-graph1        558051  female   35
# 16             1      comment          survey-text        561375  female   35
# 17             2  instruction        causal-graph1         11045  female   31
# 18             2  instruction        causal-graph1         17027  female   31
# 19             2  instruction        causal-graph1         39513  female   31
# 20             2  instruction        causal-graph1         53108  female   31
# 21             2  instruction        causal-graph1         75650  female   31
# 22             2  instruction        causal-graph1         82891  female   31
# 23             2  instruction  survey-multi-choice        121943  female   31
# 24             2  instruction        causal-graph1        125682  female   31
# 25             2  instruction        causal-graph1        127057  female   31
# 26             2  instruction        causal-graph1        128162  female   31
# 27             2  instruction        causal-graph1        132512  female   31
# 28             2  instruction        causal-graph1        133381  female   31
# 29             2  instruction        causal-graph1        139073  female   31
# 30             2  instruction        causal-graph1        140837  female   31
# 31             2  instruction  survey-multi-choice        173351  female   31
# 32             2  instruction        causal-graph1        175122  female   31
# 33             2     chainS_L        causal-graph1        192921  female   31
# 34             2       UAS_LT        causal-graph1        209266  female   31
# 35             2      UAAS_LB        causal-graph1        230512  female   31
# 36             2      UBAS_LB        causal-graph1        245596  female   31
# 37             2      UBBS_LT        causal-graph1        279744  female   31
# 38             2      UABS_LT        causal-graph1        294871  female   31
# 39             2       UBS_LT        causal-graph1        307511  female   31
# 40             2  instruction        causal-graph1        309293  female   31
# 41             2      comment          survey-text        347353  female   31
# 42             3  instruction        causal-graph1          5119    male   47
# 43             3  instruction        causal-graph1          6822    male   47
# 44             3  instruction        causal-graph1         12567    male   47
# 45             3  instruction        causal-graph1         14695    male   47
# 46             3  instruction        causal-graph1         22695    male   47
# 47             3  instruction        causal-graph1         24967    male   47
# 48             3  instruction  survey-multi-choice         32080    male   47
# 49             3  instruction        causal-graph1         34562    male   47
# ...          ...          ...                  ...           ...     ...  ...
# 1662          46      UAAS_RT        causal-graph1        188443  female   36
# 1663          46       UBS_RT        causal-graph1        213095  female   36
# 1664          46      UBBS_RB        causal-graph1        227940  female   36
# 1665          46       UAS_RB        causal-graph1        241983  female   36
# 1666          46     chainS_R        causal-graph1        255061  female   36
# 1667          46      UABS_RT        causal-graph1        273003  female   36
# 1668          46  instruction        causal-graph1        277447  female   36
# 1669          46      comment          survey-text        288226  female   36
# 1670          47  instruction        causal-graph1         22923  female   44
# 1671          47  instruction        causal-graph1         28267  female   44
# 1672          47  instruction        causal-graph1         62099  female   44
# 1673          47  instruction        causal-graph1         73426  female   44
# 1674          47  instruction        causal-graph1        101346  female   44
# 1675          47  instruction        causal-graph1        118626  female   44
# 1676          47  instruction  survey-multi-choice        155486  female   44
# 1677          47  instruction        causal-graph1        158626  female   44
# 1678          47  instruction        causal-graph1        160906  female   44
# 1679          47  instruction        causal-graph1        162994  female   44
# 1680          47  instruction        causal-graph1        172810  female   44
# 1681          47  instruction        causal-graph1        174873  female   44
# 1682          47  instruction        causal-graph1        182522  female   44
# 1683          47  instruction        causal-graph1        186433  female   44
# 1684          47  instruction  survey-multi-choice        202018  female   44
# 1685          47  instruction        causal-graph1        204290  female   44
# 1686          47      UBBS_LB        causal-graph1        221946  female   44
# 1687          47      UABS_LT        causal-graph1        238450  female   44
# 1688          47      UAAS_LB        causal-graph1        256458  female   44
# 1689          47       UBS_LT        causal-graph1        270180  female   44
# 1690          47     chainS_L        causal-graph1        293244  female   44
# 1691          47       UAS_LT        causal-graph1        307217  female   44
# 1692          47      UBAS_LB        causal-graph1        332433  female   44
# 1693          47  instruction        causal-graph1        335193  female   44
# 1694          47      comment          survey-text        343922  female   44
# 1695          48  instruction        causal-graph1          5022    male   26
# 1696          48  instruction        causal-graph1          8849    male   26
# 1697          48  instruction        causal-graph1         26598    male   26
# 1698          48  instruction        causal-graph1         38715    male   26
# 1699          48  instruction        causal-graph1         53899    male   26
# 1700          48  instruction        causal-graph1         63273    male   26
# 1701          48  instruction  survey-multi-choice        100002    male   26
# 1702          48  instruction        causal-graph1        101953    male   26
# 1703          48      UBBS_RT        causal-graph1        144537    male   26
# 1704          48       UBS_RT        causal-graph1        158771    male   26
# 1705          48      UBAS_RB        causal-graph1        171445    male   26
# 1706          48      UABS_RB        causal-graph1        188207    male   26
# 1707          48     chainS_R        causal-graph1        198773    male   26
# 1708          48       UAS_RT        causal-graph1        210315    male   26
# 1709          48      UAAS_RB        causal-graph1        224177    male   26
# 1710          48  instruction        causal-graph1        226031    male   26
# 1711          48      comment          survey-text        230491    male   26
#
#                language                   country sampling           turkcode  \
# 0               Turkish  United States of America     Left  R568393397970gxrw
# 1               Turkish  United States of America     Left  R568393397970gxrw
# 2               Turkish  United States of America     Left  R568393397970gxrw
# 3               Turkish  United States of America     Left  R568393397970gxrw
# 4               Turkish  United States of America     Left  R568393397970gxrw
# 5               Turkish  United States of America     Left  R568393397970gxrw
# 6               Turkish  United States of America     Left  R568393397970gxrw
# 7               Turkish  United States of America     Left  R568393397970gxrw
# 8               Turkish  United States of America     Left  R568393397970gxrw
# 9               Turkish  United States of America     Left  R568393397970gxrw
# 10              Turkish  United States of America     Left  R568393397970gxrw
# 11              Turkish  United States of America     Left  R568393397970gxrw
# 12              Turkish  United States of America     Left  R568393397970gxrw
# 13              Turkish  United States of America     Left  R568393397970gxrw
# 14              Turkish  United States of America     Left  R568393397970gxrw
# 15              Turkish  United States of America     Left  R568393397970gxrw
# 16              Turkish  United States of America     Left  R568393397970gxrw
# 17              English  United States of America     Left  R569505437620gxrw
# 18              English  United States of America     Left  R569505437620gxrw
# 19              English  United States of America     Left  R569505437620gxrw
# 20              English  United States of America     Left  R569505437620gxrw
# 21              English  United States of America     Left  R569505437620gxrw
# 22              English  United States of America     Left  R569505437620gxrw
# 23              English  United States of America     Left  R569505437620gxrw
# 24              English  United States of America     Left  R569505437620gxrw
# 25              English  United States of America     Left  R569505437620gxrw
# 26              English  United States of America     Left  R569505437620gxrw
# 27              English  United States of America     Left  R569505437620gxrw
# 28              English  United States of America     Left  R569505437620gxrw
# 29              English  United States of America     Left  R569505437620gxrw
# 30              English  United States of America     Left  R569505437620gxrw
# 31              English  United States of America     Left  R569505437620gxrw
# 32              English  United States of America     Left  R569505437620gxrw
# 33              English  United States of America     Left  R569505437620gxrw
# 34              English  United States of America     Left  R569505437620gxrw
# 35              English  United States of America     Left  R569505437620gxrw
# 36              English  United States of America     Left  R569505437620gxrw
# 37              English  United States of America     Left  R569505437620gxrw
# 38              English  United States of America     Left  R569505437620gxrw
# 39              English  United States of America     Left  R569505437620gxrw
# 40              English  United States of America     Left  R569505437620gxrw
# 41              English  United States of America     Left  R569505437620gxrw
# 42              english  United States of America     Left  R568774137640gxrw
# 43              english  United States of America     Left  R568774137640gxrw
# 44              english  United States of America     Left  R568774137640gxrw
# 45              english  United States of America     Left  R568774137640gxrw
# 46              english  United States of America     Left  R568774137640gxrw
# 47              english  United States of America     Left  R568774137640gxrw
# 48              english  United States of America     Left  R568774137640gxrw
# 49              english  United States of America     Left  R568774137640gxrw
# ...                 ...                       ...      ...                ...
# 1662            english  United States of America    Right  R564652417300gxrw
# 1663            english  United States of America    Right  R564652417300gxrw
# 1664            english  United States of America    Right  R564652417300gxrw
# 1665            english  United States of America    Right  R564652417300gxrw
# 1666            english  United States of America    Right  R564652417300gxrw
# 1667            english  United States of America    Right  R564652417300gxrw
# 1668            english  United States of America    Right  R564652417300gxrw
# 1669            english  United States of America    Right  R564652417300gxrw
# 1670            English  United States of America     Left  R562497257520gxrw
# 1671            English  United States of America     Left  R562497257520gxrw
# 1672            English  United States of America     Left  R562497257520gxrw
# 1673            English  United States of America     Left  R562497257520gxrw
# 1674            English  United States of America     Left  R562497257520gxrw
# 1675            English  United States of America     Left  R562497257520gxrw
# 1676            English  United States of America     Left  R562497257520gxrw
# 1677            English  United States of America     Left  R562497257520gxrw
# 1678            English  United States of America     Left  R562497257520gxrw
# 1679            English  United States of America     Left  R562497257520gxrw
# 1680            English  United States of America     Left  R562497257520gxrw
# 1681            English  United States of America     Left  R562497257520gxrw
# 1682            English  United States of America     Left  R562497257520gxrw
# 1683            English  United States of America     Left  R562497257520gxrw
# 1684            English  United States of America     Left  R562497257520gxrw
# 1685            English  United States of America     Left  R562497257520gxrw
# 1686            English  United States of America     Left  R562497257520gxrw
# 1687            English  United States of America     Left  R562497257520gxrw
# 1688            English  United States of America     Left  R562497257520gxrw
# 1689            English  United States of America     Left  R562497257520gxrw
# 1690            English  United States of America     Left  R562497257520gxrw
# 1691            English  United States of America     Left  R562497257520gxrw
# 1692            English  United States of America     Left  R562497257520gxrw
# 1693            English  United States of America     Left  R562497257520gxrw
# 1694            English  United States of America     Left  R562497257520gxrw
# 1695  English, Japanese  United States of America    Right  R565976917610gxrw
# 1696  English, Japanese  United States of America    Right  R565976917610gxrw
# 1697  English, Japanese  United States of America    Right  R565976917610gxrw
# 1698  English, Japanese  United States of America    Right  R565976917610gxrw
# 1699  English, Japanese  United States of America    Right  R565976917610gxrw
# 1700  English, Japanese  United States of America    Right  R565976917610gxrw
# 1701  English, Japanese  United States of America    Right  R565976917610gxrw
# 1702  English, Japanese  United States of America    Right  R565976917610gxrw
# 1703  English, Japanese  United States of America    Right  R565976917610gxrw
# 1704  English, Japanese  United States of America    Right  R565976917610gxrw
# 1705  English, Japanese  United States of America    Right  R565976917610gxrw
# 1706  English, Japanese  United States of America    Right  R565976917610gxrw
# 1707  English, Japanese  United States of America    Right  R565976917610gxrw
# 1708  English, Japanese  United States of America    Right  R565976917610gxrw
# 1709  English, Japanese  United States of America    Right  R565976917610gxrw
# 1710  English, Japanese  United States of America    Right  R565976917610gxrw
# 1711  English, Japanese  United States of America    Right  R565976917610gxrw
#
#       ...                                          responses  stim_type  \
# 0     ...                                                NaN        NaN
# 1     ...                                                NaN        NaN
# 2     ...                                                NaN        NaN
# 3     ...                                                NaN        NaN
# 4     ...                                                NaN        NaN
# 5     ...                                                NaN        NaN
# 6     ...  {"Q0":" To decide what caused the activation o...        NaN
# 7     ...                                                NaN        NaN
# 8     ...                                                NaN   AND_Gate
# 9     ...                                                NaN     ChainS
# 10    ...                                                NaN   AND_Gate
# 11    ...                                                NaN   AND_Gate
# 12    ...                                                NaN   AND_Gate
# 13    ...                                                NaN   AND_Gate
# 14    ...                                                NaN   AND_Gate
# 15    ...                                                NaN        NaN
# 16    ...                                          {"Q0":""}        NaN
# 17    ...                                                NaN        NaN
# 18    ...                                                NaN        NaN
# 19    ...                                                NaN        NaN
# 20    ...                                                NaN        NaN
# 21    ...                                                NaN        NaN
# 22    ...                                                NaN        NaN
# 23    ...  {"Q0":" To decide what caused the activation o...        NaN
# 24    ...                                                NaN        NaN
# 25    ...                                                NaN        NaN
# 26    ...                                                NaN        NaN
# 27    ...                                                NaN        NaN
# 28    ...                                                NaN        NaN
# 29    ...                                                NaN        NaN
# 30    ...                                                NaN        NaN
# 31    ...  {"Q0":" To decide what caused the activation o...        NaN
# 32    ...                                                NaN        NaN
# 33    ...                                                NaN     ChainS
# 34    ...                                                NaN   AND_Gate
# 35    ...                                                NaN   AND_Gate
# 36    ...                                                NaN   AND_Gate
# 37    ...                                                NaN   AND_Gate
# 38    ...                                                NaN   AND_Gate
# 39    ...                                                NaN   AND_Gate
# 40    ...                                                NaN        NaN
# 41    ...  {"Q0":"I thought this experiment was very inte...        NaN
# 42    ...                                                NaN        NaN
# 43    ...                                                NaN        NaN
# 44    ...                                                NaN        NaN
# 45    ...                                                NaN        NaN
# 46    ...                                                NaN        NaN
# 47    ...                                                NaN        NaN
# 48    ...  {"Q0":" To decide what caused the activation o...        NaN
# 49    ...                                                NaN        NaN
# ...   ...                                                ...        ...
# 1662  ...                                                NaN   AND_Gate
# 1663  ...                                                NaN   AND_Gate
# 1664  ...                                                NaN   AND_Gate
# 1665  ...                                                NaN   AND_Gate
# 1666  ...                                                NaN     ChainS
# 1667  ...                                                NaN   AND_Gate
# 1668  ...                                                NaN        NaN
# 1669  ...                                      {"Q0":"None"}        NaN
# 1670  ...                                                NaN        NaN
# 1671  ...                                                NaN        NaN
# 1672  ...                                                NaN        NaN
# 1673  ...                                                NaN        NaN
# 1674  ...                                                NaN        NaN
# 1675  ...                                                NaN        NaN
# 1676  ...  {"Q0":" To decide what caused the activation o...        NaN
# 1677  ...                                                NaN        NaN
# 1678  ...                                                NaN        NaN
# 1679  ...                                                NaN        NaN
# 1680  ...                                                NaN        NaN
# 1681  ...                                                NaN        NaN
# 1682  ...                                                NaN        NaN
# 1683  ...                                                NaN        NaN
# 1684  ...  {"Q0":" To decide what caused the activation o...        NaN
# 1685  ...                                                NaN        NaN
# 1686  ...                                                NaN   AND_Gate
# 1687  ...                                                NaN   AND_Gate
# 1688  ...                                                NaN   AND_Gate
# 1689  ...                                                NaN   AND_Gate
# 1690  ...                                                NaN     ChainS
# 1691  ...                                                NaN   AND_Gate
# 1692  ...                                                NaN   AND_Gate
# 1693  ...                                                NaN        NaN
# 1694  ...                                          {"Q0":""}        NaN
# 1695  ...                                                NaN        NaN
# 1696  ...                                                NaN        NaN
# 1697  ...                                                NaN        NaN
# 1698  ...                                                NaN        NaN
# 1699  ...                                                NaN        NaN
# 1700  ...                                                NaN        NaN
# 1701  ...  {"Q0":" To decide what caused the activation o...        NaN
# 1702  ...                                                NaN        NaN
# 1703  ...                                                NaN   AND_Gate
# 1704  ...                                                NaN   AND_Gate
# 1705  ...                                                NaN   AND_Gate
# 1706  ...                                                NaN   AND_Gate
# 1707  ...                                                NaN     ChainS
# 1708  ...                                                NaN   AND_Gate
# 1709  ...                                                NaN   AND_Gate
# 1710  ...                                                NaN        NaN
# 1711  ...                                          {"Q0":""}        NaN
#
#      rolled_OR_unrolled A_branch_loc A_detectors state_OR_event state_branch  \
# 0                   NaN          NaN         NaN            NaN          NaN
# 1                   NaN          NaN         NaN            NaN          NaN
# 2                   NaN          NaN         NaN            NaN          NaN
# 3                   NaN          NaN         NaN            NaN          NaN
# 4                   NaN          NaN         NaN            NaN          NaN
# 5                   NaN          NaN         NaN            NaN          NaN
# 6                   NaN          NaN         NaN            NaN          NaN
# 7                   NaN          NaN         NaN            NaN          NaN
# 8              Unrolled          Top     Squares          State            A
# 9                   NaN          NaN         NaN            NaN          NaN
# 10             Unrolled       Bottom     Squares          Event          NaN
# 11             Unrolled       Bottom     Squares          Event          NaN
# 12             Unrolled          Top     Squares          State            B
# 13             Unrolled       Bottom     Squares          Event          NaN
# 14             Unrolled          Top     Squares          Event          NaN
# 15                  NaN          NaN         NaN            NaN          NaN
# 16                  NaN          NaN         NaN            NaN          NaN
# 17                  NaN          NaN         NaN            NaN          NaN
# 18                  NaN          NaN         NaN            NaN          NaN
# 19                  NaN          NaN         NaN            NaN          NaN
# 20                  NaN          NaN         NaN            NaN          NaN
# 21                  NaN          NaN         NaN            NaN          NaN
# 22                  NaN          NaN         NaN            NaN          NaN
# 23                  NaN          NaN         NaN            NaN          NaN
# 24                  NaN          NaN         NaN            NaN          NaN
# 25                  NaN          NaN         NaN            NaN          NaN
# 26                  NaN          NaN         NaN            NaN          NaN
# 27                  NaN          NaN         NaN            NaN          NaN
# 28                  NaN          NaN         NaN            NaN          NaN
# 29                  NaN          NaN         NaN            NaN          NaN
# 30                  NaN          NaN         NaN            NaN          NaN
# 31                  NaN          NaN         NaN            NaN          NaN
# 32                  NaN          NaN         NaN            NaN          NaN
# 33                  NaN          NaN         NaN            NaN          NaN
# 34             Unrolled          Top     Squares          State            A
# 35             Unrolled       Bottom     Squares          Event          NaN
# 36             Unrolled       Bottom     Squares          Event          NaN
# 37             Unrolled          Top     Squares          Event          NaN
# 38             Unrolled          Top     Squares          Event          NaN
# 39             Unrolled          Top     Squares          State            B
# 40                  NaN          NaN         NaN            NaN          NaN
# 41                  NaN          NaN         NaN            NaN          NaN
# 42                  NaN          NaN         NaN            NaN          NaN
# 43                  NaN          NaN         NaN            NaN          NaN
# 44                  NaN          NaN         NaN            NaN          NaN
# 45                  NaN          NaN         NaN            NaN          NaN
# 46                  NaN          NaN         NaN            NaN          NaN
# 47                  NaN          NaN         NaN            NaN          NaN
# 48                  NaN          NaN         NaN            NaN          NaN
# 49                  NaN          NaN         NaN            NaN          NaN
# ...                 ...          ...         ...            ...          ...
# 1662           Unrolled          Top     Squares          Event          NaN
# 1663           Unrolled          Top     Squares          State            B
# 1664           Unrolled       Bottom     Squares          Event          NaN
# 1665           Unrolled       Bottom     Squares          State            A
# 1666                NaN          NaN         NaN            NaN          NaN
# 1667           Unrolled          Top     Squares          Event          NaN
# 1668                NaN          NaN         NaN            NaN          NaN
# 1669                NaN          NaN         NaN            NaN          NaN
# 1670                NaN          NaN         NaN            NaN          NaN
# 1671                NaN          NaN         NaN            NaN          NaN
# 1672                NaN          NaN         NaN            NaN          NaN
# 1673                NaN          NaN         NaN            NaN          NaN
# 1674                NaN          NaN         NaN            NaN          NaN
# 1675                NaN          NaN         NaN            NaN          NaN
# 1676                NaN          NaN         NaN            NaN          NaN
# 1677                NaN          NaN         NaN            NaN          NaN
# 1678                NaN          NaN         NaN            NaN          NaN
# 1679                NaN          NaN         NaN            NaN          NaN
# 1680                NaN          NaN         NaN            NaN          NaN
# 1681                NaN          NaN         NaN            NaN          NaN
# 1682                NaN          NaN         NaN            NaN          NaN
# 1683                NaN          NaN         NaN            NaN          NaN
# 1684                NaN          NaN         NaN            NaN          NaN
# 1685                NaN          NaN         NaN            NaN          NaN
# 1686           Unrolled       Bottom     Squares          Event          NaN
# 1687           Unrolled          Top     Squares          Event          NaN
# 1688           Unrolled       Bottom     Squares          Event          NaN
# 1689           Unrolled          Top     Squares          State            B
# 1690                NaN          NaN         NaN            NaN          NaN
# 1691           Unrolled          Top     Squares          State            A
# 1692           Unrolled       Bottom     Squares          Event          NaN
# 1693                NaN          NaN         NaN            NaN          NaN
# 1694                NaN          NaN         NaN            NaN          NaN
# 1695                NaN          NaN         NaN            NaN          NaN
# 1696                NaN          NaN         NaN            NaN          NaN
# 1697                NaN          NaN         NaN            NaN          NaN
# 1698                NaN          NaN         NaN            NaN          NaN
# 1699                NaN          NaN         NaN            NaN          NaN
# 1700                NaN          NaN         NaN            NaN          NaN
# 1701                NaN          NaN         NaN            NaN          NaN
# 1702                NaN          NaN         NaN            NaN          NaN
# 1703           Unrolled          Top     Squares          Event          NaN
# 1704           Unrolled          Top     Squares          State            B
# 1705           Unrolled       Bottom     Squares          Event          NaN
# 1706           Unrolled       Bottom     Squares          Event          NaN
# 1707                NaN          NaN         NaN            NaN          NaN
# 1708           Unrolled          Top     Squares          State            A
# 1709           Unrolled       Bottom     Squares          Event          NaN
# 1710                NaN          NaN         NaN            NaN          NaN
# 1711                NaN          NaN         NaN            NaN          NaN
#
#      root_1st imdt_2nd node_selected
# 0         NaN      NaN           NaN
# 1         NaN      NaN           NaN
# 2         NaN      NaN           NaN
# 3         NaN      NaN           NaN
# 4         NaN      NaN           NaN
# 5         NaN      NaN           NaN
# 6         NaN      NaN           NaN
# 7         NaN      NaN           NaN
# 8         NaN        B       nodeB19
# 9         NaN      NaN        nodeB9
# 10          A        A       nodeB20
# 11          B        B        nodeB2
# 12        NaN        A       nodeA20
# 13          B        A       nodeA25
# 14          A        B        nodeB7
# 15        NaN      NaN           NaN
# 16        NaN      NaN           NaN
# 17        NaN      NaN           NaN
# 18        NaN      NaN           NaN
# 19        NaN      NaN           NaN
# 20        NaN      NaN           NaN
# 21        NaN      NaN           NaN
# 22        NaN      NaN           NaN
# 23        NaN      NaN           NaN
# 24        NaN      NaN           NaN
# 25        NaN      NaN           NaN
# 26        NaN      NaN           NaN
# 27        NaN      NaN           NaN
# 28        NaN      NaN           NaN
# 29        NaN      NaN           NaN
# 30        NaN      NaN           NaN
# 31        NaN      NaN           NaN
# 32        NaN      NaN           NaN
# 33        NaN      NaN        nodeB9
# 34        NaN        B        nodeB7
# 35          A        A        nodeA7
# 36          B        A        nodeB4
# 37          B        B       nodeA37
# 38          A        B        nodeB7
# 39        NaN        A       nodeA20
# 40        NaN      NaN           NaN
# 41        NaN      NaN           NaN
# 42        NaN      NaN           NaN
# 43        NaN      NaN           NaN
# 44        NaN      NaN           NaN
# 45        NaN      NaN           NaN
# 46        NaN      NaN           NaN
# 47        NaN      NaN           NaN
# 48        NaN      NaN           NaN
# 49        NaN      NaN           NaN
# ...       ...      ...           ...
# 1662        A        A        nodeA7
# 1663      NaN        A       nodeA20
# 1664        B        B        nodeB2
# 1665      NaN        B        nodeB7
# 1666      NaN      NaN        nodeB9
# 1667        A        B        nodeA7
# 1668      NaN      NaN           NaN
# 1669      NaN      NaN           NaN
# 1670      NaN      NaN           NaN
# 1671      NaN      NaN           NaN
# 1672      NaN      NaN           NaN
# 1673      NaN      NaN           NaN
# 1674      NaN      NaN           NaN
# 1675      NaN      NaN           NaN
# 1676      NaN      NaN           NaN
# 1677      NaN      NaN           NaN
# 1678      NaN      NaN           NaN
# 1679      NaN      NaN           NaN
# 1680      NaN      NaN           NaN
# 1681      NaN      NaN           NaN
# 1682      NaN      NaN           NaN
# 1683      NaN      NaN           NaN
# 1684      NaN      NaN           NaN
# 1685      NaN      NaN           NaN
# 1686        B        B        nodeB2
# 1687        A        B        nodeB7
# 1688        A        A        nodeA7
# 1689      NaN        A       nodeA20
# 1690      NaN      NaN        nodeB9
# 1691      NaN        B        nodeB7
# 1692        B        A       nodeA25
# 1693      NaN      NaN           NaN
# 1694      NaN      NaN           NaN
# 1695      NaN      NaN           NaN
# 1696      NaN      NaN           NaN
# 1697      NaN      NaN           NaN
# 1698      NaN      NaN           NaN
# 1699      NaN      NaN           NaN
# 1700      NaN      NaN           NaN
# 1701      NaN      NaN           NaN
# 1702      NaN      NaN           NaN
# 1703        B        B        nodeB2
# 1704      NaN        A        nodeB4
# 1705        B        A        nodeB4
# 1706        A        B        nodeA7
# 1707      NaN      NaN        nodeB9
# 1708      NaN        B        nodeA7
# 1709        A        A        nodeA7
# 1710      NaN      NaN           NaN
# 1711      NaN      NaN           NaN
#
# [1712 rows x 22 columns]

# %%
time = []
for item in data_clean[data_clean['stimulus']=='comment']['time_elapsed']:
    time.append(item)
time = np.array(time)
time.mean()/1000/60
# Out:
# 10.202165277777777

# %%
for idx,item in enumerate(data_clean['stimulus']):
    if item == 'comment':
        print(data_clean['responses'][idx])
# Out:
# {"Q0":""}
# {"Q0":"I thought this experiment was very interesting.  Also, the instructions were clear and I had no technical problems."}
# {"Q0":"nothing good task"}
# {"Q0":""}
# {"Q0":"VErY inTErEsTIng.goOD"}
# {"Q0":""}
# {"Q0":""}
# {"Q0":""}
# {"Q0":"VERY NICE                                  "}
# {"Q0":"everything worked well, no issues"}
# {"Q0":""}
# {"Q0":"no comments"}
# {"Q0":"Thank you. I hope my input is valuable. Have a nice day"}
# {"Q0":"nothing good survey"}
# {"Q0":"good"}
# {"Q0":"likely"}
# {"Q0":""}
# {"Q0":""}
# {"Q0":""}
# {"Q0":""}
# {"Q0":""}
# {"Q0":""}
# {"Q0":"It was awesome."}
# {"Q0":""}
# {"Q0":""}
# {"Q0":"No comments"}
# {"Q0":""}
# {"Q0":""}
# {"Q0":""}
# {"Q0":""}
# {"Q0":"interesting"}
# {"Q0":""}
# {"Q0":"Everything was easy to understand and I thought the study paid well :)"}
# {"Q0":"It was kind of confusing as to if I was supposed to be scientific about it or purely visual."}
# {"Q0":""}
# {"Q0":"There should be an example of which detector to click as I was not sure because of the wording."}
# {"Q0":"GOOD"}
# {"Q0":""}
# {"Q0":"There were 2 activation inputs, which one to choose?"}
# {"Q0":" "}
# {"Q0":"easy"}
# {"Q0":""}
# {"Q0":"I'm not sure if I did the task correctly. I clicked on the detector that absorbed a radioactive particle, and that was on the sequence of detectors that reached G last."}
# {"Q0":"very inresting task"}
# {"Q0":""}
# {"Q0":"None"}
# {"Q0":""}
# {"Q0":""}

# %% [markdown]
# #### Demographical data only

# %%
data_demog = data_clean[["subject_id","gender","age","language","country","turkcode"]]
data_demog = data_demog.drop_duplicates()
data_demog
# Out:
#       subject_id  gender  age            language                   country  \
# 0              1  female   35             Turkish  United States of America
# 17             2  female   31             English  United States of America
# 42             3    male   47             english  United States of America
# 59             4    male   46             english  United States of America
# 76             5    male   49             ENGLISH  United States of America
# 93             6  female   52             English  United States of America
# 126            7    male   32             English  United States of America
# 159            8    male   29             English  United States of America
# 184            9    male   51             ENGLISH  United States of America
# 257           10  female   26             english  United States of America
# 282           11    male   65             English  United States of America
# 299           12  female   48             english  United States of America
# 340           13    male   29             english  United States of America
# 397           14    male   58             english  United States of America
# 438           15    male   38             english                   Armenia
# 479           16    male   61             english  United States of America
# 648           17    male   32             English  United States of America
# 665           18    male   33             English  United States of America
# 690           19    male   24             English  United States of America
# 707           20  female   32             English  United States of America
# 748           21    male   26             English  United States of America
# 773           22    male   38             english  United States of America
# 798           23    male   29             English  United States of America
# 863           24  female   29             English  United States of America
# 912           25   other   34             English  United States of America
# 945           26    male   52             English  United States of America
# 970           27  female   58             English  United States of America
# 987           28    male   41             English  United States of America
# 1004          29  female   50             English  United States of America
# 1021          30  female   45             english  United States of America
# 1078          31  female   35             English  United States of America
# 1103          32    male   31             English  United States of America
# 1128          33  female   23             English  United States of America
# 1145          34    male   34             English  United States of America
# 1186          35  female   61             english  United States of America
# 1219          36    male   35  English, Cantonese  United States of America
# 1236          37    male   41             ENGLISH                   Armenia
# 1277          38  female   36             English  United States of America
# 1342          39    male   44             English  United States of America
# 1375          40    male   50             English  United States of America
# 1408          41  female   46             english  United States of America
# 1473          42    male   44             English  United States of America
# 1498          43    male   19             English  United States of America
# 1523          44  female   58             English  United States of America
# 1580          45    male   68             English  United States of America
# 1653          46  female   36             english  United States of America
# 1670          47  female   44             English  United States of America
# 1695          48    male   26   English, Japanese  United States of America
#
#                turkcode
# 0     R568393397970gxrw
# 17    R569505437620gxrw
# 42    R568774137640gxrw
# 59    R562699637900gxrw
# 76    R562050947820gxrw
# 93    R562955957430gxrw
# 126   R561811987830gxrw
# 159   R569996927840gxrw
# 184   R565668727290gxrw
# 257   R561847387520gxrw
# 282   R562382347220gxrw
# 299   R565972457960gxrw
# 340   R564083597300gxrw
# 397   R565086757790gxrw
# 438   R561903857890gxrw
# 479   R564292257260gxrw
# 648   R563277577520gxrw
# 665   R566212997560gxrw
# 690   R561039097580gxrw
# 707   R567727787310gxrw
# 748   R567221167850gxrw
# 773   R563744997110gxrw
# 798   R567110527600gxrw
# 863   R566457817370gxrw
# 912   R569143367750gxrw
# 945   R562971867360gxrw
# 970   R562713167520gxrw
# 987   R562681507880gxrw
# 1004  R561216847680gxrw
# 1021  R568555707250gxrw
# 1078  R567929507110gxrw
# 1103  R565974167740gxrw
# 1128  R564062127140gxrw
# 1145  R566444937730gxrw
# 1186  R563318637580gxrw
# 1219  R565762037570gxrw
# 1236  R568815577170gxrw
# 1277  R565796087480gxrw
# 1342  R562203047100gxrw
# 1375  R569663207860gxrw
# 1408  R561246577810gxrw
# 1473  R562021027660gxrw
# 1498  R567396637450gxrw
# 1523  R567716797490gxrw
# 1580  R568611477130gxrw
# 1653  R564652417300gxrw
# 1670  R562497257520gxrw
# 1695  R565976917610gxrw

# %%
data_demog['language'].value_counts()
# Out:
# English               29
# english               13
# ENGLISH                3
# English, Japanese      1
# Turkish                1
# English, Cantonese     1
# Name: language, dtype: int64

# %% [markdown]
# #### Target stimuli only (instructions deleted)

# %%
data = data_clean[["subject_id","rt","stimulus","trial_type","sampling","nb_of_run","stim_type","rolled_OR_unrolled",
                   "A_branch_loc","A_detectors","state_OR_event","state_branch","root_1st","imdt_2nd","node_selected"]]
data = data[data["stimulus"] != "instruction"].drop(['trial_type'],axis=1)
data.reset_index(drop=True,inplace=True)

data
# Out:
#      subject_id         rt  stimulus sampling  nb_of_run stim_type  \
# 0             1  64342.000    UAS_LT     Left        2.0  AND_Gate
# 1             1  40194.000  chainS_L     Left        1.0    ChainS
# 2             1  27948.000   UAAS_LB     Left        1.0  AND_Gate
# 3             1  18863.000   UBBS_LB     Left        2.0  AND_Gate
# 4             1  15954.000    UBS_LT     Left        1.0  AND_Gate
# 5             1  17294.000   UBAS_LB     Left        1.0  AND_Gate
# 6             1  21221.000   UABS_LT     Left        1.0  AND_Gate
# 7             1   3315.000   comment     Left        NaN       NaN
# 8             2  16502.940  chainS_L     Left        1.0    ChainS
# 9             2  14628.545    UAS_LT     Left        1.0  AND_Gate
# 10            2  19263.155   UAAS_LB     Left        1.0  AND_Gate
# 11            2  13752.445   UBAS_LB     Left        1.0  AND_Gate
# 12            2  17673.240   UBBS_LT     Left        2.0  AND_Gate
# 13            2  13511.215   UABS_LT     Left        1.0  AND_Gate
# 14            2  10898.105    UBS_LT     Left        1.0  AND_Gate
# 15            2  38041.570   comment     Left        NaN       NaN
# 16            3  15782.000    UBS_LB     Left        1.0  AND_Gate
# 17            3  15288.000   UABS_LB     Left        1.0  AND_Gate
# 18            3  12808.000   UBAS_LB     Left        1.0  AND_Gate
# 19            3   9240.000    UAS_LB     Left        1.0  AND_Gate
# 20            3  14194.000   UAAS_LB     Left        1.0  AND_Gate
# 21            3  13313.000  chainS_L     Left        1.0    ChainS
# 22            3   9307.000   UBBS_LB     Left        1.0  AND_Gate
# 23            3  12944.000   comment     Left        NaN       NaN
# 24            4  14154.130   UBAS_RT    Right        1.0  AND_Gate
# 25            4  19599.285   UABS_RT    Right        1.0  AND_Gate
# 26            4  10543.145    UAS_RB    Right        1.0  AND_Gate
# 27            4  11588.285    UBS_RB    Right        1.0  AND_Gate
# 28            4  10768.230  chainS_R    Right        1.0    ChainS
# 29            4  13201.765   UAAS_RT    Right        1.0  AND_Gate
# 30            4  10593.390   UBBS_RB    Right        1.0  AND_Gate
# 31            4   3554.685   comment    Right        NaN       NaN
# 32            5  44601.000   UABS_RB    Right        3.0  AND_Gate
# 33            5  17722.000   UBBS_RB    Right        1.0  AND_Gate
# 34            5  24225.000   UAAS_RT    Right        1.0  AND_Gate
# 35            5  22467.000   UBAS_RB    Right        1.0  AND_Gate
# 36            5  20252.000  chainS_R    Right        1.0    ChainS
# 37            5  19352.000    UAS_RT    Right        1.0  AND_Gate
# 38            5  17796.000    UBS_RT    Right        1.0  AND_Gate
# 39            5  31715.000   comment    Right        NaN       NaN
# 40            6  27436.830    UAS_RB    Right        2.0  AND_Gate
# 41            6  10444.510   UAAS_RT    Right        1.0  AND_Gate
# 42            6  22220.060   UBBS_RT    Right        1.0  AND_Gate
# 43            6  10712.265    UBS_RT    Right        1.0  AND_Gate
# 44            6   8412.500  chainS_R    Right        1.0    ChainS
# 45            6  17646.135   UBAS_RT    Right        1.0  AND_Gate
# 46            6  23307.765   UABS_RB    Right        1.0  AND_Gate
# 47            6   6162.630   comment    Right        NaN       NaN
# 48            7  53783.000   UBBS_LT     Left        3.0  AND_Gate
# 49            7  18888.000    UAS_LB     Left        1.0  AND_Gate
# ..          ...        ...       ...      ...        ...       ...
# 334          42  94870.435   UABS_RB    Right        1.0  AND_Gate
# 335          42   5096.685   comment    Right        NaN       NaN
# 336          43  31827.855    UAS_LB     Left        1.0  AND_Gate
# 337          43  19189.980   UBBS_LT     Left        1.0  AND_Gate
# 338          43  12313.100  chainS_L     Left        1.0    ChainS
# 339          43  10748.410    UBS_LB     Left        1.0  AND_Gate
# 340          43  14681.455   UAAS_LB     Left        1.0  AND_Gate
# 341          43  10193.445   UBAS_LB     Left        1.0  AND_Gate
# 342          43  53003.740   UABS_LT     Left        1.0  AND_Gate
# 343          43  78621.760   comment     Left        NaN       NaN
# 344          44  26925.605   UBBS_LT     Left        1.0  AND_Gate
# 345          44  14435.925    UBS_LT     Left        1.0  AND_Gate
# 346          44  16398.345   UAAS_LB     Left        1.0  AND_Gate
# 347          44  11764.390    UAS_LB     Left        6.0  AND_Gate
# 348          44  16705.645   UABS_LB     Left        1.0  AND_Gate
# 349          44  13245.580  chainS_L     Left        1.0    ChainS
# 350          44  14943.740   UBAS_LT     Left        1.0  AND_Gate
# 351          44  85857.080   comment     Left        NaN       NaN
# 352          45  25026.000    UBS_RB    Right        1.0  AND_Gate
# 353          45  17681.000   UAAS_RB    Right        1.0  AND_Gate
# 354          45  37663.000   UABS_RT    Right        1.0  AND_Gate
# 355          45  12074.000   UBBS_RB    Right        1.0  AND_Gate
# 356          45  14354.000    UAS_RB    Right        1.0  AND_Gate
# 357          45   9846.000  chainS_R    Right        1.0    ChainS
# 358          45  21938.000   UBAS_RT    Right        1.0  AND_Gate
# 359          45   3324.000   comment    Right        NaN       NaN
# 360          46  13231.750   UBAS_RB    Right        2.0  AND_Gate
# 361          46  12032.785   UAAS_RT    Right        1.0  AND_Gate
# 362          46  18891.395    UBS_RT    Right        1.0  AND_Gate
# 363          46  10511.765   UBBS_RB    Right        1.0  AND_Gate
# 364          46  10191.580    UAS_RB    Right        1.0  AND_Gate
# 365          46   8928.120  chainS_R    Right        1.0    ChainS
# 366          46  13262.640   UABS_RT    Right        1.0  AND_Gate
# 367          46  10664.575   comment    Right        NaN       NaN
# 368          47  15142.445   UBBS_LB     Left        1.0  AND_Gate
# 369          47  14934.545   UABS_LT     Left        1.0  AND_Gate
# 370          47  12773.225   UAAS_LB     Left        1.0  AND_Gate
# 371          47  10814.265    UBS_LT     Left        1.0  AND_Gate
# 372          47  20462.195  chainS_L     Left        1.0    ChainS
# 373          47  12270.455    UAS_LT     Left        1.0  AND_Gate
# 374          47  11444.640   UBAS_LB     Left        2.0  AND_Gate
# 375          47   8678.365   comment     Left        NaN       NaN
# 376          48  10399.260   UBBS_RT    Right        2.0  AND_Gate
# 377          48  12409.110    UBS_RT    Right        1.0  AND_Gate
# 378          48  10540.760   UBAS_RB    Right        1.0  AND_Gate
# 379          48  14759.020   UABS_RB    Right        1.0  AND_Gate
# 380          48   8632.665  chainS_R    Right        1.0    ChainS
# 381          48   9954.570    UAS_RT    Right        1.0  AND_Gate
# 382          48  11990.420   UAAS_RB    Right        1.0  AND_Gate
# 383          48   4451.510   comment    Right        NaN       NaN
#
#     rolled_OR_unrolled A_branch_loc A_detectors state_OR_event state_branch  \
# 0             Unrolled          Top     Squares          State            A
# 1                  NaN          NaN         NaN            NaN          NaN
# 2             Unrolled       Bottom     Squares          Event          NaN
# 3             Unrolled       Bottom     Squares          Event          NaN
# 4             Unrolled          Top     Squares          State            B
# 5             Unrolled       Bottom     Squares          Event          NaN
# 6             Unrolled          Top     Squares          Event          NaN
# 7                  NaN          NaN         NaN            NaN          NaN
# 8                  NaN          NaN         NaN            NaN          NaN
# 9             Unrolled          Top     Squares          State            A
# 10            Unrolled       Bottom     Squares          Event          NaN
# 11            Unrolled       Bottom     Squares          Event          NaN
# 12            Unrolled          Top     Squares          Event          NaN
# 13            Unrolled          Top     Squares          Event          NaN
# 14            Unrolled          Top     Squares          State            B
# 15                 NaN          NaN         NaN            NaN          NaN
# 16            Unrolled       Bottom     Squares          State            B
# 17            Unrolled       Bottom     Squares          Event          NaN
# 18            Unrolled       Bottom     Squares          Event          NaN
# 19            Unrolled       Bottom     Squares          State            A
# 20            Unrolled       Bottom     Squares          Event          NaN
# 21                 NaN          NaN         NaN            NaN          NaN
# 22            Unrolled       Bottom     Squares          Event          NaN
# 23                 NaN          NaN         NaN            NaN          NaN
# 24            Unrolled          Top     Squares          Event          NaN
# 25            Unrolled          Top     Squares          Event          NaN
# 26            Unrolled       Bottom     Squares          State            A
# 27            Unrolled       Bottom     Squares          State            B
# 28                 NaN          NaN         NaN            NaN          NaN
# 29            Unrolled          Top     Squares          Event          NaN
# 30            Unrolled       Bottom     Squares          Event          NaN
# 31                 NaN          NaN         NaN            NaN          NaN
# 32            Unrolled       Bottom     Squares          Event          NaN
# 33            Unrolled       Bottom     Squares          Event          NaN
# 34            Unrolled          Top     Squares          Event          NaN
# 35            Unrolled       Bottom     Squares          Event          NaN
# 36                 NaN          NaN         NaN            NaN          NaN
# 37            Unrolled          Top     Squares          State            A
# 38            Unrolled          Top     Squares          State            B
# 39                 NaN          NaN         NaN            NaN          NaN
# 40            Unrolled       Bottom     Squares          State            A
# 41            Unrolled          Top     Squares          Event          NaN
# 42            Unrolled          Top     Squares          Event          NaN
# 43            Unrolled          Top     Squares          State            B
# 44                 NaN          NaN         NaN            NaN          NaN
# 45            Unrolled          Top     Squares          Event          NaN
# 46            Unrolled       Bottom     Squares          Event          NaN
# 47                 NaN          NaN         NaN            NaN          NaN
# 48            Unrolled          Top     Squares          Event          NaN
# 49            Unrolled       Bottom     Squares          State            A
# ..                 ...          ...         ...            ...          ...
# 334           Unrolled       Bottom     Squares          Event          NaN
# 335                NaN          NaN         NaN            NaN          NaN
# 336           Unrolled       Bottom     Squares          State            A
# 337           Unrolled          Top     Squares          Event          NaN
# 338                NaN          NaN         NaN            NaN          NaN
# 339           Unrolled       Bottom     Squares          State            B
# 340           Unrolled       Bottom     Squares          Event          NaN
# 341           Unrolled       Bottom     Squares          Event          NaN
# 342           Unrolled          Top     Squares          Event          NaN
# 343                NaN          NaN         NaN            NaN          NaN
# 344           Unrolled          Top     Squares          Event          NaN
# 345           Unrolled          Top     Squares          State            B
# 346           Unrolled       Bottom     Squares          Event          NaN
# 347           Unrolled       Bottom     Squares          State            A
# 348           Unrolled       Bottom     Squares          Event          NaN
# 349                NaN          NaN         NaN            NaN          NaN
# 350           Unrolled          Top     Squares          Event          NaN
# 351                NaN          NaN         NaN            NaN          NaN
# 352           Unrolled       Bottom     Squares          State            B
# 353           Unrolled       Bottom     Squares          Event          NaN
# 354           Unrolled          Top     Squares          Event          NaN
# 355           Unrolled       Bottom     Squares          Event          NaN
# 356           Unrolled       Bottom     Squares          State            A
# 357                NaN          NaN         NaN            NaN          NaN
# 358           Unrolled          Top     Squares          Event          NaN
# 359                NaN          NaN         NaN            NaN          NaN
# 360           Unrolled       Bottom     Squares          Event          NaN
# 361           Unrolled          Top     Squares          Event          NaN
# 362           Unrolled          Top     Squares          State            B
# 363           Unrolled       Bottom     Squares          Event          NaN
# 364           Unrolled       Bottom     Squares          State            A
# 365                NaN          NaN         NaN            NaN          NaN
# 366           Unrolled          Top     Squares          Event          NaN
# 367                NaN          NaN         NaN            NaN          NaN
# 368           Unrolled       Bottom     Squares          Event          NaN
# 369           Unrolled          Top     Squares          Event          NaN
# 370           Unrolled       Bottom     Squares          Event          NaN
# 371           Unrolled          Top     Squares          State            B
# 372                NaN          NaN         NaN            NaN          NaN
# 373           Unrolled          Top     Squares          State            A
# 374           Unrolled       Bottom     Squares          Event          NaN
# 375                NaN          NaN         NaN            NaN          NaN
# 376           Unrolled          Top     Squares          Event          NaN
# 377           Unrolled          Top     Squares          State            B
# 378           Unrolled       Bottom     Squares          Event          NaN
# 379           Unrolled       Bottom     Squares          Event          NaN
# 380                NaN          NaN         NaN            NaN          NaN
# 381           Unrolled          Top     Squares          State            A
# 382           Unrolled       Bottom     Squares          Event          NaN
# 383                NaN          NaN         NaN            NaN          NaN
#
#     root_1st imdt_2nd node_selected
# 0        NaN        B       nodeB19
# 1        NaN      NaN        nodeB9
# 2          A        A       nodeB20
# 3          B        B        nodeB2
# 4        NaN        A       nodeA20
# 5          B        A       nodeA25
# 6          A        B        nodeB7
# 7        NaN      NaN           NaN
# 8        NaN      NaN        nodeB9
# 9        NaN        B        nodeB7
# 10         A        A        nodeA7
# 11         B        A        nodeB4
# 12         B        B       nodeA37
# 13         A        B        nodeB7
# 14       NaN        A       nodeA20
# 15       NaN      NaN           NaN
# 16       NaN        A       nodeA11
# 17         A        B        nodeA4
# 18         B        A        nodeA4
# 19       NaN        B        nodeB2
# 20         A        A        nodeB3
# 21       NaN      NaN        nodeB4
# 22         B        B        nodeA2
# 23       NaN      NaN           NaN
# 24         B        A        nodeB4
# 25         A        B        nodeB7
# 26       NaN        B        nodeB7
# 27       NaN        A       nodeA20
# 28       NaN      NaN        nodeB9
# 29         A        A        nodeA7
# 30         B        B        nodeB2
# 31       NaN      NaN           NaN
# 32         A        B       nodeB20
# 33         B        B       nodeB20
# 34         A        A       nodeB20
# 35         B        A       nodeA41
# 36       NaN      NaN       nodeB20
# 37       NaN        B       nodeB20
# 38       NaN        A       nodeB20
# 39       NaN      NaN           NaN
# 40       NaN        B        nodeB6
# 41         A        A        nodeA6
# 42         B        B        nodeB1
# 43       NaN        A       nodeA19
# 44       NaN      NaN        nodeB8
# 45         B        A        nodeB3
# 46         A        B        nodeB6
# 47       NaN      NaN           NaN
# 48         B        B       nodeA27
# 49       NaN        B        nodeA1
# ..       ...      ...           ...
# 334        A        B        nodeA7
# 335      NaN      NaN           NaN
# 336      NaN        B        nodeB7
# 337        B        B        nodeB2
# 338      NaN      NaN        nodeB9
# 339      NaN        A       nodeA20
# 340        A        A        nodeA7
# 341        B        A       nodeA25
# 342        A        B        nodeB7
# 343      NaN      NaN           NaN
# 344        B        B       nodeB20
# 345      NaN        A       nodeB20
# 346        A        A       nodeB20
# 347      NaN        B       nodeB20
# 348        A        B       nodeB20
# 349      NaN      NaN       nodeB20
# 350        B        A       nodeB20
# 351      NaN      NaN           NaN
# 352      NaN        A        nodeB9
# 353        A        A       nodeA30
# 354        A        B       nodeA21
# 355        B        B        nodeB8
# 356      NaN        B       nodeA35
# 357      NaN      NaN       nodeB10
# 358        B        A       nodeA28
# 359      NaN      NaN           NaN
# 360        B        A        nodeB4
# 361        A        A        nodeA7
# 362      NaN        A       nodeA20
# 363        B        B        nodeB2
# 364      NaN        B        nodeB7
# 365      NaN      NaN        nodeB9
# 366        A        B        nodeA7
# 367      NaN      NaN           NaN
# 368        B        B        nodeB2
# 369        A        B        nodeB7
# 370        A        A        nodeA7
# 371      NaN        A       nodeA20
# 372      NaN      NaN        nodeB9
# 373      NaN        B        nodeB7
# 374        B        A       nodeA25
# 375      NaN      NaN           NaN
# 376        B        B        nodeB2
# 377      NaN        A        nodeB4
# 378        B        A        nodeB4
# 379        A        B        nodeA7
# 380      NaN      NaN        nodeB9
# 381      NaN        B        nodeA7
# 382        A        A        nodeA7
# 383      NaN      NaN           NaN
#
# [384 rows x 14 columns]

# %% [markdown]
# #### Chain only

# %%
data_chain = data[(data["stim_type"]=="ChainS")|(data["stim_type"]=="ChainC")].drop(["rolled_OR_unrolled","A_detectors",
                                                    "state_OR_event","state_branch","root_1st","imdt_2nd",],axis=1)
data_chain.reset_index(drop=True,inplace=True)
data_chain["stimulus"] = data_chain["stimulus"].astype("category")
data_chain["sampling"] = data_chain["sampling"].astype("category")
data_chain["stim_type"] = data_chain["stim_type"].astype("category")
data_chain.head()
# Out:
#    subject_id        rt  stimulus sampling  nb_of_run stim_type A_branch_loc  \
# 0           1  40194.00  chainS_L     Left        1.0    ChainS          NaN
# 1           2  16502.94  chainS_L     Left        1.0    ChainS          NaN
# 2           3  13313.00  chainS_L     Left        1.0    ChainS          NaN
# 3           4  10768.23  chainS_R    Right        1.0    ChainS          NaN
# 4           5  20252.00  chainS_R    Right        1.0    ChainS          NaN
#
#   node_selected
# 0        nodeB9
# 1        nodeB9
# 2        nodeB4
# 3        nodeB9
# 4       nodeB20

# %% [markdown]
# #### AND-Gate only

# %%
data_AND_Gate = data[data["stim_type"]=="AND_Gate"].drop(["stim_type"],axis=1)
data_AND_Gate.reset_index(drop=True,inplace=True)
data_AND_Gate["stimulus"] = data_AND_Gate["stimulus"].astype("category")
data_AND_Gate["state_OR_event"] = data_AND_Gate["state_OR_event"].astype("category")
data_AND_Gate["rolled_OR_unrolled"] = data_AND_Gate["rolled_OR_unrolled"].astype("category")
data_AND_Gate["A_branch_loc"] = data_AND_Gate["A_branch_loc"].astype("category")
data_AND_Gate["A_detectors"] = data_AND_Gate["A_detectors"].astype("category")
data_AND_Gate["root_1st"] = data_AND_Gate["root_1st"].astype("category")
data_AND_Gate["imdt_2nd"] = data_AND_Gate["imdt_2nd"].astype("category")
data_AND_Gate
# Out:
#      subject_id          rt stimulus sampling  nb_of_run rolled_OR_unrolled  \
# 0             1   64342.000   UAS_LT     Left        2.0           Unrolled
# 1             1   27948.000  UAAS_LB     Left        1.0           Unrolled
# 2             1   18863.000  UBBS_LB     Left        2.0           Unrolled
# 3             1   15954.000   UBS_LT     Left        1.0           Unrolled
# 4             1   17294.000  UBAS_LB     Left        1.0           Unrolled
# 5             1   21221.000  UABS_LT     Left        1.0           Unrolled
# 6             2   14628.545   UAS_LT     Left        1.0           Unrolled
# 7             2   19263.155  UAAS_LB     Left        1.0           Unrolled
# 8             2   13752.445  UBAS_LB     Left        1.0           Unrolled
# 9             2   17673.240  UBBS_LT     Left        2.0           Unrolled
# 10            2   13511.215  UABS_LT     Left        1.0           Unrolled
# 11            2   10898.105   UBS_LT     Left        1.0           Unrolled
# 12            3   15782.000   UBS_LB     Left        1.0           Unrolled
# 13            3   15288.000  UABS_LB     Left        1.0           Unrolled
# 14            3   12808.000  UBAS_LB     Left        1.0           Unrolled
# 15            3    9240.000   UAS_LB     Left        1.0           Unrolled
# 16            3   14194.000  UAAS_LB     Left        1.0           Unrolled
# 17            3    9307.000  UBBS_LB     Left        1.0           Unrolled
# 18            4   14154.130  UBAS_RT    Right        1.0           Unrolled
# 19            4   19599.285  UABS_RT    Right        1.0           Unrolled
# 20            4   10543.145   UAS_RB    Right        1.0           Unrolled
# 21            4   11588.285   UBS_RB    Right        1.0           Unrolled
# 22            4   13201.765  UAAS_RT    Right        1.0           Unrolled
# 23            4   10593.390  UBBS_RB    Right        1.0           Unrolled
# 24            5   44601.000  UABS_RB    Right        3.0           Unrolled
# 25            5   17722.000  UBBS_RB    Right        1.0           Unrolled
# 26            5   24225.000  UAAS_RT    Right        1.0           Unrolled
# 27            5   22467.000  UBAS_RB    Right        1.0           Unrolled
# 28            5   19352.000   UAS_RT    Right        1.0           Unrolled
# 29            5   17796.000   UBS_RT    Right        1.0           Unrolled
# 30            6   27436.830   UAS_RB    Right        2.0           Unrolled
# 31            6   10444.510  UAAS_RT    Right        1.0           Unrolled
# 32            6   22220.060  UBBS_RT    Right        1.0           Unrolled
# 33            6   10712.265   UBS_RT    Right        1.0           Unrolled
# 34            6   17646.135  UBAS_RT    Right        1.0           Unrolled
# 35            6   23307.765  UABS_RB    Right        1.0           Unrolled
# 36            7   53783.000  UBBS_LT     Left        3.0           Unrolled
# 37            7   18888.000   UAS_LB     Left        1.0           Unrolled
# 38            7   40351.000  UABS_LT     Left        1.0           Unrolled
# 39            7   15364.000  UAAS_LB     Left        1.0           Unrolled
# 40            7   23030.000  UBAS_LT     Left        1.0           Unrolled
# 41            7   20483.000   UBS_LB     Left        1.0           Unrolled
# 42            8   23549.000   UAS_LT     Left        1.0           Unrolled
# 43            8   13001.000  UAAS_LB     Left        1.0           Unrolled
# 44            8   15377.000  UABS_LB     Left        1.0           Unrolled
# 45            8   10854.000   UBS_LT     Left        1.0           Unrolled
# 46            8   12361.000  UBBS_LB     Left        1.0           Unrolled
# 47            8   14215.000  UBAS_LB     Left        1.0           Unrolled
# 48            9   54735.000   UBS_RT    Right        1.0           Unrolled
# 49            9   12122.000  UAAS_RT    Right        1.0           Unrolled
# ..          ...         ...      ...      ...        ...                ...
# 238          40   10372.115   UBS_LB     Left        1.0           Unrolled
# 239          40   17124.040  UBAS_LT     Left        1.0           Unrolled
# 240          41   41394.345   UBS_LB     Left        1.0           Unrolled
# 241          41   14685.680  UBAS_LT     Left        1.0           Unrolled
# 242          41   14731.485  UBBS_LB     Left        1.0           Unrolled
# 243          41   18989.805   UAS_LB     Left        1.0           Unrolled
# 244          41   23282.550  UAAS_LT     Left        1.0           Unrolled
# 245          41  115823.080  UABS_LT     Left        1.0           Unrolled
# 246          42   35057.440  UAAS_RT    Right        1.0           Unrolled
# 247          42   18298.040   UBS_RT    Right        1.0           Unrolled
# 248          42   13908.615   UAS_RB    Right        1.0           Unrolled
# 249          42   18156.580  UBBS_RB    Right        1.0           Unrolled
# 250          42   14874.725  UBAS_RB    Right        1.0           Unrolled
# 251          42   94870.435  UABS_RB    Right        1.0           Unrolled
# 252          43   31827.855   UAS_LB     Left        1.0           Unrolled
# 253          43   19189.980  UBBS_LT     Left        1.0           Unrolled
# 254          43   10748.410   UBS_LB     Left        1.0           Unrolled
# 255          43   14681.455  UAAS_LB     Left        1.0           Unrolled
# 256          43   10193.445  UBAS_LB     Left        1.0           Unrolled
# 257          43   53003.740  UABS_LT     Left        1.0           Unrolled
# 258          44   26925.605  UBBS_LT     Left        1.0           Unrolled
# 259          44   14435.925   UBS_LT     Left        1.0           Unrolled
# 260          44   16398.345  UAAS_LB     Left        1.0           Unrolled
# 261          44   11764.390   UAS_LB     Left        6.0           Unrolled
# 262          44   16705.645  UABS_LB     Left        1.0           Unrolled
# 263          44   14943.740  UBAS_LT     Left        1.0           Unrolled
# 264          45   25026.000   UBS_RB    Right        1.0           Unrolled
# 265          45   17681.000  UAAS_RB    Right        1.0           Unrolled
# 266          45   37663.000  UABS_RT    Right        1.0           Unrolled
# 267          45   12074.000  UBBS_RB    Right        1.0           Unrolled
# 268          45   14354.000   UAS_RB    Right        1.0           Unrolled
# 269          45   21938.000  UBAS_RT    Right        1.0           Unrolled
# 270          46   13231.750  UBAS_RB    Right        2.0           Unrolled
# 271          46   12032.785  UAAS_RT    Right        1.0           Unrolled
# 272          46   18891.395   UBS_RT    Right        1.0           Unrolled
# 273          46   10511.765  UBBS_RB    Right        1.0           Unrolled
# 274          46   10191.580   UAS_RB    Right        1.0           Unrolled
# 275          46   13262.640  UABS_RT    Right        1.0           Unrolled
# 276          47   15142.445  UBBS_LB     Left        1.0           Unrolled
# 277          47   14934.545  UABS_LT     Left        1.0           Unrolled
# 278          47   12773.225  UAAS_LB     Left        1.0           Unrolled
# 279          47   10814.265   UBS_LT     Left        1.0           Unrolled
# 280          47   12270.455   UAS_LT     Left        1.0           Unrolled
# 281          47   11444.640  UBAS_LB     Left        2.0           Unrolled
# 282          48   10399.260  UBBS_RT    Right        2.0           Unrolled
# 283          48   12409.110   UBS_RT    Right        1.0           Unrolled
# 284          48   10540.760  UBAS_RB    Right        1.0           Unrolled
# 285          48   14759.020  UABS_RB    Right        1.0           Unrolled
# 286          48    9954.570   UAS_RT    Right        1.0           Unrolled
# 287          48   11990.420  UAAS_RB    Right        1.0           Unrolled
#
#     A_branch_loc A_detectors state_OR_event state_branch root_1st imdt_2nd  \
# 0            Top     Squares          State            A      NaN        B
# 1         Bottom     Squares          Event          NaN        A        A
# 2         Bottom     Squares          Event          NaN        B        B
# 3            Top     Squares          State            B      NaN        A
# 4         Bottom     Squares          Event          NaN        B        A
# 5            Top     Squares          Event          NaN        A        B
# 6            Top     Squares          State            A      NaN        B
# 7         Bottom     Squares          Event          NaN        A        A
# 8         Bottom     Squares          Event          NaN        B        A
# 9            Top     Squares          Event          NaN        B        B
# 10           Top     Squares          Event          NaN        A        B
# 11           Top     Squares          State            B      NaN        A
# 12        Bottom     Squares          State            B      NaN        A
# 13        Bottom     Squares          Event          NaN        A        B
# 14        Bottom     Squares          Event          NaN        B        A
# 15        Bottom     Squares          State            A      NaN        B
# 16        Bottom     Squares          Event          NaN        A        A
# 17        Bottom     Squares          Event          NaN        B        B
# 18           Top     Squares          Event          NaN        B        A
# 19           Top     Squares          Event          NaN        A        B
# 20        Bottom     Squares          State            A      NaN        B
# 21        Bottom     Squares          State            B      NaN        A
# 22           Top     Squares          Event          NaN        A        A
# 23        Bottom     Squares          Event          NaN        B        B
# 24        Bottom     Squares          Event          NaN        A        B
# 25        Bottom     Squares          Event          NaN        B        B
# 26           Top     Squares          Event          NaN        A        A
# 27        Bottom     Squares          Event          NaN        B        A
# 28           Top     Squares          State            A      NaN        B
# 29           Top     Squares          State            B      NaN        A
# 30        Bottom     Squares          State            A      NaN        B
# 31           Top     Squares          Event          NaN        A        A
# 32           Top     Squares          Event          NaN        B        B
# 33           Top     Squares          State            B      NaN        A
# 34           Top     Squares          Event          NaN        B        A
# 35        Bottom     Squares          Event          NaN        A        B
# 36           Top     Squares          Event          NaN        B        B
# 37        Bottom     Squares          State            A      NaN        B
# 38           Top     Squares          Event          NaN        A        B
# 39        Bottom     Squares          Event          NaN        A        A
# 40           Top     Squares          Event          NaN        B        A
# 41        Bottom     Squares          State            B      NaN        A
# 42           Top     Squares          State            A      NaN        B
# 43        Bottom     Squares          Event          NaN        A        A
# 44        Bottom     Squares          Event          NaN        A        B
# 45           Top     Squares          State            B      NaN        A
# 46        Bottom     Squares          Event          NaN        B        B
# 47        Bottom     Squares          Event          NaN        B        A
# 48           Top     Squares          State            B      NaN        A
# 49           Top     Squares          Event          NaN        A        A
# ..           ...         ...            ...          ...      ...      ...
# 238       Bottom     Squares          State            B      NaN        A
# 239          Top     Squares          Event          NaN        B        A
# 240       Bottom     Squares          State            B      NaN        A
# 241          Top     Squares          Event          NaN        B        A
# 242       Bottom     Squares          Event          NaN        B        B
# 243       Bottom     Squares          State            A      NaN        B
# 244          Top     Squares          Event          NaN        A        A
# 245          Top     Squares          Event          NaN        A        B
# 246          Top     Squares          Event          NaN        A        A
# 247          Top     Squares          State            B      NaN        A
# 248       Bottom     Squares          State            A      NaN        B
# 249       Bottom     Squares          Event          NaN        B        B
# 250       Bottom     Squares          Event          NaN        B        A
# 251       Bottom     Squares          Event          NaN        A        B
# 252       Bottom     Squares          State            A      NaN        B
# 253          Top     Squares          Event          NaN        B        B
# 254       Bottom     Squares          State            B      NaN        A
# 255       Bottom     Squares          Event          NaN        A        A
# 256       Bottom     Squares          Event          NaN        B        A
# 257          Top     Squares          Event          NaN        A        B
# 258          Top     Squares          Event          NaN        B        B
# 259          Top     Squares          State            B      NaN        A
# 260       Bottom     Squares          Event          NaN        A        A
# 261       Bottom     Squares          State            A      NaN        B
# 262       Bottom     Squares          Event          NaN        A        B
# 263          Top     Squares          Event          NaN        B        A
# 264       Bottom     Squares          State            B      NaN        A
# 265       Bottom     Squares          Event          NaN        A        A
# 266          Top     Squares          Event          NaN        A        B
# 267       Bottom     Squares          Event          NaN        B        B
# 268       Bottom     Squares          State            A      NaN        B
# 269          Top     Squares          Event          NaN        B        A
# 270       Bottom     Squares          Event          NaN        B        A
# 271          Top     Squares          Event          NaN        A        A
# 272          Top     Squares          State            B      NaN        A
# 273       Bottom     Squares          Event          NaN        B        B
# 274       Bottom     Squares          State            A      NaN        B
# 275          Top     Squares          Event          NaN        A        B
# 276       Bottom     Squares          Event          NaN        B        B
# 277          Top     Squares          Event          NaN        A        B
# 278       Bottom     Squares          Event          NaN        A        A
# 279          Top     Squares          State            B      NaN        A
# 280          Top     Squares          State            A      NaN        B
# 281       Bottom     Squares          Event          NaN        B        A
# 282          Top     Squares          Event          NaN        B        B
# 283          Top     Squares          State            B      NaN        A
# 284       Bottom     Squares          Event          NaN        B        A
# 285       Bottom     Squares          Event          NaN        A        B
# 286          Top     Squares          State            A      NaN        B
# 287       Bottom     Squares          Event          NaN        A        A
#
#     node_selected
# 0         nodeB19
# 1         nodeB20
# 2          nodeB2
# 3         nodeA20
# 4         nodeA25
# 5          nodeB7
# 6          nodeB7
# 7          nodeA7
# 8          nodeB4
# 9         nodeA37
# 10         nodeB7
# 11        nodeA20
# 12        nodeA11
# 13         nodeA4
# 14         nodeA4
# 15         nodeB2
# 16         nodeB3
# 17         nodeA2
# 18         nodeB4
# 19         nodeB7
# 20         nodeB7
# 21        nodeA20
# 22         nodeA7
# 23         nodeB2
# 24        nodeB20
# 25        nodeB20
# 26        nodeB20
# 27        nodeA41
# 28        nodeB20
# 29        nodeB20
# 30         nodeB6
# 31         nodeA6
# 32         nodeB1
# 33        nodeA19
# 34         nodeB3
# 35         nodeB6
# 36        nodeA27
# 37         nodeA1
# 38         nodeB5
# 39         nodeA6
# 40         nodeA1
# 41        nodeA18
# 42         nodeB5
# 43        nodeA21
# 44         nodeB6
# 45        nodeA20
# 46         nodeB2
# 47         nodeB4
# 48        nodeB20
# 49         nodeA6
# ..            ...
# 238       nodeA41
# 239       nodeA41
# 240        nodeB6
# 241        nodeB3
# 242       nodeA37
# 243       nodeB20
# 244       nodeB20
# 245       nodeB20
# 246        nodeA7
# 247        nodeB4
# 248        nodeB7
# 249       nodeA37
# 250       nodeA25
# 251        nodeA7
# 252        nodeB7
# 253        nodeB2
# 254       nodeA20
# 255        nodeA7
# 256       nodeA25
# 257        nodeB7
# 258       nodeB20
# 259       nodeB20
# 260       nodeB20
# 261       nodeB20
# 262       nodeB20
# 263       nodeB20
# 264        nodeB9
# 265       nodeA30
# 266       nodeA21
# 267        nodeB8
# 268       nodeA35
# 269       nodeA28
# 270        nodeB4
# 271        nodeA7
# 272       nodeA20
# 273        nodeB2
# 274        nodeB7
# 275        nodeA7
# 276        nodeB2
# 277        nodeB7
# 278        nodeA7
# 279       nodeA20
# 280        nodeB7
# 281       nodeA25
# 282        nodeB2
# 283        nodeB4
# 284        nodeB4
# 285        nodeA7
# 286        nodeA7
# 287        nodeA7
#
# [288 rows x 13 columns]

# %%
data_AND_Gate['A_detectors'][(data_AND_Gate['rolled_OR_unrolled']=='Unrolled')&(data_AND_Gate['subject_id']==1)].value_counts()
# Out:
# Squares    6
# Name: A_detectors, dtype: int64

# %% [markdown]
# ## Functions

# %%
def nb(letter,lower_bound,upper_bound):
    return [letter+str(i) for i in range(lower_bound,upper_bound+1)]

def chain_node_cat(stim,node):
    stim = stim.split('_')[0]
    node = node[4:]
    if stim == 'chainS':
        categories = {'INACT':nb('B',1,7),'ROOT':['B8','B9','B10'],'INBTW':nb('B',11,18),'IMDT':['B19'],'EFFECT':['B20']}
    elif stim == 'chainC':
        categories = {'INACT':nb('A',1,24),'ROOT':['A25','A26','A27'],'INBTW':nb('A',28,40),'IMDT':['A41'],'EFFECT':['B20']}
        
    category = [cat for cat,nd in categories.items() if node in nd][0]
    
    return category

def branch_node_cat(stim,node):
    node = node[4:]
    stim = stim.split('_')[0]
    if stim == 'RAAC':
        categories = {'UNKNOWN':[],'INACT_1st':nb('A',1,4),'INACT_2nd':nb('B',1,5),'ROOT_1st':['A5','A6','A7'],
                      'ROOT_2nd':['B6','B7','B8'],'INBTW_1st':nb('A',8,19),'INBTW_2nd':nb('B',9,18),'IMDT_1st':['B19'],'IMDT_2nd':['A20'],'EFFECT':['B20']}
    elif stim == 'RAC':
        categories = {'UNKNOWN':nb('A',1,19),'INACT_1st':[],'INACT_2nd':nb('B',1,5),'ROOT_1st':[],'ROOT_2nd':['B6','B7','B8'],
                      'INBTW_1st':[],'INBTW_2nd':nb('B',9,18),'IMDT_1st':['B19'],'IMDT_2nd':['A20'],'EFFECT':['B20']}
    elif stim == 'RBAC': 
        categories = {'UNKNOWN':[],'INACT_1st':[],'INACT_2nd':nb('A',1,16),'ROOT_1st':['B1','B2','B3'],
                      'ROOT_2nd':['A17','A18','A19'],'INBTW_1st':nb('B',4,18),'INBTW_2nd':[],'IMDT_1st':['B19'],
                      'IMDT_2nd':['A20'],'EFFECT':['B20']}
    elif stim == 'RBC': 
        categories = {'UNKNOWN':[],'INACT_1st':nb('B',1,5),'INACT_2nd':nb('A',1,2),'ROOT_1st':['B6','B7','B8'],
                      'ROOT_2nd':['A3','A4','A5'],'INBTW_1st':nb('B',9,18),'INBTW_2nd':nb('A',6,19),'IMDT_1st':['B19'],
                      'IMDT_2nd':['A20'],'EFFECT':['B20']}
    elif stim == 'UAAC': 
        categories = {'UNKNOWN':[],'INACT_1st':nb('A',1,6),'INACT_2nd':nb('B',1,6),'ROOT_1st':['A6','A7','A8'],
                      'ROOT_2nd':['B6','B7','B8'],'INBTW_1st':nb('A',9,40),'INBTW_2nd':nb('B',9,18),'IMDT_1st':['B19'],
                      'IMDT_2nd':['A41'],'EFFECT':['B20']}
    elif stim == 'UAAS': 
        categories = {'UNKNOWN':[],'INACT_1st':nb('A',1,6),'INACT_2nd':nb('B',1,6),'ROOT_1st':['A6','A7','A8'],
                      'ROOT_2nd':['B6','B7','B8'],'INBTW_1st':nb('A',9,40),'INBTW_2nd':nb('B',9,18),'IMDT_1st':['B19'],
                      'IMDT_2nd':['A41'],'EFFECT':['B20']}
    elif stim == 'UABS': 
        categories = {'UNKNOWN':[],'INACT_1st':nb('A',1,5),'INACT_2nd':nb('B',1,5),'ROOT_1st':['A6','A7','A8'],
                      'ROOT_2nd':['B6','B7','B8'],'INBTW_1st':nb('A',9,40),'INBTW_2nd':nb('B',9,18),'IMDT_1st':['A41'],
                      'IMDT_2nd':['B19'],'EFFECT':['B20']}
    elif stim == 'UAS': 
        categories = {'UNKNOWN':[],'INACT_1st':nb('A',1,5),'INACT_2nd':nb('B',1,5),'ROOT_1st':['A6','A7','A8'],
                      'ROOT_2nd':['B6','B7','B8'],'INBTW_1st':nb('A',9,40),'INBTW_2nd':nb('B',9,18),'IMDT_1st':['A41'],
                      'IMDT_2nd':['B19'],'EFFECT':['B20']}
    elif stim == 'UBAC': 
        categories = {'UNKNOWN':[],'INACT_1st':nb('B',1,2),'INACT_2nd':nb('A',1,23),'ROOT_1st':['B3','B4','B5'],
                      'ROOT_2nd':['A24','A25','A26'],'INBTW_1st':nb('B',6,18),'INBTW_2nd':nb('A',27,40),'IMDT_1st':['B19'],
                      'IMDT_2nd':['A41'],'EFFECT':['B20']}
    elif stim == 'UBAS': 
        categories = {'UNKNOWN':[],'INACT_1st':nb('B',1,2),'INACT_2nd':nb('A',1,23),'ROOT_1st':['B3','B4','B5'],
                      'ROOT_2nd':['A24','A25','A26'],'INBTW_1st':nb('B',6,18),'INBTW_2nd':nb('A',27,40),'IMDT_1st':['B19'],
                      'IMDT_2nd':['A41'],'EFFECT':['B20']}
    elif stim == 'UBBS': 
        categories = {'UNKNOWN':[],'INACT_1st':[],'INACT_2nd':nb('A',1,35),'ROOT_1st':['B1','B2','B3'],
                      'ROOT_2nd':['A36','A37','A38'],'INBTW_1st':nb('B',4,18),'INBTW_2nd':nb('A',39,40),'IMDT_1st':['A41'],
                      'IMDT_2nd':['B19'],'EFFECT':['B20']}
    elif stim == 'UBC': 
        categories = {'UNKNOWN':[],'INACT_1st':nb('B',1,2),'INACT_2nd':nb('A',1,18),'ROOT_1st':['B3','B4','B5'],
                      'ROOT_2nd':['A19','A20','A21'],'INBTW_1st':nb('B',6,18),'INBTW_2nd':nb('A',22,40),'IMDT_1st':['B19'],
                      'IMDT_2nd':['A41'],'EFFECT':['B20']}
    elif stim == 'UBS': 
        categories = {'UNKNOWN':[],'INACT_1st':nb('B',1,2),'INACT_2nd':nb('A',1,18),'ROOT_1st':['B3','B4','B5'],
                      'ROOT_2nd':['A19','A20','A21'],'INBTW_1st':nb('B',6,18),'INBTW_2nd':nb('A',22,40),'IMDT_1st':['B19'],
                      'IMDT_2nd':['A41'],'EFFECT':['B20']}

    category = [cat for cat,nd in categories.items() if node in nd][0]

    return category

class AndGate(object):

    def __init__(self,rolled=False,continuity='root_1st'):
        if rolled == False:
            data = data_AND_Gate[data_AND_Gate["rolled_OR_unrolled"]=="Unrolled"]
        elif rolled == True:
            data = data_AND_Gate[data_AND_Gate["rolled_OR_unrolled"]=="Rolled"]
        if continuity == 'root_1st':
            data = data[data['root_1st']==data['imdt_2nd']]
        elif continuity == 'root_2nd':
            data = data[(data['root_1st']!=data['imdt_2nd'])|(data['state_OR_event']=='State')]
            
        self.df = data
        
        self.node_select = self.df["node_selected"].value_counts(normalize=True)*100
        values = {}
        nodes = ["nodeA"+str(i+1) for i in range(41)]+["nodeB"+str(i+1) for i in range(20)]
        for item in nodes:
            if item not in self.node_select.keys():
                values[item] = 0
            else:
                values[item] = self.node_select[item]
        self.node_select = pd.Series(values)
        
        self.node_category = self.df["node_category"].value_counts(normalize=True)*100
        values = {}
        cats = ['UNKNOWN','INACT_1st','INACT_2nd','ROOT_1st','ROOT_2nd','INBTW_1st','INBTW_2nd','IMDT_1st','IMDT_2nd','EFFECT']
        for item in cats:
            if item not in self.node_category.keys():
                values[item] = 0
            else:
                values[item] = self.node_category[item]
        self.node_category = pd.Series(values)
        
    def add_filter(self,sampling=None,level=None,state=None,root_1st=None,state_branch=None,A_detectors=None):
        if sampling == "right":
            self.df = self.df[self.df["sampling"]=="Right"]
        elif sampling == "left":
            self.df = self.df[self.df["sampling"]=="Left"]
        if level == "top":
            self.df = self.df[self.df["A_branch_loc"]=="Top"]
        elif level == "bottom":
            self.df = self.df[self.df["A_branch_loc"]=="Bottom"]
        if A_detectors == "squares":
            self.df = self.df[self.df["A_detectors"]=="Squares"]
        elif A_detectors == "circles":
            self.df = self.df[self.df["A_detectors"]=="Circles"]
        if state == False:
            self.df = self.df[self.df["state_OR_event"]=="Event"]
        elif state == True:
            self.df = self.df[self.df["state_OR_event"]=="State"]
        if root_1st == 'A':
            self.df = self.df[self.df["root_1st"]=="A"]
        elif root_1st == 'B':
            self.df = self.df[self.df["root_1st"]=="B"]
        if state_branch == 'A':
            self.df = self.df[self.df["state_branch"]=="A"]
        if state_branch == 'B':
            self.df = self.df[self.df["state_branch"]=="B"]
        
        self.node_select = self.df["node_selected"].value_counts(normalize=True)*100
        values = {}
        nodes = ["nodeA"+str(i+1) for i in range(41)]+["nodeB"+str(i+1) for i in range(20)]
        for item in nodes:
            if item not in self.node_select.keys():
                values[item] = 0
            else:
                values[item] = self.node_select[item]
        self.node_select = pd.Series(values)
        
        self.node_category = self.df["node_category"].value_counts(normalize=True)*100
        values = {}
        cats = ['UNKNOWN','INACT_1st','INACT_2nd','ROOT_1st','ROOT_2nd','INBTW_1st','INBTW_2nd','IMDT_1st','IMDT_2nd','EFFECT']
        for item in cats:
            if item not in self.node_category.keys():
                values[item] = 0
            else:
                values[item] = self.node_category[item]
        self.node_category = pd.Series(values)
        
        return self
    
class Chain(object):
    def __init__(self,stim=None):
        data = data_chain[data_chain["stim_type"] == stim]
            
        self.df = data
        
        self.node_select = self.df["node_selected"].value_counts(normalize=True)*100
        values = {}
        if stim == 'ChainS':
            nodes = ["nodeB"+str(i+1) for i in range(20)]
        elif stim == 'ChainC':
            nodes = ["nodeA"+str(i+1) for i in range(41)]+['nodesB20']
            
        for item in nodes:
            if item not in self.node_select.keys():
                values[item] = 0
            else:
                values[item] = self.node_select[item]
        self.node_select = pd.Series(values)
        
        self.node_category = self.df["node_category"].value_counts(normalize=True)*100
        values = {}
        cats = ['INACT','ROOT','INBTW','IMDT','EFFECT']
        for item in cats:
            if item not in self.node_category.keys():
                values[item] = 0
            else:
                values[item] = self.node_category[item]
        self.node_category = pd.Series(values)
        
    def add_filter(self,sampling=None,level=None):
        if sampling == "right":
            self.df = self.df[self.df["sampling"]=="Right"]
        elif sampling == "left":
            self.df = self.df[self.df["sampling"]=="Left"]
        if level == 'top':
            self.df = self.df[self.df['A_branch_loc']=='Top']
        elif level == 'bottom':
            self.df = self.df[self.df['A_branch_loc']=='Bottom']
            
        self.node_select = self.df["node_selected"].value_counts(normalize=True)*100
        values = {}
        stim = self.df['stim_type'].cat.remove_unused_categories().cat.categories[0]
        if stim == 'ChainS':
            nodes = ["nodeB"+str(i+1) for i in range(20)]
        elif stim == 'ChainC':
            nodes = ["nodeA"+str(i+1) for i in range(41)]+['nodesB20']
        for item in nodes:
            if item not in self.node_select.keys():
                values[item] = 0
            else:
                values[item] = self.node_select[item]
        self.node_select = pd.Series(values)
        
        self.node_category = self.df["node_category"].value_counts(normalize=True)*100
        values = {}
        cats = ['INACT','ROOT','INBTW','IMDT','EFFECT']
        for item in cats:
            if item not in self.node_category.keys():
                values[item] = 0
            else:
                values[item] = self.node_category[item]
        self.node_category = pd.Series(values)
        
        return self
    
def graph(list_of_data,title,x_axis='node_category'):
    fig = plt.figure(figsize=(6.6*len(list_of_data),5))
    a = str(len(list_of_data))
    for i,x in enumerate(list_of_data):
        axis = fig.add_subplot(int("1"+a+str(i+1)))
        axis.set_ylim([0,110])
        axis.set_ylabel("Percentage of responses")
        axis.label_outer()
        axis.spines["top"].set_visible(False)
        axis.spines["right"].set_visible(False)
        axis.set_title(title[i])
        if x_axis == 'node_selected':
            axis.set_xlabel("Detectors",labelpad=20)
            x.node_select.plot.bar(ax=axis)  
        elif x_axis == 'node_category':
            axis.set_xlabel("Location of the cause",labelpad=20)
            x.node_category.plot.bar(ax=axis)
            
def graph2(list_of_data,x_axis='node_category'):
    plt.rcParams['axes.grid'] = False
    fig = plt.figure(figsize=(9,4))
    #fig.suptitle("Experiment 1", fontweight="bold",y=1.05)
    a = str(len(list_of_data))
    titles = ['Unrolled squares','Unrolled circles','Rolled']
    for i,x in enumerate(list_of_data):
        axis = fig.add_subplot(int("1"+a+str(i+1)))
        axis.spines["top"].set_visible(False)
        axis.spines["right"].set_visible(False)
        axis.set_ylim([0,80])
        axis.set_ylabel("Number of responses (%)")
        axis.set_title(titles[i])
        axis.label_outer()
        categories = ['R1','I1','R2','I2','other']
        event_R1c = [x[0].node_category.ROOT_1st,x[0].node_category.IMDT_1st,x[0].node_category.ROOT_2nd,
                     x[0].node_category.IMDT_2nd,x[0].node_category.UNKNOWN+x[0].node_category.INACT_1st+
                     x[0].node_category.INACT_2nd+x[0].node_category.INBTW_1st+x[0].node_category.INBTW_2nd+
                     x[0].node_category.EFFECT]
        event_R2c = [x[1].node_category.ROOT_1st,x[1].node_category.IMDT_1st,x[1].node_category.ROOT_2nd,
                     x[1].node_category.IMDT_2nd,x[1].node_category.UNKNOWN+x[1].node_category.INACT_1st+
                     x[1].node_category.INACT_2nd+x[1].node_category.INBTW_1st+x[1].node_category.INBTW_2nd+
                     x[1].node_category.EFFECT]
        state_R2c = [x[2].node_category.ROOT_1st,x[2].node_category.IMDT_1st,x[2].node_category.ROOT_2nd,
                     x[2].node_category.IMDT_2nd,x[2].node_category.UNKNOWN+x[2].node_category.INACT_1st+
                     x[2].node_category.INACT_2nd+x[2].node_category.INBTW_1st+x[2].node_category.INBTW_2nd+
                     x[2].node_category.EFFECT]
        #if i != 2:
            #state_R1c = np.zeros(5)
        #else:
            #state_R1c = [x[3].node_category.ROOT_1st,x[3].node_category.IMDT_1st,x[3].node_category.ROOT_2nd,
                         #x[3].node_category.IMDT_2nd,x[3].node_category.UNKNOWN+x[3].node_category.INACT_1st+
                         #x[3].node_category.INACT_2nd+x[2].node_category.INBTW_1st+x[3].node_category.INBTW_2nd+
                         #x[3].node_category.EFFECT]
        
        df = pd.DataFrame({'state (R2 cont)':state_R2c,'event (R1 cont)':event_R1c,'event (R2 cont)':event_R2c,}, 
                          index=categories)
        if i != 0:
            legend = False
        else:
            legend = True
        df.plot.bar(ax=axis,legend=legend,rot=0)

# %%
data_chain['node_category'] = data_chain.apply(lambda x: chain_node_cat(x['stimulus'],x['node_selected']),axis=1)
data_chain['node_category'] = data_chain['node_category'].astype('category')
data_AND_Gate['node_category'] = data_AND_Gate.apply(lambda x: branch_node_cat(x['stimulus'],x['node_selected']),axis=1)
data_AND_Gate['node_category'] = data_AND_Gate['node_category'].astype('category')

# %%
data_chain
# Out:
#     subject_id         rt  stimulus sampling  nb_of_run stim_type  \
# 0            1  40194.000  chainS_L     Left        1.0    ChainS
# 1            2  16502.940  chainS_L     Left        1.0    ChainS
# 2            3  13313.000  chainS_L     Left        1.0    ChainS
# 3            4  10768.230  chainS_R    Right        1.0    ChainS
# 4            5  20252.000  chainS_R    Right        1.0    ChainS
# 5            6   8412.500  chainS_R    Right        1.0    ChainS
# 6            7  44315.000  chainS_L     Left        1.0    ChainS
# 7            8  17388.000  chainS_L     Left        1.0    ChainS
# 8            9  14245.000  chainS_R    Right        1.0    ChainS
# 9           10   8842.205  chainS_R    Right        1.0    ChainS
# 10          11   9335.815  chainS_R    Right        1.0    ChainS
# 11          12  10761.000  chainS_L     Left        1.0    ChainS
# 12          13  10127.085  chainS_L     Left        1.0    ChainS
# 13          14  15498.000  chainS_L     Left        1.0    ChainS
# 14          15   9745.000  chainS_L     Left        1.0    ChainS
# 15          16  64544.355  chainS_L     Left        2.0    ChainS
# 16          17  17657.640  chainS_L     Left        1.0    ChainS
# 17          18  35942.410  chainS_R    Right        1.0    ChainS
# 18          19  14122.100  chainS_R    Right        1.0    ChainS
# 19          20   9428.285  chainS_L     Left        1.0    ChainS
# 20          21  10406.515  chainS_L     Left        1.0    ChainS
# 21          22  11127.770  chainS_L     Left        1.0    ChainS
# 22          23  11728.000  chainS_L     Left        1.0    ChainS
# 23          24   8829.305  chainS_R    Right        1.0    ChainS
# 24          25  10339.475  chainS_R    Right        1.0    ChainS
# 25          26  19966.875  chainS_L     Left        1.0    ChainS
# 26          27  12490.090  chainS_L     Left        1.0    ChainS
# 27          28  10749.650  chainS_L     Left        1.0    ChainS
# 28          29  18201.805  chainS_L     Left        2.0    ChainS
# 29          30  10703.000  chainS_L     Left        1.0    ChainS
# 30          31   9848.000  chainS_R    Right        1.0    ChainS
# 31          32  10124.000  chainS_L     Left        1.0    ChainS
# 32          33  15842.000  chainS_R    Right        1.0    ChainS
# 33          34   9115.545  chainS_R    Right        1.0    ChainS
# 34          35   8729.355  chainS_L     Left        1.0    ChainS
# 35          36  14956.685  chainS_L     Left        1.0    ChainS
# 36          37   9831.000  chainS_L     Left        1.0    ChainS
# 37          38   8601.755  chainS_L     Left        1.0    ChainS
# 38          39  13455.930  chainS_L     Left        1.0    ChainS
# 39          40  14748.415  chainS_L     Left        1.0    ChainS
# 40          41  22104.285  chainS_L     Left        1.0    ChainS
# 41          42  11598.355  chainS_R    Right        1.0    ChainS
# 42          43  12313.100  chainS_L     Left        1.0    ChainS
# 43          44  13245.580  chainS_L     Left        1.0    ChainS
# 44          45   9846.000  chainS_R    Right        1.0    ChainS
# 45          46   8928.120  chainS_R    Right        1.0    ChainS
# 46          47  20462.195  chainS_L     Left        1.0    ChainS
# 47          48   8632.665  chainS_R    Right        1.0    ChainS
#
#    A_branch_loc node_selected node_category
# 0           NaN        nodeB9          ROOT
# 1           NaN        nodeB9          ROOT
# 2           NaN        nodeB4         INACT
# 3           NaN        nodeB9          ROOT
# 4           NaN       nodeB20        EFFECT
# 5           NaN        nodeB8          ROOT
# 6           NaN        nodeB2         INACT
# 7           NaN        nodeB9          ROOT
# 8           NaN        nodeB8          ROOT
# 9           NaN        nodeB9          ROOT
# 10          NaN       nodeB19          IMDT
# 11          NaN        nodeB9          ROOT
# 12          NaN        nodeB9          ROOT
# 13          NaN        nodeB1         INACT
# 14          NaN       nodeB16         INBTW
# 15          NaN        nodeB5         INACT
# 16          NaN       nodeB19          IMDT
# 17          NaN       nodeB19          IMDT
# 18          NaN       nodeB19          IMDT
# 19          NaN        nodeB9          ROOT
# 20          NaN       nodeB19          IMDT
# 21          NaN        nodeB9          ROOT
# 22          NaN        nodeB9          ROOT
# 23          NaN        nodeB9          ROOT
# 24          NaN        nodeB8          ROOT
# 25          NaN        nodeB9          ROOT
# 26          NaN        nodeB9          ROOT
# 27          NaN        nodeB9          ROOT
# 28          NaN       nodeB20        EFFECT
# 29          NaN       nodeB20        EFFECT
# 30          NaN       nodeB19          IMDT
# 31          NaN       nodeB19          IMDT
# 32          NaN       nodeB19          IMDT
# 33          NaN        nodeB9          ROOT
# 34          NaN        nodeB9          ROOT
# 35          NaN        nodeB9          ROOT
# 36          NaN       nodeB20        EFFECT
# 37          NaN        nodeB9          ROOT
# 38          NaN        nodeB9          ROOT
# 39          NaN       nodeB19          IMDT
# 40          NaN        nodeB9          ROOT
# 41          NaN        nodeB9          ROOT
# 42          NaN        nodeB9          ROOT
# 43          NaN       nodeB20        EFFECT
# 44          NaN       nodeB10          ROOT
# 45          NaN        nodeB9          ROOT
# 46          NaN        nodeB9          ROOT
# 47          NaN        nodeB9          ROOT

# %%
data_AND_Gate
# Out:
#      subject_id          rt stimulus sampling  nb_of_run rolled_OR_unrolled  \
# 0             1   64342.000   UAS_LT     Left        2.0           Unrolled
# 1             1   27948.000  UAAS_LB     Left        1.0           Unrolled
# 2             1   18863.000  UBBS_LB     Left        2.0           Unrolled
# 3             1   15954.000   UBS_LT     Left        1.0           Unrolled
# 4             1   17294.000  UBAS_LB     Left        1.0           Unrolled
# 5             1   21221.000  UABS_LT     Left        1.0           Unrolled
# 6             2   14628.545   UAS_LT     Left        1.0           Unrolled
# 7             2   19263.155  UAAS_LB     Left        1.0           Unrolled
# 8             2   13752.445  UBAS_LB     Left        1.0           Unrolled
# 9             2   17673.240  UBBS_LT     Left        2.0           Unrolled
# 10            2   13511.215  UABS_LT     Left        1.0           Unrolled
# 11            2   10898.105   UBS_LT     Left        1.0           Unrolled
# 12            3   15782.000   UBS_LB     Left        1.0           Unrolled
# 13            3   15288.000  UABS_LB     Left        1.0           Unrolled
# 14            3   12808.000  UBAS_LB     Left        1.0           Unrolled
# 15            3    9240.000   UAS_LB     Left        1.0           Unrolled
# 16            3   14194.000  UAAS_LB     Left        1.0           Unrolled
# 17            3    9307.000  UBBS_LB     Left        1.0           Unrolled
# 18            4   14154.130  UBAS_RT    Right        1.0           Unrolled
# 19            4   19599.285  UABS_RT    Right        1.0           Unrolled
# 20            4   10543.145   UAS_RB    Right        1.0           Unrolled
# 21            4   11588.285   UBS_RB    Right        1.0           Unrolled
# 22            4   13201.765  UAAS_RT    Right        1.0           Unrolled
# 23            4   10593.390  UBBS_RB    Right        1.0           Unrolled
# 24            5   44601.000  UABS_RB    Right        3.0           Unrolled
# 25            5   17722.000  UBBS_RB    Right        1.0           Unrolled
# 26            5   24225.000  UAAS_RT    Right        1.0           Unrolled
# 27            5   22467.000  UBAS_RB    Right        1.0           Unrolled
# 28            5   19352.000   UAS_RT    Right        1.0           Unrolled
# 29            5   17796.000   UBS_RT    Right        1.0           Unrolled
# 30            6   27436.830   UAS_RB    Right        2.0           Unrolled
# 31            6   10444.510  UAAS_RT    Right        1.0           Unrolled
# 32            6   22220.060  UBBS_RT    Right        1.0           Unrolled
# 33            6   10712.265   UBS_RT    Right        1.0           Unrolled
# 34            6   17646.135  UBAS_RT    Right        1.0           Unrolled
# 35            6   23307.765  UABS_RB    Right        1.0           Unrolled
# 36            7   53783.000  UBBS_LT     Left        3.0           Unrolled
# 37            7   18888.000   UAS_LB     Left        1.0           Unrolled
# 38            7   40351.000  UABS_LT     Left        1.0           Unrolled
# 39            7   15364.000  UAAS_LB     Left        1.0           Unrolled
# 40            7   23030.000  UBAS_LT     Left        1.0           Unrolled
# 41            7   20483.000   UBS_LB     Left        1.0           Unrolled
# 42            8   23549.000   UAS_LT     Left        1.0           Unrolled
# 43            8   13001.000  UAAS_LB     Left        1.0           Unrolled
# 44            8   15377.000  UABS_LB     Left        1.0           Unrolled
# 45            8   10854.000   UBS_LT     Left        1.0           Unrolled
# 46            8   12361.000  UBBS_LB     Left        1.0           Unrolled
# 47            8   14215.000  UBAS_LB     Left        1.0           Unrolled
# 48            9   54735.000   UBS_RT    Right        1.0           Unrolled
# 49            9   12122.000  UAAS_RT    Right        1.0           Unrolled
# ..          ...         ...      ...      ...        ...                ...
# 238          40   10372.115   UBS_LB     Left        1.0           Unrolled
# 239          40   17124.040  UBAS_LT     Left        1.0           Unrolled
# 240          41   41394.345   UBS_LB     Left        1.0           Unrolled
# 241          41   14685.680  UBAS_LT     Left        1.0           Unrolled
# 242          41   14731.485  UBBS_LB     Left        1.0           Unrolled
# 243          41   18989.805   UAS_LB     Left        1.0           Unrolled
# 244          41   23282.550  UAAS_LT     Left        1.0           Unrolled
# 245          41  115823.080  UABS_LT     Left        1.0           Unrolled
# 246          42   35057.440  UAAS_RT    Right        1.0           Unrolled
# 247          42   18298.040   UBS_RT    Right        1.0           Unrolled
# 248          42   13908.615   UAS_RB    Right        1.0           Unrolled
# 249          42   18156.580  UBBS_RB    Right        1.0           Unrolled
# 250          42   14874.725  UBAS_RB    Right        1.0           Unrolled
# 251          42   94870.435  UABS_RB    Right        1.0           Unrolled
# 252          43   31827.855   UAS_LB     Left        1.0           Unrolled
# 253          43   19189.980  UBBS_LT     Left        1.0           Unrolled
# 254          43   10748.410   UBS_LB     Left        1.0           Unrolled
# 255          43   14681.455  UAAS_LB     Left        1.0           Unrolled
# 256          43   10193.445  UBAS_LB     Left        1.0           Unrolled
# 257          43   53003.740  UABS_LT     Left        1.0           Unrolled
# 258          44   26925.605  UBBS_LT     Left        1.0           Unrolled
# 259          44   14435.925   UBS_LT     Left        1.0           Unrolled
# 260          44   16398.345  UAAS_LB     Left        1.0           Unrolled
# 261          44   11764.390   UAS_LB     Left        6.0           Unrolled
# 262          44   16705.645  UABS_LB     Left        1.0           Unrolled
# 263          44   14943.740  UBAS_LT     Left        1.0           Unrolled
# 264          45   25026.000   UBS_RB    Right        1.0           Unrolled
# 265          45   17681.000  UAAS_RB    Right        1.0           Unrolled
# 266          45   37663.000  UABS_RT    Right        1.0           Unrolled
# 267          45   12074.000  UBBS_RB    Right        1.0           Unrolled
# 268          45   14354.000   UAS_RB    Right        1.0           Unrolled
# 269          45   21938.000  UBAS_RT    Right        1.0           Unrolled
# 270          46   13231.750  UBAS_RB    Right        2.0           Unrolled
# 271          46   12032.785  UAAS_RT    Right        1.0           Unrolled
# 272          46   18891.395   UBS_RT    Right        1.0           Unrolled
# 273          46   10511.765  UBBS_RB    Right        1.0           Unrolled
# 274          46   10191.580   UAS_RB    Right        1.0           Unrolled
# 275          46   13262.640  UABS_RT    Right        1.0           Unrolled
# 276          47   15142.445  UBBS_LB     Left        1.0           Unrolled
# 277          47   14934.545  UABS_LT     Left        1.0           Unrolled
# 278          47   12773.225  UAAS_LB     Left        1.0           Unrolled
# 279          47   10814.265   UBS_LT     Left        1.0           Unrolled
# 280          47   12270.455   UAS_LT     Left        1.0           Unrolled
# 281          47   11444.640  UBAS_LB     Left        2.0           Unrolled
# 282          48   10399.260  UBBS_RT    Right        2.0           Unrolled
# 283          48   12409.110   UBS_RT    Right        1.0           Unrolled
# 284          48   10540.760  UBAS_RB    Right        1.0           Unrolled
# 285          48   14759.020  UABS_RB    Right        1.0           Unrolled
# 286          48    9954.570   UAS_RT    Right        1.0           Unrolled
# 287          48   11990.420  UAAS_RB    Right        1.0           Unrolled
#
#     A_branch_loc A_detectors state_OR_event state_branch root_1st imdt_2nd  \
# 0            Top     Squares          State            A      NaN        B
# 1         Bottom     Squares          Event          NaN        A        A
# 2         Bottom     Squares          Event          NaN        B        B
# 3            Top     Squares          State            B      NaN        A
# 4         Bottom     Squares          Event          NaN        B        A
# 5            Top     Squares          Event          NaN        A        B
# 6            Top     Squares          State            A      NaN        B
# 7         Bottom     Squares          Event          NaN        A        A
# 8         Bottom     Squares          Event          NaN        B        A
# 9            Top     Squares          Event          NaN        B        B
# 10           Top     Squares          Event          NaN        A        B
# 11           Top     Squares          State            B      NaN        A
# 12        Bottom     Squares          State            B      NaN        A
# 13        Bottom     Squares          Event          NaN        A        B
# 14        Bottom     Squares          Event          NaN        B        A
# 15        Bottom     Squares          State            A      NaN        B
# 16        Bottom     Squares          Event          NaN        A        A
# 17        Bottom     Squares          Event          NaN        B        B
# 18           Top     Squares          Event          NaN        B        A
# 19           Top     Squares          Event          NaN        A        B
# 20        Bottom     Squares          State            A      NaN        B
# 21        Bottom     Squares          State            B      NaN        A
# 22           Top     Squares          Event          NaN        A        A
# 23        Bottom     Squares          Event          NaN        B        B
# 24        Bottom     Squares          Event          NaN        A        B
# 25        Bottom     Squares          Event          NaN        B        B
# 26           Top     Squares          Event          NaN        A        A
# 27        Bottom     Squares          Event          NaN        B        A
# 28           Top     Squares          State            A      NaN        B
# 29           Top     Squares          State            B      NaN        A
# 30        Bottom     Squares          State            A      NaN        B
# 31           Top     Squares          Event          NaN        A        A
# 32           Top     Squares          Event          NaN        B        B
# 33           Top     Squares          State            B      NaN        A
# 34           Top     Squares          Event          NaN        B        A
# 35        Bottom     Squares          Event          NaN        A        B
# 36           Top     Squares          Event          NaN        B        B
# 37        Bottom     Squares          State            A      NaN        B
# 38           Top     Squares          Event          NaN        A        B
# 39        Bottom     Squares          Event          NaN        A        A
# 40           Top     Squares          Event          NaN        B        A
# 41        Bottom     Squares          State            B      NaN        A
# 42           Top     Squares          State            A      NaN        B
# 43        Bottom     Squares          Event          NaN        A        A
# 44        Bottom     Squares          Event          NaN        A        B
# 45           Top     Squares          State            B      NaN        A
# 46        Bottom     Squares          Event          NaN        B        B
# 47        Bottom     Squares          Event          NaN        B        A
# 48           Top     Squares          State            B      NaN        A
# 49           Top     Squares          Event          NaN        A        A
# ..           ...         ...            ...          ...      ...      ...
# 238       Bottom     Squares          State            B      NaN        A
# 239          Top     Squares          Event          NaN        B        A
# 240       Bottom     Squares          State            B      NaN        A
# 241          Top     Squares          Event          NaN        B        A
# 242       Bottom     Squares          Event          NaN        B        B
# 243       Bottom     Squares          State            A      NaN        B
# 244          Top     Squares          Event          NaN        A        A
# 245          Top     Squares          Event          NaN        A        B
# 246          Top     Squares          Event          NaN        A        A
# 247          Top     Squares          State            B      NaN        A
# 248       Bottom     Squares          State            A      NaN        B
# 249       Bottom     Squares          Event          NaN        B        B
# 250       Bottom     Squares          Event          NaN        B        A
# 251       Bottom     Squares          Event          NaN        A        B
# 252       Bottom     Squares          State            A      NaN        B
# 253          Top     Squares          Event          NaN        B        B
# 254       Bottom     Squares          State            B      NaN        A
# 255       Bottom     Squares          Event          NaN        A        A
# 256       Bottom     Squares          Event          NaN        B        A
# 257          Top     Squares          Event          NaN        A        B
# 258          Top     Squares          Event          NaN        B        B
# 259          Top     Squares          State            B      NaN        A
# 260       Bottom     Squares          Event          NaN        A        A
# 261       Bottom     Squares          State            A      NaN        B
# 262       Bottom     Squares          Event          NaN        A        B
# 263          Top     Squares          Event          NaN        B        A
# 264       Bottom     Squares          State            B      NaN        A
# 265       Bottom     Squares          Event          NaN        A        A
# 266          Top     Squares          Event          NaN        A        B
# 267       Bottom     Squares          Event          NaN        B        B
# 268       Bottom     Squares          State            A      NaN        B
# 269          Top     Squares          Event          NaN        B        A
# 270       Bottom     Squares          Event          NaN        B        A
# 271          Top     Squares          Event          NaN        A        A
# 272          Top     Squares          State            B      NaN        A
# 273       Bottom     Squares          Event          NaN        B        B
# 274       Bottom     Squares          State            A      NaN        B
# 275          Top     Squares          Event          NaN        A        B
# 276       Bottom     Squares          Event          NaN        B        B
# 277          Top     Squares          Event          NaN        A        B
# 278       Bottom     Squares          Event          NaN        A        A
# 279          Top     Squares          State            B      NaN        A
# 280          Top     Squares          State            A      NaN        B
# 281       Bottom     Squares          Event          NaN        B        A
# 282          Top     Squares          Event          NaN        B        B
# 283          Top     Squares          State            B      NaN        A
# 284       Bottom     Squares          Event          NaN        B        A
# 285       Bottom     Squares          Event          NaN        A        B
# 286          Top     Squares          State            A      NaN        B
# 287       Bottom     Squares          Event          NaN        A        A
#
#     node_selected node_category
# 0         nodeB19      IMDT_2nd
# 1         nodeB20        EFFECT
# 2          nodeB2      ROOT_1st
# 3         nodeA20      ROOT_2nd
# 4         nodeA25      ROOT_2nd
# 5          nodeB7      ROOT_2nd
# 6          nodeB7      ROOT_2nd
# 7          nodeA7      ROOT_1st
# 8          nodeB4      ROOT_1st
# 9         nodeA37      ROOT_2nd
# 10         nodeB7      ROOT_2nd
# 11        nodeA20      ROOT_2nd
# 12        nodeA11     INACT_2nd
# 13         nodeA4     INACT_1st
# 14         nodeA4     INACT_2nd
# 15         nodeB2     INACT_2nd
# 16         nodeB3     INACT_2nd
# 17         nodeA2     INACT_2nd
# 18         nodeB4      ROOT_1st
# 19         nodeB7      ROOT_2nd
# 20         nodeB7      ROOT_2nd
# 21        nodeA20      ROOT_2nd
# 22         nodeA7      ROOT_1st
# 23         nodeB2      ROOT_1st
# 24        nodeB20        EFFECT
# 25        nodeB20        EFFECT
# 26        nodeB20        EFFECT
# 27        nodeA41      IMDT_2nd
# 28        nodeB20        EFFECT
# 29        nodeB20        EFFECT
# 30         nodeB6      ROOT_2nd
# 31         nodeA6     INACT_1st
# 32         nodeB1      ROOT_1st
# 33        nodeA19      ROOT_2nd
# 34         nodeB3      ROOT_1st
# 35         nodeB6      ROOT_2nd
# 36        nodeA27     INACT_2nd
# 37         nodeA1     INACT_1st
# 38         nodeB5     INACT_2nd
# 39         nodeA6     INACT_1st
# 40         nodeA1     INACT_2nd
# 41        nodeA18     INACT_2nd
# 42         nodeB5     INACT_2nd
# 43        nodeA21     INBTW_1st
# 44         nodeB6      ROOT_2nd
# 45        nodeA20      ROOT_2nd
# 46         nodeB2      ROOT_1st
# 47         nodeB4      ROOT_1st
# 48        nodeB20        EFFECT
# 49         nodeA6     INACT_1st
# ..            ...           ...
# 238       nodeA41      IMDT_2nd
# 239       nodeA41      IMDT_2nd
# 240        nodeB6     INBTW_1st
# 241        nodeB3      ROOT_1st
# 242       nodeA37      ROOT_2nd
# 243       nodeB20        EFFECT
# 244       nodeB20        EFFECT
# 245       nodeB20        EFFECT
# 246        nodeA7      ROOT_1st
# 247        nodeB4      ROOT_1st
# 248        nodeB7      ROOT_2nd
# 249       nodeA37      ROOT_2nd
# 250       nodeA25      ROOT_2nd
# 251        nodeA7      ROOT_1st
# 252        nodeB7      ROOT_2nd
# 253        nodeB2      ROOT_1st
# 254       nodeA20      ROOT_2nd
# 255        nodeA7      ROOT_1st
# 256       nodeA25      ROOT_2nd
# 257        nodeB7      ROOT_2nd
# 258       nodeB20        EFFECT
# 259       nodeB20        EFFECT
# 260       nodeB20        EFFECT
# 261       nodeB20        EFFECT
# 262       nodeB20        EFFECT
# 263       nodeB20        EFFECT
# 264        nodeB9     INBTW_1st
# 265       nodeA30     INBTW_1st
# 266       nodeA21     INBTW_1st
# 267        nodeB8     INBTW_1st
# 268       nodeA35     INBTW_1st
# 269       nodeA28     INBTW_2nd
# 270        nodeB4      ROOT_1st
# 271        nodeA7      ROOT_1st
# 272       nodeA20      ROOT_2nd
# 273        nodeB2      ROOT_1st
# 274        nodeB7      ROOT_2nd
# 275        nodeA7      ROOT_1st
# 276        nodeB2      ROOT_1st
# 277        nodeB7      ROOT_2nd
# 278        nodeA7      ROOT_1st
# 279       nodeA20      ROOT_2nd
# 280        nodeB7      ROOT_2nd
# 281       nodeA25      ROOT_2nd
# 282        nodeB2      ROOT_1st
# 283        nodeB4      ROOT_1st
# 284        nodeB4      ROOT_1st
# 285        nodeA7      ROOT_1st
# 286        nodeA7      ROOT_1st
# 287        nodeA7      ROOT_1st
#
# [288 rows x 14 columns]

# %% [markdown]
# ## General comparison

# %%
# For Unrolled: only graphs with SQUARES for branch A

chainS = Chain(stim='ChainS')
UnrolledS_state = AndGate(rolled=False,continuity='root_2nd').add_filter(A_detectors='squares',state=True)
UnrolledS_stateA = AndGate(rolled=False,continuity='root_2nd').add_filter(A_detectors='squares',state=True,state_branch='A')
UnrolledS_stateB = AndGate(rolled=False,continuity='root_2nd').add_filter(A_detectors='squares',state=True,state_branch='B')
UnrolledS_AA_BB = AndGate(rolled=False,continuity='root_1st').add_filter(A_detectors='squares')
UnrolledS_AA = AndGate(rolled=False,continuity='root_1st').add_filter(A_detectors='squares',root_1st='A')
UnrolledS_BB = AndGate(rolled=False,continuity='root_1st').add_filter(A_detectors='squares',root_1st='B')
UnrolledS_AB_BA = AndGate(rolled=False,continuity='root_2nd').add_filter(A_detectors='squares',state=False)
UnrolledS_AB = AndGate(rolled=False,continuity='root_2nd').add_filter(A_detectors='squares',state=False,root_1st='A')
UnrolledS_BA = AndGate(rolled=False,continuity='root_2nd').add_filter(A_detectors='squares',state=False,root_1st='B')

graph([chainS],['Chain squares','Chain circles'])
graph([UnrolledS_state,UnrolledS_stateA,UnrolledS_stateB],['Unrolled A or B in state condition','Unrolled A in state condition','Unrolled B in state condition'])
graph([UnrolledS_AA_BB,UnrolledS_AA,UnrolledS_BB],['Unrolled AA or BB','Unrolled AA','Unrolled BB'])
graph([UnrolledS_AB_BA,UnrolledS_AB,UnrolledS_BA],['Unrolled AB or BA','Unrolled AB','Unrolled BA'])

# %%
graph2([[UnrolledS_AA_BB,UnrolledS_AB_BA,UnrolledS_state]])
#plt.savefig('results_E2.png',dpi=300,bbox_inches='tight')

# %% [markdown]
# ## Comparison Right *vs* Left

# %%
# Same as the general comparison BUT only for the condition 'right'

chainS = Chain(stim='ChainS').add_filter(sampling='right')
Unrolled_state = AndGate(rolled=False,continuity='root_2nd').add_filter(sampling='right',state=True)
Unrolled_stateA = AndGate(rolled=False,continuity='root_2nd').add_filter(sampling='right',state=True,state_branch='A')
Unrolled_stateB = AndGate(rolled=False,continuity='root_2nd').add_filter(sampling='right',state=True,state_branch='B')
Unrolled_AA_BB = AndGate(rolled=False,continuity='root_1st').add_filter(sampling='right')
Unrolled_AA = AndGate(rolled=False,continuity='root_1st').add_filter(sampling='right',root_1st='A')
Unrolled_BB = AndGate(rolled=False,continuity='root_1st').add_filter(sampling='right',root_1st='B')
Unrolled_AB_BA = AndGate(rolled=False,continuity='root_2nd').add_filter(sampling='right',state=False)
Unrolled_AB = AndGate(rolled=False,continuity='root_2nd').add_filter(sampling='right',state=False,root_1st='A')
Unrolled_BA = AndGate(rolled=False,continuity='root_2nd').add_filter(sampling='right',state=False,root_1st='B')

graph([chainS],['Chain squares','Chain circles'])
graph([Unrolled_state,Unrolled_stateA,Unrolled_stateB],['Unrolled A or B in state condition','Unrolled A in state condition','Unrolled B in state condition'])
graph([Unrolled_AA_BB,Unrolled_AA,Unrolled_BB],['Unrolled AA or BB','Unrolled AA','Unrolled BB'])
graph([Unrolled_AB_BA,Unrolled_AB,Unrolled_BA],['Unrolled AB or BA','Unrolled AB','Unrolled BA'])

# %%
# Same as the general comparison BUT only for the condition 'left'

chainS = Chain(stim='ChainS').add_filter(sampling='left')
Unrolled_state = AndGate(rolled=False,continuity='root_2nd').add_filter(sampling='left',A_detectors='squares',state=True)
Unrolled_stateA = AndGate(rolled=False,continuity='root_2nd').add_filter(sampling='left',A_detectors='squares',state=True,state_branch='A')
Unrolled_stateB = AndGate(rolled=False,continuity='root_2nd').add_filter(sampling='left',A_detectors='squares',state=True,state_branch='B')
Unrolled_AA_BB = AndGate(rolled=False,continuity='root_1st').add_filter(A_detectors='squares',sampling='left')
Unrolled_AA = AndGate(rolled=False,continuity='root_1st').add_filter(sampling='left',A_detectors='squares',root_1st='A')
Unrolled_BB = AndGate(rolled=False,continuity='root_1st').add_filter(sampling='left',A_detectors='squares',root_1st='B')
Unrolled_AB_BA = AndGate(rolled=False,continuity='root_2nd').add_filter(sampling='left',A_detectors='squares',state=False)
Unrolled_AB = AndGate(rolled=False,continuity='root_2nd').add_filter(sampling='left',A_detectors='squares',state=False,root_1st='A')
Unrolled_BA = AndGate(rolled=False,continuity='root_2nd').add_filter(sampling='left',A_detectors='squares',state=False,root_1st='B')

graph([chainS],['Chain squares','Chain circles'])
graph([Unrolled_state,Unrolled_stateA,Unrolled_stateB],['Unrolled A or B in state condition','Unrolled A in state condition','Unrolled B in state condition'])
graph([Unrolled_AA_BB,Unrolled_AA,Unrolled_BB],['Unrolled AA or BB','Unrolled AA','Unrolled BB'])
graph([Unrolled_AB_BA,Unrolled_AB,Unrolled_BA],['Unrolled AB or BA','Unrolled AB','Unrolled BA'])

# %%
# Broad comparison between right vs left sampling

chainS_Right = Chain(stim='ChainS').add_filter(sampling='right')
chainS_Left = Chain(stim='ChainS').add_filter(sampling='left')
Unrolled_state_Right = AndGate(rolled=False,continuity='root_2nd').add_filter(sampling='right',state=True)
Unrolled_state_Left = AndGate(rolled=False,continuity='root_2nd').add_filter(sampling='left',state=True)
Unrolled_AA_BB_Right = AndGate(rolled=False,continuity='root_1st').add_filter(sampling='right')
Unrolled_AA_BB_Left = AndGate(rolled=False,continuity='root_1st').add_filter(sampling='left')
Unrolled_AB_BA_Right = AndGate(rolled=False,continuity='root_2nd').add_filter(sampling='right',state=False)
Unrolled_AB_BA_Left = AndGate(rolled=False,continuity='root_2nd').add_filter(sampling='left',state=False)

graph([chainS_Left,chainS_Right],['Chain squares left','Chain squares right'])
graph([Unrolled_state_Left,Unrolled_state_Right],['Unrolled A or B in state left','Unrolled A or B in state condition right'])
graph([Unrolled_AA_BB_Left,Unrolled_AA_BB_Right],['Unrolled AA or BB left','Unrolled AA or BB right'])
graph([Unrolled_AB_BA_Left,Unrolled_AB_BA_Right],['Unrolled AB or BA left','Unrolled AB or BA right'])

# %% [markdown]
# ## Comparison Top *vs* Bottom

# %%
# Broad comparison between TOP vs BOTTOM location of branch A

Unrolled_state_Top = AndGate(rolled=False,continuity='root_2nd').add_filter(level='top',state=True)
Unrolled_state_Bottom = AndGate(rolled=False,continuity='root_2nd').add_filter(level='bottom',state=True)
Unrolled_AA_BB_Top = AndGate(rolled=False,continuity='root_1st').add_filter(level='top')
Unrolled_AA_BB_Bottom = AndGate(rolled=False,continuity='root_1st').add_filter(level='bottom')
Unrolled_AB_BA_Top = AndGate(rolled=False,continuity='root_2nd').add_filter(level='top',state=False)
Unrolled_AB_BA_Bottom = AndGate(rolled=False,continuity='root_2nd').add_filter(level='bottom',state=False)

graph([Unrolled_state_Bottom,Unrolled_state_Top],['Unrolled A or B in state bottom','Unrolled A or B in state condition top'])
graph([Unrolled_AA_BB_Bottom,Unrolled_AA_BB_Top],['Unrolled AA or BB bottom','Unrolled AA or BB top'])
graph([Unrolled_AB_BA_Bottom,Unrolled_AB_BA_Top],['Unrolled AB or BA bottom','Unrolled AB or BA top'])
