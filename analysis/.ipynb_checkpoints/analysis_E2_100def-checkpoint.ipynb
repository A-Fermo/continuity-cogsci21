# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
#from jupyterthemes import jtplot
#jtplot.style(theme="chesterish")
pd.options.display.max_rows = 700

# %% [markdown]
# ## Data structuring

# %% [markdown]
# #### Importing data.csv

# %%
root_dir = os.path.dirname(os.getcwd())
data_clean = pd.read_csv("{}/data/data_E2_100def.csv".format(root_dir))
data_clean
# Out:
#       subject_id     stimulus     trial_type  time_elapsed  gender  age  \
# 0              1  instruction  causal-graph1          6362  female   31
# 1              1  instruction  causal-graph1         11076  female   31
# 2              1  instruction  causal-graph1         23724  female   31
# 3              1  instruction  causal-graph1         29399  female   31
# 4              1  instruction  causal-graph1         40590  female   31
# ...          ...          ...            ...           ...     ...  ...
# 2471         100       UBS_RT  causal-graph1        521552  female   37
# 2472         100      UABS_RB  causal-graph1        535960  female   37
# 2473         100     chainS_R  causal-graph1        552680  female   37
# 2474         100  instruction  causal-graph1        554990  female   37
# 2475         100      comment    survey-text        558439  female   37
#
#                  language                   country sampling  \
# 0     English, Indonesian  United States of America    Right
# 1     English, Indonesian  United States of America    Right
# 2     English, Indonesian  United States of America    Right
# 3     English, Indonesian  United States of America    Right
# 4     English, Indonesian  United States of America    Right
# ...                   ...                       ...      ...
# 2471              English  United States of America    Right
# 2472              English  United States of America    Right
# 2473              English  United States of America    Right
# 2474              English  United States of America    Right
# 2475              English  United States of America    Right
#
#                turkcode  ...  responses  stim_type rolled_OR_unrolled  \
# 0     R565304137610gxrw  ...        NaN        NaN                NaN
# 1     R565304137610gxrw  ...        NaN        NaN                NaN
# 2     R565304137610gxrw  ...        NaN        NaN                NaN
# 3     R565304137610gxrw  ...        NaN        NaN                NaN
# 4     R565304137610gxrw  ...        NaN        NaN                NaN
# ...                 ...  ...        ...        ...                ...
# 2471  R565986147390gxrw  ...        NaN   AND_Gate           Unrolled
# 2472  R565986147390gxrw  ...        NaN   AND_Gate           Unrolled
# 2473  R565986147390gxrw  ...        NaN     ChainS                NaN
# 2474  R565986147390gxrw  ...        NaN        NaN                NaN
# 2475  R565986147390gxrw  ...  {"Q0":""}        NaN                NaN
#
#      A_branch_loc A_detectors state_OR_event state_branch root_1st imdt_2nd  \
# 0             NaN         NaN            NaN          NaN      NaN      NaN
# 1             NaN         NaN            NaN          NaN      NaN      NaN
# 2             NaN         NaN            NaN          NaN      NaN      NaN
# 3             NaN         NaN            NaN          NaN      NaN      NaN
# 4             NaN         NaN            NaN          NaN      NaN      NaN
# ...           ...         ...            ...          ...      ...      ...
# 2471          Top     Squares          State            B      NaN        A
# 2472       Bottom     Squares          Event          NaN        A        B
# 2473          NaN         NaN            NaN          NaN      NaN      NaN
# 2474          NaN         NaN            NaN          NaN      NaN      NaN
# 2475          NaN         NaN            NaN          NaN      NaN      NaN
#
#      node_selected
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# ...            ...
# 2471       nodeA30
# 2472        nodeB8
# 2473       nodeB19
# 2474           NaN
# 2475           NaN
#
# [2476 rows x 22 columns]

# %%
time = []
for item in data_clean[data_clean['stimulus']=='comment']['time_elapsed']:
    time.append(item)
time = np.array(time)
time.mean()/1000/60
# Out:
# 6.961863333333333

# %%
for idx,item in enumerate(data_clean['stimulus']):
    if item == 'comment':
        print(data_clean['responses'][idx])
# Out:
# {"Q0":""}
# {"Q0":""}
# {"Q0":""}
# {"Q0":"I was a little confused when you asked which detector caused G to activate, as each detector can be activated by the detector before it. "}
# {"Q0":""}
# {"Q0":""}
# {"Q0":""}
# {"Q0":""}
# {"Q0":""}
# {"Q0":""}
# {"Q0":""}
# {"Q0":""}
# {"Q0":""}
# {"Q0":"None"}
# {"Q0":""}
# {"Q0":""}
# {"Q0":""}
# {"Q0":""}
# {"Q0":""}
# {"Q0":""}
# {"Q0":""}
# {"Q0":""}
# {"Q0":""}
# {"Q0":""}
# {"Q0":"Thank you."}
# {"Q0":""}
# {"Q0":""}
# {"Q0":""}
# {"Q0":"THANK YOU."}
# {"Q0":""}
# {"Q0":"Thank you!"}
# {"Q0":""}
# {"Q0":"It was different but I don't know if I really understand this "}
# {"Q0":""}
# {"Q0":"None to add"}
# {"Q0":""}
# {"Q0":""}
# {"Q0":""}
# {"Q0":""}
# {"Q0":""}
# {"Q0":""}
# {"Q0":""}
# {"Q0":"none"}
# {"Q0":""}
# {"Q0":""}
# {"Q0":""}
# {"Q0":""}
# {"Q0":""}
# {"Q0":"The instructions didn't help much with finding the cause of G\"/ activation."}
# {"Q0":""}
# {"Q0":""}
# {"Q0":""}
# {"Q0":""}
# {"Q0":""}
# {"Q0":"I hope I got  the answers right on most, I realized maybe it was the same as my last answers afterall."}
# {"Q0":""}
# {"Q0":""}
# {"Q0":""}
# {"Q0":""}
# {"Q0":""}
# {"Q0":"None thank you"}
# {"Q0":""}
# {"Q0":""}
# {"Q0":"Even after reviewing the instructions carefully it was kind of confusing to know what information you were wanting. Did you want the particle that initiated the the others who in turn activated G? Or the particle itself that was directly responsible for activating G? I went with the particle that I considered directly responsible. "}
# {"Q0":""}
# {"Q0":""}
# {"Q0":""}
# {"Q0":""}
# {"Q0":""}
# {"Q0":"none"}
# {"Q0":""}
# {"Q0":""}
# {"Q0":"N/A"}
# {"Q0":""}
# {"Q0":"None"}
# {"Q0":""}
# {"Q0":""}
# {"Q0":"everything worked as intended"}
# {"Q0":"It ook a while but i learned what to do."}
# {"Q0":""}
# {"Q0":""}
# {"Q0":"Interesting survey. Straight forward and fast paced. Thank you!"}
# {"Q0":"This task is awesome."}
# {"Q0":""}
# {"Q0":""}
# {"Q0":""}
# {"Q0":""}
# {"Q0":"GOOD STUDY."}
# {"Q0":"This was very interesting. The instructions were very clear and easy to follow. Good luck with your research. "}
# {"Q0":"In every instance I though there were at least 2 causes, not one, but I could only select one"}
# {"Q0":""}
# {"Q0":""}
# {"Q0":""}
# {"Q0":""}
# {"Q0":""}
# {"Q0":"Didn't really understand it.  What it supposed to be the last block before the G, or the first one to get radioactive particles?"}
# {"Q0":""}
# {"Q0":""}
# {"Q0":"I'm a little confused as I suspect that the task was so easy I was uncertain about whether or not my answers were correct, especially concerning the connection that the inactivating change of inputs relate to the activated chain of inputs and which chain (and its prior, responsible first input) was responsible for G's activation in the end.\n\neames.chris1900@gmail.com"}
# {"Q0":""}

# %% [markdown]
# #### Demographical data only

# %%
data_demog = data_clean[["subject_id","gender","age","language","country","turkcode"]]
data_demog = data_demog.drop_duplicates()
data_demog
# Out:
#       subject_id  gender  age             language                   country  \
# 0              1  female   31  English, Indonesian  United States of America
# 17             2    male   31              English  United States of America
# 34             3    male   47              english  United States of America
# 51             4    male   25              English  United States of America
# 68             5  female   33              English  United States of America
# 85             6  female   19              english  United States of America
# 110            7  female   64              English  United States of America
# 135            8  female   25              English  United States of America
# 160            9  female   35              english  United States of America
# 209           10  female   32              English  United States of America
# 226           11    male   47              English  United States of America
# 259           12  female   54              English  United States of America
# 276           13  female   41              English  United States of America
# 293           14  female   43              English  United States of America
# 318           15    male   42              English  United States of America
# 335           16    male   36              English  United States of America
# 360           17    male   33              English  United States of America
# 377           18    male   39              English  United States of America
# 394           19    male   27              English  United States of America
# 411           20  female   34              English  United States of America
# 436           21    male   24              English  United States of America
# 453           22    male   32              english  United States of America
# 470           23    male   38              English  United States of America
# 487           24  female   49              English  United States of America
# 504           25  female   40              English  United States of America
# 529           26  female   57              English  United States of America
# 546           27  female   46              English  United States of America
# 563           28    male   35              english  United States of America
# 588           29    male   59              ENGLISH  United States of America
# 637           30  female   29              english  United States of America
# 662           31  female   30              English  United States of America
# 679           32  female   41              English  United States of America
# 704           33  female   58             English   United States of America
# 737           34  female   60                  eng  United States of America
# 770           35    male   26              English  United States of America
# 819           36    male   31              English  United States of America
# 836           37  female   34              English  United States of America
# 861           38    male   32              English  United States of America
# 878           39    male   45              English  United States of America
# 903           40    male   49              English  United States of America
# 920           41  female   40              english  United States of America
# 945           42    male   37              English  United States of America
# 962           43  female   46              English  United States of America
# 987           44    male   38              English  United States of America
# 1004          45    male   44              English  United States of America
# 1021          46    male   33              English  United States of America
# 1046          47    male   62              English  United States of America
# 1071          48    male   37     Russian, English  United States of America
# 1112          49    male   23              English  United States of America
# 1145          50    male   27              English  United States of America
# 1162          51    male   53              English  United States of America
# 1187          52    male   73              english  United States of America
# 1204          53  female   49              English  United States of America
# 1229          54    male   53              English  United States of America
# 1246          55  female   57              English  United States of America
# 1279          56    male   24             English.  United States of America
# 1304          57  female   37              English  United States of America
# 1321          58  female   37              english  United States of America
# 1338          59    male   33              English  United States of America
# 1363          60  female   56              English  United States of America
# 1388          61    male   30              English  United States of America
# 1437          62  female   39              English  United States of America
# 1454          63    male   23              English  United States of America
# 1471          64  female   39              English  United States of America
# 1512          65    male   27              English  United States of America
# 1561          66  female   33              English  United States of America
# 1578          67    male   24              English  United States of America
# 1595          68    male   46              english  United States of America
# 1620          69  female   49              English  United States of America
# 1637          70    male   38              english  United States of America
# 1662          71    male   26              english  United States of America
# 1687          72  female   27              english  United States of America
# 1728          73    male   23              English  United States of America
# 1753          74    male   38              English  United States of America
# 1778          75    male   31              English  United States of America
# 1803          76    male   30              English  United States of America
# 1820          77    male   28              English  United States of America
# 1845          78  female   39              English  United States of America
# 1862          79    male   58              english  United States of America
# 1895          80  female   31              english  United States of America
# 1960          81    male   56              English  United States of America
# 2009          82  female   54              English  United States of America
# 2026          83    male   62              English  United States of America
# 2051          84    male   30              English  United States of America
# 2076          85    male   33              English  United States of America
# 2093          86    male   32              english  United States of America
# 2110          87    male   36              English  United States of America
# 2135          88    male   30              ENGLISH  United States of America
# 2160          89    male   45              English  United States of America
# 2177          90    male   33              English  United States of America
# 2210          91    male   35              English  United States of America
# 2235          92    male   30              English  United States of America
# 2252          93    male   31              English  United States of America
# 2285          94    male   25              English  United States of America
# 2302          95  female   27              English  United States of America
# 2343          96    male   49              english  United States of America
# 2376          97    male   29              English  United States of America
# 2393          98  female   26              English  United States of America
# 2426          99    male   23              English  United States of America
# 2443         100  female   37              English  United States of America
#
#                turkcode
# 0     R565304137610gxrw
# 17    R568037847200gxrw
# 34    R567007587810gxrw
# 51    R562293107890gxrw
# 68    R564425597290gxrw
# 85    R566015437170gxrw
# 110   R565225457430gxrw
# 135   R564891937510gxrw
# 160   R564914717360gxrw
# 209   R567462027230gxrw
# 226   R569839927200gxrw
# 259   R567382397420gxrw
# 276   R561692637360gxrw
# 293   R567209797420gxrw
# 318   R567431727960gxrw
# 335   R569778127550gxrw
# 360   R564283037450gxrw
# 377   R568424107440gxrw
# 394   R562717627310gxrw
# 411   R564385287730gxrw
# 436   R564927097300gxrw
# 453   R567072427720gxrw
# 470   R565616437700gxrw
# 487   R564974807240gxrw
# 504   R565102177690gxrw
# 529   R565390917210gxrw
# 546   R568788967700gxrw
# 563   R565796347770gxrw
# 588   R561817947540gxrw
# 637   R565951837980gxrw
# 662   R567280867770gxrw
# 679   R563892367170gxrw
# 704   R562080497850gxrw
# 737   R567189477500gxrw
# 770   R563103597710gxrw
# 819   R564453527100gxrw
# 836   R562013587380gxrw
# 861   R564488067420gxrw
# 878   R561288177410gxrw
# 903   R564771007790gxrw
# 920   R568381327180gxrw
# 945   R561679417780gxrw
# 962   R563690957290gxrw
# 987   R561290117100gxrw
# 1004  R564577597560gxrw
# 1021  R561773827670gxrw
# 1046  R562332347600gxrw
# 1071  R561288317930gxrw
# 1112  R569984007440gxrw
# 1145  R562140177340gxrw
# 1162  R565269147300gxrw
# 1187  R569663677410gxrw
# 1204  R567164037820gxrw
# 1229  R562549397410gxrw
# 1246  R565373437870gxrw
# 1279  R561206867210gxrw
# 1304  R564112577560gxrw
# 1321  R562367667790gxrw
# 1338  R565051477310gxrw
# 1363  R566806247670gxrw
# 1388  R565233047520gxrw
# 1437  R562605447570gxrw
# 1454  R568649397740gxrw
# 1471  R565892187370gxrw
# 1512  R567334787900gxrw
# 1561  R569209847320gxrw
# 1578  R562461907520gxrw
# 1595  R566212297330gxrw
# 1620  R561437747750gxrw
# 1637  R568923367480gxrw
# 1662  R567462487730gxrw
# 1687  R568523057460gxrw
# 1728  R561188127970gxrw
# 1753  R561745517200gxrw
# 1778  R565359417370gxrw
# 1803  R567969477950gxrw
# 1820  R567539147580gxrw
# 1845  R563957057110gxrw
# 1862  R561875557360gxrw
# 1895  R567911377750gxrw
# 1960  R566247267790gxrw
# 2009  R568907077360gxrw
# 2026  R561555167480gxrw
# 2051  R562670387250gxrw
# 2076  R561829147980gxrw
# 2093  R567427357190gxrw
# 2110  R565226487920gxrw
# 2135  R564241567170gxrw
# 2160  R567211767700gxrw
# 2177  R563398467940gxrw
# 2210  R563541877780gxrw
# 2235  R563317837530gxrw
# 2252  R562054327460gxrw
# 2285  R563852317500gxrw
# 2302  R565981247860gxrw
# 2343  R568353977340gxrw
# 2376  R562207107830gxrw
# 2393  R566849427520gxrw
# 2426  R565987507110gxrw
# 2443  R565986147390gxrw

# %%
data_demog['gender'].value_counts()
# Out:
# male      61
# female    39
# Name: gender, dtype: int64

# %%
data_demog['language'].value_counts()
# Out:
# English                76
# english                17
# ENGLISH                 2
# eng                     1
# English                 1
# English.                1
# English, Indonesian     1
# Russian, English        1
# Name: language, dtype: int64

# %%
data_demog[data_demog['gender'] == 'male']['age'].mean()
# Out:
# 36.65573770491803

# %% [markdown]
# #### Target stimuli only (instructions deleted)

# %%
data = data_clean[["subject_id","rt","stimulus","trial_type","sampling","nb_of_run","stim_type","rolled_OR_unrolled",
                   "A_branch_loc","A_detectors","state_OR_event","state_branch","root_1st","imdt_2nd","node_selected"]]
data = data[(data["stimulus"] != "instruction")&(data["stimulus"] != "comment")].drop(['trial_type'],axis=1)
data.reset_index(drop=True,inplace=True)

data
# Out:
#      subject_id          rt  stimulus sampling  nb_of_run stim_type  \
# 0             1   19950.760   UAAS_RT    Right        1.0  AND_Gate
# 1             1   14289.955   UABS_RB    Right        1.0  AND_Gate
# 2             1   12181.330   UBBS_RT    Right        2.0  AND_Gate
# 3             1   13457.560    UAS_RB    Right        1.0  AND_Gate
# 4             1   10690.350  chainS_R    Right        1.0    ChainS
# 5             1   12429.980    UBS_RB    Right        1.0  AND_Gate
# 6             1   10832.470   UBAS_RT    Right        2.0  AND_Gate
# 7             2   22205.620    UAS_LB     Left        1.0  AND_Gate
# 8             2   17773.830    UBS_LT     Left        1.0  AND_Gate
# 9             2   11323.835   UAAS_LB     Left        1.0  AND_Gate
# 10            2   10251.860   UBBS_LB     Left        1.0  AND_Gate
# 11            2   10636.100   UBAS_LT     Left        1.0  AND_Gate
# 12            2    8851.390  chainS_L     Left        1.0    ChainS
# 13            2   12453.805   UABS_LT     Left        1.0  AND_Gate
# 14            3   18117.000  chainS_R    Right        1.0    ChainS
# 15            3   28741.000   UBBS_RT    Right        1.0  AND_Gate
# 16            3   16028.000   UBAS_RB    Right        1.0  AND_Gate
# 17            3   14004.000    UAS_RB    Right        2.0  AND_Gate
# 18            3   16613.000    UBS_RB    Right        1.0  AND_Gate
# 19            3   14915.000   UABS_RB    Right        1.0  AND_Gate
# 20            3   14407.000   UAAS_RT    Right        1.0  AND_Gate
# 21            4   13172.380  chainS_L     Left        2.0    ChainS
# 22            4   12532.130   UAAS_LT     Left        2.0  AND_Gate
# 23            4   13785.460   UBAS_LT     Left        1.0  AND_Gate
# 24            4   23058.360    UAS_LT     Left        1.0  AND_Gate
# 25            4   21011.405   UABS_LB     Left        1.0  AND_Gate
# 26            4   22344.200   UBBS_LB     Left        2.0  AND_Gate
# 27            4   10957.365    UBS_LT     Left        1.0  AND_Gate
# 28            5   41070.930   UBAS_RT    Right        1.0  AND_Gate
# 29            5   12315.000    UAS_RT    Right        1.0  AND_Gate
# 30            5    8726.075  chainS_R    Right        1.0    ChainS
# 31            5   17614.945   UABS_RB    Right        1.0  AND_Gate
# 32            5   19886.620    UBS_RB    Right        1.0  AND_Gate
# 33            5   27907.325   UBBS_RT    Right        1.0  AND_Gate
# 34            5   10975.605   UAAS_RB    Right        1.0  AND_Gate
# 35            6   11361.475   UAAS_RT    Right        2.0  AND_Gate
# 36            6   11968.060   UABS_RT    Right        1.0  AND_Gate
# 37            6    9263.490   UBBS_RT    Right        1.0  AND_Gate
# 38            6   11788.795    UBS_RT    Right        1.0  AND_Gate
# 39            6    8505.340  chainS_R    Right        1.0    ChainS
# 40            6    9837.330   UBAS_RB    Right        1.0  AND_Gate
# 41            6   12747.790    UAS_RT    Right        1.0  AND_Gate
# 42            7   19507.570    UAS_LB     Left        1.0  AND_Gate
# 43            7   11984.040   UBBS_LB     Left        1.0  AND_Gate
# 44            7   12516.135   UBAS_LB     Left        1.0  AND_Gate
# 45            7   12404.190  chainS_L     Left        1.0    ChainS
# 46            7   11653.400    UBS_LB     Left        1.0  AND_Gate
# 47            7   16938.320   UABS_LB     Left        1.0  AND_Gate
# 48            7   13465.315   UAAS_LB     Left        1.0  AND_Gate
# 49            8   21732.420   UABS_LT     Left        1.0  AND_Gate
# 50            8   11055.775   UBBS_LT     Left        1.0  AND_Gate
# 51            8   14431.980   UAAS_LB     Left        1.0  AND_Gate
# 52            8   13427.315  chainS_L     Left        1.0    ChainS
# 53            8   13032.255    UAS_LT     Left        1.0  AND_Gate
# 54            8   11963.515   UBAS_LB     Left        1.0  AND_Gate
# 55            8   14734.590    UBS_LB     Left        1.0  AND_Gate
# 56            9   15379.935  chainS_R    Right        1.0    ChainS
# 57            9   16069.515    UAS_RB    Right        1.0  AND_Gate
# 58            9    9699.820   UBBS_RB    Right        1.0  AND_Gate
# 59            9   11413.830    UBS_RB    Right        1.0  AND_Gate
# 60            9   15111.910   UABS_RB    Right        1.0  AND_Gate
# 61            9   10563.785   UAAS_RB    Right        1.0  AND_Gate
# 62            9   10958.435   UBAS_RT    Right        1.0  AND_Gate
# 63           10   13241.275   UBBS_RB    Right        2.0  AND_Gate
# 64           10   11701.825    UAS_RT    Right        2.0  AND_Gate
# 65           10   14340.995   UABS_RB    Right        1.0  AND_Gate
# 66           10   12222.380   UBAS_RT    Right        1.0  AND_Gate
# 67           10   10356.090    UBS_RB    Right        1.0  AND_Gate
# 68           10    8439.875  chainS_R    Right        1.0    ChainS
# 69           10   11719.870   UAAS_RT    Right        1.0  AND_Gate
# 70           11   28754.565   UABS_RB    Right        1.0  AND_Gate
# 71           11   17309.895    UAS_RB    Right        1.0  AND_Gate
# 72           11   13038.965    UBS_RT    Right        1.0  AND_Gate
# 73           11   23010.930   UAAS_RB    Right        1.0  AND_Gate
# 74           11    9523.385  chainS_R    Right        1.0    ChainS
# 75           11   19661.030   UBBS_RT    Right        1.0  AND_Gate
# 76           11   13856.595   UBAS_RT    Right        1.0  AND_Gate
# 77           12   21210.365   UBBS_LB     Left        1.0  AND_Gate
# 78           12   12153.525   UBAS_LB     Left        1.0  AND_Gate
# 79           12   21244.985    UBS_LT     Left        1.0  AND_Gate
# 80           12   15506.660   UABS_LT     Left        1.0  AND_Gate
# 81           12   13474.685    UAS_LB     Left        1.0  AND_Gate
# 82           12   10375.785  chainS_L     Left        1.0    ChainS
# 83           12   11244.785   UAAS_LB     Left        1.0  AND_Gate
# 84           13   21004.165  chainS_R    Right        1.0    ChainS
# 85           13   24181.970    UAS_RT    Right        1.0  AND_Gate
# 86           13    9838.865   UBAS_RT    Right        1.0  AND_Gate
# 87           13   10435.350   UAAS_RB    Right        1.0  AND_Gate
# 88           13   12133.290   UABS_RT    Right        1.0  AND_Gate
# 89           13   11085.960   UBBS_RT    Right        1.0  AND_Gate
# 90           13   10477.610    UBS_RT    Right        1.0  AND_Gate
# 91           14   22433.035    UAS_LB     Left        1.0  AND_Gate
# 92           14   38436.445   UABS_LB     Left        1.0  AND_Gate
# 93           14   18817.610    UBS_LT     Left        1.0  AND_Gate
# 94           14   15478.465   UBBS_LB     Left        1.0  AND_Gate
# 95           14   10241.805  chainS_L     Left        1.0    ChainS
# 96           14   11861.680   UBAS_LT     Left        1.0  AND_Gate
# 97           14   11811.815   UAAS_LT     Left        1.0  AND_Gate
# 98           15   16247.810    UAS_LB     Left        1.0  AND_Gate
# 99           15   10988.320  chainS_L     Left        1.0    ChainS
# 100          15   15217.210   UABS_LT     Left        1.0  AND_Gate
# 101          15   10570.175   UBBS_LT     Left        1.0  AND_Gate
# 102          15   12031.615   UAAS_LB     Left        1.0  AND_Gate
# 103          15   10935.935    UBS_LT     Left        1.0  AND_Gate
# 104          15   12505.330   UBAS_LT     Left        1.0  AND_Gate
# 105          16   14677.000   UBBS_RT    Right        1.0  AND_Gate
# 106          16   11168.000    UBS_RT    Right        1.0  AND_Gate
# 107          16    8575.000  chainS_R    Right        1.0    ChainS
# 108          16   10834.000   UAAS_RT    Right        1.0  AND_Gate
# 109          16   12483.000   UABS_RB    Right        1.0  AND_Gate
# 110          16   10841.000    UAS_RB    Right        1.0  AND_Gate
# 111          16   10186.000   UBAS_RT    Right        1.0  AND_Gate
# 112          17   14582.345    UBS_LB     Left        1.0  AND_Gate
# 113          17   12354.535   UABS_LB     Left        1.0  AND_Gate
# 114          17   10113.090   UBAS_LB     Left        1.0  AND_Gate
# 115          17    8417.960  chainS_L     Left        1.0    ChainS
# 116          17    9154.895   UBBS_LB     Left        1.0  AND_Gate
# 117          17   10756.585    UAS_LB     Left        1.0  AND_Gate
# 118          17   10934.055   UAAS_LB     Left        1.0  AND_Gate
# 119          18   26118.000   UBBS_RT    Right        1.0  AND_Gate
# 120          18   17445.000   UABS_RB    Right        1.0  AND_Gate
# 121          18   15311.000    UAS_RT    Right        1.0  AND_Gate
# 122          18   12278.000    UBS_RT    Right        1.0  AND_Gate
# 123          18   12246.000   UBAS_RB    Right        1.0  AND_Gate
# 124          18   11566.000   UAAS_RT    Right        1.0  AND_Gate
# 125          18   12207.000  chainS_R    Right        1.0    ChainS
# 126          19   23480.135   UABS_RB    Right        1.0  AND_Gate
# 127          19   11806.375   UBBS_RT    Right        1.0  AND_Gate
# 128          19    8948.425  chainS_R    Right        1.0    ChainS
# 129          19   12432.885    UBS_RB    Right        1.0  AND_Gate
# 130          19   10567.320   UAAS_RB    Right        1.0  AND_Gate
# 131          19    9928.390   UBAS_RB    Right        1.0  AND_Gate
# 132          19   10718.350    UAS_RB    Right        1.0  AND_Gate
# 133          20   14437.210    UAS_RT    Right        1.0  AND_Gate
# 134          20   14926.820   UBAS_RB    Right        1.0  AND_Gate
# 135          20    9548.515   UBBS_RT    Right        1.0  AND_Gate
# 136          20   13354.655    UBS_RT    Right        1.0  AND_Gate
# 137          20   11844.040   UAAS_RT    Right        1.0  AND_Gate
# 138          20   12345.735   UABS_RB    Right        1.0  AND_Gate
# 139          20    8669.350  chainS_R    Right        1.0    ChainS
# 140          21   20471.245    UAS_LB     Left        1.0  AND_Gate
# 141          21   12158.710   UBAS_LB     Left        1.0  AND_Gate
# 142          21   10190.380  chainS_L     Left        1.0    ChainS
# 143          21   10302.555   UBBS_LB     Left        1.0  AND_Gate
# 144          21   14942.750   UABS_LB     Left        1.0  AND_Gate
# 145          21   11590.695    UBS_LT     Left        1.0  AND_Gate
# 146          21   12326.905   UAAS_LB     Left        1.0  AND_Gate
# 147          22   23526.000  chainS_R    Right        1.0    ChainS
# 148          22   17378.000    UBS_RT    Right        1.0  AND_Gate
# 149          22   12866.000   UABS_RB    Right        1.0  AND_Gate
# 150          22    9624.000   UBBS_RB    Right        1.0  AND_Gate
# 151          22   10867.000   UBAS_RT    Right        1.0  AND_Gate
# 152          22   11031.000    UAS_RB    Right        1.0  AND_Gate
# 153          22   12541.000   UAAS_RB    Right        1.0  AND_Gate
# 154          23   20741.985  chainS_R    Right        1.0    ChainS
# 155          23   14266.710   UBBS_RB    Right        1.0  AND_Gate
# 156          23   11722.275    UBS_RB    Right        1.0  AND_Gate
# 157          23   11965.000   UABS_RB    Right        1.0  AND_Gate
# 158          23   10859.815   UAAS_RT    Right        1.0  AND_Gate
# 159          23   12255.850    UAS_RB    Right        1.0  AND_Gate
# 160          23   12664.220   UBAS_RT    Right        1.0  AND_Gate
# 161          24   13667.005   UAAS_RT    Right        3.0  AND_Gate
# 162          24   14610.235   UBBS_RT    Right        3.0  AND_Gate
# 163          24    9046.895  chainS_R    Right        2.0    ChainS
# 164          24   11750.965    UBS_RB    Right        2.0  AND_Gate
# 165          24   12187.340   UABS_RT    Right        3.0  AND_Gate
# 166          24   10861.815   UBAS_RT    Right        2.0  AND_Gate
# 167          24   11792.185    UAS_RT    Right        1.0  AND_Gate
# 168          25   14461.690   UAAS_LB     Left        2.0  AND_Gate
# 169          25   13028.795   UBAS_LT     Left        1.0  AND_Gate
# 170          25   11037.710  chainS_L     Left        1.0    ChainS
# 171          25   14956.665    UAS_LB     Left        1.0  AND_Gate
# 172          25   10869.510   UBBS_LT     Left        1.0  AND_Gate
# 173          25   11253.645    UBS_LT     Left        1.0  AND_Gate
# 174          25   16485.190   UABS_LT     Left        1.0  AND_Gate
# 175          26   19880.000   UAAS_RB    Right        1.0  AND_Gate
# 176          26   16765.000   UBAS_RB    Right        1.0  AND_Gate
# 177          26   13049.000  chainS_R    Right        1.0    ChainS
# 178          26   11752.000   UBBS_RT    Right        2.0  AND_Gate
# 179          26   16383.000    UAS_RB    Right        1.0  AND_Gate
# 180          26   18569.000   UABS_RT    Right        1.0  AND_Gate
# 181          26   16011.000    UBS_RB    Right        1.0  AND_Gate
# 182          27   18795.620   UAAS_RB    Right        1.0  AND_Gate
# 183          27   17377.365   UABS_RT    Right        1.0  AND_Gate
# 184          27   14596.670   UBBS_RT    Right        1.0  AND_Gate
# 185          27   13488.885   UBAS_RB    Right        1.0  AND_Gate
# 186          27   12091.355  chainS_R    Right        1.0    ChainS
# 187          27   13552.450    UAS_RT    Right        1.0  AND_Gate
# 188          27   14157.080    UBS_RB    Right        1.0  AND_Gate
# 189          28   22666.320   UBBS_RT    Right        1.0  AND_Gate
# 190          28   13914.970   UABS_RT    Right        1.0  AND_Gate
# 191          28   17479.700   UAAS_RT    Right        1.0  AND_Gate
# 192          28    9980.405   UBAS_RT    Right        1.0  AND_Gate
# 193          28    9447.650  chainS_R    Right        1.0    ChainS
# 194          28   14280.070    UAS_RB    Right        1.0  AND_Gate
# 195          28   10486.945    UBS_RB    Right        1.0  AND_Gate
# 196          29   11011.860   UBAS_RB    Right        2.0  AND_Gate
# 197          29   13181.780    UAS_RT    Right        1.0  AND_Gate
# 198          29   12942.710   UBBS_RT    Right        1.0  AND_Gate
# 199          29    9806.295  chainS_R    Right        1.0    ChainS
# 200          29   15917.760   UABS_RB    Right        1.0  AND_Gate
# 201          29   14541.215   UAAS_RT    Right        1.0  AND_Gate
# 202          29   10599.165    UBS_RB    Right        1.0  AND_Gate
# 203          30   26005.000    UAS_LT     Left        1.0  AND_Gate
# 204          30   12320.000   UBAS_LB     Left        1.0  AND_Gate
# 205          30   14335.000   UBBS_LB     Left        1.0  AND_Gate
# 206          30   11662.000  chainS_L     Left        1.0    ChainS
# 207          30   14377.000   UABS_LB     Left        1.0  AND_Gate
# 208          30   14205.000    UBS_LB     Left        1.0  AND_Gate
# 209          30   11931.000   UAAS_LT     Left        1.0  AND_Gate
# 210          31   16534.890    UBS_RT    Right        1.0  AND_Gate
# 211          31   16067.050   UBBS_RT    Right        2.0  AND_Gate
# 212          31   12391.060   UBAS_RT    Right        1.0  AND_Gate
# 213          31   13449.050   UABS_RT    Right        1.0  AND_Gate
# 214          31   19400.325  chainS_R    Right        1.0    ChainS
# 215          31   10948.495    UAS_RT    Right        1.0  AND_Gate
# 216          31   12086.075   UAAS_RT    Right        1.0  AND_Gate
# 217          32   16555.635    UBS_LT     Left        1.0  AND_Gate
# 218          32   12277.025    UAS_LT     Left        1.0  AND_Gate
# 219          32   13492.825   UAAS_LB     Left        1.0  AND_Gate
# 220          32   10508.965   UBBS_LB     Left        1.0  AND_Gate
# 221          32    8452.700  chainS_L     Left        1.0    ChainS
# 222          32   12763.710   UBAS_LT     Left        1.0  AND_Gate
# 223          32   13260.650   UABS_LB     Left        1.0  AND_Gate
# 224          33   17933.975  chainS_L     Left        1.0    ChainS
# 225          33   22188.220   UABS_LB     Left        1.0  AND_Gate
# 226          33   13182.705   UAAS_LT     Left        1.0  AND_Gate
# 227          33   12533.650    UAS_LT     Left        1.0  AND_Gate
# 228          33   13430.080    UBS_LB     Left        1.0  AND_Gate
# 229          33   11004.235   UBBS_LB     Left        1.0  AND_Gate
# 230          33   12245.585   UBAS_LT     Left        1.0  AND_Gate
# 231          34   24340.370   UABS_RT    Right        1.0  AND_Gate
# 232          34   16157.695  chainS_R    Right        1.0    ChainS
# 233          34   12126.135   UAAS_RT    Right        2.0  AND_Gate
# 234          34   10133.325   UBAS_RT    Right        1.0  AND_Gate
# 235          34    9278.490   UBBS_RT    Right        1.0  AND_Gate
# 236          34   10709.500    UBS_RB    Right        1.0  AND_Gate
# 237          34   11757.560    UAS_RT    Right        1.0  AND_Gate
# 238          35   21245.135   UAAS_LT     Left        1.0  AND_Gate
# 239          35   18445.145   UABS_LB     Left        1.0  AND_Gate
# 240          35  106172.425    UBS_LT     Left        1.0  AND_Gate
# 241          35   14035.540  chainS_L     Left        1.0    ChainS
# 242          35   94973.215    UAS_LT     Left        1.0  AND_Gate
# 243          35   11233.545   UBAS_LT     Left        1.0  AND_Gate
# 244          35    9793.225   UBBS_LT     Left        1.0  AND_Gate
# 245          36   27387.850   UABS_RB    Right        2.0  AND_Gate
# 246          36   14728.015   UAAS_RB    Right        2.0  AND_Gate
# 247          36   12853.400   UBBS_RB    Right        1.0  AND_Gate
# 248          36   11413.510   UBAS_RT    Right        2.0  AND_Gate
# 249          36   10812.065    UBS_RB    Right        1.0  AND_Gate
# 250          36   19369.625    UAS_RB    Right        1.0  AND_Gate
# 251          36    9775.965  chainS_R    Right        1.0    ChainS
# 252          37   33330.035    UAS_LT     Left        2.0  AND_Gate
# 253          37   14766.390   UABS_LB     Left        1.0  AND_Gate
# 254          37   10775.345    UBS_LB     Left        1.0  AND_Gate
# 255          37   14949.535  chainS_L     Left        1.0    ChainS
# 256          37   10913.655   UBAS_LT     Left        1.0  AND_Gate
# 257          37   11559.845   UAAS_LT     Left        1.0  AND_Gate
# 258          37   13434.935   UBBS_LT     Left        1.0  AND_Gate
# 259          38   30562.820    UAS_LT     Left        1.0  AND_Gate
# 260          38   15195.440  chainS_L     Left        1.0    ChainS
# 261          38   16641.300   UABS_LT     Left        1.0  AND_Gate
# 262          38   11179.180   UBBS_LB     Left        2.0  AND_Gate
# 263          38   12340.870    UBS_LT     Left        1.0  AND_Gate
# 264          38   12045.475   UAAS_LT     Left        1.0  AND_Gate
# 265          38   10294.660   UBAS_LT     Left        1.0  AND_Gate
# 266          39   18165.290   UBBS_LT     Left        2.0  AND_Gate
# 267          39   14608.080   UBAS_LT     Left        1.0  AND_Gate
# 268          39   13219.300   UABS_LB     Left        2.0  AND_Gate
# 269          39   13175.905    UAS_LB     Left        1.0  AND_Gate
# 270          39   17793.320   UAAS_LT     Left        1.0  AND_Gate
# 271          39   10895.185    UBS_LT     Left        1.0  AND_Gate
# 272          39   14397.480  chainS_L     Left        1.0    ChainS
# 273          40   18892.440   UAAS_LB     Left        2.0  AND_Gate
# 274          40   13509.825    UAS_LB     Left        1.0  AND_Gate
# 275          40    9042.515  chainS_L     Left        1.0    ChainS
# 276          40   11145.735   UBAS_LT     Left        1.0  AND_Gate
# 277          40   12789.425   UBBS_LT     Left        1.0  AND_Gate
# 278          40   12743.410   UABS_LB     Left        1.0  AND_Gate
# 279          40   12999.710    UBS_LB     Left        1.0  AND_Gate
# 280          41   15420.255  chainS_R    Right        2.0    ChainS
# 281          41   11237.245    UBS_RB    Right        2.0  AND_Gate
# 282          41   23113.845    UAS_RB    Right        1.0  AND_Gate
# 283          41   11300.110   UBBS_RB    Right        1.0  AND_Gate
# 284          41   13034.285   UAAS_RT    Right        1.0  AND_Gate
# 285          41   16959.095   UABS_RT    Right        1.0  AND_Gate
# 286          41   15281.695   UBAS_RT    Right        1.0  AND_Gate
# 287          42   29853.260    UBS_LT     Left        1.0  AND_Gate
# 288          42   16901.250   UABS_LB     Left        1.0  AND_Gate
# 289          42   15757.265   UBAS_LT     Left        1.0  AND_Gate
# 290          42   14213.085   UAAS_LB     Left        1.0  AND_Gate
# 291          42   12684.320   UBBS_LT     Left        1.0  AND_Gate
# 292          42   12540.640    UAS_LT     Left        1.0  AND_Gate
# 293          42   15876.585  chainS_L     Left        1.0    ChainS
# 294          43   13761.455   UBBS_RB    Right        2.0  AND_Gate
# 295          43   10675.925  chainS_R    Right        1.0    ChainS
# 296          43   12441.335   UABS_RB    Right        1.0  AND_Gate
# 297          43   11273.890   UAAS_RT    Right        1.0  AND_Gate
# 298          43   11257.595   UBAS_RB    Right        2.0  AND_Gate
# 299          43   12057.800    UAS_RB    Right        1.0  AND_Gate
# 300          43   12718.235    UBS_RB    Right        1.0  AND_Gate
# 301          44   18810.125    UBS_RT    Right        1.0  AND_Gate
# 302          44   22030.350   UBAS_RB    Right        1.0  AND_Gate
# 303          44   10941.360   UAAS_RB    Right        1.0  AND_Gate
# 304          44    8686.675  chainS_R    Right        1.0    ChainS
# 305          44   12232.355   UBBS_RB    Right        1.0  AND_Gate
# 306          44   10774.850    UAS_RB    Right        1.0  AND_Gate
# 307          44   20700.965   UABS_RT    Right        1.0  AND_Gate
# 308          45   29756.580    UBS_LB     Left        1.0  AND_Gate
# 309          45   14540.105    UAS_LT     Left        1.0  AND_Gate
# 310          45   12339.435  chainS_L     Left        1.0    ChainS
# 311          45   13939.670   UABS_LT     Left        1.0  AND_Gate
# 312          45   11764.515   UAAS_LB     Left        1.0  AND_Gate
# 313          45   11283.045   UBAS_LB     Left        1.0  AND_Gate
# 314          45   12650.755   UBBS_LT     Left        1.0  AND_Gate
# 315          46   21948.000    UBS_RB    Right        1.0  AND_Gate
# 316          46   12019.000    UAS_RB    Right        1.0  AND_Gate
# 317          46   10621.000   UBBS_RT    Right        1.0  AND_Gate
# 318          46   13527.000   UABS_RT    Right        1.0  AND_Gate
# 319          46   13496.000  chainS_R    Right        1.0    ChainS
# 320          46   11408.000   UAAS_RB    Right        1.0  AND_Gate
# 321          46   13800.000   UBAS_RT    Right        1.0  AND_Gate
# 322          47   24562.655   UBBS_RB    Right        2.0  AND_Gate
# 323          47   14786.315   UAAS_RT    Right        1.0  AND_Gate
# 324          47   13386.670    UBS_RT    Right        1.0  AND_Gate
# 325          47   12435.215  chainS_R    Right        1.0    ChainS
# 326          47   13529.305   UBAS_RB    Right        1.0  AND_Gate
# 327          47   13927.600   UABS_RB    Right        1.0  AND_Gate
# 328          47   14643.425    UAS_RT    Right        1.0  AND_Gate
# 329          48   12148.280   UAAS_RT    Right        2.0  AND_Gate
# 330          48   13643.355   UABS_RT    Right        1.0  AND_Gate
# 331          48   51449.225    UBS_RT    Right        1.0  AND_Gate
# 332          48   16372.185    UAS_RB    Right        1.0  AND_Gate
# 333          48   11027.135   UBAS_RB    Right        1.0  AND_Gate
# 334          48   22567.960   UBBS_RB    Right        1.0  AND_Gate
# 335          48   16580.185  chainS_R    Right        1.0    ChainS
# 336          49   10002.000   UBBS_RB    Right        2.0  AND_Gate
# 337          49   11252.000    UAS_RB    Right        1.0  AND_Gate
# 338          49   13798.000   UBAS_RT    Right        1.0  AND_Gate
# 339          49   12021.000   UABS_RB    Right        1.0  AND_Gate
# 340          49   14024.000   UAAS_RT    Right        1.0  AND_Gate
# 341          49   18811.000  chainS_R    Right        1.0    ChainS
# 342          49   24418.000    UBS_RT    Right        1.0  AND_Gate
# 343          50   23831.000   UBBS_LB     Left        1.0  AND_Gate
# 344          50   14216.000   UABS_LT     Left        1.0  AND_Gate
# 345          50   11216.000    UAS_LB     Left        1.0  AND_Gate
# 346          50   12191.000    UBS_LT     Left        1.0  AND_Gate
# 347          50   11080.000   UAAS_LB     Left        1.0  AND_Gate
# 348          50    9362.000  chainS_L     Left        1.0    ChainS
# 349          50   10564.000   UBAS_LB     Left        1.0  AND_Gate
# 350          51   20482.055    UBS_LT     Left        1.0  AND_Gate
# 351          51   25669.300   UABS_LT     Left        1.0  AND_Gate
# 352          51   14195.450   UAAS_LB     Left        1.0  AND_Gate
# 353          51   12035.990    UAS_LB     Left        1.0  AND_Gate
# 354          51   11260.415   UBBS_LB     Left        1.0  AND_Gate
# 355          51   14400.270  chainS_L     Left        1.0    ChainS
# 356          51   10434.225   UBAS_LT     Left        1.0  AND_Gate
# 357          52   34286.000   UBAS_RB    Right        1.0  AND_Gate
# 358          52   39882.000  chainS_R    Right        1.0    ChainS
# 359          52   15558.000   UABS_RT    Right        1.0  AND_Gate
# 360          52   19101.000    UAS_RT    Right        2.0  AND_Gate
# 361          52   13621.000    UBS_RB    Right        2.0  AND_Gate
# 362          52   15671.000   UBBS_RT    Right        1.0  AND_Gate
# 363          52   18186.000   UAAS_RT    Right        1.0  AND_Gate
# 364          53   12399.005  chainS_R    Right        1.0    ChainS
# 365          53   11622.715    UAS_RT    Right        1.0  AND_Gate
# 366          53   11994.515   UBAS_RT    Right        1.0  AND_Gate
# 367          53   11164.135   UAAS_RB    Right        1.0  AND_Gate
# 368          53   10854.780    UBS_RB    Right        1.0  AND_Gate
# 369          53   14282.885   UABS_RT    Right        1.0  AND_Gate
# 370          53    9006.945   UBBS_RB    Right        1.0  AND_Gate
# 371          54   16227.570   UBBS_LB     Left        1.0  AND_Gate
# 372          54   11012.300   UBAS_LB     Left        1.0  AND_Gate
# 373          54   13812.695   UAAS_LB     Left        1.0  AND_Gate
# 374          54   12248.275    UBS_LB     Left        1.0  AND_Gate
# 375          54   12792.425    UAS_LT     Left        1.0  AND_Gate
# 376          54    9426.640  chainS_L     Left        1.0    ChainS
# 377          54   13475.745   UABS_LB     Left        1.0  AND_Gate
# 378          55   12947.880   UAAS_RB    Right        2.0  AND_Gate
# 379          55   11129.845    UBS_RB    Right        1.0  AND_Gate
# 380          55   13496.280  chainS_R    Right        1.0    ChainS
# 381          55   11578.335    UAS_RB    Right        1.0  AND_Gate
# 382          55   11795.685   UABS_RB    Right        1.0  AND_Gate
# 383          55   11329.165   UBAS_RT    Right        1.0  AND_Gate
# 384          55   11775.040   UBBS_RT    Right        1.0  AND_Gate
# 385          56   42417.000  chainS_L     Left        1.0    ChainS
# 386          56   24208.000   UBAS_LT     Left        1.0  AND_Gate
# 387          56   16259.000    UBS_LT     Left        1.0  AND_Gate
# 388          56   33146.000   UAAS_LT     Left        2.0  AND_Gate
# 389          56   16454.000   UBBS_LB     Left        2.0  AND_Gate
# 390          56   16354.000   UABS_LB     Left        3.0  AND_Gate
# 391          56   17540.000    UAS_LT     Left        2.0  AND_Gate
# 392          57   19111.915    UAS_LB     Left        1.0  AND_Gate
# 393          57    9980.080   UBAS_LB     Left        1.0  AND_Gate
# 394          57   11885.220   UBBS_LT     Left        1.0  AND_Gate
# 395          57    9820.690    UBS_LB     Left        1.0  AND_Gate
# 396          57   11749.015   UABS_LT     Left        1.0  AND_Gate
# 397          57    8203.025  chainS_L     Left        1.0    ChainS
# 398          57   10793.975   UAAS_LB     Left        1.0  AND_Gate
# 399          58   17617.870    UAS_LT     Left        1.0  AND_Gate
# 400          58    8678.645  chainS_L     Left        1.0    ChainS
# 401          58   13491.475   UBBS_LB     Left        1.0  AND_Gate
# 402          58   12763.615   UABS_LT     Left        1.0  AND_Gate
# 403          58   11623.965   UAAS_LB     Left        1.0  AND_Gate
# 404          58   10873.580    UBS_LT     Left        1.0  AND_Gate
# 405          58   11183.515   UBAS_LB     Left        1.0  AND_Gate
# 406          59   17656.000    UAS_LT     Left        1.0  AND_Gate
# 407          59   18329.000   UABS_LT     Left        1.0  AND_Gate
# 408          59   10306.000   UBAS_LB     Left        1.0  AND_Gate
# 409          59   10686.000    UBS_LT     Left        1.0  AND_Gate
# 410          59    9793.000   UBBS_LB     Left        1.0  AND_Gate
# 411          59   10590.000  chainS_L     Left        1.0    ChainS
# 412          59   17686.000   UAAS_LB     Left        1.0  AND_Gate
# 413          60   14479.585    UBS_RT    Right        2.0  AND_Gate
# 414          60   11886.030  chainS_R    Right        1.0    ChainS
# 415          60   13539.340   UAAS_RB    Right        1.0  AND_Gate
# 416          60   10739.965   UBBS_RT    Right        1.0  AND_Gate
# 417          60   13640.945   UABS_RB    Right        1.0  AND_Gate
# 418          60   11481.315    UAS_RT    Right        1.0  AND_Gate
# 419          60   21249.345   UBAS_RB    Right        1.0  AND_Gate
# 420          61   24670.635   UAAS_RT    Right        1.0  AND_Gate
# 421          61   15261.490   UABS_RT    Right        1.0  AND_Gate
# 422          61   16149.550   UBAS_RT    Right        1.0  AND_Gate
# 423          61   14232.335    UBS_RT    Right        1.0  AND_Gate
# 424          61   10200.500   UBBS_RT    Right        1.0  AND_Gate
# 425          61   13230.965    UAS_RB    Right        1.0  AND_Gate
# 426          61   27544.140  chainS_R    Right        1.0    ChainS
# 427          62   14747.755    UAS_LT     Left        1.0  AND_Gate
# 428          62   12366.265    UBS_LT     Left        1.0  AND_Gate
# 429          62   11149.550   UBAS_LT     Left        1.0  AND_Gate
# 430          62   10101.310  chainS_L     Left        1.0    ChainS
# 431          62   11861.760   UAAS_LT     Left        1.0  AND_Gate
# 432          62   12710.695   UABS_LT     Left        1.0  AND_Gate
# 433          62   11581.950   UBBS_LT     Left        1.0  AND_Gate
# 434          63   17833.050  chainS_R    Right        1.0    ChainS
# 435          63   16639.570    UAS_RB    Right        1.0  AND_Gate
# 436          63   11591.485    UBS_RT    Right        1.0  AND_Gate
# 437          63   11532.070   UBAS_RT    Right        1.0  AND_Gate
# 438          63   11261.290   UBBS_RT    Right        1.0  AND_Gate
# 439          63   12722.580   UABS_RB    Right        1.0  AND_Gate
# 440          63   15680.215   UAAS_RB    Right        1.0  AND_Gate
# 441          64   40894.360   UABS_RB    Right        1.0  AND_Gate
# 442          64   13117.000   UBBS_RT    Right        1.0  AND_Gate
# 443          64   14465.845   UAAS_RB    Right        1.0  AND_Gate
# 444          64   13328.700  chainS_R    Right        1.0    ChainS
# 445          64   13345.145    UAS_RT    Right        1.0  AND_Gate
# 446          64   12333.730   UBAS_RB    Right        1.0  AND_Gate
# 447          64   11727.240    UBS_RB    Right        2.0  AND_Gate
# 448          65   22904.795    UBS_RB    Right        1.0  AND_Gate
# 449          65   11703.225   UBAS_RT    Right        1.0  AND_Gate
# 450          65   13566.475   UAAS_RB    Right        1.0  AND_Gate
# 451          65   12581.915   UABS_RB    Right        1.0  AND_Gate
# 452          65    8326.835  chainS_R    Right        1.0    ChainS
# 453          65    8944.405   UBBS_RB    Right        1.0  AND_Gate
# 454          65   10350.340    UAS_RT    Right        1.0  AND_Gate
# 455          66   16896.745   UABS_RB    Right        1.0  AND_Gate
# 456          66   12877.105    UBS_RB    Right        1.0  AND_Gate
# 457          66    9585.970  chainS_R    Right        1.0    ChainS
# 458          66   10628.785   UBBS_RT    Right        1.0  AND_Gate
# 459          66   10656.110   UBAS_RT    Right        1.0  AND_Gate
# 460          66   11851.830    UAS_RT    Right        1.0  AND_Gate
# 461          66   11947.155   UAAS_RB    Right        1.0  AND_Gate
# 462          67   13586.940   UABS_RT    Right        1.0  AND_Gate
# 463          67   16596.125   UAAS_RB    Right        1.0  AND_Gate
# 464          67    9905.560   UBAS_RB    Right        1.0  AND_Gate
# 465          67    8970.465   UBBS_RT    Right        1.0  AND_Gate
# 466          67   11214.390    UBS_RB    Right        1.0  AND_Gate
# 467          67   10420.010    UAS_RT    Right        1.0  AND_Gate
# 468          67    8073.260  chainS_R    Right        1.0    ChainS
# 469          68   23340.725  chainS_L     Left        1.0    ChainS
# 470          68   18636.825   UABS_LT     Left        1.0  AND_Gate
# 471          68   11240.510    UAS_LB     Left        1.0  AND_Gate
# 472          68   11742.515   UAAS_LB     Left        1.0  AND_Gate
# 473          68   10647.005    UBS_LT     Left        1.0  AND_Gate
# 474          68   10339.650   UBBS_LB     Left        1.0  AND_Gate
# 475          68   10701.880   UBAS_LT     Left        1.0  AND_Gate
# 476          69   24982.715    UAS_LB     Left        1.0  AND_Gate
# 477          69   12116.310  chainS_L     Left        1.0    ChainS
# 478          69   13869.360   UBBS_LB     Left        2.0  AND_Gate
# 479          69   13904.500   UABS_LB     Left        1.0  AND_Gate
# 480          69   12315.090   UAAS_LT     Left        1.0  AND_Gate
# 481          69   11265.140   UBAS_LT     Left        1.0  AND_Gate
# 482          69   12530.965    UBS_LT     Left        1.0  AND_Gate
# 483          70   20477.890   UABS_RT    Right        1.0  AND_Gate
# 484          70   23757.555   UBAS_RT    Right        1.0  AND_Gate
# 485          70   12998.270  chainS_R    Right        1.0    ChainS
# 486          70   10469.945    UBS_RT    Right        1.0  AND_Gate
# 487          70   13197.520   UBBS_RB    Right        1.0  AND_Gate
# 488          70   11485.275   UAAS_RB    Right        1.0  AND_Gate
# 489          70   11942.815    UAS_RB    Right        1.0  AND_Gate
# 490          71   20520.715    UAS_LT     Left        1.0  AND_Gate
# 491          71   12761.795   UAAS_LT     Left        1.0  AND_Gate
# 492          71   11634.580   UBAS_LB     Left        1.0  AND_Gate
# 493          71    9332.235   UBBS_LT     Left        1.0  AND_Gate
# 494          71   10204.415    UBS_LB     Left        1.0  AND_Gate
# 495          71    8856.505  chainS_L     Left        1.0    ChainS
# 496          71   12005.870   UABS_LT     Left        1.0  AND_Gate
# 497          72   25567.510   UABS_LT     Left        1.0  AND_Gate
# 498          72   17385.215    UBS_LB     Left        1.0  AND_Gate
# 499          72   14570.985   UAAS_LT     Left        1.0  AND_Gate
# 500          72    9244.755  chainS_L     Left        1.0    ChainS
# 501          72   13042.785    UAS_LB     Left        1.0  AND_Gate
# 502          72   11297.000   UBBS_LT     Left        3.0  AND_Gate
# 503          72   12442.250   UBAS_LT     Left        1.0  AND_Gate
# 504          73   13785.985    UBS_RB    Right        2.0  AND_Gate
# 505          73   11370.620   UBAS_RT    Right        1.0  AND_Gate
# 506          73   10509.000    UAS_RB    Right        1.0  AND_Gate
# 507          73   12002.955   UABS_RT    Right        1.0  AND_Gate
# 508          73   18796.160  chainS_R    Right        1.0    ChainS
# 509          73   10372.270   UAAS_RB    Right        1.0  AND_Gate
# 510          73   12000.320   UBBS_RT    Right        1.0  AND_Gate
# 511          74   47335.600   UABS_LB     Left        1.0  AND_Gate
# 512          74   19678.000  chainS_L     Left        1.0    ChainS
# 513          74   11300.100   UBAS_LB     Left        2.0  AND_Gate
# 514          74   16601.900   UAAS_LB     Left        1.0  AND_Gate
# 515          74   16742.000    UAS_LB     Left        1.0  AND_Gate
# 516          74   13503.500   UBBS_LB     Left        1.0  AND_Gate
# 517          74   13019.200    UBS_LT     Left        1.0  AND_Gate
# 518          75   23720.825   UBAS_LB     Left        1.0  AND_Gate
# 519          75   11304.425   UAAS_LB     Left        1.0  AND_Gate
# 520          75   11208.770    UAS_LB     Left        1.0  AND_Gate
# 521          75   11839.455  chainS_L     Left        1.0    ChainS
# 522          75   11169.740    UBS_LB     Left        1.0  AND_Gate
# 523          75   12496.815   UABS_LB     Left        2.0  AND_Gate
# 524          75   10897.125   UBBS_LT     Left        1.0  AND_Gate
# 525          76   16135.000   UBAS_LB     Left        1.0  AND_Gate
# 526          76    8776.000  chainS_L     Left        1.0    ChainS
# 527          76   13290.000   UBBS_LT     Left        1.0  AND_Gate
# 528          76   10982.000   UAAS_LB     Left        1.0  AND_Gate
# 529          76   11278.000    UAS_LT     Left        1.0  AND_Gate
# 530          76   12362.000   UABS_LT     Left        1.0  AND_Gate
# 531          76   10628.000    UBS_LB     Left        1.0  AND_Gate
# 532          77   22198.000   UABS_RB    Right        1.0  AND_Gate
# 533          77   10715.000  chainS_R    Right        1.0    ChainS
# 534          77   10958.000    UAS_RT    Right        1.0  AND_Gate
# 535          77   10846.000   UAAS_RB    Right        1.0  AND_Gate
# 536          77    9063.000   UBBS_RT    Right        1.0  AND_Gate
# 537          77   10021.000   UBAS_RB    Right        1.0  AND_Gate
# 538          77   11857.000    UBS_RT    Right        1.0  AND_Gate
# 539          78   21297.020    UAS_LB     Left        1.0  AND_Gate
# 540          78   11295.705   UAAS_LB     Left        1.0  AND_Gate
# 541          78   13679.605   UBAS_LT     Left        1.0  AND_Gate
# 542          78    8951.025  chainS_L     Left        1.0    ChainS
# 543          78   13071.885   UABS_LB     Left        1.0  AND_Gate
# 544          78   10039.625   UBBS_LT     Left        1.0  AND_Gate
# 545          78   13407.115    UBS_LT     Left        1.0  AND_Gate
# 546          79  118256.700  chainS_R    Right        1.0    ChainS
# 547          79   19880.575    UBS_RB    Right        1.0  AND_Gate
# 548          79   15736.940   UBBS_RB    Right        1.0  AND_Gate
# 549          79   14537.140    UAS_RB    Right        1.0  AND_Gate
# 550          79   13121.515   UBAS_RT    Right        1.0  AND_Gate
# 551          79   14252.625   UABS_RT    Right        1.0  AND_Gate
# 552          79   16040.195   UAAS_RT    Right        1.0  AND_Gate
# 553          80   26346.360   UBAS_LT     Left        2.0  AND_Gate
# 554          80   10989.110    UBS_LB     Left        1.0  AND_Gate
# 555          80   13569.595   UAAS_LB     Left        1.0  AND_Gate
# 556          80    8892.990  chainS_L     Left        1.0    ChainS
# 557          80   11805.215   UBBS_LB     Left        1.0  AND_Gate
# 558          80   14035.695    UAS_LB     Left        1.0  AND_Gate
# 559          80   12388.000   UABS_LB     Left        1.0  AND_Gate
# 560          81   14548.000   UBAS_RT    Right        3.0  AND_Gate
# 561          81   13784.000  chainS_R    Right        1.0    ChainS
# 562          81   12907.000   UABS_RT    Right        1.0  AND_Gate
# 563          81   11486.000   UAAS_RT    Right        2.0  AND_Gate
# 564          81   12361.000    UBS_RT    Right        1.0  AND_Gate
# 565          81   12593.000    UAS_RB    Right        2.0  AND_Gate
# 566          81   10185.000   UBBS_RT    Right        1.0  AND_Gate
# 567          82   23773.635    UAS_LB     Left        1.0  AND_Gate
# 568          82   24768.160   UABS_LT     Left        1.0  AND_Gate
# 569          82   11166.450   UBAS_LB     Left        1.0  AND_Gate
# 570          82   12514.810  chainS_L     Left        1.0    ChainS
# 571          82   11942.915    UBS_LT     Left        1.0  AND_Gate
# 572          82   10791.035   UBBS_LB     Left        2.0  AND_Gate
# 573          82   13145.325   UAAS_LT     Left        1.0  AND_Gate
# 574          83   17426.000    UAS_RB    Right        2.0  AND_Gate
# 575          83   23166.000   UBBS_RT    Right        1.0  AND_Gate
# 576          83   21392.000   UAAS_RT    Right        1.0  AND_Gate
# 577          83   15936.000  chainS_R    Right        1.0    ChainS
# 578          83   65716.000    UBS_RT    Right        1.0  AND_Gate
# 579          83   13796.000   UBAS_RT    Right        1.0  AND_Gate
# 580          83   13937.000   UABS_RT    Right        1.0  AND_Gate
# 581          84   14772.000  chainS_R    Right        1.0    ChainS
# 582          84   14788.000   UBAS_RB    Right        1.0  AND_Gate
# 583          84   12909.000   UABS_RB    Right        1.0  AND_Gate
# 584          84   11180.000    UAS_RT    Right        1.0  AND_Gate
# 585          84    8956.000   UBBS_RT    Right        2.0  AND_Gate
# 586          84   10133.000    UBS_RB    Right        1.0  AND_Gate
# 587          84   10798.000   UAAS_RT    Right        1.0  AND_Gate
# 588          85   10096.000   UBBS_LT     Left        3.0  AND_Gate
# 589          85   11346.000    UAS_LB     Left        1.0  AND_Gate
# 590          85    9409.000  chainS_L     Left        1.0    ChainS
# 591          85   10523.000   UBAS_LB     Left        1.0  AND_Gate
# 592          85   14659.000   UABS_LB     Left        1.0  AND_Gate
# 593          85   13721.000   UAAS_LT     Left        1.0  AND_Gate
# 594          85   20816.000    UBS_LB     Left        1.0  AND_Gate
# 595          86   21476.395   UABS_LT     Left        1.0  AND_Gate
# 596          86   14320.570  chainS_L     Left        1.0    ChainS
# 597          86   12910.630    UBS_LT     Left        1.0  AND_Gate
# 598          86   12936.615   UBBS_LT     Left        1.0  AND_Gate
# 599          86   13478.210   UAAS_LB     Left        1.0  AND_Gate
# 600          86   19487.780   UBAS_LT     Left        1.0  AND_Gate
# 601          86   14118.535    UAS_LT     Left        1.0  AND_Gate
# 602          87   24657.270    UAS_LT     Left        1.0  AND_Gate
# 603          87   10456.195   UBBS_LT     Left        1.0  AND_Gate
# 604          87   11378.360    UBS_LT     Left        1.0  AND_Gate
# 605          87   11166.215   UBAS_LB     Left        1.0  AND_Gate
# 606          87   11496.060   UAAS_LB     Left        1.0  AND_Gate
# 607          87   12192.995   UABS_LB     Left        1.0  AND_Gate
# 608          87    8983.545  chainS_L     Left        1.0    ChainS
# 609          88   23172.000   UBAS_LT     Left        1.0  AND_Gate
# 610          88   12474.000    UAS_LT     Left        1.0  AND_Gate
# 611          88   14640.000   UAAS_LB     Left        1.0  AND_Gate
# 612          88   13303.000   UBBS_LT     Left        1.0  AND_Gate
# 613          88   17156.000    UBS_LT     Left        1.0  AND_Gate
# 614          88   11751.000  chainS_L     Left        1.0    ChainS
# 615          88   12108.000   UABS_LT     Left        1.0  AND_Gate
# 616          89   21105.055   UABS_RT    Right        1.0  AND_Gate
# 617          89   14921.525   UBAS_RT    Right        1.0  AND_Gate
# 618          89   11589.980    UBS_RT    Right        1.0  AND_Gate
# 619          89   13452.555    UAS_RB    Right        1.0  AND_Gate
# 620          89   11363.230   UBBS_RT    Right        1.0  AND_Gate
# 621          89   11133.860  chainS_R    Right        1.0    ChainS
# 622          89   11124.610   UAAS_RT    Right        2.0  AND_Gate
# 623          90   19292.515   UBAS_LT     Left        1.0  AND_Gate
# 624          90   14525.820   UABS_LT     Left        1.0  AND_Gate
# 625          90   10045.635  chainS_L     Left        1.0    ChainS
# 626          90   16055.420   UAAS_LB     Left        2.0  AND_Gate
# 627          90   10650.085    UBS_LB     Left        1.0  AND_Gate
# 628          90   11021.075   UBBS_LB     Left        1.0  AND_Gate
# 629          90   10739.580    UAS_LT     Left        1.0  AND_Gate
# 630          91   18596.765   UAAS_RB    Right        2.0  AND_Gate
# 631          91   13421.270    UBS_RB    Right        1.0  AND_Gate
# 632          91   12205.490   UBAS_RT    Right        1.0  AND_Gate
# 633          91   24412.730    UAS_RB    Right        1.0  AND_Gate
# 634          91   12197.460   UABS_RB    Right        1.0  AND_Gate
# 635          91   16021.340   UBBS_RT    Right        1.0  AND_Gate
# 636          91   10157.510  chainS_R    Right        1.0    ChainS
# 637          92   12200.785   UAAS_RB    Right        2.0  AND_Gate
# 638          92   25983.085    UBS_RT    Right        1.0  AND_Gate
# 639          92    9137.635  chainS_R    Right        1.0    ChainS
# 640          92   10204.605   UBBS_RB    Right        1.0  AND_Gate
# 641          92   10524.900    UAS_RT    Right        1.0  AND_Gate
# 642          92   10191.225   UBAS_RT    Right        1.0  AND_Gate
# 643          92   11859.205   UABS_RB    Right        1.0  AND_Gate
# 644          93   24745.715   UABS_RB    Right        1.0  AND_Gate
# 645          93   15546.655    UBS_RB    Right        1.0  AND_Gate
# 646          93   18094.965   UBBS_RT    Right        2.0  AND_Gate
# 647          93   11092.570    UAS_RT    Right        1.0  AND_Gate
# 648          93    8343.835  chainS_R    Right        1.0    ChainS
# 649          93   17580.110   UAAS_RT    Right        1.0  AND_Gate
# 650          93   12935.185   UBAS_RB    Right        1.0  AND_Gate
# 651          94   12891.510  chainS_L     Left        1.0    ChainS
# 652          94   15955.975   UBAS_LB     Left        1.0  AND_Gate
# 653          94   15571.805    UBS_LB     Left        1.0  AND_Gate
# 654          94   11507.495    UAS_LB     Left        1.0  AND_Gate
# 655          94   11829.345   UAAS_LB     Left        1.0  AND_Gate
# 656          94    9302.960   UBBS_LT     Left        1.0  AND_Gate
# 657          94   12134.285   UABS_LT     Left        1.0  AND_Gate
# 658          95   16905.000  chainS_L     Left        2.0    ChainS
# 659          95   21583.000    UAS_LT     Left        1.0  AND_Gate
# 660          95   11863.000   UBBS_LT     Left        1.0  AND_Gate
# 661          95   12770.000   UAAS_LT     Left        1.0  AND_Gate
# 662          95   12026.000    UBS_LB     Left        1.0  AND_Gate
# 663          95   16401.000   UABS_LB     Left        1.0  AND_Gate
# 664          95   10576.000   UBAS_LB     Left        1.0  AND_Gate
# 665          96   12622.590   UBAS_RB    Right        2.0  AND_Gate
# 666          96   15509.650  chainS_R    Right        1.0    ChainS
# 667          96   16037.850   UAAS_RB    Right        1.0  AND_Gate
# 668          96    9973.745   UBBS_RB    Right        2.0  AND_Gate
# 669          96   13309.445    UAS_RT    Right        1.0  AND_Gate
# 670          96   14094.330   UABS_RB    Right        1.0  AND_Gate
# 671          96   11381.670    UBS_RB    Right        1.0  AND_Gate
# 672          97   17231.545   UAAS_LT     Left        1.0  AND_Gate
# 673          97   10336.180   UBBS_LB     Left        1.0  AND_Gate
# 674          97   10463.925   UBAS_LT     Left        1.0  AND_Gate
# ...
# 279      NaN        A       nodeA30
# 280      NaN      NaN        nodeB9
# 281      NaN        A        nodeB8
# 282      NaN        B       nodeA27
# 283        B        B        nodeB2
# 284        A        A        nodeA7
# 285        A        B        nodeA7
# 286        B        A        nodeB4
# 287      NaN        A       nodeA30
# 288        A        B        nodeB7
# 289        B        A       nodeA25
# 290        A        A        nodeB7
# 291        B        B        nodeB2
# 292      NaN        B        nodeB8
# 293      NaN      NaN        nodeB9
# 294        B        B        nodeB2
# 295      NaN      NaN       nodeB19
# 296        A        B       nodeB19
# 297        A        A       nodeA41
# 298        B        A       nodeA41
# 299      NaN        B       nodeB19
# 300      NaN        A       nodeA41
# 301      NaN        A        nodeB8
# 302        B        A        nodeB4
# 303        A        A        nodeA7
# 304      NaN      NaN        nodeB9
# 305        B        B       nodeA37
# 306      NaN        B       nodeA27
# 307        A        B        nodeB7
# 308      NaN        A       nodeA41
# 309      NaN        B       nodeB19
# 310      NaN      NaN       nodeB19
# 311        A        B       nodeB19
# 312        A        A       nodeA41
# 313        B        A       nodeA41
# 314        B        B       nodeB19
# 315      NaN        A       nodeA41
# 316      NaN        B       nodeB19
# 317        B        B       nodeB19
# 318        A        B       nodeB19
# 319      NaN      NaN       nodeB19
# 320        A        A       nodeA41
# 321        B        A       nodeA41
# 322        B        B        nodeB1
# 323        A        A        nodeA6
# 324      NaN        A        nodeB7
# 325      NaN      NaN        nodeB8
# 326        B        A        nodeB3
# 327        A        B        nodeA6
# 328      NaN        B       nodeA26
# 329        A        A       nodeA41
# 330        A        B       nodeB19
# 331      NaN        A       nodeA41
# 332      NaN        B       nodeB19
# 333        B        A       nodeA41
# 334        B        B       nodeB19
# 335      NaN      NaN       nodeB19
# 336        B        B       nodeB19
# 337      NaN        B       nodeB19
# 338        B        A       nodeA41
# 339        A        B       nodeB19
# 340        A        A       nodeA41
# 341      NaN      NaN        nodeB9
# 342      NaN        A       nodeA41
# 343        B        B       nodeB19
# 344        A        B       nodeB19
# 345      NaN        B       nodeB19
# 346      NaN        A       nodeA41
# 347        A        A       nodeA41
# 348      NaN      NaN       nodeB19
# 349        B        A       nodeA41
# 350      NaN        A       nodeA41
# 351        A        B        nodeB7
# 352        A        A        nodeB7
# 353      NaN        B        nodeB8
# 354        B        B       nodeA37
# 355      NaN      NaN        nodeB9
# 356        B        A       nodeA25
# 357        B        A       nodeB20
# 358      NaN      NaN        nodeB9
# 359        A        B        nodeB7
# 360      NaN        B        nodeB8
# 361      NaN        A       nodeA30
# 362        B        B        nodeB2
# 363        A        A        nodeA7
# 364      NaN      NaN       nodeB20
# 365      NaN        B       nodeB20
# 366        B        A       nodeA41
# 367        A        A       nodeA41
# 368      NaN        A       nodeA41
# 369        A        B       nodeB19
# 370        B        B       nodeB19
# 371        B        B        nodeB2
# 372        B        A        nodeB4
# 373        A        A        nodeA7
# 374      NaN        A       nodeA30
# 375      NaN        B        nodeB8
# 376      NaN      NaN        nodeB9
# 377        A        B        nodeB7
# 378        A        A        nodeB7
# 379      NaN        A       nodeA30
# 380      NaN      NaN       nodeB20
# 381      NaN        B       nodeB20
# 382        A        B       nodeB20
# 383        B        A       nodeB20
# 384        B        B       nodeB20
# 385      NaN      NaN        nodeB9
# 386        B        A       nodeA25
# 387      NaN        A       nodeA30
# 388        A        A        nodeA7
# 389        B        B        nodeB2
# 390        A        B        nodeB7
# 391      NaN        B        nodeB8
# 392      NaN        B        nodeB8
# 393        B        A       nodeA25
# 394        B        B       nodeB19
# 395      NaN        A       nodeA30
# 396        A        B        nodeB7
# 397      NaN      NaN        nodeB9
# 398        A        A       nodeA41
# 399      NaN        B        nodeB8
# 400      NaN      NaN        nodeB9
# 401        B        B        nodeB2
# 402        A        B        nodeB7
# 403        A        A        nodeB7
# 404      NaN        A       nodeA30
# 405        B        A       nodeA25
# 406      NaN        B       nodeA27
# 407        A        B        nodeA5
# 408        B        A       nodeA25
# 409      NaN        A       nodeA30
# 410        B        B        nodeB2
# 411      NaN      NaN        nodeB9
# 412        A        A        nodeA7
# 413      NaN        A       nodeA41
# 414      NaN      NaN       nodeB19
# 415        A        A       nodeA41
# 416        B        B       nodeB19
# 417        A        B       nodeB19
# 418      NaN        B       nodeB19
# 419        B        A       nodeA41
# 420        A        A       nodeB17
# 421        A        B       nodeB19
# 422        B        A       nodeA39
# 423      NaN        A       nodeB16
# 424        B        B       nodeB18
# 425      NaN        B       nodeB14
# 426      NaN      NaN       nodeB11
# 427      NaN        B       nodeB19
# 428      NaN        A       nodeA41
# 429        B        A       nodeA41
# 430      NaN      NaN       nodeB19
# 431        A        A       nodeA41
# 432        A        B       nodeB19
# 433        B        B       nodeB19
# 434      NaN      NaN       nodeB19
# 435      NaN        B       nodeB19
# 436      NaN        A       nodeA41
# 437        B        A       nodeA41
# 438        B        B       nodeB19
# 439        A        B       nodeB19
# 440        A        A       nodeA41
# 441        A        B       nodeB19
# 442        B        B       nodeB19
# 443        A        A       nodeA41
# 444      NaN      NaN       nodeB19
# 445      NaN        B       nodeB19
# 446        B        A       nodeA41
# 447      NaN        A       nodeA41
# 448      NaN        A        nodeB8
# 449        B        A        nodeB4
# 450        A        A        nodeB7
# 451        A        B        nodeA7
# 452      NaN      NaN        nodeB9
# 453        B        B       nodeA37
# 454      NaN        B       nodeA27
# 455        A        B       nodeB19
# 456      NaN        A       nodeA41
# 457      NaN      NaN       nodeB19
# 458        B        B       nodeB19
# 459        B        A       nodeA41
# 460      NaN        B       nodeB19
# 461        A        A       nodeA41
# 462        A        B       nodeB20
# 463        A        A       nodeA41
# 464        B        A       nodeA41
# 465        B        B       nodeB19
# 466      NaN        A       nodeB19
# 467      NaN        B       nodeB19
# 468      NaN      NaN       nodeB20
# 469      NaN      NaN        nodeB9
# 470        A        B        nodeB7
# 471      NaN        B        nodeB8
# 472        A        A        nodeA7
# 473      NaN        A       nodeA30
# 474        B        B        nodeB2
# 475        B        A       nodeA25
# 476      NaN        B        nodeB8
# 477      NaN      NaN        nodeB9
# 478        B        B        nodeB2
# 479        A        B        nodeB7
# 480        A        A        nodeA7
# 481        B        A       nodeA25
# 482      NaN        A       nodeA30
# 483        A        B       nodeB19
# 484        B        A       nodeA41
# 485      NaN      NaN       nodeB19
# 486      NaN        A       nodeA41
# 487        B        B       nodeB19
# 488        A        A       nodeA41
# 489      NaN        B       nodeB19
# 490      NaN        B        nodeB8
# 491        A        A        nodeA7
# 492        B        A       nodeA25
# 493        B        B       nodeA37
# 494      NaN        A       nodeA30
# 495      NaN      NaN        nodeB9
# 496        A        B        nodeB7
# 497        A        B        nodeA7
# 498      NaN        A        nodeB8
# 499        A        A        nodeA7
# 500      NaN      NaN        nodeB9
# 501      NaN        B       nodeA27
# 502        B        B        nodeB2
# 503        B        A        nodeB4
# 504      NaN        A       nodeB19
# 505        B        A       nodeA33
# 506      NaN        B       nodeB19
# 507        A        B       nodeB19
# 508      NaN      NaN       nodeB19
# 509        A        A       nodeA41
# 510        B        B       nodeB19
# 511        A        B       nodeB19
# 512      NaN      NaN       nodeB20
# 513        B        A       nodeB20
# 514        A        A       nodeB20
# 515      NaN        B       nodeB20
# 516        B        B       nodeB20
# 517      NaN        A       nodeB20
# 518        B        A       nodeA26
# 519        A        A       nodeA12
# 520      NaN        B       nodeB11
# 521      NaN      NaN       nodeB13
# 522      NaN        A       nodeB16
# 523        A        B       nodeA21
# 524        B        B        nodeB7
# 525        B        A       nodeA25
# 526      NaN      NaN        nodeB9
# 527        B        B       nodeA37
# 528        A        A        nodeB7
# 529      NaN        B        nodeB8
# 530        A        B        nodeB7
# 531      NaN        A       nodeA30
# 532        A        B        nodeA7
# 533      NaN      NaN        nodeB9
# 534      NaN        B       nodeA27
# 535        A        A        nodeA7
# 536        B        B        nodeB2
# 537        B        A        nodeB4
# 538      NaN        A        nodeB8
# 539      NaN        B       nodeA27
# 540        A        A        nodeA7
# 541        B        A        nodeB4
# 542      NaN      NaN        nodeB9
# 543        A        B        nodeA7
# 544        B        B        nodeB2
# 545      NaN        A        nodeB8
# 546      NaN      NaN        nodeB9
# 547      NaN        A        nodeB8
# 548        B        B        nodeB2
# 549      NaN        B       nodeA27
# 550        B        A        nodeB4
# 551        A        B        nodeA7
# 552        A        A        nodeA7
# 553        B        A       nodeA20
# 554      NaN        A       nodeA29
# 555        A        A        nodeB6
# 556      NaN      NaN        nodeB1
# 557        B        B       nodeA36
# 558      NaN        B       nodeA26
# 559        A        B        nodeB6
# 560        B        A       nodeA25
# 561      NaN      NaN       nodeB20
# 562        A        B        nodeB7
# 563        A        A       nodeA41
# 564      NaN        A       nodeA41
# 565      NaN        B       nodeB19
# 566        B        B       nodeB20
# 567      NaN        B        nodeB8
# 568        A        B        nodeB7
# 569        B        A       nodeA25
# 570      NaN      NaN        nodeB9
# 571      NaN        A       nodeA30
# 572        B        B        nodeB2
# 573        A        A        nodeB7
# 574      NaN        B        nodeB8
# 575        B        B        nodeB2
# 576        A        A        nodeA7
# 577      NaN      NaN        nodeB9
# 578      NaN        A       nodeA30
# 579        B        A       nodeA25
# 580        A        B        nodeB7
# 581      NaN      NaN        nodeB9
# 582        B        A       nodeA25
# 583        A        B        nodeB7
# 584      NaN        B        nodeB8
# 585        B        B       nodeA37
# 586      NaN        A       nodeA30
# 587        A        A        nodeB7
# 588        B        B        nodeB2
# 589      NaN        B        nodeB8
# 590      NaN      NaN        nodeB9
# 591        B        A       nodeA25
# 592        A        B        nodeB7
# 593        A        A        nodeA7
# 594      NaN        A       nodeA30
# 595        A        B        nodeB7
# 596      NaN      NaN        nodeB9
# 597      NaN        A       nodeA30
# 598        B        B        nodeB2
# 599        A        A        nodeA7
# 600        B        A       nodeA25
# 601      NaN        B        nodeB8
# 602      NaN        B        nodeB8
# 603        B        B        nodeB2
# 604      NaN        A        nodeB8
# 605        B        A        nodeB4
# 606        A        A        nodeA7
# 607        A        B        nodeA7
# 608      NaN      NaN        nodeB9
# 609        B        A       nodeA24
# 610      NaN        B       nodeA26
# 611        A        A        nodeB6
# 612        B        B       nodeA36
# 613      NaN        A       nodeA29
# 614      NaN      NaN        nodeB8
# 615        A        B        nodeB6
# 616        A        B       nodeB19
# 617        B        A       nodeA41
# 618      NaN        A       nodeA41
# 619      NaN        B       nodeB19
# 620        B        B       nodeB19
# 621      NaN      NaN       nodeB19
# 622        A        A       nodeA41
# 623        B        A       nodeA41
# 624        A        B       nodeB19
# 625      NaN      NaN        nodeB9
# 626        A        A        nodeA7
# 627      NaN        A       nodeA30
# 628        B        B       nodeA37
# 629      NaN        B        nodeB8
# 630        A        A        nodeA7
# 631      NaN        A        nodeB8
# 632        B        A        nodeB4
# 633      NaN        B       nodeA27
# 634        A        B        nodeA7
# 635        B        B        nodeB2
# 636      NaN      NaN        nodeB9
# 637        A        A        nodeA7
# 638      NaN        A       nodeA30
# 639      NaN      NaN        nodeB9
# 640        B        B        nodeB2
# 641      NaN        B        nodeB8
# 642        B        A       nodeA25
# 643        A        B        nodeB7
# 644        A        B        nodeA7
# 645      NaN        A       nodeA30
# 646        B        B        nodeB2
# 647      NaN        B       nodeA27
# 648      NaN      NaN        nodeB9
# 649        A        A        nodeA7
# 650        B        A       nodeA25
# 651      NaN      NaN        nodeB9
# 652        B        A       nodeA25
# 653      NaN        A       nodeA30
# 654      NaN        B        nodeB8
# 655        A        A        nodeA7
# 656        B        B        nodeB2
# 657        A        B        nodeB7
# 658      NaN      NaN        nodeB8
# 659      NaN        B       nodeA27
# 660        B        B        nodeB1
# 661        A        A        nodeA7
# 662      NaN        A       nodeA29
# 663        A        B        nodeA6
# 664        B        A       nodeA25
# 665        B        A        nodeB4
# 666      NaN      NaN       nodeB19
# 667        A        A        nodeA7
# 668        B        B       nodeB19
# 669      NaN        B       nodeB19
# 670        A        B       nodeB19
# 671      NaN        A       nodeA41
# 672        A        A        nodeA7
# 673        B        B        nodeB2
# 674        B        A        nodeB4
# 675      NaN        A        nodeB8
# 676      NaN        B       nodeA27
# 677        A        B        nodeA7
# 678      NaN      NaN        nodeB9
# 679      NaN        B       nodeB19
# 680        A        B       nodeB19
# 681        B        B       nodeB19
# 682        B        A       nodeA41
# 683      NaN        A       nodeA41
# 684      NaN      NaN       nodeB19
# 685        A        A       nodeA41
# 686      NaN      NaN        nodeB9
# 687        B        A       nodeA25
# 688      NaN        B        nodeB8
# 689        A        A        nodeA7
# 690      NaN        A       nodeA30
# 691        A        B        nodeB7
# 692        B        B        nodeB2
# 693        A        A        nodeA7
# 694        B        A       nodeA25
# 695        B        B       nodeB16
# 696      NaN        B        nodeB8
# 697      NaN        A       nodeA30
# 698        A        B        nodeB8
# 699      NaN      NaN       nodeB19

# %%
data["nb_of_run"].value_counts()
# Out:
# 1.0    633
# 2.0     60
# 3.0      7
# Name: nb_of_run, dtype: int64

# %% [markdown]
# #### Chain only

# %%
data_chain = data[(data["stim_type"]=="ChainS")|(data["stim_type"]=="ChainC")].drop(["rolled_OR_unrolled","A_detectors",
                                                    "state_OR_event","state_branch","root_1st","imdt_2nd",],axis=1)
data_chain.reset_index(drop=True,inplace=True)
data_chain["stimulus"] = data_chain["stimulus"].astype("category")
data_chain["sampling"] = data_chain["sampling"].astype("category")
data_chain["stim_type"] = data_chain["stim_type"].astype("category")
data_chain.head()
# Out:
#    subject_id         rt  stimulus sampling  nb_of_run stim_type A_branch_loc  \
# 0           1  10690.350  chainS_R    Right        1.0    ChainS          NaN
# 1           2   8851.390  chainS_L     Left        1.0    ChainS          NaN
# 2           3  18117.000  chainS_R    Right        1.0    ChainS          NaN
# 3           4  13172.380  chainS_L     Left        2.0    ChainS          NaN
# 4           5   8726.075  chainS_R    Right        1.0    ChainS          NaN
#
#   node_selected
# 0        nodeB9
# 1        nodeB9
# 2        nodeB9
# 3       nodeB19
# 4        nodeB9

# %% [markdown]
# #### AND-Gate only

# %%
#data_AND_Gate = data[data["stim_type"]=="AND_Gate"].drop(["stim_type"],axis=1)
data_AND_Gate = data[data["stim_type"]=="AND_Gate"].copy()
data_AND_Gate.reset_index(drop=True,inplace=True)
data_AND_Gate["stimulus"] = data_AND_Gate["stimulus"].astype("category")
data_AND_Gate["state_OR_event"] = data_AND_Gate["state_OR_event"].astype("category")
data_AND_Gate["rolled_OR_unrolled"] = data_AND_Gate["rolled_OR_unrolled"].astype("category")
data_AND_Gate["A_branch_loc"] = data_AND_Gate["A_branch_loc"].astype("category")
data_AND_Gate["A_detectors"] = data_AND_Gate["A_detectors"].astype("category")
data_AND_Gate["root_1st"] = data_AND_Gate["root_1st"].astype("category")
data_AND_Gate["imdt_2nd"] = data_AND_Gate["imdt_2nd"].astype("category")
data_AND_Gate
# Out:
#      subject_id          rt stimulus sampling  nb_of_run stim_type  \
# 0             1   19950.760  UAAS_RT    Right        1.0  AND_Gate
# 1             1   14289.955  UABS_RB    Right        1.0  AND_Gate
# 2             1   12181.330  UBBS_RT    Right        2.0  AND_Gate
# 3             1   13457.560   UAS_RB    Right        1.0  AND_Gate
# 4             1   12429.980   UBS_RB    Right        1.0  AND_Gate
# 5             1   10832.470  UBAS_RT    Right        2.0  AND_Gate
# 6             2   22205.620   UAS_LB     Left        1.0  AND_Gate
# 7             2   17773.830   UBS_LT     Left        1.0  AND_Gate
# 8             2   11323.835  UAAS_LB     Left        1.0  AND_Gate
# 9             2   10251.860  UBBS_LB     Left        1.0  AND_Gate
# 10            2   10636.100  UBAS_LT     Left        1.0  AND_Gate
# 11            2   12453.805  UABS_LT     Left        1.0  AND_Gate
# 12            3   28741.000  UBBS_RT    Right        1.0  AND_Gate
# 13            3   16028.000  UBAS_RB    Right        1.0  AND_Gate
# 14            3   14004.000   UAS_RB    Right        2.0  AND_Gate
# 15            3   16613.000   UBS_RB    Right        1.0  AND_Gate
# 16            3   14915.000  UABS_RB    Right        1.0  AND_Gate
# 17            3   14407.000  UAAS_RT    Right        1.0  AND_Gate
# 18            4   12532.130  UAAS_LT     Left        2.0  AND_Gate
# 19            4   13785.460  UBAS_LT     Left        1.0  AND_Gate
# 20            4   23058.360   UAS_LT     Left        1.0  AND_Gate
# 21            4   21011.405  UABS_LB     Left        1.0  AND_Gate
# 22            4   22344.200  UBBS_LB     Left        2.0  AND_Gate
# 23            4   10957.365   UBS_LT     Left        1.0  AND_Gate
# 24            5   41070.930  UBAS_RT    Right        1.0  AND_Gate
# 25            5   12315.000   UAS_RT    Right        1.0  AND_Gate
# 26            5   17614.945  UABS_RB    Right        1.0  AND_Gate
# 27            5   19886.620   UBS_RB    Right        1.0  AND_Gate
# 28            5   27907.325  UBBS_RT    Right        1.0  AND_Gate
# 29            5   10975.605  UAAS_RB    Right        1.0  AND_Gate
# 30            6   11361.475  UAAS_RT    Right        2.0  AND_Gate
# 31            6   11968.060  UABS_RT    Right        1.0  AND_Gate
# 32            6    9263.490  UBBS_RT    Right        1.0  AND_Gate
# 33            6   11788.795   UBS_RT    Right        1.0  AND_Gate
# 34            6    9837.330  UBAS_RB    Right        1.0  AND_Gate
# 35            6   12747.790   UAS_RT    Right        1.0  AND_Gate
# 36            7   19507.570   UAS_LB     Left        1.0  AND_Gate
# 37            7   11984.040  UBBS_LB     Left        1.0  AND_Gate
# 38            7   12516.135  UBAS_LB     Left        1.0  AND_Gate
# 39            7   11653.400   UBS_LB     Left        1.0  AND_Gate
# 40            7   16938.320  UABS_LB     Left        1.0  AND_Gate
# 41            7   13465.315  UAAS_LB     Left        1.0  AND_Gate
# 42            8   21732.420  UABS_LT     Left        1.0  AND_Gate
# 43            8   11055.775  UBBS_LT     Left        1.0  AND_Gate
# 44            8   14431.980  UAAS_LB     Left        1.0  AND_Gate
# 45            8   13032.255   UAS_LT     Left        1.0  AND_Gate
# 46            8   11963.515  UBAS_LB     Left        1.0  AND_Gate
# 47            8   14734.590   UBS_LB     Left        1.0  AND_Gate
# 48            9   16069.515   UAS_RB    Right        1.0  AND_Gate
# 49            9    9699.820  UBBS_RB    Right        1.0  AND_Gate
# 50            9   11413.830   UBS_RB    Right        1.0  AND_Gate
# 51            9   15111.910  UABS_RB    Right        1.0  AND_Gate
# 52            9   10563.785  UAAS_RB    Right        1.0  AND_Gate
# 53            9   10958.435  UBAS_RT    Right        1.0  AND_Gate
# 54           10   13241.275  UBBS_RB    Right        2.0  AND_Gate
# 55           10   11701.825   UAS_RT    Right        2.0  AND_Gate
# 56           10   14340.995  UABS_RB    Right        1.0  AND_Gate
# 57           10   12222.380  UBAS_RT    Right        1.0  AND_Gate
# 58           10   10356.090   UBS_RB    Right        1.0  AND_Gate
# 59           10   11719.870  UAAS_RT    Right        1.0  AND_Gate
# 60           11   28754.565  UABS_RB    Right        1.0  AND_Gate
# 61           11   17309.895   UAS_RB    Right        1.0  AND_Gate
# 62           11   13038.965   UBS_RT    Right        1.0  AND_Gate
# 63           11   23010.930  UAAS_RB    Right        1.0  AND_Gate
# 64           11   19661.030  UBBS_RT    Right        1.0  AND_Gate
# 65           11   13856.595  UBAS_RT    Right        1.0  AND_Gate
# 66           12   21210.365  UBBS_LB     Left        1.0  AND_Gate
# 67           12   12153.525  UBAS_LB     Left        1.0  AND_Gate
# 68           12   21244.985   UBS_LT     Left        1.0  AND_Gate
# 69           12   15506.660  UABS_LT     Left        1.0  AND_Gate
# 70           12   13474.685   UAS_LB     Left        1.0  AND_Gate
# 71           12   11244.785  UAAS_LB     Left        1.0  AND_Gate
# 72           13   24181.970   UAS_RT    Right        1.0  AND_Gate
# 73           13    9838.865  UBAS_RT    Right        1.0  AND_Gate
# 74           13   10435.350  UAAS_RB    Right        1.0  AND_Gate
# 75           13   12133.290  UABS_RT    Right        1.0  AND_Gate
# 76           13   11085.960  UBBS_RT    Right        1.0  AND_Gate
# 77           13   10477.610   UBS_RT    Right        1.0  AND_Gate
# 78           14   22433.035   UAS_LB     Left        1.0  AND_Gate
# 79           14   38436.445  UABS_LB     Left        1.0  AND_Gate
# 80           14   18817.610   UBS_LT     Left        1.0  AND_Gate
# 81           14   15478.465  UBBS_LB     Left        1.0  AND_Gate
# 82           14   11861.680  UBAS_LT     Left        1.0  AND_Gate
# 83           14   11811.815  UAAS_LT     Left        1.0  AND_Gate
# 84           15   16247.810   UAS_LB     Left        1.0  AND_Gate
# 85           15   15217.210  UABS_LT     Left        1.0  AND_Gate
# 86           15   10570.175  UBBS_LT     Left        1.0  AND_Gate
# 87           15   12031.615  UAAS_LB     Left        1.0  AND_Gate
# 88           15   10935.935   UBS_LT     Left        1.0  AND_Gate
# 89           15   12505.330  UBAS_LT     Left        1.0  AND_Gate
# 90           16   14677.000  UBBS_RT    Right        1.0  AND_Gate
# 91           16   11168.000   UBS_RT    Right        1.0  AND_Gate
# 92           16   10834.000  UAAS_RT    Right        1.0  AND_Gate
# 93           16   12483.000  UABS_RB    Right        1.0  AND_Gate
# 94           16   10841.000   UAS_RB    Right        1.0  AND_Gate
# 95           16   10186.000  UBAS_RT    Right        1.0  AND_Gate
# 96           17   14582.345   UBS_LB     Left        1.0  AND_Gate
# 97           17   12354.535  UABS_LB     Left        1.0  AND_Gate
# 98           17   10113.090  UBAS_LB     Left        1.0  AND_Gate
# 99           17    9154.895  UBBS_LB     Left        1.0  AND_Gate
# 100          17   10756.585   UAS_LB     Left        1.0  AND_Gate
# 101          17   10934.055  UAAS_LB     Left        1.0  AND_Gate
# 102          18   26118.000  UBBS_RT    Right        1.0  AND_Gate
# 103          18   17445.000  UABS_RB    Right        1.0  AND_Gate
# 104          18   15311.000   UAS_RT    Right        1.0  AND_Gate
# 105          18   12278.000   UBS_RT    Right        1.0  AND_Gate
# 106          18   12246.000  UBAS_RB    Right        1.0  AND_Gate
# 107          18   11566.000  UAAS_RT    Right        1.0  AND_Gate
# 108          19   23480.135  UABS_RB    Right        1.0  AND_Gate
# 109          19   11806.375  UBBS_RT    Right        1.0  AND_Gate
# 110          19   12432.885   UBS_RB    Right        1.0  AND_Gate
# 111          19   10567.320  UAAS_RB    Right        1.0  AND_Gate
# 112          19    9928.390  UBAS_RB    Right        1.0  AND_Gate
# 113          19   10718.350   UAS_RB    Right        1.0  AND_Gate
# 114          20   14437.210   UAS_RT    Right        1.0  AND_Gate
# 115          20   14926.820  UBAS_RB    Right        1.0  AND_Gate
# 116          20    9548.515  UBBS_RT    Right        1.0  AND_Gate
# 117          20   13354.655   UBS_RT    Right        1.0  AND_Gate
# 118          20   11844.040  UAAS_RT    Right        1.0  AND_Gate
# 119          20   12345.735  UABS_RB    Right        1.0  AND_Gate
# 120          21   20471.245   UAS_LB     Left        1.0  AND_Gate
# 121          21   12158.710  UBAS_LB     Left        1.0  AND_Gate
# 122          21   10302.555  UBBS_LB     Left        1.0  AND_Gate
# 123          21   14942.750  UABS_LB     Left        1.0  AND_Gate
# 124          21   11590.695   UBS_LT     Left        1.0  AND_Gate
# 125          21   12326.905  UAAS_LB     Left        1.0  AND_Gate
# 126          22   17378.000   UBS_RT    Right        1.0  AND_Gate
# 127          22   12866.000  UABS_RB    Right        1.0  AND_Gate
# 128          22    9624.000  UBBS_RB    Right        1.0  AND_Gate
# 129          22   10867.000  UBAS_RT    Right        1.0  AND_Gate
# 130          22   11031.000   UAS_RB    Right        1.0  AND_Gate
# 131          22   12541.000  UAAS_RB    Right        1.0  AND_Gate
# 132          23   14266.710  UBBS_RB    Right        1.0  AND_Gate
# 133          23   11722.275   UBS_RB    Right        1.0  AND_Gate
# 134          23   11965.000  UABS_RB    Right        1.0  AND_Gate
# 135          23   10859.815  UAAS_RT    Right        1.0  AND_Gate
# 136          23   12255.850   UAS_RB    Right        1.0  AND_Gate
# 137          23   12664.220  UBAS_RT    Right        1.0  AND_Gate
# 138          24   13667.005  UAAS_RT    Right        3.0  AND_Gate
# 139          24   14610.235  UBBS_RT    Right        3.0  AND_Gate
# 140          24   11750.965   UBS_RB    Right        2.0  AND_Gate
# 141          24   12187.340  UABS_RT    Right        3.0  AND_Gate
# 142          24   10861.815  UBAS_RT    Right        2.0  AND_Gate
# 143          24   11792.185   UAS_RT    Right        1.0  AND_Gate
# 144          25   14461.690  UAAS_LB     Left        2.0  AND_Gate
# 145          25   13028.795  UBAS_LT     Left        1.0  AND_Gate
# 146          25   14956.665   UAS_LB     Left        1.0  AND_Gate
# 147          25   10869.510  UBBS_LT     Left        1.0  AND_Gate
# 148          25   11253.645   UBS_LT     Left        1.0  AND_Gate
# 149          25   16485.190  UABS_LT     Left        1.0  AND_Gate
# 150          26   19880.000  UAAS_RB    Right        1.0  AND_Gate
# 151          26   16765.000  UBAS_RB    Right        1.0  AND_Gate
# 152          26   11752.000  UBBS_RT    Right        2.0  AND_Gate
# 153          26   16383.000   UAS_RB    Right        1.0  AND_Gate
# 154          26   18569.000  UABS_RT    Right        1.0  AND_Gate
# 155          26   16011.000   UBS_RB    Right        1.0  AND_Gate
# 156          27   18795.620  UAAS_RB    Right        1.0  AND_Gate
# 157          27   17377.365  UABS_RT    Right        1.0  AND_Gate
# 158          27   14596.670  UBBS_RT    Right        1.0  AND_Gate
# 159          27   13488.885  UBAS_RB    Right        1.0  AND_Gate
# 160          27   13552.450   UAS_RT    Right        1.0  AND_Gate
# 161          27   14157.080   UBS_RB    Right        1.0  AND_Gate
# 162          28   22666.320  UBBS_RT    Right        1.0  AND_Gate
# 163          28   13914.970  UABS_RT    Right        1.0  AND_Gate
# 164          28   17479.700  UAAS_RT    Right        1.0  AND_Gate
# 165          28    9980.405  UBAS_RT    Right        1.0  AND_Gate
# 166          28   14280.070   UAS_RB    Right        1.0  AND_Gate
# 167          28   10486.945   UBS_RB    Right        1.0  AND_Gate
# 168          29   11011.860  UBAS_RB    Right        2.0  AND_Gate
# 169          29   13181.780   UAS_RT    Right        1.0  AND_Gate
# 170          29   12942.710  UBBS_RT    Right        1.0  AND_Gate
# 171          29   15917.760  UABS_RB    Right        1.0  AND_Gate
# 172          29   14541.215  UAAS_RT    Right        1.0  AND_Gate
# 173          29   10599.165   UBS_RB    Right        1.0  AND_Gate
# 174          30   26005.000   UAS_LT     Left        1.0  AND_Gate
# 175          30   12320.000  UBAS_LB     Left        1.0  AND_Gate
# 176          30   14335.000  UBBS_LB     Left        1.0  AND_Gate
# 177          30   14377.000  UABS_LB     Left        1.0  AND_Gate
# 178          30   14205.000   UBS_LB     Left        1.0  AND_Gate
# 179          30   11931.000  UAAS_LT     Left        1.0  AND_Gate
# 180          31   16534.890   UBS_RT    Right        1.0  AND_Gate
# 181          31   16067.050  UBBS_RT    Right        2.0  AND_Gate
# 182          31   12391.060  UBAS_RT    Right        1.0  AND_Gate
# 183          31   13449.050  UABS_RT    Right        1.0  AND_Gate
# 184          31   10948.495   UAS_RT    Right        1.0  AND_Gate
# 185          31   12086.075  UAAS_RT    Right        1.0  AND_Gate
# 186          32   16555.635   UBS_LT     Left        1.0  AND_Gate
# 187          32   12277.025   UAS_LT     Left        1.0  AND_Gate
# 188          32   13492.825  UAAS_LB     Left        1.0  AND_Gate
# 189          32   10508.965  UBBS_LB     Left        1.0  AND_Gate
# 190          32   12763.710  UBAS_LT     Left        1.0  AND_Gate
# 191          32   13260.650  UABS_LB     Left        1.0  AND_Gate
# 192          33   22188.220  UABS_LB     Left        1.0  AND_Gate
# 193          33   13182.705  UAAS_LT     Left        1.0  AND_Gate
# 194          33   12533.650   UAS_LT     Left        1.0  AND_Gate
# 195          33   13430.080   UBS_LB     Left        1.0  AND_Gate
# 196          33   11004.235  UBBS_LB     Left        1.0  AND_Gate
# 197          33   12245.585  UBAS_LT     Left        1.0  AND_Gate
# 198          34   24340.370  UABS_RT    Right        1.0  AND_Gate
# 199          34   12126.135  UAAS_RT    Right        2.0  AND_Gate
# 200          34   10133.325  UBAS_RT    Right        1.0  AND_Gate
# 201          34    9278.490  UBBS_RT    Right        1.0  AND_Gate
# 202          34   10709.500   UBS_RB    Right        1.0  AND_Gate
# 203          34   11757.560   UAS_RT    Right        1.0  AND_Gate
# 204          35   21245.135  UAAS_LT     Left        1.0  AND_Gate
# 205          35   18445.145  UABS_LB     Left        1.0  AND_Gate
# 206          35  106172.425   UBS_LT     Left        1.0  AND_Gate
# 207          35   94973.215   UAS_LT     Left        1.0  AND_Gate
# 208          35   11233.545  UBAS_LT     Left        1.0  AND_Gate
# 209          35    9793.225  UBBS_LT     Left        1.0  AND_Gate
# 210          36   27387.850  UABS_RB    Right        2.0  AND_Gate
# 211          36   14728.015  UAAS_RB    Right        2.0  AND_Gate
# 212          36   12853.400  UBBS_RB    Right        1.0  AND_Gate
# 213          36   11413.510  UBAS_RT    Right        2.0  AND_Gate
# 214          36   10812.065   UBS_RB    Right        1.0  AND_Gate
# 215          36   19369.625   UAS_RB    Right        1.0  AND_Gate
# 216          37   33330.035   UAS_LT     Left        2.0  AND_Gate
# 217          37   14766.390  UABS_LB     Left        1.0  AND_Gate
# 218          37   10775.345   UBS_LB     Left        1.0  AND_Gate
# 219          37   10913.655  UBAS_LT     Left        1.0  AND_Gate
# 220          37   11559.845  UAAS_LT     Left        1.0  AND_Gate
# 221          37   13434.935  UBBS_LT     Left        1.0  AND_Gate
# 222          38   30562.820   UAS_LT     Left        1.0  AND_Gate
# 223          38   16641.300  UABS_LT     Left        1.0  AND_Gate
# 224          38   11179.180  UBBS_LB     Left        2.0  AND_Gate
# 225          38   12340.870   UBS_LT     Left        1.0  AND_Gate
# 226          38   12045.475  UAAS_LT     Left        1.0  AND_Gate
# 227          38   10294.660  UBAS_LT     Left        1.0  AND_Gate
# 228          39   18165.290  UBBS_LT     Left        2.0  AND_Gate
# 229          39   14608.080  UBAS_LT     Left        1.0  AND_Gate
# 230          39   13219.300  UABS_LB     Left        2.0  AND_Gate
# 231          39   13175.905   UAS_LB     Left        1.0  AND_Gate
# 232          39   17793.320  UAAS_LT     Left        1.0  AND_Gate
# 233          39   10895.185   UBS_LT     Left        1.0  AND_Gate
# 234          40   18892.440  UAAS_LB     Left        2.0  AND_Gate
# 235          40   13509.825   UAS_LB     Left        1.0  AND_Gate
# 236          40   11145.735  UBAS_LT     Left        1.0  AND_Gate
# 237          40   12789.425  UBBS_LT     Left        1.0  AND_Gate
# 238          40   12743.410  UABS_LB     Left        1.0  AND_Gate
# 239          40   12999.710   UBS_LB     Left        1.0  AND_Gate
# 240          41   11237.245   UBS_RB    Right        2.0  AND_Gate
# 241          41   23113.845   UAS_RB    Right        1.0  AND_Gate
# 242          41   11300.110  UBBS_RB    Right        1.0  AND_Gate
# 243          41   13034.285  UAAS_RT    Right        1.0  AND_Gate
# 244          41   16959.095  UABS_RT    Right        1.0  AND_Gate
# 245          41   15281.695  UBAS_RT    Right        1.0  AND_Gate
# 246          42   29853.260   UBS_LT     Left        1.0  AND_Gate
# 247          42   16901.250  UABS_LB     Left        1.0  AND_Gate
# 248          42   15757.265  UBAS_LT     Left        1.0  AND_Gate
# 249          42   14213.085  UAAS_LB     Left        1.0  AND_Gate
# 250          42   12684.320  UBBS_LT     Left        1.0  AND_Gate
# 251          42   12540.640   UAS_LT     Left        1.0  AND_Gate
# 252          43   13761.455  UBBS_RB    Right        2.0  AND_Gate
# 253          43   12441.335  UABS_RB    Right        1.0  AND_Gate
# 254          43   11273.890  UAAS_RT    Right        1.0  AND_Gate
# 255          43   11257.595  UBAS_RB    Right        2.0  AND_Gate
# 256          43   12057.800   UAS_RB    Right        1.0  AND_Gate
# 257          43   12718.235   UBS_RB    Right        1.0  AND_Gate
# 258          44   18810.125   UBS_RT    Right        1.0  AND_Gate
# 259          44   22030.350  UBAS_RB    Right        1.0  AND_Gate
# 260          44   10941.360  UAAS_RB    Right        1.0  AND_Gate
# 261          44   12232.355  UBBS_RB    Right        1.0  AND_Gate
# 262          44   10774.850   UAS_RB    Right        1.0  AND_Gate
# 263          44   20700.965  UABS_RT    Right        1.0  AND_Gate
# 264          45   29756.580   UBS_LB     Left        1.0  AND_Gate
# 265          45   14540.105   UAS_LT     Left        1.0  AND_Gate
# 266          45   13939.670  UABS_LT     Left        1.0  AND_Gate
# 267          45   11764.515  UAAS_LB     Left        1.0  AND_Gate
# 268          45   11283.045  UBAS_LB     Left        1.0  AND_Gate
# 269          45   12650.755  UBBS_LT     Left        1.0  AND_Gate
# 270          46   21948.000   UBS_RB    Right        1.0  AND_Gate
# 271          46   12019.000   UAS_RB    Right        1.0  AND_Gate
# 272          46   10621.000  UBBS_RT    Right        1.0  AND_Gate
# 273          46   13527.000  UABS_RT    Right        1.0  AND_Gate
# 274          46   11408.000  UAAS_RB    Right        1.0  AND_Gate
# 275          46   13800.000  UBAS_RT    Right        1.0  AND_Gate
# 276          47   24562.655  UBBS_RB    Right        2.0  AND_Gate
# 277          47   14786.315  UAAS_RT    Right        1.0  AND_Gate
# 278          47   13386.670   UBS_RT    Right        1.0  AND_Gate
# 279          47   13529.305  UBAS_RB    Right        1.0  AND_Gate
# 280          47   13927.600  UABS_RB    Right        1.0  AND_Gate
# 281          47   14643.425   UAS_RT    Right        1.0  AND_Gate
# 282          48   12148.280  UAAS_RT    Right        2.0  AND_Gate
# 283          48   13643.355  UABS_RT    Right        1.0  AND_Gate
# 284          48   51449.225   UBS_RT    Right        1.0  AND_Gate
# 285          48   16372.185   UAS_RB    Right        1.0  AND_Gate
# 286          48   11027.135  UBAS_RB    Right        1.0  AND_Gate
# 287          48   22567.960  UBBS_RB    Right        1.0  AND_Gate
# 288          49   10002.000  UBBS_RB    Right        2.0  AND_Gate
# 289          49   11252.000   UAS_RB    Right        1.0  AND_Gate
# 290          49   13798.000  UBAS_RT    Right        1.0  AND_Gate
# 291          49   12021.000  UABS_RB    Right        1.0  AND_Gate
# 292          49   14024.000  UAAS_RT    Right        1.0  AND_Gate
# 293          49   24418.000   UBS_RT    Right        1.0  AND_Gate
# 294          50   23831.000  UBBS_LB     Left        1.0  AND_Gate
# 295          50   14216.000  UABS_LT     Left        1.0  AND_Gate
# 296          50   11216.000   UAS_LB     Left        1.0  AND_Gate
# 297          50   12191.000   UBS_LT     Left        1.0  AND_Gate
# 298          50   11080.000  UAAS_LB     Left        1.0  AND_Gate
# 299          50   10564.000  UBAS_LB     Left        1.0  AND_Gate
# 300          51   20482.055   UBS_LT     Left        1.0  AND_Gate
# 301          51   25669.300  UABS_LT     Left        1.0  AND_Gate
# 302          51   14195.450  UAAS_LB     Left        1.0  AND_Gate
# 303          51   12035.990   UAS_LB     Left        1.0  AND_Gate
# 304          51   11260.415  UBBS_LB     Left        1.0  AND_Gate
# 305          51   10434.225  UBAS_LT     Left        1.0  AND_Gate
# 306          52   34286.000  UBAS_RB    Right        1.0  AND_Gate
# 307          52   15558.000  UABS_RT    Right        1.0  AND_Gate
# 308          52   19101.000   UAS_RT    Right        2.0  AND_Gate
# 309          52   13621.000   UBS_RB    Right        2.0  AND_Gate
# 310          52   15671.000  UBBS_RT    Right        1.0  AND_Gate
# 311          52   18186.000  UAAS_RT    Right        1.0  AND_Gate
# 312          53   11622.715   UAS_RT    Right        1.0  AND_Gate
# 313          53   11994.515  UBAS_RT    Right        1.0  AND_Gate
# 314          53   11164.135  UAAS_RB    Right        1.0  AND_Gate
# 315          53   10854.780   UBS_RB    Right        1.0  AND_Gate
# 316          53   14282.885  UABS_RT    Right        1.0  AND_Gate
# 317          53    9006.945  UBBS_RB    Right        1.0  AND_Gate
# 318          54   16227.570  UBBS_LB     Left        1.0  AND_Gate
# 319          54   11012.300  UBAS_LB     Left        1.0  AND_Gate
# 320          54   13812.695  UAAS_LB     Left        1.0  AND_Gate
# 321          54   12248.275   UBS_LB     Left        1.0  AND_Gate
# 322          54   12792.425   UAS_LT     Left        1.0  AND_Gate
# 323          54   13475.745  UABS_LB     Left        1.0  AND_Gate
# 324          55   12947.880  UAAS_RB    Right        2.0  AND_Gate
# 325          55   11129.845   UBS_RB    Right        1.0  AND_Gate
# 326          55   11578.335   UAS_RB    Right        1.0  AND_Gate
# 327          55   11795.685  UABS_RB    Right        1.0  AND_Gate
# 328          55   11329.165  UBAS_RT    Right        1.0  AND_Gate
# 329          55   11775.040  UBBS_RT    Right        1.0  AND_Gate
# 330          56   24208.000  UBAS_LT     Left        1.0  AND_Gate
# 331          56   16259.000   UBS_LT     Left        1.0  AND_Gate
# 332          56   33146.000  UAAS_LT     Left        2.0  AND_Gate
# 333          56   16454.000  UBBS_LB     Left        2.0  AND_Gate
# 334          56   16354.000  UABS_LB     Left        3.0  AND_Gate
# 335          56   17540.000   UAS_LT     Left        2.0  AND_Gate
# 336          57   19111.915   UAS_LB     Left        1.0  AND_Gate
# 337          57    9980.080  UBAS_LB     Left        1.0  AND_Gate
# 338          57   11885.220  UBBS_LT     Left        1.0  AND_Gate
# 339          57    9820.690   UBS_LB     Left        1.0  AND_Gate
# 340          57   11749.015  UABS_LT     Left        1.0  AND_Gate
# 341          57   10793.975  UAAS_LB     Left        1.0  AND_Gate
# 342          58   17617.870   UAS_LT     Left        1.0  AND_Gate
# 343          58   13491.475  UBBS_LB     Left        1.0  AND_Gate
# 344          58   12763.615  UABS_LT     Left        1.0  AND_Gate
# 345          58   11623.965  UAAS_LB     Left        1.0  AND_Gate
# 346          58   10873.580   UBS_LT     Left        1.0  AND_Gate
# 347          58   11183.515  UBAS_LB     Left        1.0  AND_Gate
# 348          59   17656.000   UAS_LT     Left        1.0  AND_Gate
# 349          59   18329.000  UABS_LT     Left        1.0  AND_Gate
# 350          59   10306.000  UBAS_LB     Left        1.0  AND_Gate
# 351          59   10686.000   UBS_LT     Left        1.0  AND_Gate
# 352          59    9793.000  UBBS_LB     Left        1.0  AND_Gate
# 353          59   17686.000  UAAS_LB     Left        1.0  AND_Gate
# 354          60   14479.585   UBS_RT    Right        2.0  AND_Gate
# 355          60   13539.340  UAAS_RB    Right        1.0  AND_Gate
# 356          60   10739.965  UBBS_RT    Right        1.0  AND_Gate
# 357          60   13640.945  UABS_RB    Right        1.0  AND_Gate
# 358          60   11481.315   UAS_RT    Right        1.0  AND_Gate
# 359          60   21249.345  UBAS_RB    Right        1.0  AND_Gate
# 360          61   24670.635  UAAS_RT    Right        1.0  AND_Gate
# 361          61   15261.490  UABS_RT    Right        1.0  AND_Gate
# 362          61   16149.550  UBAS_RT    Right        1.0  AND_Gate
# 363          61   14232.335   UBS_RT    Right        1.0  AND_Gate
# 364          61   10200.500  UBBS_RT    Right        1.0  AND_Gate
# 365          61   13230.965   UAS_RB    Right        1.0  AND_Gate
# 366          62   14747.755   UAS_LT     Left        1.0  AND_Gate
# 367          62   12366.265   UBS_LT     Left        1.0  AND_Gate
# 368          62   11149.550  UBAS_LT     Left        1.0  AND_Gate
# 369          62   11861.760  UAAS_LT     Left        1.0  AND_Gate
# 370          62   12710.695  UABS_LT     Left        1.0  AND_Gate
# 371          62   11581.950  UBBS_LT     Left        1.0  AND_Gate
# 372          63   16639.570   UAS_RB    Right        1.0  AND_Gate
# 373          63   11591.485   UBS_RT    Right        1.0  AND_Gate
# 374          63   11532.070  UBAS_RT    Right        1.0  AND_Gate
# 375          63   11261.290  UBBS_RT    Right        1.0  AND_Gate
# 376          63   12722.580  UABS_RB    Right        1.0  AND_Gate
# 377          63   15680.215  UAAS_RB    Right        1.0  AND_Gate
# 378          64   40894.360  UABS_RB    Right        1.0  AND_Gate
# 379          64   13117.000  UBBS_RT    Right        1.0  AND_Gate
# 380          64   14465.845  UAAS_RB    Right        1.0  AND_Gate
# 381          64   13345.145   UAS_RT    Right        1.0  AND_Gate
# 382          64   12333.730  UBAS_RB    Right        1.0  AND_Gate
# 383          64   11727.240   UBS_RB    Right        2.0  AND_Gate
# 384          65   22904.795   UBS_RB    Right        1.0  AND_Gate
# 385          65   11703.225  UBAS_RT    Right        1.0  AND_Gate
# 386          65   13566.475  UAAS_RB    Right        1.0  AND_Gate
# 387          65   12581.915  UABS_RB    Right        1.0  AND_Gate
# 388          65    8944.405  UBBS_RB    Right        1.0  AND_Gate
# 389          65   10350.340   UAS_RT    Right        1.0  AND_Gate
# 390          66   16896.745  UABS_RB    Right        1.0  AND_Gate
# 391          66   12877.105   UBS_RB    Right        1.0  AND_Gate
# 392          66   10628.785  UBBS_RT    Right        1.0  AND_Gate
# 393          66   10656.110  UBAS_RT    Right        1.0  AND_Gate
# 394          66   11851.830   UAS_RT    Right        1.0  AND_Gate
# 395          66   11947.155  UAAS_RB    Right        1.0  AND_Gate
# 396          67   13586.940  UABS_RT    Right        1.0  AND_Gate
# 397          67   16596.125  UAAS_RB    Right        1.0  AND_Gate
# 398          67    9905.560  UBAS_RB    Right        1.0  AND_Gate
# 399          67    8970.465  UBBS_RT    Right        1.0  AND_Gate
# 400          67   11214.390   UBS_RB    Right        1.0  AND_Gate
# 401          67   10420.010   UAS_RT    Right        1.0  AND_Gate
# 402          68   18636.825  UABS_LT     Left        1.0  AND_Gate
# 403          68   11240.510   UAS_LB     Left        1.0  AND_Gate
# 404          68   11742.515  UAAS_LB     Left        1.0  AND_Gate
# 405          68   10647.005   UBS_LT     Left        1.0  AND_Gate
# 406          68   10339.650  UBBS_LB     Left        1.0  AND_Gate
# 407          68   10701.880  UBAS_LT     Left        1.0  AND_Gate
# 408          69   24982.715   UAS_LB     Left        1.0  AND_Gate
# 409          69   13869.360  UBBS_LB     Left        2.0  AND_Gate
# 410          69   13904.500  UABS_LB     Left        1.0  AND_Gate
# 411          69   12315.090  UAAS_LT     Left        1.0  AND_Gate
# 412          69   11265.140  UBAS_LT     Left        1.0  AND_Gate
# 413          69   12530.965   UBS_LT     Left        1.0  AND_Gate
# 414          70   20477.890  UABS_RT    Right        1.0  AND_Gate
# 415          70   23757.555  UBAS_RT    Right        1.0  AND_Gate
# 416          70   10469.945   UBS_RT    Right        1.0  AND_Gate
# 417          70   13197.520  UBBS_RB    Right        1.0  AND_Gate
# 418          70   11485.275  UAAS_RB    Right        1.0  AND_Gate
# 419          70   11942.815   UAS_RB    Right        1.0  AND_Gate
# 420          71   20520.715   UAS_LT     Left        1.0  AND_Gate
# 421          71   12761.795  UAAS_LT     Left        1.0  AND_Gate
# 422          71   11634.580  UBAS_LB     Left        1.0  AND_Gate
# 423          71    9332.235  UBBS_LT     Left        1.0  AND_Gate
# 424          71   10204.415   UBS_LB     Left        1.0  AND_Gate
# 425          71   12005.870  UABS_LT     Left        1.0  AND_Gate
# 426          72   25567.510  UABS_LT     Left        1.0  AND_Gate
# 427          72   17385.215   UBS_LB     Left        1.0  AND_Gate
# 428          72   14570.985  UAAS_LT     Left        1.0  AND_Gate
# 429          72   13042.785   UAS_LB     Left        1.0  AND_Gate
# 430          72   11297.000  UBBS_LT     Left        3.0  AND_Gate
# 431          72   12442.250  UBAS_LT     Left        1.0  AND_Gate
# 432          73   13785.985   UBS_RB    Right        2.0  AND_Gate
# 433          73   11370.620  UBAS_RT    Right        1.0  AND_Gate
# 434          73   10509.000   UAS_RB    Right        1.0  AND_Gate
# 435          73   12002.955  UABS_RT    Right        1.0  AND_Gate
# 436          73   10372.270  UAAS_RB    Right        1.0  AND_Gate
# 437          73   12000.320  UBBS_RT    Right        1.0  AND_Gate
# 438          74   47335.600  UABS_LB     Left        1.0  AND_Gate
# 439          74   11300.100  UBAS_LB     Left        2.0  AND_Gate
# 440          74   16601.900  UAAS_LB     Left        1.0  AND_Gate
# 441          74   16742.000   UAS_LB     Left        1.0  AND_Gate
# 442          74   13503.500  UBBS_LB     Left        1.0  AND_Gate
# 443          74   13019.200   UBS_LT     Left        1.0  AND_Gate
# 444          75   23720.825  UBAS_LB     Left        1.0  AND_Gate
# 445          75   11304.425  UAAS_LB     Left        1.0  AND_Gate
# 446          75   11208.770   UAS_LB     Left        1.0  AND_Gate
# 447          75   11169.740   UBS_LB     Left        1.0  AND_Gate
# 448          75   12496.815  UABS_LB     Left        2.0  AND_Gate
# 449          75   10897.125  UBBS_LT     Left        1.0  AND_Gate
# 450          76   16135.000  UBAS_LB     Left        1.0  AND_Gate
# 451          76   13290.000  UBBS_LT     Left        1.0  AND_Gate
# 452          76   10982.000  UAAS_LB     Left        1.0  AND_Gate
# 453          76   11278.000   UAS_LT     Left        1.0  AND_Gate
# 454          76   12362.000  UABS_LT     Left        1.0  AND_Gate
# 455          76   10628.000   UBS_LB     Left        1.0  AND_Gate
# 456          77   22198.000  UABS_RB    Right        1.0  AND_Gate
# 457          77   10958.000   UAS_RT    Right        1.0  AND_Gate
# 458          77   10846.000  UAAS_RB    Right        1.0  AND_Gate
# 459          77    9063.000  UBBS_RT    Right        1.0  AND_Gate
# 460          77   10021.000  UBAS_RB    Right        1.0  AND_Gate
# 461          77   11857.000   UBS_RT    Right        1.0  AND_Gate
# 462          78   21297.020   UAS_LB     Left        1.0  AND_Gate
# 463          78   11295.705  UAAS_LB     Left        1.0  AND_Gate
# 464          78   13679.605  UBAS_LT     Left        1.0  AND_Gate
# 465          78   13071.885  UABS_LB     Left        1.0  AND_Gate
# 466          78   10039.625  UBBS_LT     Left        1.0  AND_Gate
# 467          78   13407.115   UBS_LT     Left        1.0  AND_Gate
# 468          79   19880.575   UBS_RB    Right        1.0  AND_Gate
# 469          79   15736.940  UBBS_RB    Right        1.0  AND_Gate
# 470          79   14537.140   UAS_RB    Right        1.0  AND_Gate
# 471          79   13121.515  UBAS_RT    Right        1.0  AND_Gate
# 472          79   14252.625  UABS_RT    Right        1.0  AND_Gate
# 473          79   16040.195  UAAS_RT    Right        1.0  AND_Gate
# 474          80   26346.360  UBAS_LT     Left        2.0  AND_Gate
# 475          80   10989.110   UBS_LB     Left        1.0  AND_Gate
# 476          80   13569.595  UAAS_LB     Left        1.0  AND_Gate
# 477          80   11805.215  UBBS_LB     Left        1.0  AND_Gate
# 478          80   14035.695   UAS_LB     Left        1.0  AND_Gate
# 479          80   12388.000  UABS_LB     Left        1.0  AND_Gate
# 480          81   14548.000  UBAS_RT    Right        3.0  AND_Gate
# 481          81   12907.000  UABS_RT    Right        1.0  AND_Gate
# 482          81   11486.000  UAAS_RT    Right        2.0  AND_Gate
# 483          81   12361.000   UBS_RT    Right        1.0  AND_Gate
# 484          81   12593.000   UAS_RB    Right        2.0  AND_Gate
# 485          81   10185.000  UBBS_RT    Right        1.0  AND_Gate
# 486          82   23773.635   UAS_LB     Left        1.0  AND_Gate
# 487          82   24768.160  UABS_LT     Left        1.0  AND_Gate
# 488          82   11166.450  UBAS_LB     Left        1.0  AND_Gate
# 489          82   11942.915   UBS_LT     Left        1.0  AND_Gate
# 490          82   10791.035  UBBS_LB     Left        2.0  AND_Gate
# 491          82   13145.325  UAAS_LT     Left        1.0  AND_Gate
# 492          83   17426.000   UAS_RB    Right        2.0  AND_Gate
# 493          83   23166.000  UBBS_RT    Right        1.0  AND_Gate
# 494          83   21392.000  UAAS_RT    Right        1.0  AND_Gate
# 495          83   65716.000   UBS_RT    Right        1.0  AND_Gate
# 496          83   13796.000  UBAS_RT    Right        1.0  AND_Gate
# 497          83   13937.000  UABS_RT    Right        1.0  AND_Gate
# 498          84   14788.000  UBAS_RB    Right        1.0  AND_Gate
# 499          84   12909.000  UABS_RB    Right        1.0  AND_Gate
# 500          84   11180.000   UAS_RT    Right        1.0  AND_Gate
# 501          84    8956.000  UBBS_RT    Right        2.0  AND_Gate
# 502          84   10133.000   UBS_RB    Right        1.0  AND_Gate
# 503          84   10798.000  UAAS_RT    Right        1.0  AND_Gate
# 504          85   10096.000  UBBS_LT     Left        3.0  AND_Gate
# 505          85   11346.000   UAS_LB     Left        1.0  AND_Gate
# 506          85   10523.000  UBAS_LB     Left        1.0  AND_Gate
# 507          85   14659.000  UABS_LB     Left        1.0  AND_Gate
# 508          85   13721.000  UAAS_LT     Left        1.0  AND_Gate
# 509          85   20816.000   UBS_LB     Left        1.0  AND_Gate
# 510          86   21476.395  UABS_LT     Left        1.0  AND_Gate
# 511          86   12910.630   UBS_LT     Left        1.0  AND_Gate
# 512          86   12936.615  UBBS_LT     Left        1.0  AND_Gate
# 513          86   13478.210  UAAS_LB     Left        1.0  AND_Gate
# 514          86   19487.780  UBAS_LT     Left        1.0  AND_Gate
# 515          86   14118.535   UAS_LT     Left        1.0  AND_Gate
# 516          87   24657.270   UAS_LT     Left        1.0  AND_Gate
# 517          87   10456.195  UBBS_LT     Left        1.0  AND_Gate
# 518          87   11378.360   UBS_LT     Left        1.0  AND_Gate
# 519          87   11166.215  UBAS_LB     Left        1.0  AND_Gate
# 520          87   11496.060  UAAS_LB     Left        1.0  AND_Gate
# 521          87   12192.995  UABS_LB     Left        1.0  AND_Gate
# 522          88   23172.000  UBAS_LT     Left        1.0  AND_Gate
# 523          88   12474.000   UAS_LT     Left        1.0  AND_Gate
# 524          88   14640.000  UAAS_LB     Left        1.0  AND_Gate
# 525          88   13303.000  UBBS_LT     Left        1.0  AND_Gate
# 526          88   17156.000   UBS_LT     Left        1.0  AND_Gate
# 527          88   12108.000  UABS_LT     Left        1.0  AND_Gate
# 528          89   21105.055  UABS_RT    Right        1.0  AND_Gate
# 529          89   14921.525  UBAS_RT    Right        1.0  AND_Gate
# 530          89   11589.980   UBS_RT    Right        1.0  AND_Gate
# 531          89   13452.555   UAS_RB    Right        1.0  AND_Gate
# 532          89   11363.230  UBBS_RT    Right        1.0  AND_Gate
# 533          89   11124.610  UAAS_RT    Right        2.0  AND_Gate
# 534          90   19292.515  UBAS_LT     Left        1.0  AND_Gate
# 535          90   14525.820  UABS_LT     Left        1.0  AND_Gate
# 536          90   16055.420  UAAS_LB     Left        2.0  AND_Gate
# 537          90   10650.085   UBS_LB     Left        1.0  AND_Gate
# 538          90   11021.075  UBBS_LB     Left        1.0  AND_Gate
# 539          90   10739.580   UAS_LT     Left        1.0  AND_Gate
# 540          91   18596.765  UAAS_RB    Right        2.0  AND_Gate
# 541          91   13421.270   UBS_RB    Right        1.0  AND_Gate
# 542          91   12205.490  UBAS_RT    Right        1.0  AND_Gate
# 543          91   24412.730   UAS_RB    Right        1.0  AND_Gate
# 544          91   12197.460  UABS_RB    Right        1.0  AND_Gate
# 545          91   16021.340  UBBS_RT    Right        1.0  AND_Gate
# 546          92   12200.785  UAAS_RB    Right        2.0  AND_Gate
# 547          92   25983.085   UBS_RT    Right        1.0  AND_Gate
# 548          92   10204.605  UBBS_RB    Right        1.0  AND_Gate
# 549          92   10524.900   UAS_RT    Right        1.0  AND_Gate
# 550          92   10191.225  UBAS_RT    Right        1.0  AND_Gate
# 551          92   11859.205  UABS_RB    Right        1.0  AND_Gate
# 552          93   24745.715  UABS_RB    Right        1.0  AND_Gate
# 553          93   15546.655   UBS_RB    Right        1.0  AND_Gate
# 554          93   18094.965  UBBS_RT    Right        2.0  AND_Gate
# 555          93   11092.570   UAS_RT    Right        1.0  AND_Gate
# 556          93   17580.110  UAAS_RT    Right        1.0  AND_Gate
# 557          93   12935.185  UBAS_RB    Right        1.0  AND_Gate
# 558          94   15955.975  UBAS_LB     Left        1.0  AND_Gate
# 559          94   15571.805   UBS_LB     Left        1.0  AND_Gate
# 560          94   11507.495   UAS_LB     Left        1.0  AND_Gate
# 561          94   11829.345  UAAS_LB     Left        1.0  AND_Gate
# 562          94    9302.960  UBBS_LT     Left        1.0  AND_Gate
# 563          94   12134.285  UABS_LT     Left        1.0  AND_Gate
# 564          95   21583.000   UAS_LT     Left        1.0  AND_Gate
# 565          95   11863.000  UBBS_LT     Left        1.0  AND_Gate
# 566          95   12770.000  UAAS_LT     Left        1.0  AND_Gate
# 567          95   12026.000   UBS_LB     Left        1.0  AND_Gate
# 568          95   16401.000  UABS_LB     Left        1.0  AND_Gate
# 569          95   10576.000  UBAS_LB     Left        1.0  AND_Gate
# 570          96   12622.590  UBAS_RB    Right        2.0  AND_Gate
# 571          96   16037.850  UAAS_RB    Right        1.0  AND_Gate
# 572          96    9973.745  UBBS_RB    Right        2.0  AND_Gate
# 573          96   13309.445   UAS_RT    Right        1.0  AND_Gate
# 574          96   14094.330  UABS_RB    Right        1.0  AND_Gate
# 575          96   11381.670   UBS_RB    Right        1.0  AND_Gate
# 576          97   17231.545  UAAS_LT     Left        1.0  AND_Gate
# 577          97   10336.180  UBBS_LB     Left        1.0  AND_Gate
# 578          97   10463.925  UBAS_LT     Left        1.0  AND_Gate
# 579          97   10927.335   UBS_LT     Left        1.0  AND_Gate
# 580          97   11096.490   UAS_LB     Left        1.0  AND_Gate
# 581          97   11775.965  UABS_LB     Left        1.0  AND_Gate
# 582          98   22487.410   UAS_RB    Right        1.0  AND_Gate
# 583          98   19563.995  UABS_RB    Right        1.0  AND_Gate
# 584          98   10547.820  UBBS_RB    Right        1.0  AND_Gate
# 585          98   11416.055  UBAS_RB    Right        1.0  AND_Gate
# 586          98   11070.765   UBS_RT    Right        1.0  AND_Gate
# 587          98   11888.860  UAAS_RB    Right        1.0  AND_Gate
# 588          99   12801.080  UBAS_RT    Right        1.0  AND_Gate
# 589          99   10569.115   UAS_RB    Right        2.0  AND_Gate
# 590          99   10941.885  UAAS_RB    Right        1.0  AND_Gate
# 591          99   10523.850   UBS_RB    Right        1.0  AND_Gate
# 592          99   13583.175  UABS_RT    Right        1.0  AND_Gate
# 593          99   13258.530  UBBS_RB    Right        1.0  AND_Gate
# 594         100   18707.000  UAAS_RB    Right        1.0  AND_Gate
# 595         100   23013.000  UBAS_RT    Right        1.0  AND_Gate
# 596         100   11951.000  UBBS_RB    Right        2.0  AND_Gate
# 597         100   14898.000   UAS_RT    Right        1.0  AND_Gate
# 598         100   11452.000   UBS_RT    Right        1.0  AND_Gate
# 599         100   12388.000  UABS_RB    Right        1.0  AND_Gate
#
#     rolled_OR_unrolled A_branch_loc A_detectors state_OR_event state_branch  \
# 0             Unrolled          Top     Squares          Event          NaN
# 1             Unrolled       Bottom     Squares          Event          NaN
# 2             Unrolled          Top     Squares          Event          NaN
# 3             Unrolled       Bottom     Squares          State            A
# 4             Unrolled       Bottom     Squares          State            B
# 5             Unrolled          Top     Squares          Event          NaN
# 6             Unrolled       Bottom     Squares          State            A
# 7             Unrolled          Top     Squares          State            B
# 8             Unrolled       Bottom     Squares          Event          NaN
# 9             Unrolled       Bottom     Squares          Event          NaN
# 10            Unrolled          Top     Squares          Event          NaN
# 11            Unrolled          Top     Squares          Event          NaN
# 12            Unrolled          Top     Squares          Event          NaN
# 13            Unrolled       Bottom     Squares          Event          NaN
# 14            Unrolled       Bottom     Squares          State            A
# 15            Unrolled       Bottom     Squares          State            B
# 16            Unrolled       Bottom     Squares          Event          NaN
# 17            Unrolled          Top     Squares          Event          NaN
# 18            Unrolled          Top     Squares          Event          NaN
# 19            Unrolled          Top     Squares          Event          NaN
# 20            Unrolled          Top     Squares          State            A
# 21            Unrolled       Bottom     Squares          Event          NaN
# 22            Unrolled       Bottom     Squares          Event          NaN
# 23            Unrolled          Top     Squares          State            B
# 24            Unrolled          Top     Squares          Event          NaN
# 25            Unrolled          Top     Squares          State            A
# 26            Unrolled       Bottom     Squares          Event          NaN
# 27            Unrolled       Bottom     Squares          State            B
# 28            Unrolled          Top     Squares          Event          NaN
# 29            Unrolled       Bottom     Squares          Event          NaN
# 30            Unrolled          Top     Squares          Event          NaN
# 31            Unrolled          Top     Squares          Event          NaN
# 32            Unrolled          Top     Squares          Event          NaN
# 33            Unrolled          Top     Squares          State            B
# 34            Unrolled       Bottom     Squares          Event          NaN
# 35            Unrolled          Top     Squares          State            A
# 36            Unrolled       Bottom     Squares          State            A
# 37            Unrolled       Bottom     Squares          Event          NaN
# 38            Unrolled       Bottom     Squares          Event          NaN
# 39            Unrolled       Bottom     Squares          State            B
# 40            Unrolled       Bottom     Squares          Event          NaN
# 41            Unrolled       Bottom     Squares          Event          NaN
# 42            Unrolled          Top     Squares          Event          NaN
# 43            Unrolled          Top     Squares          Event          NaN
# 44            Unrolled       Bottom     Squares          Event          NaN
# 45            Unrolled          Top     Squares          State            A
# 46            Unrolled       Bottom     Squares          Event          NaN
# 47            Unrolled       Bottom     Squares          State            B
# 48            Unrolled       Bottom     Squares          State            A
# 49            Unrolled       Bottom     Squares          Event          NaN
# 50            Unrolled       Bottom     Squares          State            B
# 51            Unrolled       Bottom     Squares          Event          NaN
# 52            Unrolled       Bottom     Squares          Event          NaN
# 53            Unrolled          Top     Squares          Event          NaN
# 54            Unrolled       Bottom     Squares          Event          NaN
# 55            Unrolled          Top     Squares          State            A
# 56            Unrolled       Bottom     Squares          Event          NaN
# 57            Unrolled          Top     Squares          Event          NaN
# 58            Unrolled       Bottom     Squares          State            B
# 59            Unrolled          Top     Squares          Event          NaN
# 60            Unrolled       Bottom     Squares          Event          NaN
# 61            Unrolled       Bottom     Squares          State            A
# 62            Unrolled          Top     Squares          State            B
# 63            Unrolled       Bottom     Squares          Event          NaN
# 64            Unrolled          Top     Squares          Event          NaN
# 65            Unrolled          Top     Squares          Event          NaN
# 66            Unrolled       Bottom     Squares          Event          NaN
# 67            Unrolled       Bottom     Squares          Event          NaN
# 68            Unrolled          Top     Squares          State            B
# 69            Unrolled          Top     Squares          Event          NaN
# 70            Unrolled       Bottom     Squares          State            A
# 71            Unrolled       Bottom     Squares          Event          NaN
# 72            Unrolled          Top     Squares          State            A
# 73            Unrolled          Top     Squares          Event          NaN
# ...
# 179        A        A        nodeB6
# 180      NaN        A       nodeA41
# 181        B        B       nodeB19
# 182        B        A       nodeA41
# 183        A        B       nodeB19
# 184      NaN        B       nodeB19
# 185        A        A       nodeA41
# 186      NaN        A        nodeB8
# 187      NaN        B       nodeB19
# 188        A        A       nodeA41
# 189        B        B       nodeB19
# 190        B        A       nodeA41
# 191        A        B       nodeB19
# 192        A        B        nodeB7
# 193        A        A        nodeA7
# 194      NaN        B        nodeB8
# 195      NaN        A       nodeA30
# 196        B        B        nodeB2
# 197        B        A       nodeA25
# 198        A        B        nodeA7
# 199        A        A        nodeB7
# 200        B        A        nodeB4
# 201        B        B        nodeB2
# 202      NaN        A        nodeB8
# 203      NaN        B       nodeA27
# 204        A        A        nodeB7
# 205        A        B        nodeB7
# 206      NaN        A       nodeA30
# 207      NaN        B        nodeB8
# 208        B        A        nodeB4
# 209        B        B        nodeB2
# 210        A        B        nodeB7
# 211        A        A        nodeB7
# 212        B        B       nodeA37
# 213        B        A       nodeA25
# 214      NaN        A       nodeA30
# 215      NaN        B        nodeB8
# 216      NaN        B       nodeA27
# 217        A        B        nodeB7
# 218      NaN        A       nodeA30
# 219        B        A       nodeA25
# 220        A        A        nodeB7
# 221        B        B        nodeB2
# 222      NaN        B        nodeB8
# 223        A        B        nodeB7
# 224        B        B        nodeB2
# 225      NaN        A       nodeA30
# 226        A        A        nodeA7
# 227        B        A       nodeA25
# 228        B        B       nodeB19
# 229        B        A       nodeA41
# 230        A        B       nodeB19
# 231      NaN        B       nodeB19
# 232        A        A       nodeA41
# 233      NaN        A       nodeA41
# 234        A        A        nodeB7
# 235      NaN        B        nodeB8
# 236        B        A       nodeA25
# 237        B        B       nodeA37
# 238        A        B        nodeB7
# 239      NaN        A       nodeA30
# 240      NaN        A        nodeB8
# 241      NaN        B       nodeA27
# 242        B        B        nodeB2
# 243        A        A        nodeA7
# 244        A        B        nodeA7
# 245        B        A        nodeB4
# 246      NaN        A       nodeA30
# 247        A        B        nodeB7
# 248        B        A       nodeA25
# 249        A        A        nodeB7
# 250        B        B        nodeB2
# 251      NaN        B        nodeB8
# 252        B        B        nodeB2
# 253        A        B       nodeB19
# 254        A        A       nodeA41
# 255        B        A       nodeA41
# 256      NaN        B       nodeB19
# 257      NaN        A       nodeA41
# 258      NaN        A        nodeB8
# 259        B        A        nodeB4
# 260        A        A        nodeA7
# 261        B        B       nodeA37
# 262      NaN        B       nodeA27
# 263        A        B        nodeB7
# 264      NaN        A       nodeA41
# 265      NaN        B       nodeB19
# 266        A        B       nodeB19
# 267        A        A       nodeA41
# 268        B        A       nodeA41
# 269        B        B       nodeB19
# 270      NaN        A       nodeA41
# 271      NaN        B       nodeB19
# 272        B        B       nodeB19
# 273        A        B       nodeB19
# 274        A        A       nodeA41
# 275        B        A       nodeA41
# 276        B        B        nodeB1
# 277        A        A        nodeA6
# 278      NaN        A        nodeB7
# 279        B        A        nodeB3
# 280        A        B        nodeA6
# 281      NaN        B       nodeA26
# 282        A        A       nodeA41
# 283        A        B       nodeB19
# 284      NaN        A       nodeA41
# 285      NaN        B       nodeB19
# 286        B        A       nodeA41
# 287        B        B       nodeB19
# 288        B        B       nodeB19
# 289      NaN        B       nodeB19
# 290        B        A       nodeA41
# 291        A        B       nodeB19
# 292        A        A       nodeA41
# 293      NaN        A       nodeA41
# 294        B        B       nodeB19
# 295        A        B       nodeB19
# 296      NaN        B       nodeB19
# 297      NaN        A       nodeA41
# 298        A        A       nodeA41
# 299        B        A       nodeA41
# 300      NaN        A       nodeA41
# 301        A        B        nodeB7
# 302        A        A        nodeB7
# 303      NaN        B        nodeB8
# 304        B        B       nodeA37
# 305        B        A       nodeA25
# 306        B        A       nodeB20
# 307        A        B        nodeB7
# 308      NaN        B        nodeB8
# 309      NaN        A       nodeA30
# 310        B        B        nodeB2
# 311        A        A        nodeA7
# 312      NaN        B       nodeB20
# 313        B        A       nodeA41
# 314        A        A       nodeA41
# 315      NaN        A       nodeA41
# 316        A        B       nodeB19
# 317        B        B       nodeB19
# 318        B        B        nodeB2
# 319        B        A        nodeB4
# 320        A        A        nodeA7
# 321      NaN        A       nodeA30
# 322      NaN        B        nodeB8
# 323        A        B        nodeB7
# 324        A        A        nodeB7
# 325      NaN        A       nodeA30
# 326      NaN        B       nodeB20
# 327        A        B       nodeB20
# 328        B        A       nodeB20
# 329        B        B       nodeB20
# 330        B        A       nodeA25
# 331      NaN        A       nodeA30
# 332        A        A        nodeA7
# 333        B        B        nodeB2
# 334        A        B        nodeB7
# 335      NaN        B        nodeB8
# 336      NaN        B        nodeB8
# 337        B        A       nodeA25
# 338        B        B       nodeB19
# 339      NaN        A       nodeA30
# 340        A        B        nodeB7
# 341        A        A       nodeA41
# 342      NaN        B        nodeB8
# 343        B        B        nodeB2
# 344        A        B        nodeB7
# 345        A        A        nodeB7
# 346      NaN        A       nodeA30
# 347        B        A       nodeA25
# 348      NaN        B       nodeA27
# 349        A        B        nodeA5
# 350        B        A       nodeA25
# 351      NaN        A       nodeA30
# 352        B        B        nodeB2
# 353        A        A        nodeA7
# 354      NaN        A       nodeA41
# 355        A        A       nodeA41
# 356        B        B       nodeB19
# 357        A        B       nodeB19
# 358      NaN        B       nodeB19
# 359        B        A       nodeA41
# 360        A        A       nodeB17
# 361        A        B       nodeB19
# 362        B        A       nodeA39
# 363      NaN        A       nodeB16
# 364        B        B       nodeB18
# 365      NaN        B       nodeB14
# 366      NaN        B       nodeB19
# 367      NaN        A       nodeA41
# 368        B        A       nodeA41
# 369        A        A       nodeA41
# 370        A        B       nodeB19
# 371        B        B       nodeB19
# 372      NaN        B       nodeB19
# 373      NaN        A       nodeA41
# 374        B        A       nodeA41
# 375        B        B       nodeB19
# 376        A        B       nodeB19
# 377        A        A       nodeA41
# 378        A        B       nodeB19
# 379        B        B       nodeB19
# 380        A        A       nodeA41
# 381      NaN        B       nodeB19
# 382        B        A       nodeA41
# 383      NaN        A       nodeA41
# 384      NaN        A        nodeB8
# 385        B        A        nodeB4
# 386        A        A        nodeB7
# 387        A        B        nodeA7
# 388        B        B       nodeA37
# 389      NaN        B       nodeA27
# 390        A        B       nodeB19
# 391      NaN        A       nodeA41
# 392        B        B       nodeB19
# 393        B        A       nodeA41
# 394      NaN        B       nodeB19
# 395        A        A       nodeA41
# 396        A        B       nodeB20
# 397        A        A       nodeA41
# 398        B        A       nodeA41
# 399        B        B       nodeB19
# 400      NaN        A       nodeB19
# 401      NaN        B       nodeB19
# 402        A        B        nodeB7
# 403      NaN        B        nodeB8
# 404        A        A        nodeA7
# 405      NaN        A       nodeA30
# 406        B        B        nodeB2
# 407        B        A       nodeA25
# 408      NaN        B        nodeB8
# 409        B        B        nodeB2
# 410        A        B        nodeB7
# 411        A        A        nodeA7
# 412        B        A       nodeA25
# 413      NaN        A       nodeA30
# 414        A        B       nodeB19
# 415        B        A       nodeA41
# 416      NaN        A       nodeA41
# 417        B        B       nodeB19
# 418        A        A       nodeA41
# 419      NaN        B       nodeB19
# 420      NaN        B        nodeB8
# 421        A        A        nodeA7
# 422        B        A       nodeA25
# 423        B        B       nodeA37
# 424      NaN        A       nodeA30
# 425        A        B        nodeB7
# 426        A        B        nodeA7
# 427      NaN        A        nodeB8
# 428        A        A        nodeA7
# 429      NaN        B       nodeA27
# 430        B        B        nodeB2
# 431        B        A        nodeB4
# 432      NaN        A       nodeB19
# 433        B        A       nodeA33
# 434      NaN        B       nodeB19
# 435        A        B       nodeB19
# 436        A        A       nodeA41
# 437        B        B       nodeB19
# 438        A        B       nodeB19
# 439        B        A       nodeB20
# 440        A        A       nodeB20
# 441      NaN        B       nodeB20
# 442        B        B       nodeB20
# 443      NaN        A       nodeB20
# 444        B        A       nodeA26
# 445        A        A       nodeA12
# 446      NaN        B       nodeB11
# 447      NaN        A       nodeB16
# 448        A        B       nodeA21
# 449        B        B        nodeB7
# 450        B        A       nodeA25
# 451        B        B       nodeA37
# 452        A        A        nodeB7
# 453      NaN        B        nodeB8
# 454        A        B        nodeB7
# 455      NaN        A       nodeA30
# 456        A        B        nodeA7
# 457      NaN        B       nodeA27
# 458        A        A        nodeA7
# 459        B        B        nodeB2
# 460        B        A        nodeB4
# 461      NaN        A        nodeB8
# 462      NaN        B       nodeA27
# 463        A        A        nodeA7
# 464        B        A        nodeB4
# 465        A        B        nodeA7
# 466        B        B        nodeB2
# 467      NaN        A        nodeB8
# 468      NaN        A        nodeB8
# 469        B        B        nodeB2
# 470      NaN        B       nodeA27
# 471        B        A        nodeB4
# 472        A        B        nodeA7
# 473        A        A        nodeA7
# 474        B        A       nodeA20
# 475      NaN        A       nodeA29
# 476        A        A        nodeB6
# 477        B        B       nodeA36
# 478      NaN        B       nodeA26
# 479        A        B        nodeB6
# 480        B        A       nodeA25
# 481        A        B        nodeB7
# 482        A        A       nodeA41
# 483      NaN        A       nodeA41
# 484      NaN        B       nodeB19
# 485        B        B       nodeB20
# 486      NaN        B        nodeB8
# 487        A        B        nodeB7
# 488        B        A       nodeA25
# 489      NaN        A       nodeA30
# 490        B        B        nodeB2
# 491        A        A        nodeB7
# 492      NaN        B        nodeB8
# 493        B        B        nodeB2
# 494        A        A        nodeA7
# 495      NaN        A       nodeA30
# 496        B        A       nodeA25
# 497        A        B        nodeB7
# 498        B        A       nodeA25
# 499        A        B        nodeB7
# 500      NaN        B        nodeB8
# 501        B        B       nodeA37
# 502      NaN        A       nodeA30
# 503        A        A        nodeB7
# 504        B        B        nodeB2
# 505      NaN        B        nodeB8
# 506        B        A       nodeA25
# 507        A        B        nodeB7
# 508        A        A        nodeA7
# 509      NaN        A       nodeA30
# 510        A        B        nodeB7
# 511      NaN        A       nodeA30
# 512        B        B        nodeB2
# 513        A        A        nodeA7
# 514        B        A       nodeA25
# 515      NaN        B        nodeB8
# 516      NaN        B        nodeB8
# 517        B        B        nodeB2
# 518      NaN        A        nodeB8
# 519        B        A        nodeB4
# 520        A        A        nodeA7
# 521        A        B        nodeA7
# 522        B        A       nodeA24
# 523      NaN        B       nodeA26
# 524        A        A        nodeB6
# 525        B        B       nodeA36
# 526      NaN        A       nodeA29
# 527        A        B        nodeB6
# 528        A        B       nodeB19
# 529        B        A       nodeA41
# 530      NaN        A       nodeA41
# 531      NaN        B       nodeB19
# 532        B        B       nodeB19
# 533        A        A       nodeA41
# 534        B        A       nodeA41
# 535        A        B       nodeB19
# 536        A        A        nodeA7
# 537      NaN        A       nodeA30
# 538        B        B       nodeA37
# 539      NaN        B        nodeB8
# 540        A        A        nodeA7
# 541      NaN        A        nodeB8
# 542        B        A        nodeB4
# 543      NaN        B       nodeA27
# 544        A        B        nodeA7
# 545        B        B        nodeB2
# 546        A        A        nodeA7
# 547      NaN        A       nodeA30
# 548        B        B        nodeB2
# 549      NaN        B        nodeB8
# 550        B        A       nodeA25
# 551        A        B        nodeB7
# 552        A        B        nodeA7
# 553      NaN        A       nodeA30
# 554        B        B        nodeB2
# 555      NaN        B       nodeA27
# 556        A        A        nodeA7
# 557        B        A       nodeA25
# 558        B        A       nodeA25
# 559      NaN        A       nodeA30
# 560      NaN        B        nodeB8
# 561        A        A        nodeA7
# 562        B        B        nodeB2
# 563        A        B        nodeB7
# 564      NaN        B       nodeA27
# 565        B        B        nodeB1
# 566        A        A        nodeA7
# 567      NaN        A       nodeA29
# 568        A        B        nodeA6
# 569        B        A       nodeA25
# 570        B        A        nodeB4
# 571        A        A        nodeA7
# 572        B        B       nodeB19
# 573      NaN        B       nodeB19
# 574        A        B       nodeB19
# 575      NaN        A       nodeA41
# 576        A        A        nodeA7
# 577        B        B        nodeB2
# 578        B        A        nodeB4
# 579      NaN        A        nodeB8
# 580      NaN        B       nodeA27
# 581        A        B        nodeA7
# 582      NaN        B       nodeB19
# 583        A        B       nodeB19
# 584        B        B       nodeB19
# 585        B        A       nodeA41
# 586      NaN        A       nodeA41
# 587        A        A       nodeA41
# 588        B        A       nodeA25
# 589      NaN        B        nodeB8
# 590        A        A        nodeA7
# 591      NaN        A       nodeA30
# 592        A        B        nodeB7
# 593        B        B        nodeB2
# 594        A        A        nodeA7
# 595        B        A       nodeA25
# 596        B        B       nodeB16
# 597      NaN        B        nodeB8
# 598      NaN        A       nodeA30
# 599        A        B        nodeB8

# %% [markdown]
# ## Functions

# %%
def newCatLabels(root1,imdt2,cat):
    if cat in ['INACT','EFFECT','INBTW','INACT_1st','INACT_2nd','INBTW_1st','INBTW_2nd']:
        label = "other"
    elif cat == "ROOT":
        label = 'RC'
    elif cat == 'IMDT_1st':
        label = 'ID'
    elif cat in ['IMDT_2nd','IMDT']:
        label = 'IC'   
    if root1 in ['A','B']:
        if cat == 'ROOT_2nd' and root1 != imdt2:
            label = 'RC'
        elif cat == 'ROOT_2nd' and root1 == imdt2:
            label = 'RD'
        elif cat == 'ROOT_1st' and root1 != imdt2:
            label = 'RD'
        elif cat == 'ROOT_1st' and root1 == imdt2:
            label = 'RC'
    else:
        if cat == 'ROOT_1st':
            label = 'RD'
        elif cat == 'ROOT_2nd':
            label = 'RC'

    return label

def newStimNames(name):
    nm1 = name.split('_')[0]
    nm2 = name.split('_')[1]
    if len(nm1) == 6:
        nm2 = 'Rb'
        newName = nm1+'_'+nm2
    else:
        nm2 = 'RTb'
        newName = nm1+'_'+nm2
    return newName

def newStimType(name):
    if name == 'AND_Gate':
        nm = 'dualbranch'
    else:
        nm = 'chain'
    return nm 

def order(name):
    name = name.split('_')[0]
    if len(name) == 6:
        order = np.nan
    elif len(name) == 4:
        if name[1:3] in ['AA','BB']:
            order = 'RC_RD_ID'
        elif name[1:3] in ['AB','BA']:
            order = 'RD_RC_ID'
    elif len(name) == 3:
        order = 'RD_ID_RC'
        
    return order


def nb(letter,lower_bound,upper_bound):
    return [letter+str(i) for i in range(lower_bound,upper_bound+1)]

def node_cat(stim,node,stim_type):
    if stim_type == 'ChainS':
        stim = stim.split('_')[0]
        node = node[4:]
        if stim == 'chainS':
            categories = {'INACT':nb('B',1,7),'ROOT':['B8','B9','B10'],'INBTW':nb('B',11,18),'IMDT':['B19'],'EFFECT':['B20']}
        elif stim == 'chainC':
            categories = {'INACT':nb('A',1,24),'ROOT':['A25','A26','A27'],'INBTW':nb('A',28,40),'IMDT':['A41'],'EFFECT':['B20']}

        category = [cat for cat,nd in categories.items() if node in nd][0]
    
    else:
        node = node[4:]
        stim = stim.split('_')[0]
        if stim == 'UAAS': 
            categories = {'UNKNOWN':[],'INACT_1st':nb('A',1,6),'INACT_2nd':nb('B',1,6),'ROOT_1st':['A6','A7','A8'],
                          'ROOT_2nd':['B6','B7','B8'],'INBTW_1st':nb('A',9,40),'INBTW_2nd':nb('B',9,18),'IMDT_1st':['B19'],
                          'IMDT_2nd':['A41'],'EFFECT':['B20']}
        elif stim == 'UABS': 
            categories = {'UNKNOWN':[],'INACT_1st':nb('A',1,5),'INACT_2nd':nb('B',1,5),'ROOT_1st':['A6','A7','A8'],
                          'ROOT_2nd':['B6','B7','B8'],'INBTW_1st':nb('A',9,40),'INBTW_2nd':nb('B',9,18),'IMDT_1st':['A41'],
                          'IMDT_2nd':['B19'],'EFFECT':['B20']}
        elif stim == 'UAS': 
            categories = {'UNKNOWN':[],'INACT_1st':nb('A',1,25),'INACT_2nd':nb('B',1,6),'ROOT_1st':['A26','A27','A28'],
                          'ROOT_2nd':['B7','B8','B9'],'INBTW_1st':nb('A',29,40),'INBTW_2nd':nb('B',10,18),'IMDT_1st':['A41'],
                          'IMDT_2nd':['B19'],'EFFECT':['B20']}
        elif stim == 'UBAS': 
            categories = {'UNKNOWN':[],'INACT_1st':nb('B',1,2),'INACT_2nd':nb('A',1,23),'ROOT_1st':['B3','B4','B5'],
                          'ROOT_2nd':['A24','A25','A26'],'INBTW_1st':nb('B',6,18),'INBTW_2nd':nb('A',27,40),'IMDT_1st':['B19'],
                          'IMDT_2nd':['A41'],'EFFECT':['B20']}
        elif stim == 'UBBS': 
            categories = {'UNKNOWN':[],'INACT_1st':[],'INACT_2nd':nb('A',1,35),'ROOT_1st':['B1','B2','B3'],
                          'ROOT_2nd':['A36','A37','A38'],'INBTW_1st':nb('B',4,18),'INBTW_2nd':nb('A',39,40),'IMDT_1st':['A41'],
                          'IMDT_2nd':['B19'],'EFFECT':['B20']}
        elif stim == 'UBS': 
            categories = {'UNKNOWN':[],'INACT_1st':nb('B',1,6),'INACT_2nd':nb('A',1,28),'ROOT_1st':['B7','B8','B9'],
                          'ROOT_2nd':['A29','A30','A31'],'INBTW_1st':nb('B',10,18),'INBTW_2nd':nb('A',32,40),'IMDT_1st':['B19'],
                          'IMDT_2nd':['A41'],'EFFECT':['B20']}

        category = [cat for cat,nd in categories.items() if node in nd][0]

    return category

class AndGate(object):

    def __init__(self,rolled=False,continuity='root_1st'):
        if rolled == False:
            data = data_AND_Gate[data_AND_Gate["rolled_OR_unrolled"]=="Unrolled"]
        elif rolled == True:
            data = data_AND_Gate[data_AND_Gate["rolled_OR_unrolled"]=="Rolled"]
        if continuity == 'root_1st':
            data = data[data['root_1st']==data['imdt_2nd']]
        elif continuity == 'root_2nd':
            data = data[(data['root_1st']!=data['imdt_2nd'])|(data['state_OR_event']=='State')]
            
        self.df = data
        
        self.node_select = self.df["node_selected"].value_counts(normalize=True)*100
        values = {}
        nodes = ["nodeA"+str(i+1) for i in range(41)]+["nodeB"+str(i+1) for i in range(20)]
        for item in nodes:
            if item not in self.node_select.keys():
                values[item] = 0
            else:
                values[item] = self.node_select[item]
        self.node_select = pd.Series(values)
        
        self.node_category = self.df["node_category"].value_counts(normalize=True)*100
        values = {}
        cats = ['UNKNOWN','INACT_1st','INACT_2nd','ROOT_1st','ROOT_2nd','INBTW_1st','INBTW_2nd','IMDT_1st','IMDT_2nd','EFFECT']
        for item in cats:
            if item not in self.node_category.keys():
                values[item] = 0
            else:
                values[item] = self.node_category[item]
        self.node_category = pd.Series(values)
        
    def add_filter(self,sampling=None,level=None,state=None,root_1st=None,state_branch=None,A_detectors=None):
        if sampling == "right":
            self.df = self.df[self.df["sampling"]=="Right"]
        elif sampling == "left":
            self.df = self.df[self.df["sampling"]=="Left"]
        if level == "top":
            self.df = self.df[self.df["A_branch_loc"]=="Top"]
        elif level == "bottom":
            self.df = self.df[self.df["A_branch_loc"]=="Bottom"]
        if A_detectors == "squares":
            self.df = self.df[self.df["A_detectors"]=="Squares"]
        elif A_detectors == "circles":
            self.df = self.df[self.df["A_detectors"]=="Circles"]
        if state == False:
            self.df = self.df[self.df["state_OR_event"]=="Event"]
        elif state == True:
            self.df = self.df[self.df["state_OR_event"]=="State"]
        if root_1st == 'A':
            self.df = self.df[self.df["root_1st"]=="A"]
        elif root_1st == 'B':
            self.df = self.df[self.df["root_1st"]=="B"]
        if state_branch == 'A':
            self.df = self.df[self.df["state_branch"]=="A"]
        if state_branch == 'B':
            self.df = self.df[self.df["state_branch"]=="B"]
        
        self.node_select = self.df["node_selected"].value_counts(normalize=True)*100
        values = {}
        nodes = ["nodeA"+str(i+1) for i in range(41)]+["nodeB"+str(i+1) for i in range(20)]
        for item in nodes:
            if item not in self.node_select.keys():
                values[item] = 0
            else:
                values[item] = self.node_select[item]
        self.node_select = pd.Series(values)
        
        self.node_category = self.df["node_category"].value_counts(normalize=True)*100
        values = {}
        cats = ['UNKNOWN','INACT_1st','INACT_2nd','ROOT_1st','ROOT_2nd','INBTW_1st','INBTW_2nd','IMDT_1st','IMDT_2nd','EFFECT']
        for item in cats:
            if item not in self.node_category.keys():
                values[item] = 0
            else:
                values[item] = self.node_category[item]
        self.node_category = pd.Series(values)
        
        return self
    
class Chain(object):
    def __init__(self,stim=None):
        data = data_chain[data_chain["stim_type"] == stim]
            
        self.df = data
        
        self.node_select = self.df["node_selected"].value_counts(normalize=True)*100
        values = {}
        if stim == 'ChainS':
            nodes = ["nodeB"+str(i+1) for i in range(20)]
        elif stim == 'ChainC':
            nodes = ["nodeA"+str(i+1) for i in range(41)]+['nodesB20']
            
        for item in nodes:
            if item not in self.node_select.keys():
                values[item] = 0
            else:
                values[item] = self.node_select[item]
        self.node_select = pd.Series(values)
        
        self.node_category = self.df["node_category"].value_counts(normalize=True)*100
        values = {}
        cats = ['INACT','ROOT','INBTW','IMDT','EFFECT']
        for item in cats:
            if item not in self.node_category.keys():
                values[item] = 0
            else:
                values[item] = self.node_category[item]
        self.node_category = pd.Series(values)
        
    def add_filter(self,sampling=None,level=None):
        if sampling == "right":
            self.df = self.df[self.df["sampling"]=="Right"]
        elif sampling == "left":
            self.df = self.df[self.df["sampling"]=="Left"]
        if level == 'top':
            self.df = self.df[self.df['A_branch_loc']=='Top']
        elif level == 'bottom':
            self.df = self.df[self.df['A_branch_loc']=='Bottom']
            
        self.node_select = self.df["node_selected"].value_counts(normalize=True)*100
        values = {}
        stim = self.df['stim_type'].cat.remove_unused_categories().cat.categories[0]
        if stim == 'ChainS':
            nodes = ["nodeB"+str(i+1) for i in range(20)]
        elif stim == 'ChainC':
            nodes = ["nodeA"+str(i+1) for i in range(41)]+['nodesB20']
        for item in nodes:
            if item not in self.node_select.keys():
                values[item] = 0
            else:
                values[item] = self.node_select[item]
        self.node_select = pd.Series(values)
        
        self.node_category = self.df["node_category"].value_counts(normalize=True)*100
        values = {}
        cats = ['INACT','ROOT','INBTW','IMDT','EFFECT']
        for item in cats:
            if item not in self.node_category.keys():
                values[item] = 0
            else:
                values[item] = self.node_category[item]
        self.node_category = pd.Series(values)
        
        return self
    
def bootstrap(stim):
    df_mean_std = {}
    data = stim.df.node_category.to_numpy()
    labels = stim.df.node_category.cat.categories.to_list()
    if len(labels) == 9:
        labels = ['INACT_1st','INACT_2nd','ROOT_1st','ROOT_2nd','INBTW_1st','INBTW_2nd','IMDT_1st','IMDT_2nd','EFFECT']
    else:
        labels = ['INACT','ROOT','INBTW','IMDT','EFFECT']

    mean_per_cat = []
    std_per_cat = []    

    sample_mean = {}
    for category in labels:
            sample_mean[category] = []
    for _ in range(100):
        sample_n = np.random.choice(data, size=98)
        series = pd.Series(sample_n).value_counts(normalize=True)*100
        
        for category in sample_mean.keys():
            if category in series.index:
                mean = series[category]
                sample_mean[category].append(mean)

    for category in sample_mean.keys():
        sample_mean[category] = np.array(sample_mean[category])
        if len(sample_mean[category]) != 0:
            mean = np.mean(sample_mean[category])
            std = np.std(sample_mean[category])
        else:
            mean = 0
            std = 0

        mean_per_cat.append(mean)
        std_per_cat.append(std)

    df_mean_std["mean"] = mean_per_cat
    df_mean_std["std"] = std_per_cat

    df_mean_std = pd.DataFrame(df_mean_std,columns=['mean','std'],index=labels)
        
    return df_mean_std

def bootstrap2(stim):
    df_mean_std = {}
    data = stim.df.response.to_numpy()
    labels = ['RC','RD','IC','ID','other']

    mean_per_cat = []
    std_per_cat = []    

    sample_mean = {}
    for category in labels:
            sample_mean[category] = []
    for _ in range(100):
        sample_n = np.random.choice(data, size=100)
        series = pd.Series(sample_n).value_counts(normalize=True)*100
        
        for category in sample_mean.keys():
            if category in series.index:
                mean = series[category]
                sample_mean[category].append(mean)

    for category in sample_mean.keys():
        sample_mean[category] = np.array(sample_mean[category])
        if len(sample_mean[category]) != 0:
            mean = np.mean(sample_mean[category])
            std = np.std(sample_mean[category])
        else:
            mean = 0
            std = 0

        mean_per_cat.append(mean)
        std_per_cat.append(std)

    df_mean_std["mean"] = mean_per_cat
    df_mean_std["std"] = std_per_cat

    df_mean_std = pd.DataFrame(df_mean_std,columns=['mean','std'],index=labels)
        
    return df_mean_std
    
def graph(list_of_df,title,x_axis='node_category'):
    plt.rcParams['axes.grid'] = False
    fig = plt.figure(figsize=(6.6*len(list_of_df),5))
    #fig = plt.figure(figsize=(6,5))
    a = str(len(list_of_df))
    for i,x in enumerate(list_of_df):
        axis = fig.add_subplot(int("1"+a+str(i+1)))
        #axis = fig.add_subplot(111)
        axis.set_ylim([0,80])
        axis.set_ylabel("Percentage of responses")
        axis.label_outer()
        axis.spines["top"].set_visible(False)
        axis.spines["right"].set_visible(False)
        axis.set_title(title[i])
        
        labels = x.index.to_list()
        mean_per_cat = x['mean'].values
        std_per_cat = x['std'].values
        axis.bar(labels, mean_per_cat, yerr=std_per_cat,capsize=3,ecolor='black',error_kw={'markeredgewidth':1})
        plt.xticks(rotation=90)
            
def graph2(x,x_axis='node_category'):
    plt.rcParams['axes.grid'] = False
    fig = plt.figure(figsize=(3.15,1.57))
    #fig.suptitle("Experiment 1", fontweight="bold",y=1.05)
    axis = fig.add_subplot(111)
    axis.spines["top"].set_visible(False)
    axis.spines["right"].set_visible(False)
    axis.set_ylim([0,80])
    kwargs={'fontsize':7}
    axis.set_ylabel("Number of responses (%)",**kwargs)
    #axis.set_title('Summary of the results',**kwargs)
    axis.label_outer()
    categories = ['$\mathregular{1^{st}}$ R','$\mathregular{1^{st}}$ I','$\mathregular{2^{nd}}$ R','$\mathregular{2^{nd}}$ I','other']
    event_R1c_mean = [x[0].loc["ROOT_1st","mean"],x[0].loc["IMDT_1st","mean"],x[0].loc["ROOT_2nd",'mean'],
                 x[0].loc['IMDT_2nd','mean'],x[0].loc['INACT_1st','mean']+x[0].loc['INACT_2nd','mean']+
                 x[0].loc['INBTW_1st','mean']+x[0].loc['INBTW_2nd','mean']+x[0].loc['EFFECT','mean']]
    event_R2c_mean = [x[1].loc["ROOT_1st","mean"],x[1].loc["IMDT_1st","mean"],x[1].loc["ROOT_2nd",'mean'],
                 x[1].loc['IMDT_2nd','mean'],x[1].loc['INACT_1st','mean']+x[1].loc['INACT_2nd','mean']+
                 x[1].loc['INBTW_1st','mean']+x[1].loc['INBTW_2nd','mean']+x[1].loc['EFFECT','mean']]
    state_R2c_mean = [x[2].loc["ROOT_1st","mean"],x[2].loc["IMDT_1st","mean"],x[2].loc["ROOT_2nd",'mean'],
                 x[2].loc['IMDT_2nd','mean'],x[2].loc['INACT_1st','mean']+x[2].loc['INACT_2nd','mean']+
                 x[2].loc['INBTW_1st','mean']+x[2].loc['INBTW_2nd','mean']+x[2].loc['EFFECT','mean']]
                      
    event_R1c_std = [x[0].loc["ROOT_1st","std"],x[0].loc["IMDT_1st","std"],x[0].loc["ROOT_2nd",'std'],
                 x[0].loc['IMDT_2nd','std'],x[0].loc['INACT_1st','std']+x[0].loc['INACT_2nd','std']+
                 x[0].loc['INBTW_1st','std']+x[0].loc['INBTW_2nd','std']+x[0].loc['EFFECT','std']]
    event_R2c_std = [x[1].loc["ROOT_1st","std"],x[1].loc["IMDT_1st","std"],x[1].loc["ROOT_2nd",'std'],
                 x[1].loc['IMDT_2nd','std'],x[1].loc['INACT_1st','std']+x[1].loc['INACT_2nd','std']+
                 x[1].loc['INBTW_1st','std']+x[1].loc['INBTW_2nd','std']+x[1].loc['EFFECT','std']]
    state_R2c_std = [x[2].loc["ROOT_1st","std"],x[2].loc["IMDT_1st","std"],x[2].loc["ROOT_2nd",'std'],
                 x[2].loc['IMDT_2nd','std'],x[2].loc['INACT_1st','std']+x[2].loc['INACT_2nd','std']+
                 x[2].loc['INBTW_1st','std']+x[2].loc['INBTW_2nd','std']+x[2].loc['EFFECT','std']]
    
    df_mean = pd.DataFrame({'$R_C$,$R_D$,$I_D$,$I_C$':event_R1c_mean,'$R_D$,$R_C$,$I_D$,$I_C$':event_R2c_mean,'$R_D$,$I_D$,$R_C$,$I_C$':state_R2c_mean}, 
                          index=categories)
    df_std = pd.DataFrame({'$R_C$,$R_D$,$I_D$,$I_C$':event_R1c_std,'$R_D$,$R_C$,$I_D$,$I_C$':event_R2c_std,'$R_D$,$I_D$,$R_C$,$I_C$':state_R2c_std}, 
                          index=categories)
    
    #df_mean.plot.bar(ax=axis,yerr=df_std,capsize=2,ecolor='black',rot=0,error_kw={'markeredgewidth':0.0},fontsize=7)
    df_mean.plot.bar(ax=axis,yerr=df_std,capsize=1,ecolor='black',rot=0,error_kw={'elinewidth':0.5,'capthick':0.5},fontsize=7)
    axis.legend(fontsize=7)
    
def graph3(x,x_axis='node_category'):
    plt.rcParams['axes.grid'] = False
    fig = plt.figure(figsize=(3.15,1.57))
    #fig.suptitle("Experiment 1", fontweight="bold",y=1.05)
    axis = fig.add_subplot(111)
    axis.spines["top"].set_visible(False)
    axis.spines["right"].set_visible(False)
    axis.set_ylim([0,80])
    kwargs={'fontsize':7}
    axis.set_ylabel("Number of responses (%)",**kwargs)
    #axis.set_title('Summary of the results',**kwargs)
    axis.label_outer()
    categories = ['$R_C$','$R_D$','$I_C$','$I_D$','other']
    event_R1c_mean = [x[0].loc["RC","mean"],x[0].loc["RD","mean"],x[0].loc["IC",'mean'],
                 x[0].loc['ID','mean'],x[0].loc['other','mean']]
    event_R2c_mean = [x[1].loc["RC","mean"],x[0].loc["RD","mean"],x[1].loc["IC",'mean'],
                 x[1].loc['ID','mean'],x[1].loc['other','mean']]
    state_R2c_mean = [x[2].loc["RC","mean"],x[2].loc["RD","mean"],x[2].loc["IC",'mean'],
                 x[2].loc['ID','mean'],x[2].loc['other','mean']]
                      
    event_R1c_std = [x[0].loc["RC","std"],x[0].loc["RD","std"],x[0].loc["IC",'std'],
                 x[0].loc['ID','std'],x[0].loc['other','std']]
    event_R2c_std = [x[1].loc["RC","std"],x[1].loc["RD","std"],x[1].loc["IC",'std'],
                 x[1].loc['ID','std'],x[1].loc['other','std']]
    state_R2c_std = [x[2].loc["RC","std"],x[2].loc["RD","std"],x[2].loc["IC",'std'],
                 x[2].loc['ID','std'],x[2].loc['other','std']]
    
    df_mean = pd.DataFrame({'$R_C$,$R_D$,$I_D$,$I_C$':event_R1c_mean,'$R_D$,$R_C$,$I_D$,$I_C$':event_R2c_mean,'$R_D$,$I_D$,$R_C$,$I_C$':state_R2c_mean}, 
                          index=categories)
    df_std = pd.DataFrame({'$R_C$,$R_D$,$I_D$,$I_C$':event_R1c_std,'$R_D$,$R_C$,$I_D$,$I_C$':event_R2c_std,'$R_D$,$I_D$,$R_C$,$I_C$':state_R2c_std}, 
                          index=categories)   
    df_mean.plot.bar(ax=axis,yerr=df_std,capsize=1,ecolor='black',rot=0,error_kw={'elinewidth':0.5,'capthick':0.5},fontsize=7)
    axis.legend(fontsize=7)

# %%
data2 = data
data2['node_category'] = data2.apply(lambda x: node_cat(x['stimulus'],x['node_selected'],x['stim_type']),axis=1)
data2['response'] = data2.apply(lambda x: newCatLabels(x['root_1st'],x['imdt_2nd'],x['node_category']),axis=1)
data2['stimulusid'] = data2.apply(lambda x: newStimNames(x['stimulus']),axis=1)
data2['stimulustype'] = data2.apply(lambda x: newStimType(x['stim_type']),axis=1)
data2['order'] = data2.apply(lambda x: order(x['stimulus']),axis=1)
data2 = data2.drop(['rt','nb_of_run','node_selected','node_category','stimulus','stim_type','rolled_OR_unrolled',
                   'A_detectors','state_OR_event','state_branch','root_1st','imdt_2nd'],axis=1)
data2.rename(columns={'subject_id':'participantnum','sampling':'orientation',
                      'A_branch_loc':'position'},inplace=True)
data2['orientation']=data2['orientation'].str.lower()
data2['position']=data2['position'].str.lower()
data2 = data2[['participantnum','stimulusid','stimulustype','orientation','position','order','response']]
data2.head()
# Out:
#    participantnum stimulusid stimulustype orientation position     order  \
# 0               1   UAAS_RTb   dualbranch       right      top  RC_RD_ID
# 1               1   UABS_RTb   dualbranch       right   bottom  RD_RC_ID
# 2               1   UBBS_RTb   dualbranch       right      top  RC_RD_ID
# 3               1    UAS_RTb   dualbranch       right   bottom  RD_ID_RC
# 4               1  chainS_Rb        chain       right      NaN       NaN
#
#   response
# 0       RC
# 1       ID
# 2    other
# 3       ID
# 4       RC

# %%
data2['response'] = data2['response'].astype('category')

# %%
data2
# Out:
#      participantnum stimulusid stimulustype orientation position     order  \
# 0                 1   UAAS_RTb   dualbranch       right      top  RC_RD_ID
# 1                 1   UABS_RTb   dualbranch       right   bottom  RD_RC_ID
# 2                 1   UBBS_RTb   dualbranch       right      top  RC_RD_ID
# 3                 1    UAS_RTb   dualbranch       right   bottom  RD_ID_RC
# 4                 1  chainS_Rb        chain       right      NaN       NaN
# 5                 1    UBS_RTb   dualbranch       right   bottom  RD_ID_RC
# 6                 1   UBAS_RTb   dualbranch       right      top  RD_RC_ID
# 7                 2    UAS_RTb   dualbranch        left   bottom  RD_ID_RC
# 8                 2    UBS_RTb   dualbranch        left      top  RD_ID_RC
# 9                 2   UAAS_RTb   dualbranch        left   bottom  RC_RD_ID
# 10                2   UBBS_RTb   dualbranch        left   bottom  RC_RD_ID
# 11                2   UBAS_RTb   dualbranch        left      top  RD_RC_ID
# 12                2  chainS_Rb        chain        left      NaN       NaN
# 13                2   UABS_RTb   dualbranch        left      top  RD_RC_ID
# 14                3  chainS_Rb        chain       right      NaN       NaN
# 15                3   UBBS_RTb   dualbranch       right      top  RC_RD_ID
# 16                3   UBAS_RTb   dualbranch       right   bottom  RD_RC_ID
# 17                3    UAS_RTb   dualbranch       right   bottom  RD_ID_RC
# 18                3    UBS_RTb   dualbranch       right   bottom  RD_ID_RC
# 19                3   UABS_RTb   dualbranch       right   bottom  RD_RC_ID
# 20                3   UAAS_RTb   dualbranch       right      top  RC_RD_ID
# 21                4  chainS_Rb        chain        left      NaN       NaN
# 22                4   UAAS_RTb   dualbranch        left      top  RC_RD_ID
# 23                4   UBAS_RTb   dualbranch        left      top  RD_RC_ID
# 24                4    UAS_RTb   dualbranch        left      top  RD_ID_RC
# 25                4   UABS_RTb   dualbranch        left   bottom  RD_RC_ID
# 26                4   UBBS_RTb   dualbranch        left   bottom  RC_RD_ID
# 27                4    UBS_RTb   dualbranch        left      top  RD_ID_RC
# 28                5   UBAS_RTb   dualbranch       right      top  RD_RC_ID
# 29                5    UAS_RTb   dualbranch       right      top  RD_ID_RC
# 30                5  chainS_Rb        chain       right      NaN       NaN
# 31                5   UABS_RTb   dualbranch       right   bottom  RD_RC_ID
# 32                5    UBS_RTb   dualbranch       right   bottom  RD_ID_RC
# 33                5   UBBS_RTb   dualbranch       right      top  RC_RD_ID
# 34                5   UAAS_RTb   dualbranch       right   bottom  RC_RD_ID
# 35                6   UAAS_RTb   dualbranch       right      top  RC_RD_ID
# 36                6   UABS_RTb   dualbranch       right      top  RD_RC_ID
# 37                6   UBBS_RTb   dualbranch       right      top  RC_RD_ID
# 38                6    UBS_RTb   dualbranch       right      top  RD_ID_RC
# 39                6  chainS_Rb        chain       right      NaN       NaN
# 40                6   UBAS_RTb   dualbranch       right   bottom  RD_RC_ID
# 41                6    UAS_RTb   dualbranch       right      top  RD_ID_RC
# 42                7    UAS_RTb   dualbranch        left   bottom  RD_ID_RC
# 43                7   UBBS_RTb   dualbranch        left   bottom  RC_RD_ID
# 44                7   UBAS_RTb   dualbranch        left   bottom  RD_RC_ID
# 45                7  chainS_Rb        chain        left      NaN       NaN
# 46                7    UBS_RTb   dualbranch        left   bottom  RD_ID_RC
# 47                7   UABS_RTb   dualbranch        left   bottom  RD_RC_ID
# 48                7   UAAS_RTb   dualbranch        left   bottom  RC_RD_ID
# 49                8   UABS_RTb   dualbranch        left      top  RD_RC_ID
# 50                8   UBBS_RTb   dualbranch        left      top  RC_RD_ID
# 51                8   UAAS_RTb   dualbranch        left   bottom  RC_RD_ID
# 52                8  chainS_Rb        chain        left      NaN       NaN
# 53                8    UAS_RTb   dualbranch        left      top  RD_ID_RC
# 54                8   UBAS_RTb   dualbranch        left   bottom  RD_RC_ID
# 55                8    UBS_RTb   dualbranch        left   bottom  RD_ID_RC
# 56                9  chainS_Rb        chain       right      NaN       NaN
# 57                9    UAS_RTb   dualbranch       right   bottom  RD_ID_RC
# 58                9   UBBS_RTb   dualbranch       right   bottom  RC_RD_ID
# 59                9    UBS_RTb   dualbranch       right   bottom  RD_ID_RC
# 60                9   UABS_RTb   dualbranch       right   bottom  RD_RC_ID
# 61                9   UAAS_RTb   dualbranch       right   bottom  RC_RD_ID
# 62                9   UBAS_RTb   dualbranch       right      top  RD_RC_ID
# 63               10   UBBS_RTb   dualbranch       right   bottom  RC_RD_ID
# 64               10    UAS_RTb   dualbranch       right      top  RD_ID_RC
# 65               10   UABS_RTb   dualbranch       right   bottom  RD_RC_ID
# 66               10   UBAS_RTb   dualbranch       right      top  RD_RC_ID
# 67               10    UBS_RTb   dualbranch       right   bottom  RD_ID_RC
# 68               10  chainS_Rb        chain       right      NaN       NaN
# 69               10   UAAS_RTb   dualbranch       right      top  RC_RD_ID
# 70               11   UABS_RTb   dualbranch       right   bottom  RD_RC_ID
# 71               11    UAS_RTb   dualbranch       right   bottom  RD_ID_RC
# 72               11    UBS_RTb   dualbranch       right      top  RD_ID_RC
# 73               11   UAAS_RTb   dualbranch       right   bottom  RC_RD_ID
# 74               11  chainS_Rb        chain       right      NaN       NaN
# 75               11   UBBS_RTb   dualbranch       right      top  RC_RD_ID
# 76               11   UBAS_RTb   dualbranch       right      top  RD_RC_ID
# 77               12   UBBS_RTb   dualbranch        left   bottom  RC_RD_ID
# 78               12   UBAS_RTb   dualbranch        left   bottom  RD_RC_ID
# 79               12    UBS_RTb   dualbranch        left      top  RD_ID_RC
# 80               12   UABS_RTb   dualbranch        left      top  RD_RC_ID
# 81               12    UAS_RTb   dualbranch        left   bottom  RD_ID_RC
# 82               12  chainS_Rb        chain        left      NaN       NaN
# 83               12   UAAS_RTb   dualbranch        left   bottom  RC_RD_ID
# 84               13  chainS_Rb        chain       right      NaN       NaN
# 85               13    UAS_RTb   dualbranch       right      top  RD_ID_RC
# 86               13   UBAS_RTb   dualbranch       right      top  RD_RC_ID
# 87               13   UAAS_RTb   dualbranch       right   bottom  RC_RD_ID
# 88               13   UABS_RTb   dualbranch       right      top  RD_RC_ID
# 89               13   UBBS_RTb   dualbranch       right      top  RC_RD_ID
# 90               13    UBS_RTb   dualbranch       right      top  RD_ID_RC
# 91               14    UAS_RTb   dualbranch        left   bottom  RD_ID_RC
# 92               14   UABS_RTb   dualbranch        left   bottom  RD_RC_ID
# 93               14    UBS_RTb   dualbranch        left      top  RD_ID_RC
# 94               14   UBBS_RTb   dualbranch        left   bottom  RC_RD_ID
# 95               14  chainS_Rb        chain        left      NaN       NaN
# 96               14   UBAS_RTb   dualbranch        left      top  RD_RC_ID
# 97               14   UAAS_RTb   dualbranch        left      top  RC_RD_ID
# 98               15    UAS_RTb   dualbranch        left   bottom  RD_ID_RC
# 99               15  chainS_Rb        chain        left      NaN       NaN
# 100              15   UABS_RTb   dualbranch        left      top  RD_RC_ID
# 101              15   UBBS_RTb   dualbranch        left      top  RC_RD_ID
# 102              15   UAAS_RTb   dualbranch        left   bottom  RC_RD_ID
# 103              15    UBS_RTb   dualbranch        left      top  RD_ID_RC
# 104              15   UBAS_RTb   dualbranch        left      top  RD_RC_ID
# 105              16   UBBS_RTb   dualbranch       right      top  RC_RD_ID
# 106              16    UBS_RTb   dualbranch       right      top  RD_ID_RC
# 107              16  chainS_Rb        chain       right      NaN       NaN
# 108              16   UAAS_RTb   dualbranch       right      top  RC_RD_ID
# 109              16   UABS_RTb   dualbranch       right   bottom  RD_RC_ID
# 110              16    UAS_RTb   dualbranch       right   bottom  RD_ID_RC
# 111              16   UBAS_RTb   dualbranch       right      top  RD_RC_ID
# 112              17    UBS_RTb   dualbranch        left   bottom  RD_ID_RC
# 113              17   UABS_RTb   dualbranch        left   bottom  RD_RC_ID
# 114              17   UBAS_RTb   dualbranch        left   bottom  RD_RC_ID
# 115              17  chainS_Rb        chain        left      NaN       NaN
# 116              17   UBBS_RTb   dualbranch        left   bottom  RC_RD_ID
# 117              17    UAS_RTb   dualbranch        left   bottom  RD_ID_RC
# 118              17   UAAS_RTb   dualbranch        left   bottom  RC_RD_ID
# 119              18   UBBS_RTb   dualbranch       right      top  RC_RD_ID
# 120              18   UABS_RTb   dualbranch       right   bottom  RD_RC_ID
# 121              18    UAS_RTb   dualbranch       right      top  RD_ID_RC
# 122              18    UBS_RTb   dualbranch       right      top  RD_ID_RC
# 123              18   UBAS_RTb   dualbranch       right   bottom  RD_RC_ID
# 124              18   UAAS_RTb   dualbranch       right      top  RC_RD_ID
# 125              18  chainS_Rb        chain       right      NaN       NaN
# 126              19   UABS_RTb   dualbranch       right   bottom  RD_RC_ID
# 127              19   UBBS_RTb   dualbranch       right      top  RC_RD_ID
# 128              19  chainS_Rb        chain       right      NaN       NaN
# 129              19    UBS_RTb   dualbranch       right   bottom  RD_ID_RC
# 130              19   UAAS_RTb   dualbranch       right   bottom  RC_RD_ID
# 131              19   UBAS_RTb   dualbranch       right   bottom  RD_RC_ID
# 132              19    UAS_RTb   dualbranch       right   bottom  RD_ID_RC
# 133              20    UAS_RTb   dualbranch       right      top  RD_ID_RC
# 134              20   UBAS_RTb   dualbranch       right   bottom  RD_RC_ID
# 135              20   UBBS_RTb   dualbranch       right      top  RC_RD_ID
# 136              20    UBS_RTb   dualbranch       right      top  RD_ID_RC
# 137              20   UAAS_RTb   dualbranch       right      top  RC_RD_ID
# 138              20   UABS_RTb   dualbranch       right   bottom  RD_RC_ID
# 139              20  chainS_Rb        chain       right      NaN       NaN
# 140              21    UAS_RTb   dualbranch        left   bottom  RD_ID_RC
# 141              21   UBAS_RTb   dualbranch        left   bottom  RD_RC_ID
# 142              21  chainS_Rb        chain        left      NaN       NaN
# 143              21   UBBS_RTb   dualbranch        left   bottom  RC_RD_ID
# 144              21   UABS_RTb   dualbranch        left   bottom  RD_RC_ID
# 145              21    UBS_RTb   dualbranch        left      top  RD_ID_RC
# 146              21   UAAS_RTb   dualbranch        left   bottom  RC_RD_ID
# 147              22  chainS_Rb        chain       right      NaN       NaN
# 148              22    UBS_RTb   dualbranch       right      top  RD_ID_RC
# 149              22   UABS_RTb   dualbranch       right   bottom  RD_RC_ID
# 150              22   UBBS_RTb   dualbranch       right   bottom  RC_RD_ID
# 151              22   UBAS_RTb   dualbranch       right      top  RD_RC_ID
# 152              22    UAS_RTb   dualbranch       right   bottom  RD_ID_RC
# 153              22   UAAS_RTb   dualbranch       right   bottom  RC_RD_ID
# 154              23  chainS_Rb        chain       right      NaN       NaN
# 155              23   UBBS_RTb   dualbranch       right   bottom  RC_RD_ID
# 156              23    UBS_RTb   dualbranch       right   bottom  RD_ID_RC
# 157              23   UABS_RTb   dualbranch       right   bottom  RD_RC_ID
# 158              23   UAAS_RTb   dualbranch       right      top  RC_RD_ID
# 159              23    UAS_RTb   dualbranch       right   bottom  RD_ID_RC
# 160              23   UBAS_RTb   dualbranch       right      top  RD_RC_ID
# 161              24   UAAS_RTb   dualbranch       right      top  RC_RD_ID
# 162              24   UBBS_RTb   dualbranch       right      top  RC_RD_ID
# 163              24  chainS_Rb        chain       right      NaN       NaN
# 164              24    UBS_RTb   dualbranch       right   bottom  RD_ID_RC
# 165              24   UABS_RTb   dualbranch       right      top  RD_RC_ID
# 166              24   UBAS_RTb   dualbranch       right      top  RD_RC_ID
# 167              24    UAS_RTb   dualbranch       right      top  RD_ID_RC
# 168              25   UAAS_RTb   dualbranch        left   bottom  RC_RD_ID
# 169              25   UBAS_RTb   dualbranch        left      top  RD_RC_ID
# 170              25  chainS_Rb        chain        left      NaN       NaN
# 171              25    UAS_RTb   dualbranch        left   bottom  RD_ID_RC
# 172              25   UBBS_RTb   dualbranch        left      top  RC_RD_ID
# 173              25    UBS_RTb   dualbranch        left      top  RD_ID_RC
# 174              25   UABS_RTb   dualbranch        left      top  RD_RC_ID
# 175              26   UAAS_RTb   dualbranch       right   bottom  RC_RD_ID
# 176              26   UBAS_RTb   dualbranch       right   bottom  RD_RC_ID
# 177              26  chainS_Rb        chain       right      NaN       NaN
# 178              26   UBBS_RTb   dualbranch       right      top  RC_RD_ID
# 179              26    UAS_RTb   dualbranch       right   bottom  RD_ID_RC
# 180              26   UABS_RTb   dualbranch       right      top  RD_RC_ID
# 181              26    UBS_RTb   dualbranch       right   bottom  RD_ID_RC
# 182              27   UAAS_RTb   dualbranch       right   bottom  RC_RD_ID
# 183              27   UABS_RTb   dualbranch       right      top  RD_RC_ID
# 184              27   UBBS_RTb   dualbranch       right      top  RC_RD_ID
# 185              27   UBAS_RTb   dualbranch       right   bottom  RD_RC_ID
# 186              27  chainS_Rb        chain       right      NaN       NaN
# 187              27    UAS_RTb   dualbranch       right      top  RD_ID_RC
# 188              27    UBS_RTb   dualbranch       right   bottom  RD_ID_RC
# 189              28   UBBS_RTb   dualbranch       right      top  RC_RD_ID
# 190              28   UABS_RTb   dualbranch       right      top  RD_RC_ID
# 191              28   UAAS_RTb   dualbranch       right      top  RC_RD_ID
# 192              28   UBAS_RTb   dualbranch       right      top  RD_RC_ID
# 193              28  chainS_Rb        chain       right      NaN       NaN
# 194              28    UAS_RTb   dualbranch       right   bottom  RD_ID_RC
# 195              28    UBS_RTb   dualbranch       right   bottom  RD_ID_RC
# 196              29   UBAS_RTb   dualbranch       right   bottom  RD_RC_ID
# 197              29    UAS_RTb   dualbranch       right      top  RD_ID_RC
# 198              29   UBBS_RTb   dualbranch       right      top  RC_RD_ID
# 199              29  chainS_Rb        chain       right      NaN       NaN
# 200              29   UABS_RTb   dualbranch       right   bottom  RD_RC_ID
# 201              29   UAAS_RTb   dualbranch       right      top  RC_RD_ID
# 202              29    UBS_RTb   dualbranch       right   bottom  RD_ID_RC
# 203              30    UAS_RTb   dualbranch        left      top  RD_ID_RC
# 204              30   UBAS_RTb   dualbranch        left   bottom  RD_RC_ID
# 205              30   UBBS_RTb   dualbranch        left   bottom  RC_RD_ID
# 206              30  chainS_Rb        chain        left      NaN       NaN
# 207              30   UABS_RTb   dualbranch        left   bottom  RD_RC_ID
# 208              30    UBS_RTb   dualbranch        left   bottom  RD_ID_RC
# 209              30   UAAS_RTb   dualbranch        left      top  RC_RD_ID
# 210              31    UBS_RTb   dualbranch       right      top  RD_ID_RC
# 211              31   UBBS_RTb   dualbranch       right      top  RC_RD_ID
# 212              31   UBAS_RTb   dualbranch       right      top  RD_RC_ID
# 213              31   UABS_RTb   dualbranch       right      top  RD_RC_ID
# 214              31  chainS_Rb        chain       right      NaN       NaN
# 215              31    UAS_RTb   dualbranch       right      top  RD_ID_RC
# 216              31   UAAS_RTb   dualbranch       right      top  RC_RD_ID
# 217              32    UBS_RTb   dualbranch        left      top  RD_ID_RC
# 218              32    UAS_RTb   dualbranch        left      top  RD_ID_RC
# 219              32   UAAS_RTb   dualbranch        left   bottom  RC_RD_ID
# 220              32   UBBS_RTb   dualbranch        left   bottom  RC_RD_ID
# 221              32  chainS_Rb        chain        left      NaN       NaN
# 222              32   UBAS_RTb   dualbranch        left      top  RD_RC_ID
# 223              32   UABS_RTb   dualbranch        left   bottom  RD_RC_ID
# 224              33  chainS_Rb        chain        left      NaN       NaN
# 225              33   UABS_RTb   dualbranch        left   bottom  RD_RC_ID
# 226              33   UAAS_RTb   dualbranch        left      top  RC_RD_ID
# 227              33    UAS_RTb   dualbranch        left      top  RD_ID_RC
# 228              33    UBS_RTb   dualbranch        left   bottom  RD_ID_RC
# 229              33   UBBS_RTb   dualbranch        left   bottom  RC_RD_ID
# 230              33   UBAS_RTb   dualbranch        left      top  RD_RC_ID
# 231              34   UABS_RTb   dualbranch       right      top  RD_RC_ID
# 232              34  chainS_Rb        chain       right      NaN       NaN
# 233              34   UAAS_RTb   dualbranch       right      top  RC_RD_ID
# 234              34   UBAS_RTb   dualbranch       right      top  RD_RC_ID
# 235              34   UBBS_RTb   dualbranch       right      top  RC_RD_ID
# 236              34    UBS_RTb   dualbranch       right   bottom  RD_ID_RC
# 237              34    UAS_RTb   dualbranch       right      top  RD_ID_RC
# 238              35   UAAS_RTb   dualbranch        left      top  RC_RD_ID
# 239              35   UABS_RTb   dualbranch        left   bottom  RD_RC_ID
# 240              35    UBS_RTb   dualbranch        left      top  RD_ID_RC
# 241              35  chainS_Rb        chain        left      NaN       NaN
# 242              35    UAS_RTb   dualbranch        left      top  RD_ID_RC
# 243              35   UBAS_RTb   dualbranch        left      top  RD_RC_ID
# 244              35   UBBS_RTb   dualbranch        left      top  RC_RD_ID
# 245              36   UABS_RTb   dualbranch       right   bottom  RD_RC_ID
# 246              36   UAAS_RTb   dualbranch       right   bottom  RC_RD_ID
# 247              36   UBBS_RTb   dualbranch       right   bottom  RC_RD_ID
# 248              36   UBAS_RTb   dualbranch       right      top  RD_RC_ID
# 249              36    UBS_RTb   dualbranch       right   bottom  RD_ID_RC
# 250              36    UAS_RTb   dualbranch       right   bottom  RD_ID_RC
# 251              36  chainS_Rb        chain       right      NaN       NaN
# 252              37    UAS_RTb   dualbranch        left      top  RD_ID_RC
# 253              37   UABS_RTb   dualbranch        left   bottom  RD_RC_ID
# 254              37    UBS_RTb   dualbranch        left   bottom  RD_ID_RC
# 255              37  chainS_Rb        chain        left      NaN       NaN
# 256              37   UBAS_RTb   dualbranch        left      top  RD_RC_ID
# 257              37   UAAS_RTb   dualbranch        left      top  RC_RD_ID
# 258              37   UBBS_RTb   dualbranch        left      top  RC_RD_ID
# 259              38    UAS_RTb   dualbranch        left      top  RD_ID_RC
# 260              38  chainS_Rb        chain        left      NaN       NaN
# 261              38   UABS_RTb   dualbranch        left      top  RD_RC_ID
# 262              38   UBBS_RTb   dualbranch        left   bottom  RC_RD_ID
# 263              38    UBS_RTb   dualbranch        left      top  RD_ID_RC
# 264              38   UAAS_RTb   dualbranch        left      top  RC_RD_ID
# 265              38   UBAS_RTb   dualbranch        left      top  RD_RC_ID
# 266              39   UBBS_RTb   dualbranch        left      top  RC_RD_ID
# 267              39   UBAS_RTb   dualbranch        left      top  RD_RC_ID
# 268              39   UABS_RTb   dualbranch        left   bottom  RD_RC_ID
# 269              39    UAS_RTb   dualbranch        left   bottom  RD_ID_RC
# 270              39   UAAS_RTb   dualbranch        left      top  RC_RD_ID
# 271              39    UBS_RTb   dualbranch        left      top  RD_ID_RC
# 272              39  chainS_Rb        chain        left      NaN       NaN
# 273              40   UAAS_RTb   dualbranch        left   bottom  RC_RD_ID
# 274              40    UAS_RTb   dualbranch        left   bottom  RD_ID_RC
# 275              40  chainS_Rb        chain        left      NaN       NaN
# 276              40   UBAS_RTb   dualbranch        left      top  RD_RC_ID
# 277              40   UBBS_RTb   dualbranch        left      top  RC_RD_ID
# 278              40   UABS_RTb   dualbranch        left   bottom  RD_RC_ID
# 279              40    UBS_RTb   dualbranch        left   bottom  RD_ID_RC
# 280              41  chainS_Rb        chain       right      NaN       NaN
# 281              41    UBS_RTb   dualbranch       right   bottom  RD_ID_RC
# 282              41    UAS_RTb   dualbranch       right   bottom  RD_ID_RC
# 283              41   UBBS_RTb   dualbranch       right   bottom  RC_RD_ID
# 284              41   UAAS_RTb   dualbranch       right      top  RC_RD_ID
# 285              41   UABS_RTb   dualbranch       right      top  RD_RC_ID
# 286              41   UBAS_RTb   dualbranch       right      top  RD_RC_ID
# 287              42    UBS_RTb   dualbranch        left      top  RD_ID_RC
# 288              42   UABS_RTb   dualbranch        left   bottom  RD_RC_ID
# 289              42   UBAS_RTb   dualbranch        left      top  RD_RC_ID
# 290              42   UAAS_RTb   dualbranch        left   bottom  RC_RD_ID
# 291              42   UBBS_RTb   dualbranch        left      top  RC_RD_ID
# 292              42    UAS_RTb   dualbranch        left      top  RD_ID_RC
# 293              42  chainS_Rb        chain        left      NaN       NaN
# 294              43   UBBS_RTb   dualbranch       right   bottom  RC_RD_ID
# 295              43  chainS_Rb        chain       right      NaN       NaN
# 296              43   UABS_RTb   dualbranch       right   bottom  RD_RC_ID
# 297              43   UAAS_RTb   dualbranch       right      top  RC_RD_ID
# 298              43   UBAS_RTb   dualbranch       right   bottom  RD_RC_ID
# 299              43    UAS_RTb   dualbranch       right   bottom  RD_ID_RC
# 300              43    UBS_RTb   dualbranch       right   bottom  RD_ID_RC
# 301              44    UBS_RTb   dualbranch       right      top  RD_ID_RC
# 302              44   UBAS_RTb   dualbranch       right   bottom  RD_RC_ID
# 303              44   UAAS_RTb   dualbranch       right   bottom  RC_RD_ID
# 304              44  chainS_Rb        chain       right      NaN       NaN
# 305              44   UBBS_RTb   dualbranch       right   bottom  RC_RD_ID
# 306              44    UAS_RTb   dualbranch       right   bottom  RD_ID_RC
# 307              44   UABS_RTb   dualbranch       right      top  RD_RC_ID
# 308              45    UBS_RTb   dualbranch        left   bottom  RD_ID_RC
# 309              45    UAS_RTb   dualbranch        left      top  RD_ID_RC
# 310              45  chainS_Rb        chain        left      NaN       NaN
# 311              45   UABS_RTb   dualbranch        left      top  RD_RC_ID
# 312              45   UAAS_RTb   dualbranch        left   bottom  RC_RD_ID
# 313              45   UBAS_RTb   dualbranch        left   bottom  RD_RC_ID
# 314              45   UBBS_RTb   dualbranch        left      top  RC_RD_ID
# 315              46    UBS_RTb   dualbranch       right   bottom  RD_ID_RC
# 316              46    UAS_RTb   dualbranch       right   bottom  RD_ID_RC
# 317              46   UBBS_RTb   dualbranch       right      top  RC_RD_ID
# 318              46   UABS_RTb   dualbranch       right      top  RD_RC_ID
# 319              46  chainS_Rb        chain       right      NaN       NaN
# 320              46   UAAS_RTb   dualbranch       right   bottom  RC_RD_ID
# 321              46   UBAS_RTb   dualbranch       right      top  RD_RC_ID
# 322              47   UBBS_RTb   dualbranch       right   bottom  RC_RD_ID
# 323              47   UAAS_RTb   dualbranch       right      top  RC_RD_ID
# 324              47    UBS_RTb   dualbranch       right      top  RD_ID_RC
# 325              47  chainS_Rb        chain       right      NaN       NaN
# 326              47   UBAS_RTb   dualbranch       right   bottom  RD_RC_ID
# 327              47   UABS_RTb   dualbranch       right   bottom  RD_RC_ID
# 328              47    UAS_RTb   dualbranch       right      top  RD_ID_RC
# 329              48   UAAS_RTb   dualbranch       right      top  RC_RD_ID
# 330              48   UABS_RTb   dualbranch       right      top  RD_RC_ID
# 331              48    UBS_RTb   dualbranch       right      top  RD_ID_RC
# 332              48    UAS_RTb   dualbranch       right   bottom  RD_ID_RC
# 333              48   UBAS_RTb   dualbranch       right   bottom  RD_RC_ID
# 334              48   UBBS_RTb   dualbranch       right   bottom  RC_RD_ID
# 335              48  chainS_Rb        chain       right      NaN       NaN
# 336              49   UBBS_RTb   dualbranch       right   bottom  RC_RD_ID
# 337              49    UAS_RTb   dualbranch       right   bottom  RD_ID_RC
# 338              49   UBAS_RTb   dualbranch       right      top  RD_RC_ID
# 339              49   UABS_RTb   dualbranch       right   bottom  RD_RC_ID
# 340              49   UAAS_RTb   dualbranch       right      top  RC_RD_ID
# 341              49  chainS_Rb        chain       right      NaN       NaN
# 342              49    UBS_RTb   dualbranch       right      top  RD_ID_RC
# 343              50   UBBS_RTb   dualbranch        left   bottom  RC_RD_ID
# 344              50   UABS_RTb   dualbranch        left      top  RD_RC_ID
# 345              50    UAS_RTb   dualbranch        left   bottom  RD_ID_RC
# 346              50    UBS_RTb   dualbranch        left      top  RD_ID_RC
# 347              50   UAAS_RTb   dualbranch        left   bottom  RC_RD_ID
# 348              50  chainS_Rb        chain        left      NaN       NaN
# 349              50   UBAS_RTb   dualbranch        left   bottom  RD_RC_ID
# 350              51    UBS_RTb   dualbranch        left      top  RD_ID_RC
# 351              51   UABS_RTb   dualbranch        left      top  RD_RC_ID
# 352              51   UAAS_RTb   dualbranch        left   bottom  RC_RD_ID
# 353              51    UAS_RTb   dualbranch        left   bottom  RD_ID_RC
# 354              51   UBBS_RTb   dualbranch        left   bottom  RC_RD_ID
# 355              51  chainS_Rb        chain        left      NaN       NaN
# 356              51   UBAS_RTb   dualbranch        left      top  RD_RC_ID
# 357              52   UBAS_RTb   dualbranch       right   bottom  RD_RC_ID
# 358              52  chainS_Rb        chain       right      NaN       NaN
# 359              52   UABS_RTb   dualbranch       right      top  RD_RC_ID
# 360              52    UAS_RTb   dualbranch       right      top  RD_ID_RC
# 361              52    UBS_RTb   dualbranch       right   bottom  RD_ID_RC
# 362              52   UBBS_RTb   dualbranch       right      top  RC_RD_ID
# 363              52   UAAS_RTb   dualbranch       right      top  RC_RD_ID
# 364              53  chainS_Rb        chain       right      NaN       NaN
# 365              53    UAS_RTb   dualbranch       right      top  RD_ID_RC
# 366              53   UBAS_RTb   dualbranch       right      top  RD_RC_ID
# 367              53   UAAS_RTb   dualbranch       right   bottom  RC_RD_ID
# 368              53    UBS_RTb   dualbranch       right   bottom  RD_ID_RC
# 369              53   UABS_RTb   dualbranch       right      top  RD_RC_ID
# 370              53   UBBS_RTb   dualbranch       right   bottom  RC_RD_ID
# 371              54   UBBS_RTb   dualbranch        left   bottom  RC_RD_ID
# 372              54   UBAS_RTb   dualbranch        left   bottom  RD_RC_ID
# 373              54   UAAS_RTb   dualbranch        left   bottom  RC_RD_ID
# 374              54    UBS_RTb   dualbranch        left   bottom  RD_ID_RC
# 375              54    UAS_RTb   dualbranch        left      top  RD_ID_RC
# 376              54  chainS_Rb        chain        left      NaN       NaN
# 377              54   UABS_RTb   dualbranch        left   bottom  RD_RC_ID
# 378              55   UAAS_RTb   dualbranch       right   bottom  RC_RD_ID
# 379              55    UBS_RTb   dualbranch       right   bottom  RD_ID_RC
# 380              55  chainS_Rb        chain       right      NaN       NaN
# 381              55    UAS_RTb   dualbranch       right   bottom  RD_ID_RC
# 382              55   UABS_RTb   dualbranch       right   bottom  RD_RC_ID
# 383              55   UBAS_RTb   dualbranch       right      top  RD_RC_ID
# 384              55   UBBS_RTb   dualbranch       right      top  RC_RD_ID
# 385              56  chainS_Rb        chain        left      NaN       NaN
# 386              56   UBAS_RTb   dualbranch        left      top  RD_RC_ID
# 387              56    UBS_RTb   dualbranch        left      top  RD_ID_RC
# 388              56   UAAS_RTb   dualbranch        left      top  RC_RD_ID
# 389              56   UBBS_RTb   dualbranch        left   bottom  RC_RD_ID
# 390              56   UABS_RTb   dualbranch        left   bottom  RD_RC_ID
# 391              56    UAS_RTb   dualbranch        left      top  RD_ID_RC
# 392              57    UAS_RTb   dualbranch        left   bottom  RD_ID_RC
# 393              57   UBAS_RTb   dualbranch        left   bottom  RD_RC_ID
# 394              57   UBBS_RTb   dualbranch        left      top  RC_RD_ID
# 395              57    UBS_RTb   dualbranch        left   bottom  RD_ID_RC
# 396              57   UABS_RTb   dualbranch        left      top  RD_RC_ID
# 397              57  chainS_Rb        chain        left      NaN       NaN
# 398              57   UAAS_RTb   dualbranch        left   bottom  RC_RD_ID
# 399              58    UAS_RTb   dualbranch        left      top  RD_ID_RC
# 400              58  chainS_Rb        chain        left      NaN       NaN
# 401              58   UBBS_RTb   dualbranch        left   bottom  RC_RD_ID
# 402              58   UABS_RTb   dualbranch        left      top  RD_RC_ID
# 403              58   UAAS_RTb   dualbranch        left   bottom  RC_RD_ID
# 404              58    UBS_RTb   dualbranch        left      top  RD_ID_RC
# 405              58   UBAS_RTb   dualbranch        left   bottom  RD_RC_ID
# 406              59    UAS_RTb   dualbranch        left      top  RD_ID_RC
# 407              59   UABS_RTb   dualbranch        left      top  RD_RC_ID
# 408              59   UBAS_RTb   dualbranch        left   bottom  RD_RC_ID
# 409              59    UBS_RTb   dualbranch        left      top  RD_ID_RC
# 410              59   UBBS_RTb   dualbranch        left   bottom  RC_RD_ID
# 411              59  chainS_Rb        chain        left      NaN       NaN
# 412              59   UAAS_RTb   dualbranch        left   bottom  RC_RD_ID
# 413              60    UBS_RTb   dualbranch       right      top  RD_ID_RC
# 414              60  chainS_Rb        chain       right      NaN       NaN
# 415              60   UAAS_RTb   dualbranch       right   bottom  RC_RD_ID
# 416              60   UBBS_RTb   dualbranch       right      top  RC_RD_ID
# 417              60   UABS_RTb   dualbranch       right   bottom  RD_RC_ID
# 418              60    UAS_RTb   dualbranch       right      top  RD_ID_RC
# 419              60   UBAS_RTb   dualbranch       right   bottom  RD_RC_ID
# 420              61   UAAS_RTb   dualbranch       right      top  RC_RD_ID
# 421              61   UABS_RTb   dualbranch       right      top  RD_RC_ID
# 422              61   UBAS_RTb   dualbranch       right      top  RD_RC_ID
# 423              61    UBS_RTb   dualbranch       right      top  RD_ID_RC
# 424              61   UBBS_RTb   dualbranch       right      top  RC_RD_ID
# 425              61    UAS_RTb   dualbranch       right   bottom  RD_ID_RC
# 426              61  chainS_Rb        chain       right      NaN       NaN
# 427              62    UAS_RTb   dualbranch        left      top  RD_ID_RC
# 428              62    UBS_RTb   dualbranch        left      top  RD_ID_RC
# 429              62   UBAS_RTb   dualbranch        left      top  RD_RC_ID
# 430              62  chainS_Rb        chain        left      NaN       NaN
# 431              62   UAAS_RTb   dualbranch        left      top  RC_RD_ID
# 432              62   UABS_RTb   dualbranch        left      top  RD_RC_ID
# 433              62   UBBS_RTb   dualbranch        left      top  RC_RD_ID
# 434              63  chainS_Rb        chain       right      NaN       NaN
# 435              63    UAS_RTb   dualbranch       right   bottom  RD_ID_RC
# 436              63    UBS_RTb   dualbranch       right      top  RD_ID_RC
# 437              63   UBAS_RTb   dualbranch       right      top  RD_RC_ID
# 438              63   UBBS_RTb   dualbranch       right      top  RC_RD_ID
# 439              63   UABS_RTb   dualbranch       right   bottom  RD_RC_ID
# 440              63   UAAS_RTb   dualbranch       right   bottom  RC_RD_ID
# 441              64   UABS_RTb   dualbranch       right   bottom  RD_RC_ID
# 442              64   UBBS_RTb   dualbranch       right      top  RC_RD_ID
# 443              64   UAAS_RTb   dualbranch       right   bottom  RC_RD_ID
# 444              64  chainS_Rb        chain       right      NaN       NaN
# 445              64    UAS_RTb   dualbranch       right      top  RD_ID_RC
# 446              64   UBAS_RTb   dualbranch       right   bottom  RD_RC_ID
# 447              64    UBS_RTb   dualbranch       right   bottom  RD_ID_RC
# 448              65    UBS_RTb   dualbranch       right   bottom  RD_ID_RC
# 449              65   UBAS_RTb   dualbranch       right      top  RD_RC_ID
# 450              65   UAAS_RTb   dualbranch       right   bottom  RC_RD_ID
# 451              65   UABS_RTb   dualbranch       right   bottom  RD_RC_ID
# 452              65  chainS_Rb        chain       right      NaN       NaN
# 453              65   UBBS_RTb   dualbranch       right   bottom  RC_RD_ID
# 454              65    UAS_RTb   dualbranch       right      top  RD_ID_RC
# 455              66   UABS_RTb   dualbranch       right   bottom  RD_RC_ID
# 456              66    UBS_RTb   dualbranch       right   bottom  RD_ID_RC
# 457              66  chainS_Rb        chain       right      NaN       NaN
# 458              66   UBBS_RTb   dualbranch       right      top  RC_RD_ID
# 459              66   UBAS_RTb   dualbranch       right      top  RD_RC_ID
# 460              66    UAS_RTb   dualbranch       right      top  RD_ID_RC
# 461              66   UAAS_RTb   dualbranch       right   bottom  RC_RD_ID
# 462              67   UABS_RTb   dualbranch       right      top  RD_RC_ID
# 463              67   UAAS_RTb   dualbranch       right   bottom  RC_RD_ID
# 464              67   UBAS_RTb   dualbranch       right   bottom  RD_RC_ID
# 465              67   UBBS_RTb   dualbranch       right      top  RC_RD_ID
# 466              67    UBS_RTb   dualbranch       right   bottom  RD_ID_RC
# 467              67    UAS_RTb   dualbranch       right      top  RD_ID_RC
# 468              67  chainS_Rb        chain       right      NaN       NaN
# 469              68  chainS_Rb        chain        left      NaN       NaN
# 470              68   UABS_RTb   dualbranch        left      top  RD_RC_ID
# 471              68    UAS_RTb   dualbranch        left   bottom  RD_ID_RC
# 472              68   UAAS_RTb   dualbranch        left   bottom  RC_RD_ID
# 473              68    UBS_RTb   dualbranch        left      top  RD_ID_RC
# 474              68   UBBS_RTb   dualbranch        left   bottom  RC_RD_ID
# 475              68   UBAS_RTb   dualbranch        left      top  RD_RC_ID
# 476              69    UAS_RTb   dualbranch        left   bottom  RD_ID_RC
# 477              69  chainS_Rb        chain        left      NaN       NaN
# 478              69   UBBS_RTb   dualbranch        left   bottom  RC_RD_ID
# 479              69   UABS_RTb   dualbranch        left   bottom  RD_RC_ID
# 480              69   UAAS_RTb   dualbranch        left      top  RC_RD_ID
# 481              69   UBAS_RTb   dualbranch        left      top  RD_RC_ID
# 482              69    UBS_RTb   dualbranch        left      top  RD_ID_RC
# 483              70   UABS_RTb   dualbranch       right      top  RD_RC_ID
# 484              70   UBAS_RTb   dualbranch       right      top  RD_RC_ID
# 485              70  chainS_Rb        chain       right      NaN       NaN
# 486              70    UBS_RTb   dualbranch       right      top  RD_ID_RC
# 487              70   UBBS_RTb   dualbranch       right   bottom  RC_RD_ID
# 488              70   UAAS_RTb   dualbranch       right   bottom  RC_RD_ID
# 489              70    UAS_RTb   dualbranch       right   bottom  RD_ID_RC
# 490              71    UAS_RTb   dualbranch        left      top  RD_ID_RC
# 491              71   UAAS_RTb   dualbranch        left      top  RC_RD_ID
# 492              71   UBAS_RTb   dualbranch        left   bottom  RD_RC_ID
# 493              71   UBBS_RTb   dualbranch        left      top  RC_RD_ID
# 494              71    UBS_RTb   dualbranch        left   bottom  RD_ID_RC
# 495              71  chainS_Rb        chain        left      NaN       NaN
# 496              71   UABS_RTb   dualbranch        left      top  RD_RC_ID
# 497              72   UABS_RTb   dualbranch        left      top  RD_RC_ID
# 498              72    UBS_RTb   dualbranch        left   bottom  RD_ID_RC
# 499              72   UAAS_RTb   dualbranch        left      top  RC_RD_ID
# 500              72  chainS_Rb        chain        left      NaN       NaN
# 501              72    UAS_RTb   dualbranch        left   bottom  RD_ID_RC
# 502              72   UBBS_RTb   dualbranch        left      top  RC_RD_ID
# 503              72   UBAS_RTb   dualbranch        left      top  RD_RC_ID
# 504              73    UBS_RTb   dualbranch       right   bottom  RD_ID_RC
# 505              73   UBAS_RTb   dualbranch       right      top  RD_RC_ID
# 506              73    UAS_RTb   dualbranch       right   bottom  RD_ID_RC
# 507              73   UABS_RTb   dualbranch       right      top  RD_RC_ID
# 508              73  chainS_Rb        chain       right      NaN       NaN
# 509              73   UAAS_RTb   dualbranch       right   bottom  RC_RD_ID
# 510              73   UBBS_RTb   dualbranch       right      top  RC_RD_ID
# 511              74   UABS_RTb   dualbranch        left   bottom  RD_RC_ID
# 512              74  chainS_Rb        chain        left      NaN       NaN
# 513              74   UBAS_RTb   dualbranch        left   bottom  RD_RC_ID
# 514              74   UAAS_RTb   dualbranch        left   bottom  RC_RD_ID
# 515              74    UAS_RTb   dualbranch        left   bottom  RD_ID_RC
# 516              74   UBBS_RTb   dualbranch        left   bottom  RC_RD_ID
# 517              74    UBS_RTb   dualbranch        left      top  RD_ID_RC
# 518              75   UBAS_RTb   dualbranch        left   bottom  RD_RC_ID
# 519              75   UAAS_RTb   dualbranch        left   bottom  RC_RD_ID
# 520              75    UAS_RTb   dualbranch        left   bottom  RD_ID_RC
# 521              75  chainS_Rb        chain        left      NaN       NaN
# 522              75    UBS_RTb   dualbranch        left   bottom  RD_ID_RC
# 523              75   UABS_RTb   dualbranch        left   bottom  RD_RC_ID
# 524              75   UBBS_RTb   dualbranch        left      top  RC_RD_ID
# 525              76   UBAS_RTb   dualbranch        left   bottom  RD_RC_ID
# 526              76  chainS_Rb        chain        left      NaN       NaN
# 527              76   UBBS_RTb   dualbranch        left      top  RC_RD_ID
# 528              76   UAAS_RTb   dualbranch        left   bottom  RC_RD_ID
# 529              76    UAS_RTb   dualbranch        left      top  RD_ID_RC
# 530              76   UABS_RTb   dualbranch        left      top  RD_RC_ID
# 531              76    UBS_RTb   dualbranch        left   bottom  RD_ID_RC
# 532              77   UABS_RTb   dualbranch       right   bottom  RD_RC_ID
# 533              77  chainS_Rb        chain       right      NaN       NaN
# 534              77    UAS_RTb   dualbranch       right      top  RD_ID_RC
# 535              77   UAAS_RTb   dualbranch       right   bottom  RC_RD_ID
# 536              77   UBBS_RTb   dualbranch       right      top  RC_RD_ID
# 537              77   UBAS_RTb   dualbranch       right   bottom  RD_RC_ID
# 538              77    UBS_RTb   dualbranch       right      top  RD_ID_RC
# 539              78    UAS_RTb   dualbranch        left   bottom  RD_ID_RC
# 540              78   UAAS_RTb   dualbranch        left   bottom  RC_RD_ID
# 541              78   UBAS_RTb   dualbranch        left      top  RD_RC_ID
# 542              78  chainS_Rb        chain        left      NaN       NaN
# 543              78   UABS_RTb   dualbranch        left   bottom  RD_RC_ID
# 544              78   UBBS_RTb   dualbranch        left      top  RC_RD_ID
# 545              78    UBS_RTb   dualbranch        left      top  RD_ID_RC
# 546              79  chainS_Rb        chain       right      NaN       NaN
# 547              79    UBS_RTb   dualbranch       right   bottom  RD_ID_RC
# 548              79   UBBS_RTb   dualbranch       right   bottom  RC_RD_ID
# 549              79    UAS_RTb   dualbranch       right   bottom  RD_ID_RC
# 550              79   UBAS_RTb   dualbranch       right      top  RD_RC_ID
# 551              79   UABS_RTb   dualbranch       right      top  RD_RC_ID
# 552              79   UAAS_RTb   dualbranch       right      top  RC_RD_ID
# 553              80   UBAS_RTb   dualbranch        left      top  RD_RC_ID
# 554              80    UBS_RTb   dualbranch        left   bottom  RD_ID_RC
# 555              80   UAAS_RTb   dualbranch        left   bottom  RC_RD_ID
# 556              80  chainS_Rb        chain        left      NaN       NaN
# 557              80   UBBS_RTb   dualbranch        left   bottom  RC_RD_ID
# 558              80    UAS_RTb   dualbranch        left   bottom  RD_ID_RC
# 559              80   UABS_RTb   dualbranch        left   bottom  RD_RC_ID
# 560              81   UBAS_RTb   dualbranch       right      top  RD_RC_ID
# 561              81  chainS_Rb        chain       right      NaN       NaN
# 562              81   UABS_RTb   dualbranch       right      top  RD_RC_ID
# 563              81   UAAS_RTb   dualbranch       right      top  RC_RD_ID
# 564              81    UBS_RTb   dualbranch       right      top  RD_ID_RC
# 565              81    UAS_RTb   dualbranch       right   bottom  RD_ID_RC
# 566              81   UBBS_RTb   dualbranch       right      top  RC_RD_ID
# 567              82    UAS_RTb   dualbranch        left   bottom  RD_ID_RC
# 568              82   UABS_RTb   dualbranch        left      top  RD_RC_ID
# 569              82   UBAS_RTb   dualbranch        left   bottom  RD_RC_ID
# 570              82  chainS_Rb        chain        left      NaN       NaN
# 571              82    UBS_RTb   dualbranch        left      top  RD_ID_RC
# 572              82   UBBS_RTb   dualbranch        left   bottom  RC_RD_ID
# 573              82   UAAS_RTb   dualbranch        left      top  RC_RD_ID
# 574              83    UAS_RTb   dualbranch       right   bottom  RD_ID_RC
# 575              83   UBBS_RTb   dualbranch       right      top  RC_RD_ID
# 576              83   UAAS_RTb   dualbranch       right      top  RC_RD_ID
# 577              83  chainS_Rb        chain       right      NaN       NaN
# 578              83    UBS_RTb   dualbranch       right      top  RD_ID_RC
# 579              83   UBAS_RTb   dualbranch       right      top  RD_RC_ID
# 580              83   UABS_RTb   dualbranch       right      top  RD_RC_ID
# 581              84  chainS_Rb        chain       right      NaN       NaN
# 582              84   UBAS_RTb   dualbranch       right   bottom  RD_RC_ID
# 583              84   UABS_RTb   dualbranch       right   bottom  RD_RC_ID
# 584              84    UAS_RTb   dualbranch       right      top  RD_ID_RC
# 585              84   UBBS_RTb   dualbranch       right      top  RC_RD_ID
# 586              84    UBS_RTb   dualbranch       right   bottom  RD_ID_RC
# 587              84   UAAS_RTb   dualbranch       right      top  RC_RD_ID
# 588              85   UBBS_RTb   dualbranch        left      top  RC_RD_ID
# 589              85    UAS_RTb   dualbranch        left   bottom  RD_ID_RC
# 590              85  chainS_Rb        chain        left      NaN       NaN
# 591              85   UBAS_RTb   dualbranch        left   bottom  RD_RC_ID
# 592              85   UABS_RTb   dualbranch        left   bottom  RD_RC_ID
# 593              85   UAAS_RTb   dualbranch        left      top  RC_RD_ID
# 594              85    UBS_RTb   dualbranch        left   bottom  RD_ID_RC
# 595              86   UABS_RTb   dualbranch        left      top  RD_RC_ID
# 596              86  chainS_Rb        chain        left      NaN       NaN
# 597              86    UBS_RTb   dualbranch        left      top  RD_ID_RC
# 598              86   UBBS_RTb   dualbranch        left      top  RC_RD_ID
# 599              86   UAAS_RTb   dualbranch        left   bottom  RC_RD_ID
# 600              86   UBAS_RTb   dualbranch        left      top  RD_RC_ID
# 601              86    UAS_RTb   dualbranch        left      top  RD_ID_RC
# 602              87    UAS_RTb   dualbranch        left      top  RD_ID_RC
# 603              87   UBBS_RTb   dualbranch        left      top  RC_RD_ID
# 604              87    UBS_RTb   dualbranch        left      top  RD_ID_RC
# 605              87   UBAS_RTb   dualbranch        left   bottom  RD_RC_ID
# 606              87   UAAS_RTb   dualbranch        left   bottom  RC_RD_ID
# 607              87   UABS_RTb   dualbranch        left   bottom  RD_RC_ID
# 608              87  chainS_Rb        chain        left      NaN       NaN
# 609              88   UBAS_RTb   dualbranch        left      top  RD_RC_ID
# 610              88    UAS_RTb   dualbranch        left      top  RD_ID_RC
# 611              88   UAAS_RTb   dualbranch        left   bottom  RC_RD_ID
# 612              88   UBBS_RTb   dualbranch        left      top  RC_RD_ID
# 613              88    UBS_RTb   dualbranch        left      top  RD_ID_RC
# ...
# 630              91   UAAS_RTb   dualbranch       right   bottom  RC_RD_ID
# 631              91    UBS_RTb   dualbranch       right   bottom  RD_ID_RC
# 632              91   UBAS_RTb   dualbranch       right      top  RD_RC_ID
# 633              91    UAS_RTb   dualbranch       right   bottom  RD_ID_RC
# 634              91   UABS_RTb   dualbranch       right   bottom  RD_RC_ID
# 635              91   UBBS_RTb   dualbranch       right      top  RC_RD_ID
# 636              91  chainS_Rb        chain       right      NaN       NaN
# 637              92   UAAS_RTb   dualbranch       right   bottom  RC_RD_ID
# 638              92    UBS_RTb   dualbranch       right      top  RD_ID_RC
# 639              92  chainS_Rb        chain       right      NaN       NaN
# 640              92   UBBS_RTb   dualbranch       right   bottom  RC_RD_ID
# 641              92    UAS_RTb   dualbranch       right      top  RD_ID_RC
# 642              92   UBAS_RTb   dualbranch       right      top  RD_RC_ID
# 643              92   UABS_RTb   dualbranch       right   bottom  RD_RC_ID
# 644              93   UABS_RTb   dualbranch       right   bottom  RD_RC_ID
# 645              93    UBS_RTb   dualbranch       right   bottom  RD_ID_RC
# 646              93   UBBS_RTb   dualbranch       right      top  RC_RD_ID
# 647              93    UAS_RTb   dualbranch       right      top  RD_ID_RC
# 648              93  chainS_Rb        chain       right      NaN       NaN
# 649              93   UAAS_RTb   dualbranch       right      top  RC_RD_ID
# 650              93   UBAS_RTb   dualbranch       right   bottom  RD_RC_ID
# 651              94  chainS_Rb        chain        left      NaN       NaN
# 652              94   UBAS_RTb   dualbranch        left   bottom  RD_RC_ID
# 653              94    UBS_RTb   dualbranch        left   bottom  RD_ID_RC
# 654              94    UAS_RTb   dualbranch        left   bottom  RD_ID_RC
# 655              94   UAAS_RTb   dualbranch        left   bottom  RC_RD_ID
# 656              94   UBBS_RTb   dualbranch        left      top  RC_RD_ID
# 657              94   UABS_RTb   dualbranch        left      top  RD_RC_ID
# 658              95  chainS_Rb        chain        left      NaN       NaN
# 659              95    UAS_RTb   dualbranch        left      top  RD_ID_RC
# 660              95   UBBS_RTb   dualbranch        left      top  RC_RD_ID
# 661              95   UAAS_RTb   dualbranch        left      top  RC_RD_ID
# 662              95    UBS_RTb   dualbranch        left   bottom  RD_ID_RC
# 663              95   UABS_RTb   dualbranch        left   bottom  RD_RC_ID
# 664              95   UBAS_RTb   dualbranch        left   bottom  RD_RC_ID
# 665              96   UBAS_RTb   dualbranch       right   bottom  RD_RC_ID
# 666              96  chainS_Rb        chain       right      NaN       NaN
# 667              96   UAAS_RTb   dualbranch       right   bottom  RC_RD_ID
# 668              96   UBBS_RTb   dualbranch       right   bottom  RC_RD_ID
# 669              96    UAS_RTb   dualbranch       right      top  RD_ID_RC
# 670              96   UABS_RTb   dualbranch       right   bottom  RD_RC_ID
# 671              96    UBS_RTb   dualbranch       right   bottom  RD_ID_RC
# 672              97   UAAS_RTb   dualbranch        left      top  RC_RD_ID
# 673              97   UBBS_RTb   dualbranch        left   bottom  RC_RD_ID
# 674              97   UBAS_RTb   dualbranch        left      top  RD_RC_ID
# 675              97    UBS_RTb   dualbranch        left      top  RD_ID_RC
# 676              97    UAS_RTb   dualbranch        left   bottom  RD_ID_RC
# 677              97   UABS_RTb   dualbranch        left   bottom  RD_RC_ID
# 678              97  chainS_Rb        chain        left      NaN       NaN
# 679              98    UAS_RTb   dualbranch       right   bottom  RD_ID_RC
# 680              98   UABS_RTb   dualbranch       right   bottom  RD_RC_ID
# 681              98   UBBS_RTb   dualbranch       right   bottom  RC_RD_ID
# 682              98   UBAS_RTb   dualbranch       right   bottom  RD_RC_ID
# 683              98    UBS_RTb   dualbranch       right      top  RD_ID_RC
# 684              98  chainS_Rb        chain       right      NaN       NaN
# 685              98   UAAS_RTb   dualbranch       right   bottom  RC_RD_ID
# 686              99  chainS_Rb        chain       right      NaN       NaN
# 687              99   UBAS_RTb   dualbranch       right      top  RD_RC_ID
# 688              99    UAS_RTb   dualbranch       right   bottom  RD_ID_RC
# 689              99   UAAS_RTb   dualbranch       right   bottom  RC_RD_ID
# 690              99    UBS_RTb   dualbranch       right   bottom  RD_ID_RC
# 691              99   UABS_RTb   dualbranch       right      top  RD_RC_ID
# 692              99   UBBS_RTb   dualbranch       right   bottom  RC_RD_ID
# 693             100   UAAS_RTb   dualbranch       right   bottom  RC_RD_ID
# 694             100   UBAS_RTb   dualbranch       right      top  RD_RC_ID
# 695             100   UBBS_RTb   dualbranch       right   bottom  RC_RD_ID
# 696             100    UAS_RTb   dualbranch       right      top  RD_ID_RC
# 697             100    UBS_RTb   dualbranch       right      top  RD_ID_RC
# 698             100   UABS_RTb   dualbranch       right   bottom  RD_RC_ID
# 699             100  chainS_Rb        chain       right      NaN       NaN
#
#     response
# 0         RC
# 1         ID
# 2      other
# 3         ID
# 4         RC
# 5         ID
# 6      other
# 7         RD
# 8         RD
# 9         RC
# 10        RC
# 11        RD
# 12        RC
# 13        RD
# 14        RC
# 15        RC
# 16        RC
# 17        RC
# 18        RC
# 19        RC
# 20        RC
# 21        IC
# 22        RC
# 23        RD
# 24        IC
# 25        IC
# 26        RC
# 27        RC
# 28        RD
# 29        RD
# 30        RC
# 31        RC
# 32        RC
# 33        RD
# 34        RD
# 35     other
# 36     other
# 37     other
# 38     other
# 39        RC
# 40     other
# 41        ID
# 42        RD
# 43        RC
# 44        RC
# 45        RC
# 46        RC
# 47        RC
# 48        IC
# 49        RD
# 50        RC
# 51        RC
# 52        RC
# 53        RD
# 54        RD
# 55        RD
# 56        RC
# 57        RC
# 58        RC
# 59        RC
# 60        RC
# 61        RC
# 62        RC
# 63        RC
# 64        RC
# 65        RD
# 66        RD
# 67        RD
# 68        RC
# 69        RC
# 70        RC
# 71        RC
# 72        RC
# 73        RD
# 74        RC
# 75        RD
# 76        RC
# 77        RC
# 78        RD
# 79        RD
# 80        RD
# 81        RD
# 82        RC
# 83        RC
# 84        RC
# 85        RC
# 86        RC
# 87        RD
# 88        RC
# 89        RD
# 90        RC
# 91        RC
# 92        RC
# 93        RC
# 94        RD
# 95        RC
# 96        RC
# 97        RD
# 98        RC
# 99        RC
# 100       RC
# 101       RD
# 102       RD
# 103       RC
# 104       RC
# 105       RC
# 106       RC
# 107       RC
# 108       RC
# 109       RC
# 110       RC
# 111       RC
# 112       RD
# 113       RD
# 114       RD
# 115       RC
# 116       RC
# 117       RD
# 118       RC
# 119    other
# 120    other
# 121    other
# 122    other
# 123    other
# 124    other
# 125    other
# 126       IC
# 127       IC
# 128       IC
# 129       IC
# 130       IC
# 131       IC
# 132       IC
# 133       RC
# 134       RD
# 135       RC
# 136       RD
# 137       RC
# 138       RD
# 139       RC
# 140       IC
# 141       IC
# 142       IC
# 143       IC
# 144       IC
# 145       IC
# 146       IC
# 147       RC
# 148       RC
# 149       RC
# 150       RC
# 151       RC
# 152       RC
# 153       RC
# 154       IC
# 155       IC
# 156       IC
# 157       IC
# 158       IC
# 159       IC
# 160       IC
# 161       IC
# 162       IC
# 163       IC
# 164       IC
# 165       IC
# 166       IC
# 167       IC
# 168       RC
# 169       RC
# 170       RC
# 171       RC
# 172       RC
# 173       RC
# 174       RC
# 175       RD
# 176       RC
# 177       RC
# 178       RC
# 179       RC
# 180       RC
# 181       RC
# 182       RD
# 183       RC
# 184       RD
# 185       RC
# 186       RC
# 187       RC
# 188       RC
# 189       RC
# 190       RD
# 191       RC
# 192       RD
# 193       RC
# 194       RD
# 195       RD
# 196       RD
# 197       RD
# 198       RC
# 199       RC
# 200       RD
# 201       RD
# 202       RD
# 203    other
# 204    other
# 205    other
# 206       RC
# 207    other
# 208    other
# 209    other
# 210       IC
# 211       IC
# 212       IC
# 213       IC
# 214       IC
# 215       IC
# 216       IC
# 217       RD
# 218       IC
# 219       IC
# 220       IC
# 221       IC
# 222       IC
# 223       IC
# 224       RC
# 225       RC
# 226       RC
# 227       RC
# 228       RC
# 229       RC
# 230       RC
# 231       RD
# 232       RC
# 233       RD
# 234       RD
# 235       RC
# 236       RD
# 237       RD
# 238       RD
# 239       RC
# 240       RC
# 241       RC
# 242       RC
# 243       RD
# 244       RC
# 245       RC
# 246       RD
# 247       RD
# 248       RC
# 249       RC
# 250       RC
# 251       RC
# 252       RD
# 253       RC
# 254       RC
# 255       RC
# 256       RC
# 257       RD
# 258       RC
# 259       RC
# 260       RC
# 261       RC
# 262       RC
# 263       RC
# 264       RC
# 265       RC
# 266       IC
# 267       IC
# 268       IC
# 269       IC
# 270       IC
# 271       IC
# 272       IC
# 273       RD
# 274       RC
# 275       RC
# 276       RC
# 277       RD
# 278       RC
# 279       RC
# 280       RC
# 281       RD
# 282       RD
# 283       RC
# 284       RC
# 285       RD
# 286       RD
# 287       RC
# 288       RC
# 289       RC
# 290       RD
# 291       RC
# 292       RC
# 293       RC
# 294       RC
# 295       IC
# 296       IC
# 297       IC
# 298       IC
# 299       IC
# 300       IC
# 301       RD
# 302       RD
# 303       RC
# 304       RC
# 305       RD
# 306       RD
# 307       RC
# 308       IC
# 309       IC
# 310       IC
# 311       IC
# 312       IC
# 313       IC
# 314       IC
# 315       IC
# 316       IC
# 317       IC
# 318       IC
# 319       IC
# 320       IC
# 321       IC
# 322       RC
# 323    other
# 324       RD
# 325       RC
# 326       RD
# 327       RD
# 328       RD
# 329       IC
# 330       IC
# 331       IC
# 332       IC
# 333       IC
# 334       IC
# 335       IC
# 336       IC
# 337       IC
# 338       IC
# 339       IC
# 340       IC
# 341       RC
# 342       IC
# 343       IC
# 344       IC
# 345       IC
# 346       IC
# 347       IC
# 348       IC
# 349       IC
# 350       IC
# 351       RC
# 352       RD
# 353       RC
# 354       RD
# 355       RC
# 356       RC
# 357    other
# 358       RC
# 359       RC
# 360       RC
# 361       RC
# 362       RC
# 363       RC
# 364    other
# 365    other
# 366       IC
# 367       IC
# 368       IC
# 369       IC
# 370       IC
# 371       RC
# 372       RD
# 373       RC
# 374       RC
# 375       RC
# 376       RC
# 377       RC
# 378       RD
# 379       RC
# 380    other
# 381    other
# 382    other
# 383    other
# 384    other
# 385       RC
# 386       RC
# 387       RC
# 388       RC
# 389       RC
# 390       RC
# 391       RC
# 392       RC
# 393       RC
# 394       IC
# 395       RC
# 396       RC
# 397       RC
# 398       IC
# 399       RC
# 400       RC
# 401       RC
# 402       RC
# 403       RD
# 404       RC
# 405       RC
# 406       RD
# 407    other
# 408       RC
# 409       RC
# 410       RC
# 411       RC
# 412       RC
# 413       IC
# 414       IC
# 415       IC
# 416       IC
# 417       IC
# 418       IC
# 419       IC
# 420    other
# 421       IC
# 422    other
# 423    other
# 424    other
# 425    other
# 426    other
# 427       IC
# 428       IC
# 429       IC
# 430       IC
# 431       IC
# 432       IC
# 433       IC
# 434       IC
# 435       IC
# 436       IC
# 437       IC
# 438       IC
# 439       IC
# 440       IC
# 441       IC
# 442       IC
# 443       IC
# 444       IC
# 445       IC
# 446       IC
# 447       IC
# 448       RD
# 449       RD
# 450       RD
# 451       RD
# 452       RC
# 453       RD
# 454       RD
# 455       IC
# 456       IC
# 457       IC
# 458       IC
# 459       IC
# 460       IC
# 461       IC
# 462    other
# 463       IC
# 464       IC
# 465       IC
# 466       ID
# 467       IC
# 468    other
# 469       RC
# 470       RC
# 471       RC
# 472       RC
# 473       RC
# 474       RC
# 475       RC
# 476       RC
# 477       RC
# 478       RC
# 479       RC
# 480       RC
# 481       RC
# 482       RC
# 483       IC
# 484       IC
# 485       IC
# 486       IC
# 487       IC
# 488       IC
# 489       IC
# 490       RC
# 491       RC
# 492       RC
# 493       RD
# 494       RC
# 495       RC
# 496       RC
# 497       RD
# 498       RD
# 499       RC
# 500       RC
# 501       RD
# 502       RC
# 503       RD
# 504       ID
# 505    other
# 506       IC
# 507       IC
# 508       IC
# 509       IC
# 510       IC
# 511       IC
# 512    other
# 513    other
# 514    other
# 515    other
# 516    other
# 517    other
# 518       RC
# 519    other
# 520    other
# 521    other
# 522    other
# 523    other
# 524    other
# 525       RC
# 526       RC
# 527       RD
# 528       RD
# 529       RC
# 530       RC
# 531       RC
# 532       RD
# 533       RC
# 534       RD
# 535       RC
# 536       RC
# 537       RD
# 538       RD
# 539       RD
# 540       RC
# 541       RD
# 542       RC
# 543       RD
# 544       RC
# 545       RD
# 546       RC
# 547       RD
# 548       RC
# 549       RD
# 550       RD
# 551       RD
# 552       RC
# 553    other
# 554       RC
# 555    other
# 556    other
# 557       RD
# 558       RD
# 559       RC
# 560       RC
# 561    other
# 562       RC
# 563       IC
# 564       IC
# 565       IC
# 566    other
# 567       RC
# 568       RC
# 569       RC
# 570       RC
# 571       RC
# 572       RC
# 573       RD
# 574       RC
# 575       RC
# 576       RC
# 577       RC
# 578       RC
# 579       RC
# 580       RC
# 581       RC
# 582       RC
# 583       RC
# 584       RC
# 585       RD
# 586       RC
# 587       RD
# 588       RC
# 589       RC
# 590       RC
# 591       RC
# 592       RC
# 593       RC
# 594       RC
# 595       RC
# 596       RC
# 597       RC
# 598       RC
# 599       RC
# 600       RC
# 601       RC
# 602       RC
# 603       RC
# 604       RD
# 605       RD
# 606       RC
# 607       RD
# 608       RC
# 609       RC
# 610       RD
# 611    other
# 612       RD
# 613       RC
# 614       RC
# 615       RC
# 616       IC
# 617       IC
# 618       IC
# 619       IC
# 620       IC
# 621       IC
# 622       IC
# 623       IC
# 624       IC
# 625       RC
# 626       RC
# 627       RC
# 628       RD
# 629       RC
# 630       RC
# 631       RD
# 632       RD
# 633       RD
# 634       RD
# 635       RC
# 636       RC
# 637       RC
# 638       RC
# 639       RC
# 640       RC
# 641       RC
# 642       RC
# 643       RC
# 644       RD
# 645       RC
# 646       RC
# 647       RD
# 648       RC
# 649       RC
# 650       RC
# 651       RC
# 652       RC
# 653       RC
# 654       RC
# 655       RC
# 656       RC
# 657       RC
# 658       RC
# 659       RD
# 660       RC
# 661       RC
# 662       RC
# 663       RD
# 664       RC
# 665       RD
# 666       IC
# 667       RC
# 668       IC
# 669       IC
# 670       IC
# 671       IC
# 672       RC
# 673       RC
# 674       RD
# 675       RD
# 676       RD
# 677       RD
# 678       RC
# 679       IC
# 680       IC
# 681       IC
# 682       IC
# 683       IC
# 684       IC
# 685       IC
# 686       RC
# 687       RC
# 688       RC
# 689       RC
# 690       RC
# 691       RC
# 692       RC
# 693       RC
# 694       RC
# 695    other
# 696       RC
# 697       RC
# 698       RC
# 699       IC

# %%
root_dir = os.path.dirname(os.getcwd())
data2.to_csv(r"{}/data/responsesOnly_E2_100def.csv".format(root_dir),index=False)

# %%
data_chain['node_category'] = data_chain.apply(lambda x: node_cat(x['stimulus'],x['node_selected'],x['stim_type']),axis=1)
data_chain['node_category'] = data_chain['node_category'].astype('category')
data_AND_Gate['node_category'] = data_AND_Gate.apply(lambda x: node_cat(x['stimulus'],x['node_selected'],x['stim_type']),axis=1)
data_AND_Gate['response'] = data_AND_Gate.apply(lambda x: newCatLabels(x['root_1st'],x['imdt_2nd'],x['node_category']),axis=1)
data_AND_Gate['node_category'] = data_AND_Gate['node_category'].astype('category')
data_AND_Gate['response'] = data_AND_Gate['response'].astype('category')

# %%
data_AND_Gate
# Out:
#      subject_id          rt stimulus sampling  nb_of_run stim_type  \
# 0             1   19950.760  UAAS_RT    Right        1.0  AND_Gate
# 1             1   14289.955  UABS_RB    Right        1.0  AND_Gate
# 2             1   12181.330  UBBS_RT    Right        2.0  AND_Gate
# 3             1   13457.560   UAS_RB    Right        1.0  AND_Gate
# 4             1   12429.980   UBS_RB    Right        1.0  AND_Gate
# 5             1   10832.470  UBAS_RT    Right        2.0  AND_Gate
# 6             2   22205.620   UAS_LB     Left        1.0  AND_Gate
# 7             2   17773.830   UBS_LT     Left        1.0  AND_Gate
# 8             2   11323.835  UAAS_LB     Left        1.0  AND_Gate
# 9             2   10251.860  UBBS_LB     Left        1.0  AND_Gate
# 10            2   10636.100  UBAS_LT     Left        1.0  AND_Gate
# 11            2   12453.805  UABS_LT     Left        1.0  AND_Gate
# 12            3   28741.000  UBBS_RT    Right        1.0  AND_Gate
# 13            3   16028.000  UBAS_RB    Right        1.0  AND_Gate
# 14            3   14004.000   UAS_RB    Right        2.0  AND_Gate
# 15            3   16613.000   UBS_RB    Right        1.0  AND_Gate
# 16            3   14915.000  UABS_RB    Right        1.0  AND_Gate
# 17            3   14407.000  UAAS_RT    Right        1.0  AND_Gate
# 18            4   12532.130  UAAS_LT     Left        2.0  AND_Gate
# 19            4   13785.460  UBAS_LT     Left        1.0  AND_Gate
# 20            4   23058.360   UAS_LT     Left        1.0  AND_Gate
# 21            4   21011.405  UABS_LB     Left        1.0  AND_Gate
# 22            4   22344.200  UBBS_LB     Left        2.0  AND_Gate
# 23            4   10957.365   UBS_LT     Left        1.0  AND_Gate
# 24            5   41070.930  UBAS_RT    Right        1.0  AND_Gate
# 25            5   12315.000   UAS_RT    Right        1.0  AND_Gate
# 26            5   17614.945  UABS_RB    Right        1.0  AND_Gate
# 27            5   19886.620   UBS_RB    Right        1.0  AND_Gate
# 28            5   27907.325  UBBS_RT    Right        1.0  AND_Gate
# 29            5   10975.605  UAAS_RB    Right        1.0  AND_Gate
# 30            6   11361.475  UAAS_RT    Right        2.0  AND_Gate
# 31            6   11968.060  UABS_RT    Right        1.0  AND_Gate
# 32            6    9263.490  UBBS_RT    Right        1.0  AND_Gate
# 33            6   11788.795   UBS_RT    Right        1.0  AND_Gate
# 34            6    9837.330  UBAS_RB    Right        1.0  AND_Gate
# 35            6   12747.790   UAS_RT    Right        1.0  AND_Gate
# 36            7   19507.570   UAS_LB     Left        1.0  AND_Gate
# 37            7   11984.040  UBBS_LB     Left        1.0  AND_Gate
# 38            7   12516.135  UBAS_LB     Left        1.0  AND_Gate
# 39            7   11653.400   UBS_LB     Left        1.0  AND_Gate
# 40            7   16938.320  UABS_LB     Left        1.0  AND_Gate
# 41            7   13465.315  UAAS_LB     Left        1.0  AND_Gate
# 42            8   21732.420  UABS_LT     Left        1.0  AND_Gate
# 43            8   11055.775  UBBS_LT     Left        1.0  AND_Gate
# 44            8   14431.980  UAAS_LB     Left        1.0  AND_Gate
# 45            8   13032.255   UAS_LT     Left        1.0  AND_Gate
# 46            8   11963.515  UBAS_LB     Left        1.0  AND_Gate
# 47            8   14734.590   UBS_LB     Left        1.0  AND_Gate
# 48            9   16069.515   UAS_RB    Right        1.0  AND_Gate
# 49            9    9699.820  UBBS_RB    Right        1.0  AND_Gate
# 50            9   11413.830   UBS_RB    Right        1.0  AND_Gate
# 51            9   15111.910  UABS_RB    Right        1.0  AND_Gate
# 52            9   10563.785  UAAS_RB    Right        1.0  AND_Gate
# 53            9   10958.435  UBAS_RT    Right        1.0  AND_Gate
# 54           10   13241.275  UBBS_RB    Right        2.0  AND_Gate
# 55           10   11701.825   UAS_RT    Right        2.0  AND_Gate
# 56           10   14340.995  UABS_RB    Right        1.0  AND_Gate
# 57           10   12222.380  UBAS_RT    Right        1.0  AND_Gate
# 58           10   10356.090   UBS_RB    Right        1.0  AND_Gate
# 59           10   11719.870  UAAS_RT    Right        1.0  AND_Gate
# 60           11   28754.565  UABS_RB    Right        1.0  AND_Gate
# 61           11   17309.895   UAS_RB    Right        1.0  AND_Gate
# 62           11   13038.965   UBS_RT    Right        1.0  AND_Gate
# 63           11   23010.930  UAAS_RB    Right        1.0  AND_Gate
# 64           11   19661.030  UBBS_RT    Right        1.0  AND_Gate
# 65           11   13856.595  UBAS_RT    Right        1.0  AND_Gate
# 66           12   21210.365  UBBS_LB     Left        1.0  AND_Gate
# 67           12   12153.525  UBAS_LB     Left        1.0  AND_Gate
# 68           12   21244.985   UBS_LT     Left        1.0  AND_Gate
# 69           12   15506.660  UABS_LT     Left        1.0  AND_Gate
# 70           12   13474.685   UAS_LB     Left        1.0  AND_Gate
# 71           12   11244.785  UAAS_LB     Left        1.0  AND_Gate
# 72           13   24181.970   UAS_RT    Right        1.0  AND_Gate
# 73           13    9838.865  UBAS_RT    Right        1.0  AND_Gate
# 74           13   10435.350  UAAS_RB    Right        1.0  AND_Gate
# 75           13   12133.290  UABS_RT    Right        1.0  AND_Gate
# 76           13   11085.960  UBBS_RT    Right        1.0  AND_Gate
# 77           13   10477.610   UBS_RT    Right        1.0  AND_Gate
# 78           14   22433.035   UAS_LB     Left        1.0  AND_Gate
# 79           14   38436.445  UABS_LB     Left        1.0  AND_Gate
# 80           14   18817.610   UBS_LT     Left        1.0  AND_Gate
# 81           14   15478.465  UBBS_LB     Left        1.0  AND_Gate
# 82           14   11861.680  UBAS_LT     Left        1.0  AND_Gate
# 83           14   11811.815  UAAS_LT     Left        1.0  AND_Gate
# 84           15   16247.810   UAS_LB     Left        1.0  AND_Gate
# 85           15   15217.210  UABS_LT     Left        1.0  AND_Gate
# 86           15   10570.175  UBBS_LT     Left        1.0  AND_Gate
# 87           15   12031.615  UAAS_LB     Left        1.0  AND_Gate
# 88           15   10935.935   UBS_LT     Left        1.0  AND_Gate
# 89           15   12505.330  UBAS_LT     Left        1.0  AND_Gate
# 90           16   14677.000  UBBS_RT    Right        1.0  AND_Gate
# 91           16   11168.000   UBS_RT    Right        1.0  AND_Gate
# 92           16   10834.000  UAAS_RT    Right        1.0  AND_Gate
# 93           16   12483.000  UABS_RB    Right        1.0  AND_Gate
# 94           16   10841.000   UAS_RB    Right        1.0  AND_Gate
# 95           16   10186.000  UBAS_RT    Right        1.0  AND_Gate
# 96           17   14582.345   UBS_LB     Left        1.0  AND_Gate
# 97           17   12354.535  UABS_LB     Left        1.0  AND_Gate
# 98           17   10113.090  UBAS_LB     Left        1.0  AND_Gate
# 99           17    9154.895  UBBS_LB     Left        1.0  AND_Gate
# 100          17   10756.585   UAS_LB     Left        1.0  AND_Gate
# 101          17   10934.055  UAAS_LB     Left        1.0  AND_Gate
# 102          18   26118.000  UBBS_RT    Right        1.0  AND_Gate
# 103          18   17445.000  UABS_RB    Right        1.0  AND_Gate
# 104          18   15311.000   UAS_RT    Right        1.0  AND_Gate
# 105          18   12278.000   UBS_RT    Right        1.0  AND_Gate
# 106          18   12246.000  UBAS_RB    Right        1.0  AND_Gate
# 107          18   11566.000  UAAS_RT    Right        1.0  AND_Gate
# 108          19   23480.135  UABS_RB    Right        1.0  AND_Gate
# 109          19   11806.375  UBBS_RT    Right        1.0  AND_Gate
# 110          19   12432.885   UBS_RB    Right        1.0  AND_Gate
# 111          19   10567.320  UAAS_RB    Right        1.0  AND_Gate
# 112          19    9928.390  UBAS_RB    Right        1.0  AND_Gate
# 113          19   10718.350   UAS_RB    Right        1.0  AND_Gate
# 114          20   14437.210   UAS_RT    Right        1.0  AND_Gate
# 115          20   14926.820  UBAS_RB    Right        1.0  AND_Gate
# 116          20    9548.515  UBBS_RT    Right        1.0  AND_Gate
# 117          20   13354.655   UBS_RT    Right        1.0  AND_Gate
# 118          20   11844.040  UAAS_RT    Right        1.0  AND_Gate
# 119          20   12345.735  UABS_RB    Right        1.0  AND_Gate
# 120          21   20471.245   UAS_LB     Left        1.0  AND_Gate
# 121          21   12158.710  UBAS_LB     Left        1.0  AND_Gate
# 122          21   10302.555  UBBS_LB     Left        1.0  AND_Gate
# 123          21   14942.750  UABS_LB     Left        1.0  AND_Gate
# 124          21   11590.695   UBS_LT     Left        1.0  AND_Gate
# 125          21   12326.905  UAAS_LB     Left        1.0  AND_Gate
# 126          22   17378.000   UBS_RT    Right        1.0  AND_Gate
# 127          22   12866.000  UABS_RB    Right        1.0  AND_Gate
# 128          22    9624.000  UBBS_RB    Right        1.0  AND_Gate
# 129          22   10867.000  UBAS_RT    Right        1.0  AND_Gate
# 130          22   11031.000   UAS_RB    Right        1.0  AND_Gate
# 131          22   12541.000  UAAS_RB    Right        1.0  AND_Gate
# 132          23   14266.710  UBBS_RB    Right        1.0  AND_Gate
# 133          23   11722.275   UBS_RB    Right        1.0  AND_Gate
# 134          23   11965.000  UABS_RB    Right        1.0  AND_Gate
# 135          23   10859.815  UAAS_RT    Right        1.0  AND_Gate
# 136          23   12255.850   UAS_RB    Right        1.0  AND_Gate
# 137          23   12664.220  UBAS_RT    Right        1.0  AND_Gate
# 138          24   13667.005  UAAS_RT    Right        3.0  AND_Gate
# 139          24   14610.235  UBBS_RT    Right        3.0  AND_Gate
# 140          24   11750.965   UBS_RB    Right        2.0  AND_Gate
# 141          24   12187.340  UABS_RT    Right        3.0  AND_Gate
# 142          24   10861.815  UBAS_RT    Right        2.0  AND_Gate
# 143          24   11792.185   UAS_RT    Right        1.0  AND_Gate
# 144          25   14461.690  UAAS_LB     Left        2.0  AND_Gate
# 145          25   13028.795  UBAS_LT     Left        1.0  AND_Gate
# 146          25   14956.665   UAS_LB     Left        1.0  AND_Gate
# 147          25   10869.510  UBBS_LT     Left        1.0  AND_Gate
# 148          25   11253.645   UBS_LT     Left        1.0  AND_Gate
# 149          25   16485.190  UABS_LT     Left        1.0  AND_Gate
# 150          26   19880.000  UAAS_RB    Right        1.0  AND_Gate
# 151          26   16765.000  UBAS_RB    Right        1.0  AND_Gate
# 152          26   11752.000  UBBS_RT    Right        2.0  AND_Gate
# 153          26   16383.000   UAS_RB    Right        1.0  AND_Gate
# 154          26   18569.000  UABS_RT    Right        1.0  AND_Gate
# 155          26   16011.000   UBS_RB    Right        1.0  AND_Gate
# 156          27   18795.620  UAAS_RB    Right        1.0  AND_Gate
# 157          27   17377.365  UABS_RT    Right        1.0  AND_Gate
# 158          27   14596.670  UBBS_RT    Right        1.0  AND_Gate
# 159          27   13488.885  UBAS_RB    Right        1.0  AND_Gate
# 160          27   13552.450   UAS_RT    Right        1.0  AND_Gate
# 161          27   14157.080   UBS_RB    Right        1.0  AND_Gate
# 162          28   22666.320  UBBS_RT    Right        1.0  AND_Gate
# 163          28   13914.970  UABS_RT    Right        1.0  AND_Gate
# 164          28   17479.700  UAAS_RT    Right        1.0  AND_Gate
# 165          28    9980.405  UBAS_RT    Right        1.0  AND_Gate
# 166          28   14280.070   UAS_RB    Right        1.0  AND_Gate
# 167          28   10486.945   UBS_RB    Right        1.0  AND_Gate
# 168          29   11011.860  UBAS_RB    Right        2.0  AND_Gate
# 169          29   13181.780   UAS_RT    Right        1.0  AND_Gate
# 170          29   12942.710  UBBS_RT    Right        1.0  AND_Gate
# 171          29   15917.760  UABS_RB    Right        1.0  AND_Gate
# 172          29   14541.215  UAAS_RT    Right        1.0  AND_Gate
# 173          29   10599.165   UBS_RB    Right        1.0  AND_Gate
# 174          30   26005.000   UAS_LT     Left        1.0  AND_Gate
# 175          30   12320.000  UBAS_LB     Left        1.0  AND_Gate
# 176          30   14335.000  UBBS_LB     Left        1.0  AND_Gate
# 177          30   14377.000  UABS_LB     Left        1.0  AND_Gate
# 178          30   14205.000   UBS_LB     Left        1.0  AND_Gate
# 179          30   11931.000  UAAS_LT     Left        1.0  AND_Gate
# 180          31   16534.890   UBS_RT    Right        1.0  AND_Gate
# 181          31   16067.050  UBBS_RT    Right        2.0  AND_Gate
# 182          31   12391.060  UBAS_RT    Right        1.0  AND_Gate
# 183          31   13449.050  UABS_RT    Right        1.0  AND_Gate
# 184          31   10948.495   UAS_RT    Right        1.0  AND_Gate
# 185          31   12086.075  UAAS_RT    Right        1.0  AND_Gate
# 186          32   16555.635   UBS_LT     Left        1.0  AND_Gate
# 187          32   12277.025   UAS_LT     Left        1.0  AND_Gate
# 188          32   13492.825  UAAS_LB     Left        1.0  AND_Gate
# 189          32   10508.965  UBBS_LB     Left        1.0  AND_Gate
# 190          32   12763.710  UBAS_LT     Left        1.0  AND_Gate
# 191          32   13260.650  UABS_LB     Left        1.0  AND_Gate
# 192          33   22188.220  UABS_LB     Left        1.0  AND_Gate
# 193          33   13182.705  UAAS_LT     Left        1.0  AND_Gate
# 194          33   12533.650   UAS_LT     Left        1.0  AND_Gate
# 195          33   13430.080   UBS_LB     Left        1.0  AND_Gate
# 196          33   11004.235  UBBS_LB     Left        1.0  AND_Gate
# 197          33   12245.585  UBAS_LT     Left        1.0  AND_Gate
# 198          34   24340.370  UABS_RT    Right        1.0  AND_Gate
# 199          34   12126.135  UAAS_RT    Right        2.0  AND_Gate
# 200          34   10133.325  UBAS_RT    Right        1.0  AND_Gate
# 201          34    9278.490  UBBS_RT    Right        1.0  AND_Gate
# 202          34   10709.500   UBS_RB    Right        1.0  AND_Gate
# 203          34   11757.560   UAS_RT    Right        1.0  AND_Gate
# 204          35   21245.135  UAAS_LT     Left        1.0  AND_Gate
# 205          35   18445.145  UABS_LB     Left        1.0  AND_Gate
# 206          35  106172.425   UBS_LT     Left        1.0  AND_Gate
# 207          35   94973.215   UAS_LT     Left        1.0  AND_Gate
# 208          35   11233.545  UBAS_LT     Left        1.0  AND_Gate
# 209          35    9793.225  UBBS_LT     Left        1.0  AND_Gate
# 210          36   27387.850  UABS_RB    Right        2.0  AND_Gate
# 211          36   14728.015  UAAS_RB    Right        2.0  AND_Gate
# 212          36   12853.400  UBBS_RB    Right        1.0  AND_Gate
# 213          36   11413.510  UBAS_RT    Right        2.0  AND_Gate
# 214          36   10812.065   UBS_RB    Right        1.0  AND_Gate
# 215          36   19369.625   UAS_RB    Right        1.0  AND_Gate
# 216          37   33330.035   UAS_LT     Left        2.0  AND_Gate
# 217          37   14766.390  UABS_LB     Left        1.0  AND_Gate
# 218          37   10775.345   UBS_LB     Left        1.0  AND_Gate
# 219          37   10913.655  UBAS_LT     Left        1.0  AND_Gate
# 220          37   11559.845  UAAS_LT     Left        1.0  AND_Gate
# 221          37   13434.935  UBBS_LT     Left        1.0  AND_Gate
# 222          38   30562.820   UAS_LT     Left        1.0  AND_Gate
# 223          38   16641.300  UABS_LT     Left        1.0  AND_Gate
# 224          38   11179.180  UBBS_LB     Left        2.0  AND_Gate
# 225          38   12340.870   UBS_LT     Left        1.0  AND_Gate
# 226          38   12045.475  UAAS_LT     Left        1.0  AND_Gate
# 227          38   10294.660  UBAS_LT     Left        1.0  AND_Gate
# 228          39   18165.290  UBBS_LT     Left        2.0  AND_Gate
# 229          39   14608.080  UBAS_LT     Left        1.0  AND_Gate
# 230          39   13219.300  UABS_LB     Left        2.0  AND_Gate
# 231          39   13175.905   UAS_LB     Left        1.0  AND_Gate
# 232          39   17793.320  UAAS_LT     Left        1.0  AND_Gate
# 233          39   10895.185   UBS_LT     Left        1.0  AND_Gate
# 234          40   18892.440  UAAS_LB     Left        2.0  AND_Gate
# 235          40   13509.825   UAS_LB     Left        1.0  AND_Gate
# 236          40   11145.735  UBAS_LT     Left        1.0  AND_Gate
# 237          40   12789.425  UBBS_LT     Left        1.0  AND_Gate
# 238          40   12743.410  UABS_LB     Left        1.0  AND_Gate
# 239          40   12999.710   UBS_LB     Left        1.0  AND_Gate
# 240          41   11237.245   UBS_RB    Right        2.0  AND_Gate
# 241          41   23113.845   UAS_RB    Right        1.0  AND_Gate
# 242          41   11300.110  UBBS_RB    Right        1.0  AND_Gate
# 243          41   13034.285  UAAS_RT    Right        1.0  AND_Gate
# 244          41   16959.095  UABS_RT    Right        1.0  AND_Gate
# 245          41   15281.695  UBAS_RT    Right        1.0  AND_Gate
# 246          42   29853.260   UBS_LT     Left        1.0  AND_Gate
# 247          42   16901.250  UABS_LB     Left        1.0  AND_Gate
# 248          42   15757.265  UBAS_LT     Left        1.0  AND_Gate
# 249          42   14213.085  UAAS_LB     Left        1.0  AND_Gate
# 250          42   12684.320  UBBS_LT     Left        1.0  AND_Gate
# 251          42   12540.640   UAS_LT     Left        1.0  AND_Gate
# 252          43   13761.455  UBBS_RB    Right        2.0  AND_Gate
# 253          43   12441.335  UABS_RB    Right        1.0  AND_Gate
# 254          43   11273.890  UAAS_RT    Right        1.0  AND_Gate
# 255          43   11257.595  UBAS_RB    Right        2.0  AND_Gate
# 256          43   12057.800   UAS_RB    Right        1.0  AND_Gate
# 257          43   12718.235   UBS_RB    Right        1.0  AND_Gate
# 258          44   18810.125   UBS_RT    Right        1.0  AND_Gate
# 259          44   22030.350  UBAS_RB    Right        1.0  AND_Gate
# 260          44   10941.360  UAAS_RB    Right        1.0  AND_Gate
# 261          44   12232.355  UBBS_RB    Right        1.0  AND_Gate
# 262          44   10774.850   UAS_RB    Right        1.0  AND_Gate
# 263          44   20700.965  UABS_RT    Right        1.0  AND_Gate
# 264          45   29756.580   UBS_LB     Left        1.0  AND_Gate
# 265          45   14540.105   UAS_LT     Left        1.0  AND_Gate
# 266          45   13939.670  UABS_LT     Left        1.0  AND_Gate
# 267          45   11764.515  UAAS_LB     Left        1.0  AND_Gate
# 268          45   11283.045  UBAS_LB     Left        1.0  AND_Gate
# 269          45   12650.755  UBBS_LT     Left        1.0  AND_Gate
# 270          46   21948.000   UBS_RB    Right        1.0  AND_Gate
# 271          46   12019.000   UAS_RB    Right        1.0  AND_Gate
# 272          46   10621.000  UBBS_RT    Right        1.0  AND_Gate
# 273          46   13527.000  UABS_RT    Right        1.0  AND_Gate
# 274          46   11408.000  UAAS_RB    Right        1.0  AND_Gate
# 275          46   13800.000  UBAS_RT    Right        1.0  AND_Gate
# 276          47   24562.655  UBBS_RB    Right        2.0  AND_Gate
# 277          47   14786.315  UAAS_RT    Right        1.0  AND_Gate
# 278          47   13386.670   UBS_RT    Right        1.0  AND_Gate
# 279          47   13529.305  UBAS_RB    Right        1.0  AND_Gate
# 280          47   13927.600  UABS_RB    Right        1.0  AND_Gate
# 281          47   14643.425   UAS_RT    Right        1.0  AND_Gate
# 282          48   12148.280  UAAS_RT    Right        2.0  AND_Gate
# 283          48   13643.355  UABS_RT    Right        1.0  AND_Gate
# 284          48   51449.225   UBS_RT    Right        1.0  AND_Gate
# 285          48   16372.185   UAS_RB    Right        1.0  AND_Gate
# 286          48   11027.135  UBAS_RB    Right        1.0  AND_Gate
# 287          48   22567.960  UBBS_RB    Right        1.0  AND_Gate
# 288          49   10002.000  UBBS_RB    Right        2.0  AND_Gate
# 289          49   11252.000   UAS_RB    Right        1.0  AND_Gate
# 290          49   13798.000  UBAS_RT    Right        1.0  AND_Gate
# 291          49   12021.000  UABS_RB    Right        1.0  AND_Gate
# 292          49   14024.000  UAAS_RT    Right        1.0  AND_Gate
# 293          49   24418.000   UBS_RT    Right        1.0  AND_Gate
# 294          50   23831.000  UBBS_LB     Left        1.0  AND_Gate
# 295          50   14216.000  UABS_LT     Left        1.0  AND_Gate
# 296          50   11216.000   UAS_LB     Left        1.0  AND_Gate
# 297          50   12191.000   UBS_LT     Left        1.0  AND_Gate
# 298          50   11080.000  UAAS_LB     Left        1.0  AND_Gate
# 299          50   10564.000  UBAS_LB     Left        1.0  AND_Gate
# 300          51   20482.055   UBS_LT     Left        1.0  AND_Gate
# 301          51   25669.300  UABS_LT     Left        1.0  AND_Gate
# 302          51   14195.450  UAAS_LB     Left        1.0  AND_Gate
# 303          51   12035.990   UAS_LB     Left        1.0  AND_Gate
# 304          51   11260.415  UBBS_LB     Left        1.0  AND_Gate
# 305          51   10434.225  UBAS_LT     Left        1.0  AND_Gate
# 306          52   34286.000  UBAS_RB    Right        1.0  AND_Gate
# 307          52   15558.000  UABS_RT    Right        1.0  AND_Gate
# 308          52   19101.000   UAS_RT    Right        2.0  AND_Gate
# 309          52   13621.000   UBS_RB    Right        2.0  AND_Gate
# 310          52   15671.000  UBBS_RT    Right        1.0  AND_Gate
# 311          52   18186.000  UAAS_RT    Right        1.0  AND_Gate
# 312          53   11622.715   UAS_RT    Right        1.0  AND_Gate
# 313          53   11994.515  UBAS_RT    Right        1.0  AND_Gate
# 314          53   11164.135  UAAS_RB    Right        1.0  AND_Gate
# 315          53   10854.780   UBS_RB    Right        1.0  AND_Gate
# 316          53   14282.885  UABS_RT    Right        1.0  AND_Gate
# 317          53    9006.945  UBBS_RB    Right        1.0  AND_Gate
# 318          54   16227.570  UBBS_LB     Left        1.0  AND_Gate
# 319          54   11012.300  UBAS_LB     Left        1.0  AND_Gate
# 320          54   13812.695  UAAS_LB     Left        1.0  AND_Gate
# 321          54   12248.275   UBS_LB     Left        1.0  AND_Gate
# 322          54   12792.425   UAS_LT     Left        1.0  AND_Gate
# 323          54   13475.745  UABS_LB     Left        1.0  AND_Gate
# 324          55   12947.880  UAAS_RB    Right        2.0  AND_Gate
# 325          55   11129.845   UBS_RB    Right        1.0  AND_Gate
# 326          55   11578.335   UAS_RB    Right        1.0  AND_Gate
# 327          55   11795.685  UABS_RB    Right        1.0  AND_Gate
# 328          55   11329.165  UBAS_RT    Right        1.0  AND_Gate
# 329          55   11775.040  UBBS_RT    Right        1.0  AND_Gate
# 330          56   24208.000  UBAS_LT     Left        1.0  AND_Gate
# 331          56   16259.000   UBS_LT     Left        1.0  AND_Gate
# 332          56   33146.000  UAAS_LT     Left        2.0  AND_Gate
# 333          56   16454.000  UBBS_LB     Left        2.0  AND_Gate
# 334          56   16354.000  UABS_LB     Left        3.0  AND_Gate
# 335          56   17540.000   UAS_LT     Left        2.0  AND_Gate
# 336          57   19111.915   UAS_LB     Left        1.0  AND_Gate
# 337          57    9980.080  UBAS_LB     Left        1.0  AND_Gate
# 338          57   11885.220  UBBS_LT     Left        1.0  AND_Gate
# 339          57    9820.690   UBS_LB     Left        1.0  AND_Gate
# 340          57   11749.015  UABS_LT     Left        1.0  AND_Gate
# 341          57   10793.975  UAAS_LB     Left        1.0  AND_Gate
# 342          58   17617.870   UAS_LT     Left        1.0  AND_Gate
# 343          58   13491.475  UBBS_LB     Left        1.0  AND_Gate
# 344          58   12763.615  UABS_LT     Left        1.0  AND_Gate
# 345          58   11623.965  UAAS_LB     Left        1.0  AND_Gate
# 346          58   10873.580   UBS_LT     Left        1.0  AND_Gate
# 347          58   11183.515  UBAS_LB     Left        1.0  AND_Gate
# 348          59   17656.000   UAS_LT     Left        1.0  AND_Gate
# 349          59   18329.000  UABS_LT     Left        1.0  AND_Gate
# 350          59   10306.000  UBAS_LB     Left        1.0  AND_Gate
# 351          59   10686.000   UBS_LT     Left        1.0  AND_Gate
# 352          59    9793.000  UBBS_LB     Left        1.0  AND_Gate
# 353          59   17686.000  UAAS_LB     Left        1.0  AND_Gate
# 354          60   14479.585   UBS_RT    Right        2.0  AND_Gate
# 355          60   13539.340  UAAS_RB    Right        1.0  AND_Gate
# 356          60   10739.965  UBBS_RT    Right        1.0  AND_Gate
# 357          60   13640.945  UABS_RB    Right        1.0  AND_Gate
# 358          60   11481.315   UAS_RT    Right        1.0  AND_Gate
# 359          60   21249.345  UBAS_RB    Right        1.0  AND_Gate
# 360          61   24670.635  UAAS_RT    Right        1.0  AND_Gate
# 361          61   15261.490  UABS_RT    Right        1.0  AND_Gate
# 362          61   16149.550  UBAS_RT    Right        1.0  AND_Gate
# 363          61   14232.335   UBS_RT    Right        1.0  AND_Gate
# 364          61   10200.500  UBBS_RT    Right        1.0  AND_Gate
# 365          61   13230.965   UAS_RB    Right        1.0  AND_Gate
# 366          62   14747.755   UAS_LT     Left        1.0  AND_Gate
# 367          62   12366.265   UBS_LT     Left        1.0  AND_Gate
# 368          62   11149.550  UBAS_LT     Left        1.0  AND_Gate
# 369          62   11861.760  UAAS_LT     Left        1.0  AND_Gate
# 370          62   12710.695  UABS_LT     Left        1.0  AND_Gate
# 371          62   11581.950  UBBS_LT     Left        1.0  AND_Gate
# 372          63   16639.570   UAS_RB    Right        1.0  AND_Gate
# 373          63   11591.485   UBS_RT    Right        1.0  AND_Gate
# 374          63   11532.070  UBAS_RT    Right        1.0  AND_Gate
# 375          63   11261.290  UBBS_RT    Right        1.0  AND_Gate
# 376          63   12722.580  UABS_RB    Right        1.0  AND_Gate
# 377          63   15680.215  UAAS_RB    Right        1.0  AND_Gate
# 378          64   40894.360  UABS_RB    Right        1.0  AND_Gate
# 379          64   13117.000  UBBS_RT    Right        1.0  AND_Gate
# 380          64   14465.845  UAAS_RB    Right        1.0  AND_Gate
# 381          64   13345.145   UAS_RT    Right        1.0  AND_Gate
# 382          64   12333.730  UBAS_RB    Right        1.0  AND_Gate
# 383          64   11727.240   UBS_RB    Right        2.0  AND_Gate
# 384          65   22904.795   UBS_RB    Right        1.0  AND_Gate
# 385          65   11703.225  UBAS_RT    Right        1.0  AND_Gate
# 386          65   13566.475  UAAS_RB    Right        1.0  AND_Gate
# 387          65   12581.915  UABS_RB    Right        1.0  AND_Gate
# 388          65    8944.405  UBBS_RB    Right        1.0  AND_Gate
# 389          65   10350.340   UAS_RT    Right        1.0  AND_Gate
# 390          66   16896.745  UABS_RB    Right        1.0  AND_Gate
# 391          66   12877.105   UBS_RB    Right        1.0  AND_Gate
# 392          66   10628.785  UBBS_RT    Right        1.0  AND_Gate
# 393          66   10656.110  UBAS_RT    Right        1.0  AND_Gate
# 394          66   11851.830   UAS_RT    Right        1.0  AND_Gate
# 395          66   11947.155  UAAS_RB    Right        1.0  AND_Gate
# 396          67   13586.940  UABS_RT    Right        1.0  AND_Gate
# 397          67   16596.125  UAAS_RB    Right        1.0  AND_Gate
# 398          67    9905.560  UBAS_RB    Right        1.0  AND_Gate
# 399          67    8970.465  UBBS_RT    Right        1.0  AND_Gate
# 400          67   11214.390   UBS_RB    Right        1.0  AND_Gate
# 401          67   10420.010   UAS_RT    Right        1.0  AND_Gate
# 402          68   18636.825  UABS_LT     Left        1.0  AND_Gate
# 403          68   11240.510   UAS_LB     Left        1.0  AND_Gate
# 404          68   11742.515  UAAS_LB     Left        1.0  AND_Gate
# 405          68   10647.005   UBS_LT     Left        1.0  AND_Gate
# 406          68   10339.650  UBBS_LB     Left        1.0  AND_Gate
# 407          68   10701.880  UBAS_LT     Left        1.0  AND_Gate
# 408          69   24982.715   UAS_LB     Left        1.0  AND_Gate
# 409          69   13869.360  UBBS_LB     Left        2.0  AND_Gate
# 410          69   13904.500  UABS_LB     Left        1.0  AND_Gate
# 411          69   12315.090  UAAS_LT     Left        1.0  AND_Gate
# 412          69   11265.140  UBAS_LT     Left        1.0  AND_Gate
# 413          69   12530.965   UBS_LT     Left        1.0  AND_Gate
# 414          70   20477.890  UABS_RT    Right        1.0  AND_Gate
# 415          70   23757.555  UBAS_RT    Right        1.0  AND_Gate
# 416          70   10469.945   UBS_RT    Right        1.0  AND_Gate
# 417          70   13197.520  UBBS_RB    Right        1.0  AND_Gate
# 418          70   11485.275  UAAS_RB    Right        1.0  AND_Gate
# 419          70   11942.815   UAS_RB    Right        1.0  AND_Gate
# 420          71   20520.715   UAS_LT     Left        1.0  AND_Gate
# 421          71   12761.795  UAAS_LT     Left        1.0  AND_Gate
# 422          71   11634.580  UBAS_LB     Left        1.0  AND_Gate
# 423          71    9332.235  UBBS_LT     Left        1.0  AND_Gate
# 424          71   10204.415   UBS_LB     Left        1.0  AND_Gate
# 425          71   12005.870  UABS_LT     Left        1.0  AND_Gate
# 426          72   25567.510  UABS_LT     Left        1.0  AND_Gate
# 427          72   17385.215   UBS_LB     Left        1.0  AND_Gate
# 428          72   14570.985  UAAS_LT     Left        1.0  AND_Gate
# 429          72   13042.785   UAS_LB     Left        1.0  AND_Gate
# 430          72   11297.000  UBBS_LT     Left        3.0  AND_Gate
# 431          72   12442.250  UBAS_LT     Left        1.0  AND_Gate
# 432          73   13785.985   UBS_RB    Right        2.0  AND_Gate
# 433          73   11370.620  UBAS_RT    Right        1.0  AND_Gate
# 434          73   10509.000   UAS_RB    Right        1.0  AND_Gate
# 435          73   12002.955  UABS_RT    Right        1.0  AND_Gate
# 436          73   10372.270  UAAS_RB    Right        1.0  AND_Gate
# 437          73   12000.320  UBBS_RT    Right        1.0  AND_Gate
# 438          74   47335.600  UABS_LB     Left        1.0  AND_Gate
# 439          74   11300.100  UBAS_LB     Left        2.0  AND_Gate
# 440          74   16601.900  UAAS_LB     Left        1.0  AND_Gate
# 441          74   16742.000   UAS_LB     Left        1.0  AND_Gate
# 442          74   13503.500  UBBS_LB     Left        1.0  AND_Gate
# 443          74   13019.200   UBS_LT     Left        1.0  AND_Gate
# 444          75   23720.825  UBAS_LB     Left        1.0  AND_Gate
# 445          75   11304.425  UAAS_LB     Left        1.0  AND_Gate
# 446          75   11208.770   UAS_LB     Left        1.0  AND_Gate
# 447          75   11169.740   UBS_LB     Left        1.0  AND_Gate
# 448          75   12496.815  UABS_LB     Left        2.0  AND_Gate
# 449          75   10897.125  UBBS_LT     Left        1.0  AND_Gate
# 450          76   16135.000  UBAS_LB     Left        1.0  AND_Gate
# 451          76   13290.000  UBBS_LT     Left        1.0  AND_Gate
# 452          76   10982.000  UAAS_LB     Left        1.0  AND_Gate
# 453          76   11278.000   UAS_LT     Left        1.0  AND_Gate
# 454          76   12362.000  UABS_LT     Left        1.0  AND_Gate
# 455          76   10628.000   UBS_LB     Left        1.0  AND_Gate
# 456          77   22198.000  UABS_RB    Right        1.0  AND_Gate
# 457          77   10958.000   UAS_RT    Right        1.0  AND_Gate
# 458          77   10846.000  UAAS_RB    Right        1.0  AND_Gate
# 459          77    9063.000  UBBS_RT    Right        1.0  AND_Gate
# 460          77   10021.000  UBAS_RB    Right        1.0  AND_Gate
# 461          77   11857.000   UBS_RT    Right        1.0  AND_Gate
# 462          78   21297.020   UAS_LB     Left        1.0  AND_Gate
# 463          78   11295.705  UAAS_LB     Left        1.0  AND_Gate
# 464          78   13679.605  UBAS_LT     Left        1.0  AND_Gate
# 465          78   13071.885  UABS_LB     Left        1.0  AND_Gate
# 466          78   10039.625  UBBS_LT     Left        1.0  AND_Gate
# 467          78   13407.115   UBS_LT     Left        1.0  AND_Gate
# 468          79   19880.575   UBS_RB    Right        1.0  AND_Gate
# 469          79   15736.940  UBBS_RB    Right        1.0  AND_Gate
# 470          79   14537.140   UAS_RB    Right        1.0  AND_Gate
# 471          79   13121.515  UBAS_RT    Right        1.0  AND_Gate
# 472          79   14252.625  UABS_RT    Right        1.0  AND_Gate
# 473          79   16040.195  UAAS_RT    Right        1.0  AND_Gate
# 474          80   26346.360  UBAS_LT     Left        2.0  AND_Gate
# 475          80   10989.110   UBS_LB     Left        1.0  AND_Gate
# 476          80   13569.595  UAAS_LB     Left        1.0  AND_Gate
# 477          80   11805.215  UBBS_LB     Left        1.0  AND_Gate
# 478          80   14035.695   UAS_LB     Left        1.0  AND_Gate
# 479          80   12388.000  UABS_LB     Left        1.0  AND_Gate
# 480          81   14548.000  UBAS_RT    Right        3.0  AND_Gate
# 481          81   12907.000  UABS_RT    Right        1.0  AND_Gate
# 482          81   11486.000  UAAS_RT    Right        2.0  AND_Gate
# 483          81   12361.000   UBS_RT    Right        1.0  AND_Gate
# 484          81   12593.000   UAS_RB    Right        2.0  AND_Gate
# 485          81   10185.000  UBBS_RT    Right        1.0  AND_Gate
# 486          82   23773.635   UAS_LB     Left        1.0  AND_Gate
# 487          82   24768.160  UABS_LT     Left        1.0  AND_Gate
# 488          82   11166.450  UBAS_LB     Left        1.0  AND_Gate
# 489          82   11942.915   UBS_LT     Left        1.0  AND_Gate
# 490          82   10791.035  UBBS_LB     Left        2.0  AND_Gate
# 491          82   13145.325  UAAS_LT     Left        1.0  AND_Gate
# 492          83   17426.000   UAS_RB    Right        2.0  AND_Gate
# 493          83   23166.000  UBBS_RT    Right        1.0  AND_Gate
# 494          83   21392.000  UAAS_RT    Right        1.0  AND_Gate
# 495          83   65716.000   UBS_RT    Right        1.0  AND_Gate
# 496          83   13796.000  UBAS_RT    Right        1.0  AND_Gate
# 497          83   13937.000  UABS_RT    Right        1.0  AND_Gate
# 498          84   14788.000  UBAS_RB    Right        1.0  AND_Gate
# 499          84   12909.000  UABS_RB    Right        1.0  AND_Gate
# 500          84   11180.000   UAS_RT    Right        1.0  AND_Gate
# 501          84    8956.000  UBBS_RT    Right        2.0  AND_Gate
# 502          84   10133.000   UBS_RB    Right        1.0  AND_Gate
# 503          84   10798.000  UAAS_RT    Right        1.0  AND_Gate
# 504          85   10096.000  UBBS_LT     Left        3.0  AND_Gate
# 505          85   11346.000   UAS_LB     Left        1.0  AND_Gate
# 506          85   10523.000  UBAS_LB     Left        1.0  AND_Gate
# 507          85   14659.000  UABS_LB     Left        1.0  AND_Gate
# 508          85   13721.000  UAAS_LT     Left        1.0  AND_Gate
# 509          85   20816.000   UBS_LB     Left        1.0  AND_Gate
# 510          86   21476.395  UABS_LT     Left        1.0  AND_Gate
# 511          86   12910.630   UBS_LT     Left        1.0  AND_Gate
# 512          86   12936.615  UBBS_LT     Left        1.0  AND_Gate
# 513          86   13478.210  UAAS_LB     Left        1.0  AND_Gate
# 514          86   19487.780  UBAS_LT     Left        1.0  AND_Gate
# 515          86   14118.535   UAS_LT     Left        1.0  AND_Gate
# 516          87   24657.270   UAS_LT     Left        1.0  AND_Gate
# 517          87   10456.195  UBBS_LT     Left        1.0  AND_Gate
# 518          87   11378.360   UBS_LT     Left        1.0  AND_Gate
# 519          87   11166.215  UBAS_LB     Left        1.0  AND_Gate
# 520          87   11496.060  UAAS_LB     Left        1.0  AND_Gate
# 521          87   12192.995  UABS_LB     Left        1.0  AND_Gate
# 522          88   23172.000  UBAS_LT     Left        1.0  AND_Gate
# 523          88   12474.000   UAS_LT     Left        1.0  AND_Gate
# 524          88   14640.000  UAAS_LB     Left        1.0  AND_Gate
# 525          88   13303.000  UBBS_LT     Left        1.0  AND_Gate
# 526          88   17156.000   UBS_LT     Left        1.0  AND_Gate
# 527          88   12108.000  UABS_LT     Left        1.0  AND_Gate
# 528          89   21105.055  UABS_RT    Right        1.0  AND_Gate
# 529          89   14921.525  UBAS_RT    Right        1.0  AND_Gate
# 530          89   11589.980   UBS_RT    Right        1.0  AND_Gate
# 531          89   13452.555   UAS_RB    Right        1.0  AND_Gate
# 532          89   11363.230  UBBS_RT    Right        1.0  AND_Gate
# 533          89   11124.610  UAAS_RT    Right        2.0  AND_Gate
# 534          90   19292.515  UBAS_LT     Left        1.0  AND_Gate
# 535          90   14525.820  UABS_LT     Left        1.0  AND_Gate
# 536          90   16055.420  UAAS_LB     Left        2.0  AND_Gate
# 537          90   10650.085   UBS_LB     Left        1.0  AND_Gate
# 538          90   11021.075  UBBS_LB     Left        1.0  AND_Gate
# 539          90   10739.580   UAS_LT     Left        1.0  AND_Gate
# 540          91   18596.765  UAAS_RB    Right        2.0  AND_Gate
# 541          91   13421.270   UBS_RB    Right        1.0  AND_Gate
# 542          91   12205.490  UBAS_RT    Right        1.0  AND_Gate
# 543          91   24412.730   UAS_RB    Right        1.0  AND_Gate
# 544          91   12197.460  UABS_RB    Right        1.0  AND_Gate
# 545          91   16021.340  UBBS_RT    Right        1.0  AND_Gate
# 546          92   12200.785  UAAS_RB    Right        2.0  AND_Gate
# 547          92   25983.085   UBS_RT    Right        1.0  AND_Gate
# 548          92   10204.605  UBBS_RB    Right        1.0  AND_Gate
# 549          92   10524.900   UAS_RT    Right        1.0  AND_Gate
# 550          92   10191.225  UBAS_RT    Right        1.0  AND_Gate
# 551          92   11859.205  UABS_RB    Right        1.0  AND_Gate
# 552          93   24745.715  UABS_RB    Right        1.0  AND_Gate
# 553          93   15546.655   UBS_RB    Right        1.0  AND_Gate
# 554          93   18094.965  UBBS_RT    Right        2.0  AND_Gate
# 555          93   11092.570   UAS_RT    Right        1.0  AND_Gate
# 556          93   17580.110  UAAS_RT    Right        1.0  AND_Gate
# 557          93   12935.185  UBAS_RB    Right        1.0  AND_Gate
# 558          94   15955.975  UBAS_LB     Left        1.0  AND_Gate
# 559          94   15571.805   UBS_LB     Left        1.0  AND_Gate
# 560          94   11507.495   UAS_LB     Left        1.0  AND_Gate
# 561          94   11829.345  UAAS_LB     Left        1.0  AND_Gate
# 562          94    9302.960  UBBS_LT     Left        1.0  AND_Gate
# 563          94   12134.285  UABS_LT     Left        1.0  AND_Gate
# 564          95   21583.000   UAS_LT     Left        1.0  AND_Gate
# 565          95   11863.000  UBBS_LT     Left        1.0  AND_Gate
# 566          95   12770.000  UAAS_LT     Left        1.0  AND_Gate
# 567          95   12026.000   UBS_LB     Left        1.0  AND_Gate
# 568          95   16401.000  UABS_LB     Left        1.0  AND_Gate
# 569          95   10576.000  UBAS_LB     Left        1.0  AND_Gate
# 570          96   12622.590  UBAS_RB    Right        2.0  AND_Gate
# 571          96   16037.850  UAAS_RB    Right        1.0  AND_Gate
# 572          96    9973.745  UBBS_RB    Right        2.0  AND_Gate
# 573          96   13309.445   UAS_RT    Right        1.0  AND_Gate
# 574          96   14094.330  UABS_RB    Right        1.0  AND_Gate
# 575          96   11381.670   UBS_RB    Right        1.0  AND_Gate
# 576          97   17231.545  UAAS_LT     Left        1.0  AND_Gate
# 577          97   10336.180  UBBS_LB     Left        1.0  AND_Gate
# 578          97   10463.925  UBAS_LT     Left        1.0  AND_Gate
# 579          97   10927.335   UBS_LT     Left        1.0  AND_Gate
# 580          97   11096.490   UAS_LB     Left        1.0  AND_Gate
# 581          97   11775.965  UABS_LB     Left        1.0  AND_Gate
# 582          98   22487.410   UAS_RB    Right        1.0  AND_Gate
# 583          98   19563.995  UABS_RB    Right        1.0  AND_Gate
# 584          98   10547.820  UBBS_RB    Right        1.0  AND_Gate
# 585          98   11416.055  UBAS_RB    Right        1.0  AND_Gate
# 586          98   11070.765   UBS_RT    Right        1.0  AND_Gate
# 587          98   11888.860  UAAS_RB    Right        1.0  AND_Gate
# 588          99   12801.080  UBAS_RT    Right        1.0  AND_Gate
# 589          99   10569.115   UAS_RB    Right        2.0  AND_Gate
# 590          99   10941.885  UAAS_RB    Right        1.0  AND_Gate
# 591          99   10523.850   UBS_RB    Right        1.0  AND_Gate
# 592          99   13583.175  UABS_RT    Right        1.0  AND_Gate
# 593          99   13258.530  UBBS_RB    Right        1.0  AND_Gate
# 594         100   18707.000  UAAS_RB    Right        1.0  AND_Gate
# 595         100   23013.000  UBAS_RT    Right        1.0  AND_Gate
# 596         100   11951.000  UBBS_RB    Right        2.0  AND_Gate
# 597         100   14898.000   UAS_RT    Right        1.0  AND_Gate
# 598         100   11452.000   UBS_RT    Right        1.0  AND_Gate
# 599         100   12388.000  UABS_RB    Right        1.0  AND_Gate
#
#     rolled_OR_unrolled A_branch_loc A_detectors state_OR_event state_branch  \
# 0             Unrolled          Top     Squares          Event          NaN
# 1             Unrolled       Bottom     Squares          Event          NaN
# 2             Unrolled          Top     Squares          Event          NaN
# 3             Unrolled       Bottom     Squares          State            A
# 4             Unrolled       Bottom     Squares          State            B
# 5             Unrolled          Top     Squares          Event          NaN
# 6             Unrolled       Bottom     Squares          State            A
# 7             Unrolled          Top     Squares          State            B
# 8             Unrolled       Bottom     Squares          Event          NaN
# 9             Unrolled       Bottom     Squares          Event          NaN
# 10            Unrolled          Top     Squares          Event          NaN
# 11            Unrolled          Top     Squares          Event          NaN
# 12            Unrolled          Top     Squares          Event          NaN
# 13            Unrolled       Bottom     Squares          Event          NaN
# 14            Unrolled       Bottom     Squares          State            A
# 15            Unrolled       Bottom     Squares          State            B
# 16            Unrolled       Bottom     Squares          Event          NaN
# 17            Unrolled          Top     Squares          Event          NaN
# 18            Unrolled          Top     Squares          Event          NaN
# 19            Unrolled          Top     Squares          Event          NaN
# 20            Unrolled          Top     Squares          State            A
# 21            Unrolled       Bottom     Squares          Event          NaN
# 22            Unrolled       Bottom     Squares          Event          NaN
# 23            Unrolled          Top     Squares          State            B
# 24            Unrolled          Top     Squares          Event          NaN
# 25            Unrolled          Top     Squares          State            A
# 26            Unrolled       Bottom     Squares          Event          NaN
# 27            Unrolled       Bottom     Squares          State            B
# 28            Unrolled          Top     Squares          Event          NaN
# 29            Unrolled       Bottom     Squares          Event          NaN
# 30            Unrolled          Top     Squares          Event          NaN
# 31            Unrolled          Top     Squares          Event          NaN
# 32            Unrolled          Top     Squares          Event          NaN
# 33            Unrolled          Top     Squares          State            B
# 34            Unrolled       Bottom     Squares          Event          NaN
# 35            Unrolled          Top     Squares          State            A
# 36            Unrolled       Bottom     Squares          State            A
# 37            Unrolled       Bottom     Squares          Event          NaN
# 38            Unrolled       Bottom     Squares          Event          NaN
# 39            Unrolled       Bottom     Squares          State            B
# 40            Unrolled       Bottom     Squares          Event          NaN
# 41            Unrolled       Bottom     Squares          Event          NaN
# 42            Unrolled          Top     Squares          Event          NaN
# 43            Unrolled          Top     Squares          Event          NaN
# 44            Unrolled       Bottom     Squares          Event          NaN
# 45            Unrolled          Top     Squares          State            A
# 46            Unrolled       Bottom     Squares          Event          NaN
# 47            Unrolled       Bottom     Squares          State            B
# 48            Unrolled       Bottom     Squares          State            A
# 49            Unrolled       Bottom     Squares          Event          NaN
# 50            Unrolled       Bottom     Squares          State            B
# 51            Unrolled       Bottom     Squares          Event          NaN
# 52            Unrolled       Bottom     Squares          Event          NaN
# 53            Unrolled          Top     Squares          Event          NaN
# 54            Unrolled       Bottom     Squares          Event          NaN
# 55            Unrolled          Top     Squares          State            A
# 56            Unrolled       Bottom     Squares          Event          NaN
# 57            Unrolled          Top     Squares          Event          NaN
# 58            Unrolled       Bottom     Squares          State            B
# 59            Unrolled          Top     Squares          Event          NaN
# 60            Unrolled       Bottom     Squares          Event          NaN
# 61            Unrolled       Bottom     Squares          State            A
# 62            Unrolled          Top     Squares          State            B
# 63            Unrolled       Bottom     Squares          Event          NaN
# 64            Unrolled          Top     Squares          Event          NaN
# 65            Unrolled          Top     Squares          Event          NaN
# 66            Unrolled       Bottom     Squares          Event          NaN
# 67            Unrolled       Bottom     Squares          Event          NaN
# 68            Unrolled          Top     Squares          State            B
# 69            Unrolled          Top     Squares          Event          NaN
# 70            Unrolled       Bottom     Squares          State            A
# 71            Unrolled       Bottom     Squares          Event          NaN
# 72            Unrolled          Top     Squares          State            A
# 73            Unrolled          Top     Squares          Event          NaN
# ...
# 338        B        B       nodeB19      IMDT_2nd       IC
# 339      NaN        A       nodeA30      ROOT_2nd       RC
# 340        A        B        nodeB7      ROOT_2nd       RC
# 341        A        A       nodeA41      IMDT_2nd       IC
# 342      NaN        B        nodeB8      ROOT_2nd       RC
# 343        B        B        nodeB2      ROOT_1st       RC
# 344        A        B        nodeB7      ROOT_2nd       RC
# 345        A        A        nodeB7      ROOT_2nd       RD
# 346      NaN        A       nodeA30      ROOT_2nd       RC
# 347        B        A       nodeA25      ROOT_2nd       RC
# 348      NaN        B       nodeA27      ROOT_1st       RD
# 349        A        B        nodeA5     INACT_1st    other
# 350        B        A       nodeA25      ROOT_2nd       RC
# 351      NaN        A       nodeA30      ROOT_2nd       RC
# 352        B        B        nodeB2      ROOT_1st       RC
# 353        A        A        nodeA7      ROOT_1st       RC
# 354      NaN        A       nodeA41      IMDT_2nd       IC
# 355        A        A       nodeA41      IMDT_2nd       IC
# 356        B        B       nodeB19      IMDT_2nd       IC
# 357        A        B       nodeB19      IMDT_2nd       IC
# 358      NaN        B       nodeB19      IMDT_2nd       IC
# 359        B        A       nodeA41      IMDT_2nd       IC
# 360        A        A       nodeB17     INBTW_2nd    other
# 361        A        B       nodeB19      IMDT_2nd       IC
# 362        B        A       nodeA39     INBTW_2nd    other
# 363      NaN        A       nodeB16     INBTW_1st    other
# 364        B        B       nodeB18     INBTW_1st    other
# 365      NaN        B       nodeB14     INBTW_2nd    other
# 366      NaN        B       nodeB19      IMDT_2nd       IC
# 367      NaN        A       nodeA41      IMDT_2nd       IC
# 368        B        A       nodeA41      IMDT_2nd       IC
# 369        A        A       nodeA41      IMDT_2nd       IC
# 370        A        B       nodeB19      IMDT_2nd       IC
# 371        B        B       nodeB19      IMDT_2nd       IC
# 372      NaN        B       nodeB19      IMDT_2nd       IC
# 373      NaN        A       nodeA41      IMDT_2nd       IC
# 374        B        A       nodeA41      IMDT_2nd       IC
# 375        B        B       nodeB19      IMDT_2nd       IC
# 376        A        B       nodeB19      IMDT_2nd       IC
# 377        A        A       nodeA41      IMDT_2nd       IC
# 378        A        B       nodeB19      IMDT_2nd       IC
# 379        B        B       nodeB19      IMDT_2nd       IC
# 380        A        A       nodeA41      IMDT_2nd       IC
# 381      NaN        B       nodeB19      IMDT_2nd       IC
# 382        B        A       nodeA41      IMDT_2nd       IC
# 383      NaN        A       nodeA41      IMDT_2nd       IC
# 384      NaN        A        nodeB8      ROOT_1st       RD
# 385        B        A        nodeB4      ROOT_1st       RD
# 386        A        A        nodeB7      ROOT_2nd       RD
# 387        A        B        nodeA7      ROOT_1st       RD
# 388        B        B       nodeA37      ROOT_2nd       RD
# 389      NaN        B       nodeA27      ROOT_1st       RD
# 390        A        B       nodeB19      IMDT_2nd       IC
# 391      NaN        A       nodeA41      IMDT_2nd       IC
# 392        B        B       nodeB19      IMDT_2nd       IC
# 393        B        A       nodeA41      IMDT_2nd       IC
# 394      NaN        B       nodeB19      IMDT_2nd       IC
# 395        A        A       nodeA41      IMDT_2nd       IC
# 396        A        B       nodeB20        EFFECT    other
# 397        A        A       nodeA41      IMDT_2nd       IC
# 398        B        A       nodeA41      IMDT_2nd       IC
# 399        B        B       nodeB19      IMDT_2nd       IC
# 400      NaN        A       nodeB19      IMDT_1st       ID
# 401      NaN        B       nodeB19      IMDT_2nd       IC
# 402        A        B        nodeB7      ROOT_2nd       RC
# 403      NaN        B        nodeB8      ROOT_2nd       RC
# 404        A        A        nodeA7      ROOT_1st       RC
# 405      NaN        A       nodeA30      ROOT_2nd       RC
# 406        B        B        nodeB2      ROOT_1st       RC
# 407        B        A       nodeA25      ROOT_2nd       RC
# 408      NaN        B        nodeB8      ROOT_2nd       RC
# 409        B        B        nodeB2      ROOT_1st       RC
# 410        A        B        nodeB7      ROOT_2nd       RC
# 411        A        A        nodeA7      ROOT_1st       RC
# 412        B        A       nodeA25      ROOT_2nd       RC
# 413      NaN        A       nodeA30      ROOT_2nd       RC
# 414        A        B       nodeB19      IMDT_2nd       IC
# 415        B        A       nodeA41      IMDT_2nd       IC
# 416      NaN        A       nodeA41      IMDT_2nd       IC
# 417        B        B       nodeB19      IMDT_2nd       IC
# 418        A        A       nodeA41      IMDT_2nd       IC
# 419      NaN        B       nodeB19      IMDT_2nd       IC
# 420      NaN        B        nodeB8      ROOT_2nd       RC
# 421        A        A        nodeA7      ROOT_1st       RC
# 422        B        A       nodeA25      ROOT_2nd       RC
# 423        B        B       nodeA37      ROOT_2nd       RD
# 424      NaN        A       nodeA30      ROOT_2nd       RC
# 425        A        B        nodeB7      ROOT_2nd       RC
# 426        A        B        nodeA7      ROOT_1st       RD
# 427      NaN        A        nodeB8      ROOT_1st       RD
# 428        A        A        nodeA7      ROOT_1st       RC
# 429      NaN        B       nodeA27      ROOT_1st       RD
# 430        B        B        nodeB2      ROOT_1st       RC
# 431        B        A        nodeB4      ROOT_1st       RD
# 432      NaN        A       nodeB19      IMDT_1st       ID
# 433        B        A       nodeA33     INBTW_2nd    other
# 434      NaN        B       nodeB19      IMDT_2nd       IC
# 435        A        B       nodeB19      IMDT_2nd       IC
# 436        A        A       nodeA41      IMDT_2nd       IC
# 437        B        B       nodeB19      IMDT_2nd       IC
# 438        A        B       nodeB19      IMDT_2nd       IC
# 439        B        A       nodeB20        EFFECT    other
# 440        A        A       nodeB20        EFFECT    other
# 441      NaN        B       nodeB20        EFFECT    other
# 442        B        B       nodeB20        EFFECT    other
# 443      NaN        A       nodeB20        EFFECT    other
# 444        B        A       nodeA26      ROOT_2nd       RC
# 445        A        A       nodeA12     INBTW_1st    other
# 446      NaN        B       nodeB11     INBTW_2nd    other
# 447      NaN        A       nodeB16     INBTW_1st    other
# 448        A        B       nodeA21     INBTW_1st    other
# 449        B        B        nodeB7     INBTW_1st    other
# 450        B        A       nodeA25      ROOT_2nd       RC
# 451        B        B       nodeA37      ROOT_2nd       RD
# 452        A        A        nodeB7      ROOT_2nd       RD
# 453      NaN        B        nodeB8      ROOT_2nd       RC
# 454        A        B        nodeB7      ROOT_2nd       RC
# 455      NaN        A       nodeA30      ROOT_2nd       RC
# 456        A        B        nodeA7      ROOT_1st       RD
# 457      NaN        B       nodeA27      ROOT_1st       RD
# 458        A        A        nodeA7      ROOT_1st       RC
# 459        B        B        nodeB2      ROOT_1st       RC
# 460        B        A        nodeB4      ROOT_1st       RD
# 461      NaN        A        nodeB8      ROOT_1st       RD
# 462      NaN        B       nodeA27      ROOT_1st       RD
# 463        A        A        nodeA7      ROOT_1st       RC
# 464        B        A        nodeB4      ROOT_1st       RD
# 465        A        B        nodeA7      ROOT_1st       RD
# 466        B        B        nodeB2      ROOT_1st       RC
# 467      NaN        A        nodeB8      ROOT_1st       RD
# 468      NaN        A        nodeB8      ROOT_1st       RD
# 469        B        B        nodeB2      ROOT_1st       RC
# 470      NaN        B       nodeA27      ROOT_1st       RD
# 471        B        A        nodeB4      ROOT_1st       RD
# 472        A        B        nodeA7      ROOT_1st       RD
# 473        A        A        nodeA7      ROOT_1st       RC
# 474        B        A       nodeA20     INACT_2nd    other
# 475      NaN        A       nodeA29      ROOT_2nd       RC
# 476        A        A        nodeB6     INACT_2nd    other
# 477        B        B       nodeA36      ROOT_2nd       RD
# 478      NaN        B       nodeA26      ROOT_1st       RD
# 479        A        B        nodeB6      ROOT_2nd       RC
# 480        B        A       nodeA25      ROOT_2nd       RC
# 481        A        B        nodeB7      ROOT_2nd       RC
# 482        A        A       nodeA41      IMDT_2nd       IC
# 483      NaN        A       nodeA41      IMDT_2nd       IC
# 484      NaN        B       nodeB19      IMDT_2nd       IC
# 485        B        B       nodeB20        EFFECT    other
# 486      NaN        B        nodeB8      ROOT_2nd       RC
# 487        A        B        nodeB7      ROOT_2nd       RC
# 488        B        A       nodeA25      ROOT_2nd       RC
# 489      NaN        A       nodeA30      ROOT_2nd       RC
# 490        B        B        nodeB2      ROOT_1st       RC
# 491        A        A        nodeB7      ROOT_2nd       RD
# 492      NaN        B        nodeB8      ROOT_2nd       RC
# 493        B        B        nodeB2      ROOT_1st       RC
# 494        A        A        nodeA7      ROOT_1st       RC
# 495      NaN        A       nodeA30      ROOT_2nd       RC
# 496        B        A       nodeA25      ROOT_2nd       RC
# 497        A        B        nodeB7      ROOT_2nd       RC
# 498        B        A       nodeA25      ROOT_2nd       RC
# 499        A        B        nodeB7      ROOT_2nd       RC
# 500      NaN        B        nodeB8      ROOT_2nd       RC
# 501        B        B       nodeA37      ROOT_2nd       RD
# 502      NaN        A       nodeA30      ROOT_2nd       RC
# 503        A        A        nodeB7      ROOT_2nd       RD
# 504        B        B        nodeB2      ROOT_1st       RC
# 505      NaN        B        nodeB8      ROOT_2nd       RC
# 506        B        A       nodeA25      ROOT_2nd       RC
# 507        A        B        nodeB7      ROOT_2nd       RC
# 508        A        A        nodeA7      ROOT_1st       RC
# 509      NaN        A       nodeA30      ROOT_2nd       RC
# 510        A        B        nodeB7      ROOT_2nd       RC
# 511      NaN        A       nodeA30      ROOT_2nd       RC
# 512        B        B        nodeB2      ROOT_1st       RC
# 513        A        A        nodeA7      ROOT_1st       RC
# 514        B        A       nodeA25      ROOT_2nd       RC
# 515      NaN        B        nodeB8      ROOT_2nd       RC
# 516      NaN        B        nodeB8      ROOT_2nd       RC
# 517        B        B        nodeB2      ROOT_1st       RC
# 518      NaN        A        nodeB8      ROOT_1st       RD
# 519        B        A        nodeB4      ROOT_1st       RD
# 520        A        A        nodeA7      ROOT_1st       RC
# 521        A        B        nodeA7      ROOT_1st       RD
# 522        B        A       nodeA24      ROOT_2nd       RC
# 523      NaN        B       nodeA26      ROOT_1st       RD
# 524        A        A        nodeB6     INACT_2nd    other
# 525        B        B       nodeA36      ROOT_2nd       RD
# 526      NaN        A       nodeA29      ROOT_2nd       RC
# 527        A        B        nodeB6      ROOT_2nd       RC
# 528        A        B       nodeB19      IMDT_2nd       IC
# 529        B        A       nodeA41      IMDT_2nd       IC
# 530      NaN        A       nodeA41      IMDT_2nd       IC
# 531      NaN        B       nodeB19      IMDT_2nd       IC
# 532        B        B       nodeB19      IMDT_2nd       IC
# 533        A        A       nodeA41      IMDT_2nd       IC
# 534        B        A       nodeA41      IMDT_2nd       IC
# 535        A        B       nodeB19      IMDT_2nd       IC
# 536        A        A        nodeA7      ROOT_1st       RC
# 537      NaN        A       nodeA30      ROOT_2nd       RC
# 538        B        B       nodeA37      ROOT_2nd       RD
# 539      NaN        B        nodeB8      ROOT_2nd       RC
# 540        A        A        nodeA7      ROOT_1st       RC
# 541      NaN        A        nodeB8      ROOT_1st       RD
# 542        B        A        nodeB4      ROOT_1st       RD
# 543      NaN        B       nodeA27      ROOT_1st       RD
# 544        A        B        nodeA7      ROOT_1st       RD
# 545        B        B        nodeB2      ROOT_1st       RC
# 546        A        A        nodeA7      ROOT_1st       RC
# 547      NaN        A       nodeA30      ROOT_2nd       RC
# 548        B        B        nodeB2      ROOT_1st       RC
# 549      NaN        B        nodeB8      ROOT_2nd       RC
# 550        B        A       nodeA25      ROOT_2nd       RC
# 551        A        B        nodeB7      ROOT_2nd       RC
# 552        A        B        nodeA7      ROOT_1st       RD
# 553      NaN        A       nodeA30      ROOT_2nd       RC
# 554        B        B        nodeB2      ROOT_1st       RC
# 555      NaN        B       nodeA27      ROOT_1st       RD
# 556        A        A        nodeA7      ROOT_1st       RC
# 557        B        A       nodeA25      ROOT_2nd       RC
# 558        B        A       nodeA25      ROOT_2nd       RC
# 559      NaN        A       nodeA30      ROOT_2nd       RC
# 560      NaN        B        nodeB8      ROOT_2nd       RC
# 561        A        A        nodeA7      ROOT_1st       RC
# 562        B        B        nodeB2      ROOT_1st       RC
# 563        A        B        nodeB7      ROOT_2nd       RC
# 564      NaN        B       nodeA27      ROOT_1st       RD
# 565        B        B        nodeB1      ROOT_1st       RC
# 566        A        A        nodeA7      ROOT_1st       RC
# 567      NaN        A       nodeA29      ROOT_2nd       RC
# 568        A        B        nodeA6      ROOT_1st       RD
# 569        B        A       nodeA25      ROOT_2nd       RC
# 570        B        A        nodeB4      ROOT_1st       RD
# 571        A        A        nodeA7      ROOT_1st       RC
# 572        B        B       nodeB19      IMDT_2nd       IC
# 573      NaN        B       nodeB19      IMDT_2nd       IC
# 574        A        B       nodeB19      IMDT_2nd       IC
# 575      NaN        A       nodeA41      IMDT_2nd       IC
# 576        A        A        nodeA7      ROOT_1st       RC
# 577        B        B        nodeB2      ROOT_1st       RC
# 578        B        A        nodeB4      ROOT_1st       RD
# 579      NaN        A        nodeB8      ROOT_1st       RD
# 580      NaN        B       nodeA27      ROOT_1st       RD
# 581        A        B        nodeA7      ROOT_1st       RD
# 582      NaN        B       nodeB19      IMDT_2nd       IC
# 583        A        B       nodeB19      IMDT_2nd       IC
# 584        B        B       nodeB19      IMDT_2nd       IC
# 585        B        A       nodeA41      IMDT_2nd       IC
# 586      NaN        A       nodeA41      IMDT_2nd       IC
# 587        A        A       nodeA41      IMDT_2nd       IC
# 588        B        A       nodeA25      ROOT_2nd       RC
# 589      NaN        B        nodeB8      ROOT_2nd       RC
# 590        A        A        nodeA7      ROOT_1st       RC
# 591      NaN        A       nodeA30      ROOT_2nd       RC
# 592        A        B        nodeB7      ROOT_2nd       RC
# 593        B        B        nodeB2      ROOT_1st       RC
# 594        A        A        nodeA7      ROOT_1st       RC
# 595        B        A       nodeA25      ROOT_2nd       RC
# 596        B        B       nodeB16     INBTW_1st    other
# 597      NaN        B        nodeB8      ROOT_2nd       RC
# 598      NaN        A       nodeA30      ROOT_2nd       RC
# 599        A        B        nodeB8      ROOT_2nd       RC

# %%
data_chain
# Out:
#     subject_id          rt  stimulus sampling  nb_of_run stim_type  \
# 0            1   10690.350  chainS_R    Right        1.0    ChainS
# 1            2    8851.390  chainS_L     Left        1.0    ChainS
# 2            3   18117.000  chainS_R    Right        1.0    ChainS
# 3            4   13172.380  chainS_L     Left        2.0    ChainS
# 4            5    8726.075  chainS_R    Right        1.0    ChainS
# 5            6    8505.340  chainS_R    Right        1.0    ChainS
# 6            7   12404.190  chainS_L     Left        1.0    ChainS
# 7            8   13427.315  chainS_L     Left        1.0    ChainS
# 8            9   15379.935  chainS_R    Right        1.0    ChainS
# 9           10    8439.875  chainS_R    Right        1.0    ChainS
# 10          11    9523.385  chainS_R    Right        1.0    ChainS
# 11          12   10375.785  chainS_L     Left        1.0    ChainS
# 12          13   21004.165  chainS_R    Right        1.0    ChainS
# 13          14   10241.805  chainS_L     Left        1.0    ChainS
# 14          15   10988.320  chainS_L     Left        1.0    ChainS
# 15          16    8575.000  chainS_R    Right        1.0    ChainS
# 16          17    8417.960  chainS_L     Left        1.0    ChainS
# 17          18   12207.000  chainS_R    Right        1.0    ChainS
# 18          19    8948.425  chainS_R    Right        1.0    ChainS
# 19          20    8669.350  chainS_R    Right        1.0    ChainS
# 20          21   10190.380  chainS_L     Left        1.0    ChainS
# 21          22   23526.000  chainS_R    Right        1.0    ChainS
# 22          23   20741.985  chainS_R    Right        1.0    ChainS
# 23          24    9046.895  chainS_R    Right        2.0    ChainS
# 24          25   11037.710  chainS_L     Left        1.0    ChainS
# 25          26   13049.000  chainS_R    Right        1.0    ChainS
# 26          27   12091.355  chainS_R    Right        1.0    ChainS
# 27          28    9447.650  chainS_R    Right        1.0    ChainS
# 28          29    9806.295  chainS_R    Right        1.0    ChainS
# 29          30   11662.000  chainS_L     Left        1.0    ChainS
# 30          31   19400.325  chainS_R    Right        1.0    ChainS
# 31          32    8452.700  chainS_L     Left        1.0    ChainS
# 32          33   17933.975  chainS_L     Left        1.0    ChainS
# 33          34   16157.695  chainS_R    Right        1.0    ChainS
# 34          35   14035.540  chainS_L     Left        1.0    ChainS
# 35          36    9775.965  chainS_R    Right        1.0    ChainS
# 36          37   14949.535  chainS_L     Left        1.0    ChainS
# 37          38   15195.440  chainS_L     Left        1.0    ChainS
# 38          39   14397.480  chainS_L     Left        1.0    ChainS
# 39          40    9042.515  chainS_L     Left        1.0    ChainS
# 40          41   15420.255  chainS_R    Right        2.0    ChainS
# 41          42   15876.585  chainS_L     Left        1.0    ChainS
# 42          43   10675.925  chainS_R    Right        1.0    ChainS
# 43          44    8686.675  chainS_R    Right        1.0    ChainS
# 44          45   12339.435  chainS_L     Left        1.0    ChainS
# 45          46   13496.000  chainS_R    Right        1.0    ChainS
# 46          47   12435.215  chainS_R    Right        1.0    ChainS
# 47          48   16580.185  chainS_R    Right        1.0    ChainS
# 48          49   18811.000  chainS_R    Right        1.0    ChainS
# 49          50    9362.000  chainS_L     Left        1.0    ChainS
# 50          51   14400.270  chainS_L     Left        1.0    ChainS
# 51          52   39882.000  chainS_R    Right        1.0    ChainS
# 52          53   12399.005  chainS_R    Right        1.0    ChainS
# 53          54    9426.640  chainS_L     Left        1.0    ChainS
# 54          55   13496.280  chainS_R    Right        1.0    ChainS
# 55          56   42417.000  chainS_L     Left        1.0    ChainS
# 56          57    8203.025  chainS_L     Left        1.0    ChainS
# 57          58    8678.645  chainS_L     Left        1.0    ChainS
# 58          59   10590.000  chainS_L     Left        1.0    ChainS
# 59          60   11886.030  chainS_R    Right        1.0    ChainS
# 60          61   27544.140  chainS_R    Right        1.0    ChainS
# 61          62   10101.310  chainS_L     Left        1.0    ChainS
# 62          63   17833.050  chainS_R    Right        1.0    ChainS
# 63          64   13328.700  chainS_R    Right        1.0    ChainS
# 64          65    8326.835  chainS_R    Right        1.0    ChainS
# 65          66    9585.970  chainS_R    Right        1.0    ChainS
# 66          67    8073.260  chainS_R    Right        1.0    ChainS
# 67          68   23340.725  chainS_L     Left        1.0    ChainS
# 68          69   12116.310  chainS_L     Left        1.0    ChainS
# 69          70   12998.270  chainS_R    Right        1.0    ChainS
# 70          71    8856.505  chainS_L     Left        1.0    ChainS
# 71          72    9244.755  chainS_L     Left        1.0    ChainS
# 72          73   18796.160  chainS_R    Right        1.0    ChainS
# 73          74   19678.000  chainS_L     Left        1.0    ChainS
# 74          75   11839.455  chainS_L     Left        1.0    ChainS
# 75          76    8776.000  chainS_L     Left        1.0    ChainS
# 76          77   10715.000  chainS_R    Right        1.0    ChainS
# 77          78    8951.025  chainS_L     Left        1.0    ChainS
# 78          79  118256.700  chainS_R    Right        1.0    ChainS
# 79          80    8892.990  chainS_L     Left        1.0    ChainS
# 80          81   13784.000  chainS_R    Right        1.0    ChainS
# 81          82   12514.810  chainS_L     Left        1.0    ChainS
# 82          83   15936.000  chainS_R    Right        1.0    ChainS
# 83          84   14772.000  chainS_R    Right        1.0    ChainS
# 84          85    9409.000  chainS_L     Left        1.0    ChainS
# 85          86   14320.570  chainS_L     Left        1.0    ChainS
# 86          87    8983.545  chainS_L     Left        1.0    ChainS
# 87          88   11751.000  chainS_L     Left        1.0    ChainS
# 88          89   11133.860  chainS_R    Right        1.0    ChainS
# 89          90   10045.635  chainS_L     Left        1.0    ChainS
# 90          91   10157.510  chainS_R    Right        1.0    ChainS
# 91          92    9137.635  chainS_R    Right        1.0    ChainS
# 92          93    8343.835  chainS_R    Right        1.0    ChainS
# 93          94   12891.510  chainS_L     Left        1.0    ChainS
# 94          95   16905.000  chainS_L     Left        2.0    ChainS
# 95          96   15509.650  chainS_R    Right        1.0    ChainS
# 96          97    8712.725  chainS_L     Left        1.0    ChainS
# 97          98   12263.975  chainS_R    Right        1.0    ChainS
# 98          99   15934.585  chainS_R    Right        1.0    ChainS
# 99         100   14964.000  chainS_R    Right        1.0    ChainS
#
#    A_branch_loc node_selected node_category
# 0           NaN        nodeB9          ROOT
# 1           NaN        nodeB9          ROOT
# 2           NaN        nodeB9          ROOT
# 3           NaN       nodeB19          IMDT
# 4           NaN        nodeB9          ROOT
# 5           NaN        nodeB9          ROOT
# 6           NaN        nodeB9          ROOT
# 7           NaN        nodeB9          ROOT
# 8           NaN        nodeB9          ROOT
# 9           NaN        nodeB9          ROOT
# 10          NaN        nodeB9          ROOT
# 11          NaN        nodeB9          ROOT
# 12          NaN        nodeB9          ROOT
# 13          NaN        nodeB9          ROOT
# 14          NaN        nodeB9          ROOT
# 15          NaN        nodeB9          ROOT
# 16          NaN        nodeB9          ROOT
# 17          NaN       nodeB20        EFFECT
# 18          NaN       nodeB19          IMDT
# 19          NaN        nodeB9          ROOT
# 20          NaN       nodeB19          IMDT
# 21          NaN        nodeB9          ROOT
# 22          NaN       nodeB19          IMDT
# 23          NaN       nodeB19          IMDT
# 24          NaN        nodeB9          ROOT
# 25          NaN        nodeB9          ROOT
# 26          NaN        nodeB9          ROOT
# 27          NaN        nodeB9          ROOT
# 28          NaN        nodeB9          ROOT
# 29          NaN        nodeB9          ROOT
# 30          NaN       nodeB19          IMDT
# 31          NaN       nodeB19          IMDT
# 32          NaN        nodeB9          ROOT
# 33          NaN        nodeB9          ROOT
# 34          NaN        nodeB9          ROOT
# 35          NaN        nodeB9          ROOT
# 36          NaN        nodeB9          ROOT
# 37          NaN        nodeB9          ROOT
# 38          NaN       nodeB19          IMDT
# 39          NaN        nodeB9          ROOT
# 40          NaN        nodeB9          ROOT
# 41          NaN        nodeB9          ROOT
# 42          NaN       nodeB19          IMDT
# 43          NaN        nodeB9          ROOT
# 44          NaN       nodeB19          IMDT
# 45          NaN       nodeB19          IMDT
# 46          NaN        nodeB8          ROOT
# 47          NaN       nodeB19          IMDT
# 48          NaN        nodeB9          ROOT
# 49          NaN       nodeB19          IMDT
# 50          NaN        nodeB9          ROOT
# 51          NaN        nodeB9          ROOT
# 52          NaN       nodeB20        EFFECT
# 53          NaN        nodeB9          ROOT
# 54          NaN       nodeB20        EFFECT
# 55          NaN        nodeB9          ROOT
# 56          NaN        nodeB9          ROOT
# 57          NaN        nodeB9          ROOT
# 58          NaN        nodeB9          ROOT
# 59          NaN       nodeB19          IMDT
# 60          NaN       nodeB11         INBTW
# 61          NaN       nodeB19          IMDT
# 62          NaN       nodeB19          IMDT
# 63          NaN       nodeB19          IMDT
# 64          NaN        nodeB9          ROOT
# 65          NaN       nodeB19          IMDT
# 66          NaN       nodeB20        EFFECT
# 67          NaN        nodeB9          ROOT
# 68          NaN        nodeB9          ROOT
# 69          NaN       nodeB19          IMDT
# 70          NaN        nodeB9          ROOT
# 71          NaN        nodeB9          ROOT
# 72          NaN       nodeB19          IMDT
# 73          NaN       nodeB20        EFFECT
# 74          NaN       nodeB13         INBTW
# 75          NaN        nodeB9          ROOT
# 76          NaN        nodeB9          ROOT
# 77          NaN        nodeB9          ROOT
# 78          NaN        nodeB9          ROOT
# 79          NaN        nodeB1         INACT
# 80          NaN       nodeB20        EFFECT
# 81          NaN        nodeB9          ROOT
# 82          NaN        nodeB9          ROOT
# 83          NaN        nodeB9          ROOT
# 84          NaN        nodeB9          ROOT
# 85          NaN        nodeB9          ROOT
# 86          NaN        nodeB9          ROOT
# 87          NaN        nodeB8          ROOT
# 88          NaN       nodeB19          IMDT
# 89          NaN        nodeB9          ROOT
# 90          NaN        nodeB9          ROOT
# 91          NaN        nodeB9          ROOT
# 92          NaN        nodeB9          ROOT
# 93          NaN        nodeB9          ROOT
# 94          NaN        nodeB8          ROOT
# 95          NaN       nodeB19          IMDT
# 96          NaN        nodeB9          ROOT
# 97          NaN       nodeB19          IMDT
# 98          NaN        nodeB9          ROOT
# 99          NaN       nodeB19          IMDT

# %% [markdown]
# ## General comparison

# %%
# For Unrolled: only graphs with SQUARES for branch A

chain = Chain(stim='ChainS')
Unrolled_state = AndGate(rolled=False,continuity='root_2nd').add_filter(A_detectors='squares',state=True)
Unrolled_stateA = AndGate(rolled=False,continuity='root_2nd').add_filter(A_detectors='squares',state=True,state_branch='A')
Unrolled_stateB = AndGate(rolled=False,continuity='root_2nd').add_filter(A_detectors='squares',state=True,state_branch='B')
Unrolled_AA_BB = AndGate(rolled=False,continuity='root_1st').add_filter(A_detectors='squares')
Unrolled_AA = AndGate(rolled=False,continuity='root_1st').add_filter(A_detectors='squares',root_1st='A')
Unrolled_BB = AndGate(rolled=False,continuity='root_1st').add_filter(A_detectors='squares',root_1st='B')
Unrolled_AB_BA = AndGate(rolled=False,continuity='root_2nd').add_filter(A_detectors='squares',state=False)
Unrolled_AB = AndGate(rolled=False,continuity='root_2nd').add_filter(A_detectors='squares',state=False,root_1st='A')
Unrolled_BA = AndGate(rolled=False,continuity='root_2nd').add_filter(A_detectors='squares',state=False,root_1st='B')

####### Bootstrapping #######

chain = bootstrap(chain)
U = bootstrap(Unrolled_state)
UA = bootstrap(Unrolled_stateA)
UB = bootstrap(Unrolled_stateB)
UAA_BB = bootstrap(Unrolled_AA_BB)
UAA = bootstrap(Unrolled_AA)
UBB = bootstrap(Unrolled_BB)
UAB_BA = bootstrap(Unrolled_AB_BA)
UAB = bootstrap(Unrolled_AB)
UBA = bootstrap(Unrolled_BA)

graph([chain],['Chain'])
graph([U,UA,UB],['Unrolled A or B in state condition','Unrolled A in state condition','Unrolled B in state condition'])
graph([UAA_BB,UAA,UBB],['Unrolled AA or BB','Unrolled AA','Unrolled BB'])
graph([UAB_BA,UAB,UBA],['Unrolled AB or BA','Unrolled AB','Unrolled BA'])

# %%
# For Unrolled: only graphs with SQUARES for branch A

chain = Chain(stim='ChainS')
Unrolled_state = AndGate(rolled=False,continuity='root_2nd').add_filter(A_detectors='squares',state=True)
Unrolled_stateA = AndGate(rolled=False,continuity='root_2nd').add_filter(A_detectors='squares',state=True,state_branch='A')
Unrolled_stateB = AndGate(rolled=False,continuity='root_2nd').add_filter(A_detectors='squares',state=True,state_branch='B')
Unrolled_AA_BB = AndGate(rolled=False,continuity='root_1st').add_filter(A_detectors='squares')
Unrolled_AA = AndGate(rolled=False,continuity='root_1st').add_filter(A_detectors='squares',root_1st='A')
Unrolled_BB = AndGate(rolled=False,continuity='root_1st').add_filter(A_detectors='squares',root_1st='B')
Unrolled_AB_BA = AndGate(rolled=False,continuity='root_2nd').add_filter(A_detectors='squares',state=False)
Unrolled_AB = AndGate(rolled=False,continuity='root_2nd').add_filter(A_detectors='squares',state=False,root_1st='A')
Unrolled_BA = AndGate(rolled=False,continuity='root_2nd').add_filter(A_detectors='squares',state=False,root_1st='B')

####### Bootstrapping #######

#chain = bootstrap2(chain)
U = bootstrap2(Unrolled_state)
UA = bootstrap2(Unrolled_stateA)
UB = bootstrap2(Unrolled_stateB)
UAA_BB = bootstrap2(Unrolled_AA_BB)
UAA = bootstrap2(Unrolled_AA)
UBB = bootstrap2(Unrolled_BB)
UAB_BA = bootstrap2(Unrolled_AB_BA)
UAB = bootstrap2(Unrolled_AB)
UBA = bootstrap2(Unrolled_BA)

#graph([chain],['Chain'])
#graph([U,UA,UB],['Unrolled A or B in state condition','Unrolled A in state condition','Unrolled B in state condition'])
#graph([UAA_BB,UAA,UBB],['Unrolled AA or BB','Unrolled AA','Unrolled BB'])
#graph([UAB_BA,UAB,UBA],['Unrolled AB or BA','Unrolled AB','Unrolled BA'])

# %%
Unrolled_stateB.df
# Out:
#      subject_id          rt stimulus sampling  nb_of_run stim_type  \
# 4             1   12429.980   UBS_RB    Right        1.0  AND_Gate
# 7             2   17773.830   UBS_LT     Left        1.0  AND_Gate
# 15            3   16613.000   UBS_RB    Right        1.0  AND_Gate
# 23            4   10957.365   UBS_LT     Left        1.0  AND_Gate
# 27            5   19886.620   UBS_RB    Right        1.0  AND_Gate
# 33            6   11788.795   UBS_RT    Right        1.0  AND_Gate
# 39            7   11653.400   UBS_LB     Left        1.0  AND_Gate
# 47            8   14734.590   UBS_LB     Left        1.0  AND_Gate
# 50            9   11413.830   UBS_RB    Right        1.0  AND_Gate
# 58           10   10356.090   UBS_RB    Right        1.0  AND_Gate
# 62           11   13038.965   UBS_RT    Right        1.0  AND_Gate
# 68           12   21244.985   UBS_LT     Left        1.0  AND_Gate
# 77           13   10477.610   UBS_RT    Right        1.0  AND_Gate
# 80           14   18817.610   UBS_LT     Left        1.0  AND_Gate
# 88           15   10935.935   UBS_LT     Left        1.0  AND_Gate
# 91           16   11168.000   UBS_RT    Right        1.0  AND_Gate
# 96           17   14582.345   UBS_LB     Left        1.0  AND_Gate
# 105          18   12278.000   UBS_RT    Right        1.0  AND_Gate
# 110          19   12432.885   UBS_RB    Right        1.0  AND_Gate
# 117          20   13354.655   UBS_RT    Right        1.0  AND_Gate
# 124          21   11590.695   UBS_LT     Left        1.0  AND_Gate
# 126          22   17378.000   UBS_RT    Right        1.0  AND_Gate
# 133          23   11722.275   UBS_RB    Right        1.0  AND_Gate
# 140          24   11750.965   UBS_RB    Right        2.0  AND_Gate
# 148          25   11253.645   UBS_LT     Left        1.0  AND_Gate
# 155          26   16011.000   UBS_RB    Right        1.0  AND_Gate
# 161          27   14157.080   UBS_RB    Right        1.0  AND_Gate
# 167          28   10486.945   UBS_RB    Right        1.0  AND_Gate
# 173          29   10599.165   UBS_RB    Right        1.0  AND_Gate
# 178          30   14205.000   UBS_LB     Left        1.0  AND_Gate
# 180          31   16534.890   UBS_RT    Right        1.0  AND_Gate
# 186          32   16555.635   UBS_LT     Left        1.0  AND_Gate
# 195          33   13430.080   UBS_LB     Left        1.0  AND_Gate
# 202          34   10709.500   UBS_RB    Right        1.0  AND_Gate
# 206          35  106172.425   UBS_LT     Left        1.0  AND_Gate
# 214          36   10812.065   UBS_RB    Right        1.0  AND_Gate
# 218          37   10775.345   UBS_LB     Left        1.0  AND_Gate
# 225          38   12340.870   UBS_LT     Left        1.0  AND_Gate
# 233          39   10895.185   UBS_LT     Left        1.0  AND_Gate
# 239          40   12999.710   UBS_LB     Left        1.0  AND_Gate
# 240          41   11237.245   UBS_RB    Right        2.0  AND_Gate
# 246          42   29853.260   UBS_LT     Left        1.0  AND_Gate
# 257          43   12718.235   UBS_RB    Right        1.0  AND_Gate
# 258          44   18810.125   UBS_RT    Right        1.0  AND_Gate
# 264          45   29756.580   UBS_LB     Left        1.0  AND_Gate
# 270          46   21948.000   UBS_RB    Right        1.0  AND_Gate
# 278          47   13386.670   UBS_RT    Right        1.0  AND_Gate
# 284          48   51449.225   UBS_RT    Right        1.0  AND_Gate
# 293          49   24418.000   UBS_RT    Right        1.0  AND_Gate
# 297          50   12191.000   UBS_LT     Left        1.0  AND_Gate
# 300          51   20482.055   UBS_LT     Left        1.0  AND_Gate
# 309          52   13621.000   UBS_RB    Right        2.0  AND_Gate
# 315          53   10854.780   UBS_RB    Right        1.0  AND_Gate
# 321          54   12248.275   UBS_LB     Left        1.0  AND_Gate
# 325          55   11129.845   UBS_RB    Right        1.0  AND_Gate
# 331          56   16259.000   UBS_LT     Left        1.0  AND_Gate
# 339          57    9820.690   UBS_LB     Left        1.0  AND_Gate
# 346          58   10873.580   UBS_LT     Left        1.0  AND_Gate
# 351          59   10686.000   UBS_LT     Left        1.0  AND_Gate
# 354          60   14479.585   UBS_RT    Right        2.0  AND_Gate
# 363          61   14232.335   UBS_RT    Right        1.0  AND_Gate
# 367          62   12366.265   UBS_LT     Left        1.0  AND_Gate
# 373          63   11591.485   UBS_RT    Right        1.0  AND_Gate
# 383          64   11727.240   UBS_RB    Right        2.0  AND_Gate
# 384          65   22904.795   UBS_RB    Right        1.0  AND_Gate
# 391          66   12877.105   UBS_RB    Right        1.0  AND_Gate
# 400          67   11214.390   UBS_RB    Right        1.0  AND_Gate
# 405          68   10647.005   UBS_LT     Left        1.0  AND_Gate
# 413          69   12530.965   UBS_LT     Left        1.0  AND_Gate
# 416          70   10469.945   UBS_RT    Right        1.0  AND_Gate
# 424          71   10204.415   UBS_LB     Left        1.0  AND_Gate
# 427          72   17385.215   UBS_LB     Left        1.0  AND_Gate
# 432          73   13785.985   UBS_RB    Right        2.0  AND_Gate
# 443          74   13019.200   UBS_LT     Left        1.0  AND_Gate
# 447          75   11169.740   UBS_LB     Left        1.0  AND_Gate
# 455          76   10628.000   UBS_LB     Left        1.0  AND_Gate
# 461          77   11857.000   UBS_RT    Right        1.0  AND_Gate
# 467          78   13407.115   UBS_LT     Left        1.0  AND_Gate
# 468          79   19880.575   UBS_RB    Right        1.0  AND_Gate
# 475          80   10989.110   UBS_LB     Left        1.0  AND_Gate
# 483          81   12361.000   UBS_RT    Right        1.0  AND_Gate
# 489          82   11942.915   UBS_LT     Left        1.0  AND_Gate
# 495          83   65716.000   UBS_RT    Right        1.0  AND_Gate
# 502          84   10133.000   UBS_RB    Right        1.0  AND_Gate
# 509          85   20816.000   UBS_LB     Left        1.0  AND_Gate
# 511          86   12910.630   UBS_LT     Left        1.0  AND_Gate
# 518          87   11378.360   UBS_LT     Left        1.0  AND_Gate
# 526          88   17156.000   UBS_LT     Left        1.0  AND_Gate
# 530          89   11589.980   UBS_RT    Right        1.0  AND_Gate
# 537          90   10650.085   UBS_LB     Left        1.0  AND_Gate
# 541          91   13421.270   UBS_RB    Right        1.0  AND_Gate
# 547          92   25983.085   UBS_RT    Right        1.0  AND_Gate
# 553          93   15546.655   UBS_RB    Right        1.0  AND_Gate
# 559          94   15571.805   UBS_LB     Left        1.0  AND_Gate
# 567          95   12026.000   UBS_LB     Left        1.0  AND_Gate
# 575          96   11381.670   UBS_RB    Right        1.0  AND_Gate
# 579          97   10927.335   UBS_LT     Left        1.0  AND_Gate
# 586          98   11070.765   UBS_RT    Right        1.0  AND_Gate
# 591          99   10523.850   UBS_RB    Right        1.0  AND_Gate
# 598         100   11452.000   UBS_RT    Right        1.0  AND_Gate
#
#     rolled_OR_unrolled A_branch_loc A_detectors state_OR_event state_branch  \
# 4             Unrolled       Bottom     Squares          State            B
# 7             Unrolled          Top     Squares          State            B
# 15            Unrolled       Bottom     Squares          State            B
# 23            Unrolled          Top     Squares          State            B
# 27            Unrolled       Bottom     Squares          State            B
# 33            Unrolled          Top     Squares          State            B
# 39            Unrolled       Bottom     Squares          State            B
# 47            Unrolled       Bottom     Squares          State            B
# 50            Unrolled       Bottom     Squares          State            B
# 58            Unrolled       Bottom     Squares          State            B
# 62            Unrolled          Top     Squares          State            B
# 68            Unrolled          Top     Squares          State            B
# 77            Unrolled          Top     Squares          State            B
# 80            Unrolled          Top     Squares          State            B
# 88            Unrolled          Top     Squares          State            B
# 91            Unrolled          Top     Squares          State            B
# 96            Unrolled       Bottom     Squares          State            B
# 105           Unrolled          Top     Squares          State            B
# 110           Unrolled       Bottom     Squares          State            B
# 117           Unrolled          Top     Squares          State            B
# 124           Unrolled          Top     Squares          State            B
# 126           Unrolled          Top     Squares          State            B
# 133           Unrolled       Bottom     Squares          State            B
# 140           Unrolled       Bottom     Squares          State            B
# 148           Unrolled          Top     Squares          State            B
# 155           Unrolled       Bottom     Squares          State            B
# 161           Unrolled       Bottom     Squares          State            B
# 167           Unrolled       Bottom     Squares          State            B
# 173           Unrolled       Bottom     Squares          State            B
# 178           Unrolled       Bottom     Squares          State            B
# 180           Unrolled          Top     Squares          State            B
# 186           Unrolled          Top     Squares          State            B
# 195           Unrolled       Bottom     Squares          State            B
# 202           Unrolled       Bottom     Squares          State            B
# 206           Unrolled          Top     Squares          State            B
# 214           Unrolled       Bottom     Squares          State            B
# 218           Unrolled       Bottom     Squares          State            B
# 225           Unrolled          Top     Squares          State            B
# 233           Unrolled          Top     Squares          State            B
# 239           Unrolled       Bottom     Squares          State            B
# 240           Unrolled       Bottom     Squares          State            B
# 246           Unrolled          Top     Squares          State            B
# 257           Unrolled       Bottom     Squares          State            B
# 258           Unrolled          Top     Squares          State            B
# 264           Unrolled       Bottom     Squares          State            B
# 270           Unrolled       Bottom     Squares          State            B
# 278           Unrolled          Top     Squares          State            B
# 284           Unrolled          Top     Squares          State            B
# 293           Unrolled          Top     Squares          State            B
# 297           Unrolled          Top     Squares          State            B
# 300           Unrolled          Top     Squares          State            B
# 309           Unrolled       Bottom     Squares          State            B
# 315           Unrolled       Bottom     Squares          State            B
# 321           Unrolled       Bottom     Squares          State            B
# 325           Unrolled       Bottom     Squares          State            B
# 331           Unrolled          Top     Squares          State            B
# 339           Unrolled       Bottom     Squares          State            B
# 346           Unrolled          Top     Squares          State            B
# 351           Unrolled          Top     Squares          State            B
# 354           Unrolled          Top     Squares          State            B
# 363           Unrolled          Top     Squares          State            B
# 367           Unrolled          Top     Squares          State            B
# 373           Unrolled          Top     Squares          State            B
# 383           Unrolled       Bottom     Squares          State            B
# 384           Unrolled       Bottom     Squares          State            B
# 391           Unrolled       Bottom     Squares          State            B
# 400           Unrolled       Bottom     Squares          State            B
# 405           Unrolled          Top     Squares          State            B
# 413           Unrolled          Top     Squares          State            B
# 416           Unrolled          Top     Squares          State            B
# 424           Unrolled       Bottom     Squares          State            B
# 427           Unrolled       Bottom     Squares          State            B
# 432           Unrolled       Bottom     Squares          State            B
# 443           Unrolled          Top     Squares          State            B
# 447           Unrolled       Bottom     Squares          State            B
# 455           Unrolled       Bottom     Squares          State            B
# 461           Unrolled          Top     Squares          State            B
# 467           Unrolled          Top     Squares          State            B
# 468           Unrolled       Bottom     Squares          State            B
# 475           Unrolled       Bottom     Squares          State            B
# 483           Unrolled          Top     Squares          State            B
# 489           Unrolled          Top     Squares          State            B
# 495           Unrolled          Top     Squares          State            B
# 502           Unrolled       Bottom     Squares          State            B
# 509           Unrolled       Bottom     Squares          State            B
# 511           Unrolled          Top     Squares          State            B
# 518           Unrolled          Top     Squares          State            B
# 526           Unrolled          Top     Squares          State            B
# 530           Unrolled          Top     Squares          State            B
# 537           Unrolled       Bottom     Squares          State            B
# 541           Unrolled       Bottom     Squares          State            B
# 547           Unrolled          Top     Squares          State            B
# 553           Unrolled       Bottom     Squares          State            B
# 559           Unrolled       Bottom     Squares          State            B
# 567           Unrolled       Bottom     Squares          State            B
# 575           Unrolled       Bottom     Squares          State            B
# 579           Unrolled          Top     Squares          State            B
# 586           Unrolled          Top     Squares          State            B
# 591           Unrolled       Bottom     Squares          State            B
# 598           Unrolled          Top     Squares          State            B
#
#     root_1st imdt_2nd node_selected node_category response
# 4        NaN        A       nodeB19      IMDT_1st       ID
# 7        NaN        A        nodeB8      ROOT_1st       RD
# 15       NaN        A       nodeA30      ROOT_2nd       RC
# 23       NaN        A       nodeA30      ROOT_2nd       RC
# 27       NaN        A       nodeA30      ROOT_2nd       RC
# 33       NaN        A       nodeB20        EFFECT    other
# 39       NaN        A       nodeA30      ROOT_2nd       RC
# 47       NaN        A        nodeB8      ROOT_1st       RD
# 50       NaN        A       nodeA30      ROOT_2nd       RC
# 58       NaN        A        nodeB8      ROOT_1st       RD
# 62       NaN        A       nodeA30      ROOT_2nd       RC
# 68       NaN        A        nodeB8      ROOT_1st       RD
# 77       NaN        A       nodeA30      ROOT_2nd       RC
# 80       NaN        A       nodeA30      ROOT_2nd       RC
# 88       NaN        A       nodeA30      ROOT_2nd       RC
# 91       NaN        A       nodeA30      ROOT_2nd       RC
# 96       NaN        A        nodeB8      ROOT_1st       RD
# 105      NaN        A       nodeB20        EFFECT    other
# 110      NaN        A       nodeA41      IMDT_2nd       IC
# 117      NaN        A        nodeB8      ROOT_1st       RD
# 124      NaN        A       nodeA41      IMDT_2nd       IC
# 126      NaN        A       nodeA30      ROOT_2nd       RC
# 133      NaN        A       nodeA41      IMDT_2nd       IC
# 140      NaN        A       nodeA41      IMDT_2nd       IC
# 148      NaN        A       nodeA30      ROOT_2nd       RC
# 155      NaN        A       nodeA30      ROOT_2nd       RC
# 161      NaN        A       nodeA30      ROOT_2nd       RC
# 167      NaN        A        nodeB8      ROOT_1st       RD
# 173      NaN        A        nodeB8      ROOT_1st       RD
# 178      NaN        A       nodeA25     INACT_2nd    other
# 180      NaN        A       nodeA41      IMDT_2nd       IC
# 186      NaN        A        nodeB8      ROOT_1st       RD
# 195      NaN        A       nodeA30      ROOT_2nd       RC
# 202      NaN        A        nodeB8      ROOT_1st       RD
# 206      NaN        A       nodeA30      ROOT_2nd       RC
# 214      NaN        A       nodeA30      ROOT_2nd       RC
# 218      NaN        A       nodeA30      ROOT_2nd       RC
# 225      NaN        A       nodeA30      ROOT_2nd       RC
# 233      NaN        A       nodeA41      IMDT_2nd       IC
# 239      NaN        A       nodeA30      ROOT_2nd       RC
# 240      NaN        A        nodeB8      ROOT_1st       RD
# 246      NaN        A       nodeA30      ROOT_2nd       RC
# 257      NaN        A       nodeA41      IMDT_2nd       IC
# 258      NaN        A        nodeB8      ROOT_1st       RD
# 264      NaN        A       nodeA41      IMDT_2nd       IC
# 270      NaN        A       nodeA41      IMDT_2nd       IC
# 278      NaN        A        nodeB7      ROOT_1st       RD
# 284      NaN        A       nodeA41      IMDT_2nd       IC
# 293      NaN        A       nodeA41      IMDT_2nd       IC
# 297      NaN        A       nodeA41      IMDT_2nd       IC
# 300      NaN        A       nodeA41      IMDT_2nd       IC
# 309      NaN        A       nodeA30      ROOT_2nd       RC
# 315      NaN        A       nodeA41      IMDT_2nd       IC
# 321      NaN        A       nodeA30      ROOT_2nd       RC
# 325      NaN        A       nodeA30      ROOT_2nd       RC
# 331      NaN        A       nodeA30      ROOT_2nd       RC
# 339      NaN        A       nodeA30      ROOT_2nd       RC
# 346      NaN        A       nodeA30      ROOT_2nd       RC
# 351      NaN        A       nodeA30      ROOT_2nd       RC
# 354      NaN        A       nodeA41      IMDT_2nd       IC
# 363      NaN        A       nodeB16     INBTW_1st    other
# 367      NaN        A       nodeA41      IMDT_2nd       IC
# 373      NaN        A       nodeA41      IMDT_2nd       IC
# 383      NaN        A       nodeA41      IMDT_2nd       IC
# 384      NaN        A        nodeB8      ROOT_1st       RD
# 391      NaN        A       nodeA41      IMDT_2nd       IC
# 400      NaN        A       nodeB19      IMDT_1st       ID
# 405      NaN        A       nodeA30      ROOT_2nd       RC
# 413      NaN        A       nodeA30      ROOT_2nd       RC
# 416      NaN        A       nodeA41      IMDT_2nd       IC
# 424      NaN        A       nodeA30      ROOT_2nd       RC
# 427      NaN        A        nodeB8      ROOT_1st       RD
# 432      NaN        A       nodeB19      IMDT_1st       ID
# 443      NaN        A       nodeB20        EFFECT    other
# 447      NaN        A       nodeB16     INBTW_1st    other
# 455      NaN        A       nodeA30      ROOT_2nd       RC
# 461      NaN        A        nodeB8      ROOT_1st       RD
# 467      NaN        A        nodeB8      ROOT_1st       RD
# 468      NaN        A        nodeB8      ROOT_1st       RD
# 475      NaN        A       nodeA29      ROOT_2nd       RC
# 483      NaN        A       nodeA41      IMDT_2nd       IC
# 489      NaN        A       nodeA30      ROOT_2nd       RC
# 495      NaN        A       nodeA30      ROOT_2nd       RC
# 502      NaN        A       nodeA30      ROOT_2nd       RC
# 509      NaN        A       nodeA30      ROOT_2nd       RC
# 511      NaN        A       nodeA30      ROOT_2nd       RC
# 518      NaN        A        nodeB8      ROOT_1st       RD
# 526      NaN        A       nodeA29      ROOT_2nd       RC
# 530      NaN        A       nodeA41      IMDT_2nd       IC
# 537      NaN        A       nodeA30      ROOT_2nd       RC
# 541      NaN        A        nodeB8      ROOT_1st       RD
# 547      NaN        A       nodeA30      ROOT_2nd       RC
# 553      NaN        A       nodeA30      ROOT_2nd       RC
# 559      NaN        A       nodeA30      ROOT_2nd       RC
# 567      NaN        A       nodeA29      ROOT_2nd       RC
# 575      NaN        A       nodeA41      IMDT_2nd       IC
# 579      NaN        A        nodeB8      ROOT_1st       RD
# 586      NaN        A       nodeA41      IMDT_2nd       IC
# 591      NaN        A       nodeA30      ROOT_2nd       RC
# 598      NaN        A       nodeA30      ROOT_2nd       RC

# %%
graph3([UAA_BB,UAB_BA,U])
#plt.savefig('results_E2.eps',format="eps",bbox_inches='tight')

# %%
data2[data2['stimulustype']=='dualbranch'].response.value_counts()
# Out:
# RC       261
# IC       154
# RD       130
# other     49
# ID         6
# Name: response, dtype: int64

# %%
data_AND_Gate.response.value_counts()
# Out:
# RC       261
# IC       154
# RD       130
# other     49
# ID         6
# Name: response, dtype: int64

# %% [markdown]
# ## Comparison Right *vs* Left

# %%
# Same as the general comparison BUT only for the condition 'right'

chain = Chain(stim='ChainS').add_filter(sampling='right')
Unrolled_state = AndGate(rolled=False,continuity='root_2nd').add_filter(sampling='right',state=True)
Unrolled_stateA = AndGate(rolled=False,continuity='root_2nd').add_filter(sampling='right',state=True,state_branch='A')
Unrolled_stateB = AndGate(rolled=False,continuity='root_2nd').add_filter(sampling='right',state=True,state_branch='B')
Unrolled_AA_BB = AndGate(rolled=False,continuity='root_1st').add_filter(sampling='right')
Unrolled_AA = AndGate(rolled=False,continuity='root_1st').add_filter(sampling='right',root_1st='A')
Unrolled_BB = AndGate(rolled=False,continuity='root_1st').add_filter(sampling='right',root_1st='B')
Unrolled_AB_BA = AndGate(rolled=False,continuity='root_2nd').add_filter(sampling='right',state=False)
Unrolled_AB = AndGate(rolled=False,continuity='root_2nd').add_filter(sampling='right',state=False,root_1st='A')
Unrolled_BA = AndGate(rolled=False,continuity='root_2nd').add_filter(sampling='right',state=False,root_1st='B')

chain = bootstrap(chain)
U = bootstrap(Unrolled_state)
UA = bootstrap(Unrolled_stateA)
UB = bootstrap(Unrolled_stateB)
UAA_BB = bootstrap(Unrolled_AA_BB)
UAA = bootstrap(Unrolled_AA)
UBB = bootstrap(Unrolled_BB)
UAB_BA = bootstrap(Unrolled_AB_BA)
UAB = bootstrap(Unrolled_AB)
UBA = bootstrap(Unrolled_BA)

graph([chain],['Chain'])
graph([U,UA,UB],['Unrolled A or B in state condition','Unrolled A in state condition','Unrolled B in state condition'])
graph([UAA_BB,UAA,UBB],['Unrolled AA or BB','Unrolled AA','Unrolled BB'])
graph([UAB_BA,UAB,UBA],['Unrolled AB or BA','Unrolled AB','Unrolled BA'])

# %%
# Same as the general comparison BUT only for the condition 'left'

chain = Chain(stim='ChainS').add_filter(sampling='left')
Unrolled_state = AndGate(rolled=False,continuity='root_2nd').add_filter(sampling='left',A_detectors='squares',state=True)
Unrolled_stateA = AndGate(rolled=False,continuity='root_2nd').add_filter(sampling='left',A_detectors='squares',state=True,state_branch='A')
Unrolled_stateB = AndGate(rolled=False,continuity='root_2nd').add_filter(sampling='left',A_detectors='squares',state=True,state_branch='B')
Unrolled_AA_BB = AndGate(rolled=False,continuity='root_1st').add_filter(A_detectors='squares',sampling='left')
Unrolled_AA = AndGate(rolled=False,continuity='root_1st').add_filter(sampling='left',A_detectors='squares',root_1st='A')
Unrolled_BB = AndGate(rolled=False,continuity='root_1st').add_filter(sampling='left',A_detectors='squares',root_1st='B')
Unrolled_AB_BA = AndGate(rolled=False,continuity='root_2nd').add_filter(sampling='left',A_detectors='squares',state=False)
Unrolled_AB = AndGate(rolled=False,continuity='root_2nd').add_filter(sampling='left',A_detectors='squares',state=False,root_1st='A')
Unrolled_BA = AndGate(rolled=False,continuity='root_2nd').add_filter(sampling='left',A_detectors='squares',state=False,root_1st='B')

chain = bootstrap(chain)
U = bootstrap(Unrolled_state)
UA = bootstrap(Unrolled_stateA)
UB = bootstrap(Unrolled_stateB)
UAA_BB = bootstrap(Unrolled_AA_BB)
UAA = bootstrap(Unrolled_AA)
UBB = bootstrap(Unrolled_BB)
UAB_BA = bootstrap(Unrolled_AB_BA)
UAB = bootstrap(Unrolled_AB)
UBA = bootstrap(Unrolled_BA)

graph([chain],['Chain'])
graph([U,UA,UB],['Unrolled A or B in state condition','Unrolled A in state condition','Unrolled B in state condition'])
graph([UAA_BB,UAA,UBB],['Unrolled AA or BB','Unrolled AA','Unrolled BB'])
graph([UAB_BA,UAB,UBA],['Unrolled AB or BA','Unrolled AB','Unrolled BA'])

# %%
# Broad comparison between right vs left sampling

chain_Right = Chain(stim='ChainS').add_filter(sampling='right')
chain_Left = Chain(stim='ChainS').add_filter(sampling='left')
Unrolled_state_Right = AndGate(rolled=False,continuity='root_2nd').add_filter(sampling='right',state=True)
Unrolled_state_Left = AndGate(rolled=False,continuity='root_2nd').add_filter(sampling='left',state=True)
Unrolled_AA_BB_Right = AndGate(rolled=False,continuity='root_1st').add_filter(sampling='right')
Unrolled_AA_BB_Left = AndGate(rolled=False,continuity='root_1st').add_filter(sampling='left')
Unrolled_AB_BA_Right = AndGate(rolled=False,continuity='root_2nd').add_filter(sampling='right',state=False)
Unrolled_AB_BA_Left = AndGate(rolled=False,continuity='root_2nd').add_filter(sampling='left',state=False)

chain_R = bootstrap(chain_Right)
chain_L = bootstrap(chain_Left)
U_R = bootstrap(Unrolled_state_Right)
U_L = bootstrap(Unrolled_state_Left)
UAA_BB_R = bootstrap(Unrolled_AA_BB_Right)
UAA_BB_L = bootstrap(Unrolled_AA_BB_Left)
UAB_BA_R = bootstrap(Unrolled_AB_BA_Right)
UAB_BA_L = bootstrap(Unrolled_AB_BA_Left)

graph([chain_R,chain_L],['Chain left','Chain right'])
graph([U_R,U_L],['Unrolled A or B in state condition left','Unrolled A or B in state condition right'])
graph([UAA_BB_R,UAA_BB_L],['Unrolled AA or BB left','Unrolled AA or BB right'])
graph([UAB_BA_R,UAB_BA_L],['Unrolled AB or BA left','Unrolled AB or BA right'])

# %% [markdown]
# ## Comparison Top *vs* Bottom

# %%
# Broad comparison between TOP vs BOTTOM location of branch A

Unrolled_state_Top = AndGate(rolled=False,continuity='root_2nd').add_filter(level='top',state=True)
Unrolled_state_Bottom = AndGate(rolled=False,continuity='root_2nd').add_filter(level='bottom',state=True)
Unrolled_AA_BB_Top = AndGate(rolled=False,continuity='root_1st').add_filter(level='top')
Unrolled_AA_BB_Bottom = AndGate(rolled=False,continuity='root_1st').add_filter(level='bottom')
Unrolled_AB_BA_Top = AndGate(rolled=False,continuity='root_2nd').add_filter(level='top',state=False)
Unrolled_AB_BA_Bottom = AndGate(rolled=False,continuity='root_2nd').add_filter(level='bottom',state=False)

US_T = bootstrap(Unrolled_state_Top)
US_B = bootstrap(Unrolled_state_Bottom)
UAA_BB_T = bootstrap(Unrolled_AA_BB_Top)
UAA_BB_B = bootstrap(Unrolled_AA_BB_Bottom)
UAB_BA_T = bootstrap(Unrolled_AB_BA_Top)
UAB_BA_B = bootstrap(Unrolled_AB_BA_Bottom)

graph([US_T,US_B],['Unrolled A or B in state condition top','Unrolled A or B in state condition bottom'])
graph([UAA_BB_T,UAA_BB_B],['Unrolled AA or BB top','Unrolled AA or BB bottom'])
graph([UAB_BA_T,UAB_BA_B],['Unrolled AB or BA top','Unrolled AB or BA bottom'])
