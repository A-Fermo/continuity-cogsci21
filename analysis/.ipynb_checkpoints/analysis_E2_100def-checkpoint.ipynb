# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from jupyterthemes import jtplot
jtplot.style(theme="chesterish")
pd.options.display.max_rows = 100

# %% [markdown]
# ## Data structuring

# %% [markdown]
# #### Importing data.csv

# %%
root_dir = os.path.dirname(os.getcwd())
data_clean = pd.read_csv("{}/data/data_E2_100def.csv".format(root_dir))
data_clean
# Out:
#       subject_id     stimulus     trial_type  time_elapsed gender  age  \
# 0              1  instruction  causal-graph1         94322   male   63
# 1              1  instruction  causal-graph1        103375   male   63
# 2              1  instruction  causal-graph1        126004   male   63
# 3              1  instruction  causal-graph1        148777   male   63
# 4              1  instruction  causal-graph1        163555   male   63
# ...          ...          ...            ...           ...    ...  ...
# 2957          98     chainS_R  causal-graph1        198773   male   26
# 2958          98       UAS_RT  causal-graph1        210315   male   26
# 2959          98      UAAS_RB  causal-graph1        224177   male   26
# 2960          98  instruction  causal-graph1        226031   male   26
# 2961          98      comment    survey-text        230491   male   26
#
#                language                   country sampling           turkcode  \
# 0               English  United States of America    Right  R568219297770gxrw
# 1               English  United States of America    Right  R568219297770gxrw
# 2               English  United States of America    Right  R568219297770gxrw
# 3               English  United States of America    Right  R568219297770gxrw
# 4               English  United States of America    Right  R568219297770gxrw
# ...                 ...                       ...      ...                ...
# 2957  English, Japanese  United States of America    Right  R565976917610gxrw
# 2958  English, Japanese  United States of America    Right  R565976917610gxrw
# 2959  English, Japanese  United States of America    Right  R565976917610gxrw
# 2960  English, Japanese  United States of America    Right  R565976917610gxrw
# 2961  English, Japanese  United States of America    Right  R565976917610gxrw
#
#       ...  responses  stim_type rolled_OR_unrolled A_branch_loc A_detectors  \
# 0     ...        NaN        NaN                NaN          NaN         NaN
# 1     ...        NaN        NaN                NaN          NaN         NaN
# 2     ...        NaN        NaN                NaN          NaN         NaN
# 3     ...        NaN        NaN                NaN          NaN         NaN
# 4     ...        NaN        NaN                NaN          NaN         NaN
# ...   ...        ...        ...                ...          ...         ...
# 2957  ...        NaN     ChainS                NaN          NaN         NaN
# 2958  ...        NaN   AND_Gate           Unrolled          Top     Squares
# 2959  ...        NaN   AND_Gate           Unrolled       Bottom     Squares
# 2960  ...        NaN        NaN                NaN          NaN         NaN
# 2961  ...  {"Q0":""}        NaN                NaN          NaN         NaN
#
#      state_OR_event state_branch root_1st imdt_2nd node_selected
# 0               NaN          NaN      NaN      NaN           NaN
# 1               NaN          NaN      NaN      NaN           NaN
# 2               NaN          NaN      NaN      NaN           NaN
# 3               NaN          NaN      NaN      NaN           NaN
# 4               NaN          NaN      NaN      NaN           NaN
# ...             ...          ...      ...      ...           ...
# 2957            NaN          NaN      NaN      NaN        nodeB9
# 2958          State            A      NaN        B        nodeA7
# 2959          Event          NaN        A        A        nodeA7
# 2960            NaN          NaN      NaN      NaN           NaN
# 2961            NaN          NaN      NaN      NaN           NaN
#
# [2962 rows x 22 columns]

# %%
time = []
for item in data_clean[data_clean['stimulus']=='comment']['time_elapsed']:
    time.append(item)
time = np.array(time)
time.mean()/1000/60
# Out:
# 8.063145578231293

# %%
for idx,item in enumerate(data_clean['stimulus']):
    if item == 'comment':
        print(data_clean['responses'][idx])
# Out:
# {"Q0":""}
# {"Q0":""}
# {"Q0":"I thought this experiment was very interesting.  Also, the instructions were clear and I had no technical problems."}
# {"Q0":"I couldn't decide if it was the last one or the one that triggered the chain linking to the last one ... hmmm"}
# {"Q0":""}
# {"Q0":""}
# {"Q0":""}
# {"Q0":"nothing good task"}
# {"Q0":""}
# {"Q0":""}
# {"Q0":"VErY inTErEsTIng.goOD"}
# {"Q0":""}
# {"Q0":"Thank you!"}
# {"Q0":""}
# {"Q0":""}
# {"Q0":""}
# {"Q0":""}
# {"Q0":"VERY NICE                                  "}
# {"Q0":""}
# {"Q0":""}
# {"Q0":""}
# {"Q0":""}
# {"Q0":"everything worked well, no issues"}
# {"Q0":""}
# {"Q0":""}
# {"Q0":""}
# {"Q0":"no comments"}
# {"Q0":"Thank you. I hope my input is valuable. Have a nice day"}
# {"Q0":"nothing good survey"}
# {"Q0":"good"}
# {"Q0":"Interesting study. Thanks!"}
# {"Q0":"likely"}
# {"Q0":""}
# {"Q0":""}
# {"Q0":""}
# {"Q0":""}
# {"Q0":"It was interesting"}
# {"Q0":"none"}
# {"Q0":""}
# {"Q0":""}
# {"Q0":""}
# {"Q0":"I got confused that only one detector that caused."}
# {"Q0":""}
# {"Q0":""}
# {"Q0":""}
# {"Q0":"Yes should had gave practice examples"}
# {"Q0":""}
# {"Q0":""}
# {"Q0":""}
# {"Q0":"It was awesome."}
# {"Q0":""}
# {"Q0":""}
# {"Q0":""}
# {"Q0":"No comments"}
# {"Q0":""}
# {"Q0":""}
# {"Q0":""}
# {"Q0":""}
# {"Q0":""}
# {"Q0":"interesting"}
# {"Q0":""}
# {"Q0":""}
# {"Q0":""}
# {"Q0":"Everything was easy to understand and I thought the study paid well :)"}
# {"Q0":"none"}
# {"Q0":""}
# {"Q0":""}
# {"Q0":""}
# {"Q0":"It was kind of confusing as to if I was supposed to be scientific about it or purely visual."}
# {"Q0":""}
# {"Q0":"There should be an example of which detector to click as I was not sure because of the wording."}
# {"Q0":""}
# {"Q0":"GOOD"}
# {"Q0":""}
# {"Q0":""}
# {"Q0":"There were 2 activation inputs, which one to choose?"}
# {"Q0":"It was simple and better paying than the work Yale gives me."}
# {"Q0":" "}
# {"Q0":"easy"}
# {"Q0":""}
# {"Q0":""}
# {"Q0":""}
# {"Q0":""}
# {"Q0":""}
# {"Q0":""}
# {"Q0":""}
# {"Q0":""}
# {"Q0":"No additional comments. Thank you."}
# {"Q0":"I'm not sure if I did the task correctly. I clicked on the detector that absorbed a radioactive particle, and that was on the sequence of detectors that reached G last."}
# {"Q0":"very inresting task"}
# {"Q0":""}
# {"Q0":""}
# {"Q0":"No feedback."}
# {"Q0":""}
# {"Q0":""}
# {"Q0":"None"}
# {"Q0":""}
# {"Q0":""}

# %% [markdown]
# #### Demographical data only

# %%
data_demog = data_clean[["subject_id","gender","age","language","country","turkcode"]]
data_demog = data_demog.drop_duplicates()
data_demog
# Out:
#       subject_id  gender  age            language                   country  \
# 0              1    male   63             English  United States of America
# 25             2  female   35             Turkish  United States of America
# 42             3  female   31             English  United States of America
# 67             4  female   59             english  United States of America
# 84             5    male   27             English  United States of America
# 101            6    male   30             English  United States of America
# 126            7  female   48             english  United States of America
# 159            8    male   47             english  United States of America
# 176            9    male   34             English  United States of America
# 193           10    male   46             english  United States of America
# 210           11    male   49             ENGLISH  United States of America
# 227           12  female   52             English  United States of America
# 260           13  female   32             English  United States of America
# 285           14    male   32             English  United States of America
# 318           15    male   31             english  United States of America
# 343           16    male   29             English  United States of America
# 368           17    male   34             English  United States of America
# 409           18    male   51             ENGLISH  United States of America
# 482           19  female   39             English  United States of America
# 507           20    male   33             English  United States of America
# 532           21  female   62             english  United States of America
# 549           22  female   42    American English  United States of America
# 566           23  female   26             english  United States of America
# 591           24  female   37             English  United States of America
# 624           25    male   65             English  United States of America
# 641           26  female   32             english  United States of America
# 666           27  female   48             english  United States of America
# 707           28    male   29             english  United States of America
# 764           29    male   58             english  United States of America
# 805           30    male   38             english                   Armenia
# 846           31  female   41             English  United States of America
# 871           32    male   61             english  United States of America
# 1040          33    male   37             English  United States of America
# 1057          34    male   32             English  United States of America
# 1074          35    male   31             english  United States of America
# 1091          36    male   71             English  United States of America
# 1108          37    male   26             English  United States of America
# 1181          38  female   33             English  United States of America
# 1198          39    male   24             English  United States of America
# 1239          40    male   37             English  United States of America
# 1272          41    male   33             English  United States of America
# 1297          42    male   44             Chinese  United States of America
# 1338          43    male   24             English  United States of America
# 1355          44  female   32             English  United States of America
# 1396          45  female   34             english  United States of America
# 1413          46    male   41             English  United States of America
# 1430          47    male   26             English  United States of America
# 1455          48    male   38             english  United States of America
# 1480          49    male   32             English  United States of America
# 1513          50    male   29             English  United States of America
# 1578          51  female   33             English  United States of America
# 1595          52  female   29             English  United States of America
# 1644          53   other   34             English  United States of America
# 1677          54    male   52             English  United States of America
# 1702          55    male   25             english  United States of America
# 1719          56  female   58             English  United States of America
# 1736          57    male   41             English  United States of America
# 1753          58  female   50             English  United States of America
# 1770          59  female   45             english  United States of America
# 1827          60  female   35             English  United States of America
# 1852          61  female   31  English, Cantonese  United States of America
# 1869          62  female   34             English  United States of America
# 1894          63    male   31             English  United States of America
# 1919          64  female   23             English  United States of America
# 1936          65  female   32             English  United States of America
# 1953          66  female   44             English  United States of America
# 1970          67    male   27             English  United States of America
# 1995          68    male   33             English  United States of America
# 2028          69    male   34             English  United States of America
# 2069          70  female   61             english  United States of America
# 2102          71    male   35  English, Cantonese  United States of America
# 2119          72  female   26             English  United States of America
# 2136          73    male   41             ENGLISH                   Armenia
# 2177          74  female   36             English  United States of America
# 2242          75    male   26             English  United States of America
# 2259          76    male   44             English  United States of America
# 2292          77    male   26             English  United States of America
# 2317          78    male   50             English  United States of America
# 2350          79  female   46             english  United States of America
# 2415          80    male   44             English  United States of America
# 2440          81  female   30             English  United States of America
# 2465          82    male   23             English  United States of America
# 2490          83    male   28             English  United States of America
# 2515          84    male   36             english  United States of America
# 2556          85  female   47             English  United States of America
# 2581          86    male   36             english  United States of America
# 2606          87    male   41             English  United States of America
# 2655          88  female   55             English  United States of America
# 2672          89    male   19             English  United States of America
# 2697          90  female   58             English  United States of America
# 2754          91    male   30             English  United States of America
# 2771          92    male   48             English  United States of America
# 2788          93  female   59             English  United States of America
# 2805          94  female   22             English  United States of America
# 2830          95    male   68             English  United States of America
# 2903          96  female   36             english  United States of America
# 2920          97  female   44             English  United States of America
# 2945          98    male   26   English, Japanese  United States of America
#
#                turkcode
# 0     R568219297770gxrw
# 25    R568393397970gxrw
# 42    R569505437620gxrw
# 67    R565237547710gxrw
# 84    R567385837480gxrw
# 101   R567276527410gxrw
# 126   R561811867620gxrw
# 159   R568774137640gxrw
# 176   R564870127320gxrw
# 193   R562699637900gxrw
# 210   R562050947820gxrw
# 227   R562955957430gxrw
# 260   R568249427370gxrw
# 285   R561811987830gxrw
# 318   R562203687270gxrw
# 343   R569996927840gxrw
# 368   R569529657850gxrw
# 409   R565668727290gxrw
# 482   R563804007140gxrw
# 507   R562739977950gxrw
# 532   R562595927890gxrw
# 549   R566602567600gxrw
# 566   R561847387520gxrw
# 591   R562384867510gxrw
# 624   R562382347220gxrw
# 641   R564913177240gxrw
# 666   R565972457960gxrw
# 707   R564083597300gxrw
# 764   R565086757790gxrw
# 805   R561903857890gxrw
# 846   R566358577480gxrw
# 871   R564292257260gxrw
# 1040  R568971107580gxrw
# 1057  R563277577520gxrw
# 1074  R562526387850gxrw
# 1091  R561310407730gxrw
# 1108  R568342347260gxrw
# 1181  R564586117770gxrw
# 1198  R561173557450gxrw
# 1239  R569352377710gxrw
# 1272  R566212997560gxrw
# 1297  R562323837680gxrw
# 1338  R561039097580gxrw
# 1355  R567727787310gxrw
# 1396  R565118307580gxrw
# 1413  R566670057440gxrw
# 1430  R567221167850gxrw
# 1455  R563744997110gxrw
# 1480  R568133087190gxrw
# 1513  R567110527600gxrw
# 1578  R568370757880gxrw
# 1595  R566457817370gxrw
# 1644  R569143367750gxrw
# 1677  R562971867360gxrw
# 1702  R563729527350gxrw
# 1719  R562713167520gxrw
# 1736  R562681507880gxrw
# 1753  R561216847680gxrw
# 1770  R568555707250gxrw
# 1827  R567929507110gxrw
# 1852  R565403957930gxrw
# 1869  R563400167320gxrw
# 1894  R565974167740gxrw
# 1919  R564062127140gxrw
# 1936  R561934427620gxrw
# 1953  R569959787250gxrw
# 1970  R565766657950gxrw
# 1995  R569805137800gxrw
# 2028  R566444937730gxrw
# 2069  R563318637580gxrw
# 2102  R565762037570gxrw
# 2119  R568770907600gxrw
# 2136  R568815577170gxrw
# 2177  R565796087480gxrw
# 2242  R568806197140gxrw
# 2259  R562203047100gxrw
# 2292  R563901867210gxrw
# 2317  R569663207860gxrw
# 2350  R561246577810gxrw
# 2415  R562021027660gxrw
# 2440  R563766157260gxrw
# 2465  R568141637110gxrw
# 2490  R568472957850gxrw
# 2515  R564403937450gxrw
# 2556  R565057607370gxrw
# 2581  R564001067180gxrw
# 2606  R561673367770gxrw
# 2655  R563522677460gxrw
# 2672  R567396637450gxrw
# 2697  R567716797490gxrw
# 2754  R564942857230gxrw
# 2771  R567983477780gxrw
# 2788  R564523987670gxrw
# 2805  R566797327800gxrw
# 2830  R568611477130gxrw
# 2903  R564652417300gxrw
# 2920  R562497257520gxrw
# 2945  R565976917610gxrw

# %%
data_demog['language'].value_counts()
# Out:
# English               66
# english               23
# ENGLISH                3
# English, Cantonese     2
# Turkish                1
# Chinese                1
# American English       1
# English, Japanese      1
# Name: language, dtype: int64

# %% [markdown]
# #### Target stimuli only (instructions deleted)

# %%
data = data_clean[["subject_id","rt","stimulus","trial_type","sampling","nb_of_run","stim_type","rolled_OR_unrolled",
                   "A_branch_loc","A_detectors","state_OR_event","state_branch","root_1st","imdt_2nd","node_selected"]]
data = data[data["stimulus"] != "instruction"].drop(['trial_type'],axis=1)
data.reset_index(drop=True,inplace=True)

data
# Out:
#      subject_id         rt  stimulus sampling  nb_of_run stim_type  \
# 0             1  40031.000   UABS_RT    Right        1.0  AND_Gate
# 1             1  11284.000  chainS_R    Right        1.0    ChainS
# 2             1  17030.000    UAS_RT    Right        1.0  AND_Gate
# 3             1  12418.000   UBBS_RB    Right        1.0  AND_Gate
# 4             1  14022.000   UBAS_RT    Right        1.0  AND_Gate
# ..          ...        ...       ...      ...        ...       ...
# 779          98  14759.020   UABS_RB    Right        1.0  AND_Gate
# 780          98   8632.665  chainS_R    Right        1.0    ChainS
# 781          98   9954.570    UAS_RT    Right        1.0  AND_Gate
# 782          98  11990.420   UAAS_RB    Right        1.0  AND_Gate
# 783          98   4451.510   comment    Right        NaN       NaN
#
#     rolled_OR_unrolled A_branch_loc A_detectors state_OR_event state_branch  \
# 0             Unrolled          Top     Squares          Event          NaN
# 1                  NaN          NaN         NaN            NaN          NaN
# 2             Unrolled          Top     Squares          State            A
# 3             Unrolled       Bottom     Squares          Event          NaN
# 4             Unrolled          Top     Squares          Event          NaN
# ..                 ...          ...         ...            ...          ...
# 779           Unrolled       Bottom     Squares          Event          NaN
# 780                NaN          NaN         NaN            NaN          NaN
# 781           Unrolled          Top     Squares          State            A
# 782           Unrolled       Bottom     Squares          Event          NaN
# 783                NaN          NaN         NaN            NaN          NaN
#
#     root_1st imdt_2nd node_selected
# 0          A        B       nodeB19
# 1        NaN      NaN       nodeB19
# 2        NaN        B       nodeB19
# 3          B        B       nodeB19
# 4          B        A       nodeA41
# ..       ...      ...           ...
# 779        A        B        nodeA7
# 780      NaN      NaN        nodeB9
# 781      NaN        B        nodeA7
# 782        A        A        nodeA7
# 783      NaN      NaN           NaN
#
# [784 rows x 14 columns]

# %% [markdown]
# #### Chain only

# %%
data_chain = data[(data["stim_type"]=="ChainS")|(data["stim_type"]=="ChainC")].drop(["rolled_OR_unrolled","A_detectors",
                                                    "state_OR_event","state_branch","root_1st","imdt_2nd",],axis=1)
data_chain.reset_index(drop=True,inplace=True)
data_chain["stimulus"] = data_chain["stimulus"].astype("category")
data_chain["sampling"] = data_chain["sampling"].astype("category")
data_chain["stim_type"] = data_chain["stim_type"].astype("category")
data_chain.head()
# Out:
#    subject_id        rt  stimulus sampling  nb_of_run stim_type A_branch_loc  \
# 0           1  11284.00  chainS_R    Right        1.0    ChainS          NaN
# 1           2  40194.00  chainS_L     Left        1.0    ChainS          NaN
# 2           3  16502.94  chainS_L     Left        1.0    ChainS          NaN
# 3           4  11292.20  chainS_R    Right        1.0    ChainS          NaN
# 4           5  23968.06  chainS_L     Left        1.0    ChainS          NaN
#
#   node_selected
# 0       nodeB19
# 1        nodeB9
# 2        nodeB9
# 3       nodeB19
# 4       nodeB19

# %% [markdown]
# #### AND-Gate only

# %%
data_AND_Gate = data[data["stim_type"]=="AND_Gate"].drop(["stim_type"],axis=1)
data_AND_Gate.reset_index(drop=True,inplace=True)
data_AND_Gate["stimulus"] = data_AND_Gate["stimulus"].astype("category")
data_AND_Gate["state_OR_event"] = data_AND_Gate["state_OR_event"].astype("category")
data_AND_Gate["rolled_OR_unrolled"] = data_AND_Gate["rolled_OR_unrolled"].astype("category")
data_AND_Gate["A_branch_loc"] = data_AND_Gate["A_branch_loc"].astype("category")
data_AND_Gate["A_detectors"] = data_AND_Gate["A_detectors"].astype("category")
data_AND_Gate["root_1st"] = data_AND_Gate["root_1st"].astype("category")
data_AND_Gate["imdt_2nd"] = data_AND_Gate["imdt_2nd"].astype("category")
data_AND_Gate
# Out:
#      subject_id        rt stimulus sampling  nb_of_run rolled_OR_unrolled  \
# 0             1  40031.00  UABS_RT    Right        1.0           Unrolled
# 1             1  17030.00   UAS_RT    Right        1.0           Unrolled
# 2             1  12418.00  UBBS_RB    Right        1.0           Unrolled
# 3             1  14022.00  UBAS_RT    Right        1.0           Unrolled
# 4             1  16359.00   UBS_RT    Right        1.0           Unrolled
# ..          ...       ...      ...      ...        ...                ...
# 583          98  12409.11   UBS_RT    Right        1.0           Unrolled
# 584          98  10540.76  UBAS_RB    Right        1.0           Unrolled
# 585          98  14759.02  UABS_RB    Right        1.0           Unrolled
# 586          98   9954.57   UAS_RT    Right        1.0           Unrolled
# 587          98  11990.42  UAAS_RB    Right        1.0           Unrolled
#
#     A_branch_loc A_detectors state_OR_event state_branch root_1st imdt_2nd  \
# 0            Top     Squares          Event          NaN        A        B
# 1            Top     Squares          State            A      NaN        B
# 2         Bottom     Squares          Event          NaN        B        B
# 3            Top     Squares          Event          NaN        B        A
# 4            Top     Squares          State            B      NaN        A
# ..           ...         ...            ...          ...      ...      ...
# 583          Top     Squares          State            B      NaN        A
# 584       Bottom     Squares          Event          NaN        B        A
# 585       Bottom     Squares          Event          NaN        A        B
# 586          Top     Squares          State            A      NaN        B
# 587       Bottom     Squares          Event          NaN        A        A
#
#     node_selected
# 0         nodeB19
# 1         nodeB19
# 2         nodeB19
# 3         nodeA41
# 4         nodeA41
# ..            ...
# 583        nodeB4
# 584        nodeB4
# 585        nodeA7
# 586        nodeA7
# 587        nodeA7
#
# [588 rows x 13 columns]

# %% [markdown]
# ## Functions

# %%
def nb(letter,lower_bound,upper_bound):
    return [letter+str(i) for i in range(lower_bound,upper_bound+1)]

def chain_node_cat(stim,node):
    stim = stim.split('_')[0]
    node = node[4:]
    if stim == 'chainS':
        categories = {'INACT':nb('B',1,7),'ROOT':['B8','B9','B10'],'INBTW':nb('B',11,18),'IMDT':['B19'],'EFFECT':['B20']}
    elif stim == 'chainC':
        categories = {'INACT':nb('A',1,24),'ROOT':['A25','A26','A27'],'INBTW':nb('A',28,40),'IMDT':['A41'],'EFFECT':['B20']}
        
    category = [cat for cat,nd in categories.items() if node in nd][0]
    
    return category

def branch_node_cat(stim,node):
    node = node[4:]
    stim = stim.split('_')[0]
    if stim == 'RAAC':
        categories = {'UNKNOWN':[],'INACT_1st':nb('A',1,4),'INACT_2nd':nb('B',1,5),'ROOT_1st':['A5','A6','A7'],
                      'ROOT_2nd':['B6','B7','B8'],'INBTW_1st':nb('A',8,19),'INBTW_2nd':nb('B',9,18),'IMDT_1st':['B19'],'IMDT_2nd':['A20'],'EFFECT':['B20']}
    elif stim == 'RAC':
        categories = {'UNKNOWN':nb('A',1,19),'INACT_1st':[],'INACT_2nd':nb('B',1,5),'ROOT_1st':[],'ROOT_2nd':['B6','B7','B8'],
                      'INBTW_1st':[],'INBTW_2nd':nb('B',9,18),'IMDT_1st':['B19'],'IMDT_2nd':['A20'],'EFFECT':['B20']}
    elif stim == 'RBAC': 
        categories = {'UNKNOWN':[],'INACT_1st':[],'INACT_2nd':nb('A',1,16),'ROOT_1st':['B1','B2','B3'],
                      'ROOT_2nd':['A17','A18','A19'],'INBTW_1st':nb('B',4,18),'INBTW_2nd':[],'IMDT_1st':['B19'],
                      'IMDT_2nd':['A20'],'EFFECT':['B20']}
    elif stim == 'RBC': 
        categories = {'UNKNOWN':[],'INACT_1st':nb('B',1,5),'INACT_2nd':nb('A',1,2),'ROOT_1st':['B6','B7','B8'],
                      'ROOT_2nd':['A3','A4','A5'],'INBTW_1st':nb('B',9,18),'INBTW_2nd':nb('A',6,19),'IMDT_1st':['B19'],
                      'IMDT_2nd':['A20'],'EFFECT':['B20']}
    elif stim == 'UAAC': 
        categories = {'UNKNOWN':[],'INACT_1st':nb('A',1,6),'INACT_2nd':nb('B',1,6),'ROOT_1st':['A6','A7','A8'],
                      'ROOT_2nd':['B6','B7','B8'],'INBTW_1st':nb('A',9,40),'INBTW_2nd':nb('B',9,18),'IMDT_1st':['B19'],
                      'IMDT_2nd':['A41'],'EFFECT':['B20']}
    elif stim == 'UAAS': 
        categories = {'UNKNOWN':[],'INACT_1st':nb('A',1,6),'INACT_2nd':nb('B',1,6),'ROOT_1st':['A6','A7','A8'],
                      'ROOT_2nd':['B6','B7','B8'],'INBTW_1st':nb('A',9,40),'INBTW_2nd':nb('B',9,18),'IMDT_1st':['B19'],
                      'IMDT_2nd':['A41'],'EFFECT':['B20']}
    elif stim == 'UABS': 
        categories = {'UNKNOWN':[],'INACT_1st':nb('A',1,5),'INACT_2nd':nb('B',1,5),'ROOT_1st':['A6','A7','A8'],
                      'ROOT_2nd':['B6','B7','B8'],'INBTW_1st':nb('A',9,40),'INBTW_2nd':nb('B',9,18),'IMDT_1st':['A41'],
                      'IMDT_2nd':['B19'],'EFFECT':['B20']}
    elif stim == 'UAS': 
        categories = {'UNKNOWN':[],'INACT_1st':nb('A',1,5),'INACT_2nd':nb('B',1,5),'ROOT_1st':['A6','A7','A8'],
                      'ROOT_2nd':['B6','B7','B8'],'INBTW_1st':nb('A',9,40),'INBTW_2nd':nb('B',9,18),'IMDT_1st':['A41'],
                      'IMDT_2nd':['B19'],'EFFECT':['B20']}
    elif stim == 'UBAC': 
        categories = {'UNKNOWN':[],'INACT_1st':nb('B',1,2),'INACT_2nd':nb('A',1,23),'ROOT_1st':['B3','B4','B5'],
                      'ROOT_2nd':['A24','A25','A26'],'INBTW_1st':nb('B',6,18),'INBTW_2nd':nb('A',27,40),'IMDT_1st':['B19'],
                      'IMDT_2nd':['A41'],'EFFECT':['B20']}
    elif stim == 'UBAS': 
        categories = {'UNKNOWN':[],'INACT_1st':nb('B',1,2),'INACT_2nd':nb('A',1,23),'ROOT_1st':['B3','B4','B5'],
                      'ROOT_2nd':['A24','A25','A26'],'INBTW_1st':nb('B',6,18),'INBTW_2nd':nb('A',27,40),'IMDT_1st':['B19'],
                      'IMDT_2nd':['A41'],'EFFECT':['B20']}
    elif stim == 'UBBS': 
        categories = {'UNKNOWN':[],'INACT_1st':[],'INACT_2nd':nb('A',1,35),'ROOT_1st':['B1','B2','B3'],
                      'ROOT_2nd':['A36','A37','A38'],'INBTW_1st':nb('B',4,18),'INBTW_2nd':nb('A',39,40),'IMDT_1st':['A41'],
                      'IMDT_2nd':['B19'],'EFFECT':['B20']}
    elif stim == 'UBC': 
        categories = {'UNKNOWN':[],'INACT_1st':nb('B',1,2),'INACT_2nd':nb('A',1,18),'ROOT_1st':['B3','B4','B5'],
                      'ROOT_2nd':['A19','A20','A21'],'INBTW_1st':nb('B',6,18),'INBTW_2nd':nb('A',22,40),'IMDT_1st':['B19'],
                      'IMDT_2nd':['A41'],'EFFECT':['B20']}
    elif stim == 'UBS': 
        categories = {'UNKNOWN':[],'INACT_1st':nb('B',1,2),'INACT_2nd':nb('A',1,18),'ROOT_1st':['B3','B4','B5'],
                      'ROOT_2nd':['A19','A20','A21'],'INBTW_1st':nb('B',6,18),'INBTW_2nd':nb('A',22,40),'IMDT_1st':['B19'],
                      'IMDT_2nd':['A41'],'EFFECT':['B20']}

    category = [cat for cat,nd in categories.items() if node in nd][0]

    return category

class AndGate(object):

    def __init__(self,rolled=False,continuity='root_1st'):
        if rolled == False:
            data = data_AND_Gate[data_AND_Gate["rolled_OR_unrolled"]=="Unrolled"]
        elif rolled == True:
            data = data_AND_Gate[data_AND_Gate["rolled_OR_unrolled"]=="Rolled"]
        if continuity == 'root_1st':
            data = data[data['root_1st']==data['imdt_2nd']]
        elif continuity == 'root_2nd':
            data = data[(data['root_1st']!=data['imdt_2nd'])|(data['state_OR_event']=='State')]
            
        self.df = data
        
        self.node_select = self.df["node_selected"].value_counts(normalize=True)*100
        values = {}
        nodes = ["nodeA"+str(i+1) for i in range(41)]+["nodeB"+str(i+1) for i in range(20)]
        for item in nodes:
            if item not in self.node_select.keys():
                values[item] = 0
            else:
                values[item] = self.node_select[item]
        self.node_select = pd.Series(values)
        
        self.node_category = self.df["node_category"].value_counts(normalize=True)*100
        values = {}
        cats = ['UNKNOWN','INACT_1st','INACT_2nd','ROOT_1st','ROOT_2nd','INBTW_1st','INBTW_2nd','IMDT_1st','IMDT_2nd','EFFECT']
        for item in cats:
            if item not in self.node_category.keys():
                values[item] = 0
            else:
                values[item] = self.node_category[item]
        self.node_category = pd.Series(values)
        
    def add_filter(self,sampling=None,level=None,state=None,root_1st=None,state_branch=None,A_detectors=None):
        if sampling == "right":
            self.df = self.df[self.df["sampling"]=="Right"]
        elif sampling == "left":
            self.df = self.df[self.df["sampling"]=="Left"]
        if level == "top":
            self.df = self.df[self.df["A_branch_loc"]=="Top"]
        elif level == "bottom":
            self.df = self.df[self.df["A_branch_loc"]=="Bottom"]
        if A_detectors == "squares":
            self.df = self.df[self.df["A_detectors"]=="Squares"]
        elif A_detectors == "circles":
            self.df = self.df[self.df["A_detectors"]=="Circles"]
        if state == False:
            self.df = self.df[self.df["state_OR_event"]=="Event"]
        elif state == True:
            self.df = self.df[self.df["state_OR_event"]=="State"]
        if root_1st == 'A':
            self.df = self.df[self.df["root_1st"]=="A"]
        elif root_1st == 'B':
            self.df = self.df[self.df["root_1st"]=="B"]
        if state_branch == 'A':
            self.df = self.df[self.df["state_branch"]=="A"]
        if state_branch == 'B':
            self.df = self.df[self.df["state_branch"]=="B"]
        
        self.node_select = self.df["node_selected"].value_counts(normalize=True)*100
        values = {}
        nodes = ["nodeA"+str(i+1) for i in range(41)]+["nodeB"+str(i+1) for i in range(20)]
        for item in nodes:
            if item not in self.node_select.keys():
                values[item] = 0
            else:
                values[item] = self.node_select[item]
        self.node_select = pd.Series(values)
        
        self.node_category = self.df["node_category"].value_counts(normalize=True)*100
        values = {}
        cats = ['UNKNOWN','INACT_1st','INACT_2nd','ROOT_1st','ROOT_2nd','INBTW_1st','INBTW_2nd','IMDT_1st','IMDT_2nd','EFFECT']
        for item in cats:
            if item not in self.node_category.keys():
                values[item] = 0
            else:
                values[item] = self.node_category[item]
        self.node_category = pd.Series(values)
        
        return self
    
class Chain(object):
    def __init__(self,stim=None):
        data = data_chain[data_chain["stim_type"] == stim]
            
        self.df = data
        
        self.node_select = self.df["node_selected"].value_counts(normalize=True)*100
        values = {}
        if stim == 'ChainS':
            nodes = ["nodeB"+str(i+1) for i in range(20)]
        elif stim == 'ChainC':
            nodes = ["nodeA"+str(i+1) for i in range(41)]+['nodesB20']
            
        for item in nodes:
            if item not in self.node_select.keys():
                values[item] = 0
            else:
                values[item] = self.node_select[item]
        self.node_select = pd.Series(values)
        
        self.node_category = self.df["node_category"].value_counts(normalize=True)*100
        values = {}
        cats = ['INACT','ROOT','INBTW','IMDT','EFFECT']
        for item in cats:
            if item not in self.node_category.keys():
                values[item] = 0
            else:
                values[item] = self.node_category[item]
        self.node_category = pd.Series(values)
        
    def add_filter(self,sampling=None,level=None):
        if sampling == "right":
            self.df = self.df[self.df["sampling"]=="Right"]
        elif sampling == "left":
            self.df = self.df[self.df["sampling"]=="Left"]
        if level == 'top':
            self.df = self.df[self.df['A_branch_loc']=='Top']
        elif level == 'bottom':
            self.df = self.df[self.df['A_branch_loc']=='Bottom']
            
        self.node_select = self.df["node_selected"].value_counts(normalize=True)*100
        values = {}
        stim = self.df['stim_type'].cat.remove_unused_categories().cat.categories[0]
        if stim == 'ChainS':
            nodes = ["nodeB"+str(i+1) for i in range(20)]
        elif stim == 'ChainC':
            nodes = ["nodeA"+str(i+1) for i in range(41)]+['nodesB20']
        for item in nodes:
            if item not in self.node_select.keys():
                values[item] = 0
            else:
                values[item] = self.node_select[item]
        self.node_select = pd.Series(values)
        
        self.node_category = self.df["node_category"].value_counts(normalize=True)*100
        values = {}
        cats = ['INACT','ROOT','INBTW','IMDT','EFFECT']
        for item in cats:
            if item not in self.node_category.keys():
                values[item] = 0
            else:
                values[item] = self.node_category[item]
        self.node_category = pd.Series(values)
        
        return self
    
def bootstrap(stim):
    df_mean_std = {}
    data = stim.df.node_category.to_numpy()
    labels = stim.df.node_category.cat.categories.to_list()
    if len(labels) == 9:
        labels = ['INACT_1st','INACT_2nd','ROOT_1st','ROOT_2nd','INBTW_1st','INBTW_2nd','IMDT_1st','IMDT_2nd','EFFECT']
    else:
        labels = ['INACT','ROOT','INBTW','IMDT','EFFECT']

    mean_per_cat = []
    std_per_cat = []    

    sample_mean = {}
    for category in labels:
            sample_mean[category] = []
    for _ in range(100):
        sample_n = np.random.choice(data, size=98)
        series = pd.Series(sample_n).value_counts(normalize=True)*100
        
        for category in sample_mean.keys():
            if category in series.index:
                mean = series[category]
                sample_mean[category].append(mean)

    for category in sample_mean.keys():
        sample_mean[category] = np.array(sample_mean[category])
        if len(sample_mean[category]) != 0:
            mean = np.mean(sample_mean[category])
            std = np.std(sample_mean[category])
        else:
            mean = 0
            std = 0

        mean_per_cat.append(mean)
        std_per_cat.append(std)

    df_mean_std["mean"] = mean_per_cat
    df_mean_std["std"] = std_per_cat

    df_mean_std = pd.DataFrame(df_mean_std,columns=['mean','std'],index=labels)
        
    return df_mean_std
    
def graph(list_of_df,title,x_axis='node_category'):
    plt.rcParams['axes.grid'] = False
    fig = plt.figure(figsize=(6.6*len(list_of_df),5))
    #fig = plt.figure(figsize=(6,5))
    a = str(len(list_of_df))
    for i,x in enumerate(list_of_df):
        axis = fig.add_subplot(int("1"+a+str(i+1)))
        #axis = fig.add_subplot(111)
        axis.set_ylim([0,80])
        axis.set_ylabel("Percentage of responses")
        axis.label_outer()
        axis.spines["top"].set_visible(False)
        axis.spines["right"].set_visible(False)
        axis.set_title(title[i])
        
        labels = x.index.to_list()
        mean_per_cat = x['mean'].values
        std_per_cat = x['std'].values
        axis.bar(labels, mean_per_cat, yerr=std_per_cat,capsize=3,ecolor='black',error_kw={'markeredgewidth':1})
        plt.xticks(rotation=90)
            
def graph2(x,x_axis='node_category'):
    plt.rcParams['axes.grid'] = False
    fig = plt.figure(figsize=(9,4))
    #fig.suptitle("Experiment 1", fontweight="bold",y=1.05)
    axis = fig.add_subplot(111)
    axis.spines["top"].set_visible(False)
    axis.spines["right"].set_visible(False)
    axis.set_ylim([0,80])
    axis.set_ylabel("Number of responses (%)")
    axis.set_title('Summary of the results')
    axis.label_outer()
    categories = ['R1','I1','R2','I2','other']
    event_R1c_mean = [x[0].loc["ROOT_1st","mean"],x[0].loc["IMDT_1st","mean"],x[0].loc["ROOT_2nd",'mean'],
                 x[0].loc['IMDT_2nd','mean'],x[0].loc['INACT_1st','mean']+x[0].loc['INACT_2nd','mean']+
                 x[0].loc['INBTW_1st','mean']+x[0].loc['INBTW_2nd','mean']+x[0].loc['EFFECT','mean']]
    event_R2c_mean = [x[1].loc["ROOT_1st","mean"],x[1].loc["IMDT_1st","mean"],x[1].loc["ROOT_2nd",'mean'],
                 x[1].loc['IMDT_2nd','mean'],x[1].loc['INACT_1st','mean']+x[1].loc['INACT_2nd','mean']+
                 x[1].loc['INBTW_1st','mean']+x[1].loc['INBTW_2nd','mean']+x[1].loc['EFFECT','mean']]
    state_R2c_mean = [x[2].loc["ROOT_1st","mean"],x[2].loc["IMDT_1st","mean"],x[2].loc["ROOT_2nd",'mean'],
                 x[2].loc['IMDT_2nd','mean'],x[2].loc['INACT_1st','mean']+x[2].loc['INACT_2nd','mean']+
                 x[2].loc['INBTW_1st','mean']+x[2].loc['INBTW_2nd','mean']+x[2].loc['EFFECT','mean']]
                      
    event_R1c_std = [x[0].loc["ROOT_1st","std"],x[0].loc["IMDT_1st","std"],x[0].loc["ROOT_2nd",'std'],
                 x[0].loc['IMDT_2nd','std'],x[0].loc['INACT_1st','std']+x[0].loc['INACT_2nd','std']+
                 x[0].loc['INBTW_1st','std']+x[0].loc['INBTW_2nd','std']+x[0].loc['EFFECT','std']]
    event_R2c_std = [x[1].loc["ROOT_1st","std"],x[1].loc["IMDT_1st","std"],x[1].loc["ROOT_2nd",'std'],
                 x[1].loc['IMDT_2nd','std'],x[1].loc['INACT_1st','std']+x[1].loc['INACT_2nd','std']+
                 x[1].loc['INBTW_1st','std']+x[1].loc['INBTW_2nd','std']+x[1].loc['EFFECT','std']]
    state_R2c_std = [x[2].loc["ROOT_1st","std"],x[2].loc["IMDT_1st","std"],x[2].loc["ROOT_2nd",'std'],
                 x[2].loc['IMDT_2nd','std'],x[2].loc['INACT_1st','std']+x[2].loc['INACT_2nd','std']+
                 x[2].loc['INBTW_1st','std']+x[2].loc['INBTW_2nd','std']+x[2].loc['EFFECT','std']]
    
    df_mean = pd.DataFrame({'event (R1 cont)':event_R1c_mean,'event (R2 cont)':event_R2c_mean,'state (R2 cont)':state_R2c_mean}, 
                          index=categories)
    df_std = pd.DataFrame({'event (R1 cont)':event_R1c_std,'event (R2 cont)':event_R2c_std,'state (R2 cont)':state_R2c_std}, 
                          index=categories)
    
    df_mean.plot.bar(ax=axis,yerr=df_std,capsize=3,ecolor='black',rot=0,error_kw={'markeredgewidth':1})

# %%
data_chain['node_category'] = data_chain.apply(lambda x: chain_node_cat(x['stimulus'],x['node_selected']),axis=1)
data_chain['node_category'] = data_chain['node_category'].astype('category')
data_AND_Gate['node_category'] = data_AND_Gate.apply(lambda x: branch_node_cat(x['stimulus'],x['node_selected']),axis=1)
data_AND_Gate['node_category'] = data_AND_Gate['node_category'].astype('category')

# %%
data_chain
# Out:
#     subject_id            rt  stimulus sampling  nb_of_run stim_type  \
# 0            1  11284.000000  chainS_R    Right        1.0    ChainS
# 1            2  40194.000000  chainS_L     Left        1.0    ChainS
# 2            3  16502.940000  chainS_L     Left        1.0    ChainS
# 3            4  11292.200000  chainS_R    Right        1.0    ChainS
# 4            5  23968.060000  chainS_L     Left        1.0    ChainS
# 5            6   9407.990000  chainS_R    Right        1.0    ChainS
# 6            7  15531.875000  chainS_R    Right        1.0    ChainS
# 7            8  13313.000000  chainS_L     Left        1.0    ChainS
# 8            9  10439.035000  chainS_R    Right        1.0    ChainS
# 9           10  10768.230000  chainS_R    Right        1.0    ChainS
# 10          11  20252.000000  chainS_R    Right        1.0    ChainS
# 11          12   8412.500000  chainS_R    Right        1.0    ChainS
# 12          13  12068.285000  chainS_L     Left        1.0    ChainS
# 13          14  44315.000000  chainS_L     Left        1.0    ChainS
# 14          15  16136.515000  chainS_R    Right        1.0    ChainS
# 15          16  17388.000000  chainS_L     Left        1.0    ChainS
# 16          17   9905.215000  chainS_R    Right        1.0    ChainS
# 17          18  14245.000000  chainS_R    Right        1.0    ChainS
# 18          19  12541.605000  chainS_R    Right        1.0    ChainS
# 19          20   9162.455000  chainS_R    Right        1.0    ChainS
# 20          21  12014.865000  chainS_L     Left        1.0    ChainS
# 21          22   9053.295000  chainS_L     Left        1.0    ChainS
# 22          23   8842.205000  chainS_R    Right        1.0    ChainS
# 23          24  33827.785000  chainS_L     Left        1.0    ChainS
# 24          25   9335.815000  chainS_R    Right        1.0    ChainS
# 25          26   8919.000000  chainS_R    Right        1.0    ChainS
# 26          27  10761.000000  chainS_L     Left        1.0    ChainS
# 27          28  10127.085000  chainS_L     Left        1.0    ChainS
# 28          29  15498.000000  chainS_L     Left        1.0    ChainS
# 29          30   9745.000000  chainS_L     Left        1.0    ChainS
# 30          31  18479.915000  chainS_L     Left        1.0    ChainS
# 31          32  64544.355000  chainS_L     Left        2.0    ChainS
# 32          33  17636.000000  chainS_R    Right        1.0    ChainS
# 33          34  17657.640000  chainS_L     Left        1.0    ChainS
# 34          35   8750.160000  chainS_R    Right        1.0    ChainS
# 35          36   9423.640000  chainS_L     Left        1.0    ChainS
# 36          37   9612.000000  chainS_R    Right        1.0    ChainS
# 37          38  11745.095000  chainS_R    Right        1.0    ChainS
# 38          39   8229.155000  chainS_R    Right        1.0    ChainS
# 39          40  21333.095000  chainS_L     Left        1.0    ChainS
# 40          41  35942.410000  chainS_R    Right        1.0    ChainS
# 41          42  17998.225000  chainS_R    Right        1.0    ChainS
# 42          43  14122.100000  chainS_R    Right        1.0    ChainS
# 43          44   9428.285000  chainS_L     Left        1.0    ChainS
# 44          45  14654.000000  chainS_L     Left        1.0    ChainS
# 45          46  34768.615000  chainS_L     Left        1.0    ChainS
# 46          47  10406.515000  chainS_L     Left        1.0    ChainS
# 47          48  11127.770000  chainS_L     Left        1.0    ChainS
# 48          49   8678.080001  chainS_L     Left        1.0    ChainS
# 49          50  11728.000000  chainS_L     Left        1.0    ChainS
# 50          51   8388.055000  chainS_R    Right        1.0    ChainS
# 51          52   8829.305000  chainS_R    Right        1.0    ChainS
# 52          53  10339.475000  chainS_R    Right        1.0    ChainS
# 53          54  19966.875000  chainS_L     Left        1.0    ChainS
# 54          55  10400.435000  chainS_L     Left        1.0    ChainS
# 55          56  12490.090000  chainS_L     Left        1.0    ChainS
# 56          57  10749.650000  chainS_L     Left        1.0    ChainS
# 57          58  18201.805000  chainS_L     Left        2.0    ChainS
# 58          59  10703.000000  chainS_L     Left        1.0    ChainS
# 59          60   9848.000000  chainS_R    Right        1.0    ChainS
# 60          61  13260.680000  chainS_L     Left        1.0    ChainS
# 61          62   9937.485000  chainS_R    Right        1.0    ChainS
# 62          63  10124.000000  chainS_L     Left        1.0    ChainS
# 63          64  15842.000000  chainS_R    Right        1.0    ChainS
# 64          65  24025.000000  chainS_L     Left        1.0    ChainS
# 65          66  12359.000000  chainS_R    Right        1.0    ChainS
# 66          67   8764.650000  chainS_L     Left        1.0    ChainS
# 67          68   7955.505000  chainS_R    Right        1.0    ChainS
# 68          69   9115.545000  chainS_R    Right        1.0    ChainS
# 69          70   8729.355000  chainS_L     Left        1.0    ChainS
# 70          71  14956.685000  chainS_L     Left        1.0    ChainS
# 71          72   8720.000000  chainS_R    Right        1.0    ChainS
# 72          73   9831.000000  chainS_L     Left        1.0    ChainS
# 73          74   8601.755000  chainS_L     Left        1.0    ChainS
# 74          75   9200.615000  chainS_L     Left        1.0    ChainS
# 75          76  13455.930000  chainS_L     Left        1.0    ChainS
# 76          77   8476.685000  chainS_L     Left        1.0    ChainS
# 77          78  14748.415000  chainS_L     Left        1.0    ChainS
# 78          79  22104.285000  chainS_L     Left        1.0    ChainS
# 79          80  11598.355000  chainS_R    Right        1.0    ChainS
# 80          81  14491.315000  chainS_L     Left        1.0    ChainS
# 81          82  13166.610000  chainS_R    Right        1.0    ChainS
# 82          83  20020.850000  chainS_L     Left        1.0    ChainS
# 83          84   9850.180000  chainS_R    Right        1.0    ChainS
# 84          85  15485.540000  chainS_L     Left        1.0    ChainS
# 85          86  11567.000000  chainS_L     Left        1.0    ChainS
# 86          87  12961.700000  chainS_R    Right        1.0    ChainS
# 87          88   8874.600000  chainS_R    Right        1.0    ChainS
# 88          89  12313.100000  chainS_L     Left        1.0    ChainS
# 89          90  13245.580000  chainS_L     Left        1.0    ChainS
# 90          91  11534.770000  chainS_R    Right        1.0    ChainS
# 91          92  14006.210000  chainS_R    Right        1.0    ChainS
# 92          93  10950.050000  chainS_L     Left        1.0    ChainS
# 93          94   8354.470000  chainS_R    Right        1.0    ChainS
# 94          95   9846.000000  chainS_R    Right        1.0    ChainS
# 95          96   8928.120000  chainS_R    Right        1.0    ChainS
# 96          97  20462.195000  chainS_L     Left        1.0    ChainS
# 97          98   8632.665000  chainS_R    Right        1.0    ChainS
#
#    A_branch_loc node_selected node_category
# 0           NaN       nodeB19          IMDT
# 1           NaN        nodeB9          ROOT
# 2           NaN        nodeB9          ROOT
# 3           NaN       nodeB19          IMDT
# 4           NaN       nodeB19          IMDT
# 5           NaN        nodeB9          ROOT
# 6           NaN       nodeB19          IMDT
# 7           NaN        nodeB4         INACT
# 8           NaN        nodeB9          ROOT
# 9           NaN        nodeB9          ROOT
# 10          NaN       nodeB20        EFFECT
# 11          NaN        nodeB8          ROOT
# 12          NaN       nodeB20        EFFECT
# 13          NaN        nodeB2         INACT
# 14          NaN        nodeB9          ROOT
# 15          NaN        nodeB9          ROOT
# 16          NaN       nodeB19          IMDT
# 17          NaN        nodeB8          ROOT
# 18          NaN        nodeB9          ROOT
# 19          NaN        nodeB9          ROOT
# 20          NaN       nodeB19          IMDT
# 21          NaN        nodeB9          ROOT
# 22          NaN        nodeB9          ROOT
# 23          NaN       nodeB19          IMDT
# 24          NaN       nodeB19          IMDT
# 25          NaN        nodeB9          ROOT
# 26          NaN        nodeB9          ROOT
# 27          NaN        nodeB9          ROOT
# 28          NaN        nodeB1         INACT
# 29          NaN       nodeB16         INBTW
# 30          NaN        nodeB9          ROOT
# 31          NaN        nodeB5         INACT
# 32          NaN        nodeB9          ROOT
# 33          NaN       nodeB19          IMDT
# 34          NaN        nodeB9          ROOT
# 35          NaN        nodeB9          ROOT
# 36          NaN        nodeB9          ROOT
# 37          NaN        nodeB9          ROOT
# 38          NaN        nodeB9          ROOT
# 39          NaN       nodeB19          IMDT
# 40          NaN       nodeB19          IMDT
# 41          NaN        nodeB9          ROOT
# 42          NaN       nodeB19          IMDT
# 43          NaN        nodeB9          ROOT
# 44          NaN        nodeB9          ROOT
# 45          NaN        nodeB9          ROOT
# 46          NaN       nodeB19          IMDT
# 47          NaN        nodeB9          ROOT
# 48          NaN        nodeB9          ROOT
# 49          NaN        nodeB9          ROOT
# 50          NaN        nodeB9          ROOT
# 51          NaN        nodeB9          ROOT
# 52          NaN        nodeB8          ROOT
# 53          NaN        nodeB9          ROOT
# 54          NaN       nodeB19          IMDT
# 55          NaN        nodeB9          ROOT
# 56          NaN        nodeB9          ROOT
# 57          NaN       nodeB20        EFFECT
# 58          NaN       nodeB20        EFFECT
# 59          NaN       nodeB19          IMDT
# 60          NaN       nodeB19          IMDT
# 61          NaN       nodeB19          IMDT
# 62          NaN       nodeB19          IMDT
# 63          NaN       nodeB19          IMDT
# 64          NaN       nodeB20        EFFECT
# 65          NaN       nodeB19          IMDT
# 66          NaN        nodeB9          ROOT
# 67          NaN       nodeB19          IMDT
# 68          NaN        nodeB9          ROOT
# 69          NaN        nodeB9          ROOT
# 70          NaN        nodeB9          ROOT
# 71          NaN        nodeB9          ROOT
# 72          NaN       nodeB20        EFFECT
# 73          NaN        nodeB9          ROOT
# 74          NaN        nodeB9          ROOT
# 75          NaN        nodeB9          ROOT
# 76          NaN       nodeB19          IMDT
# 77          NaN       nodeB19          IMDT
# 78          NaN        nodeB9          ROOT
# 79          NaN        nodeB9          ROOT
# 80          NaN       nodeB19          IMDT
# 81          NaN       nodeB19          IMDT
# 82          NaN       nodeB19          IMDT
# 83          NaN        nodeB9          ROOT
# 84          NaN        nodeB9          ROOT
# 85          NaN        nodeB9          ROOT
# 86          NaN        nodeB9          ROOT
# 87          NaN       nodeB19          IMDT
# 88          NaN        nodeB9          ROOT
# 89          NaN       nodeB20        EFFECT
# 90          NaN       nodeB19          IMDT
# 91          NaN       nodeB19          IMDT
# 92          NaN       nodeB19          IMDT
# 93          NaN        nodeB9          ROOT
# 94          NaN       nodeB10          ROOT
# 95          NaN        nodeB9          ROOT
# 96          NaN        nodeB9          ROOT
# 97          NaN        nodeB9          ROOT

# %%
data_AND_Gate
# Out:
#      subject_id        rt stimulus sampling  nb_of_run rolled_OR_unrolled  \
# 0             1  40031.00  UABS_RT    Right        1.0           Unrolled
# 1             1  17030.00   UAS_RT    Right        1.0           Unrolled
# 2             1  12418.00  UBBS_RB    Right        1.0           Unrolled
# 3             1  14022.00  UBAS_RT    Right        1.0           Unrolled
# 4             1  16359.00   UBS_RT    Right        1.0           Unrolled
# ..          ...       ...      ...      ...        ...                ...
# 583          98  12409.11   UBS_RT    Right        1.0           Unrolled
# 584          98  10540.76  UBAS_RB    Right        1.0           Unrolled
# 585          98  14759.02  UABS_RB    Right        1.0           Unrolled
# 586          98   9954.57   UAS_RT    Right        1.0           Unrolled
# 587          98  11990.42  UAAS_RB    Right        1.0           Unrolled
#
#     A_branch_loc A_detectors state_OR_event state_branch root_1st imdt_2nd  \
# 0            Top     Squares          Event          NaN        A        B
# 1            Top     Squares          State            A      NaN        B
# 2         Bottom     Squares          Event          NaN        B        B
# 3            Top     Squares          Event          NaN        B        A
# 4            Top     Squares          State            B      NaN        A
# ..           ...         ...            ...          ...      ...      ...
# 583          Top     Squares          State            B      NaN        A
# 584       Bottom     Squares          Event          NaN        B        A
# 585       Bottom     Squares          Event          NaN        A        B
# 586          Top     Squares          State            A      NaN        B
# 587       Bottom     Squares          Event          NaN        A        A
#
#     node_selected node_category
# 0         nodeB19      IMDT_2nd
# 1         nodeB19      IMDT_2nd
# 2         nodeB19      IMDT_2nd
# 3         nodeA41      IMDT_2nd
# 4         nodeA41      IMDT_2nd
# ..            ...           ...
# 583        nodeB4      ROOT_1st
# 584        nodeB4      ROOT_1st
# 585        nodeA7      ROOT_1st
# 586        nodeA7      ROOT_1st
# 587        nodeA7      ROOT_1st
#
# [588 rows x 14 columns]

# %% [markdown]
# ## General comparison

# %%
# For Unrolled: only graphs with SQUARES for branch A

chain = Chain(stim='ChainS')
Unrolled_state = AndGate(rolled=False,continuity='root_2nd').add_filter(A_detectors='squares',state=True)
Unrolled_stateA = AndGate(rolled=False,continuity='root_2nd').add_filter(A_detectors='squares',state=True,state_branch='A')
Unrolled_stateB = AndGate(rolled=False,continuity='root_2nd').add_filter(A_detectors='squares',state=True,state_branch='B')
Unrolled_AA_BB = AndGate(rolled=False,continuity='root_1st').add_filter(A_detectors='squares')
Unrolled_AA = AndGate(rolled=False,continuity='root_1st').add_filter(A_detectors='squares',root_1st='A')
Unrolled_BB = AndGate(rolled=False,continuity='root_1st').add_filter(A_detectors='squares',root_1st='B')
Unrolled_AB_BA = AndGate(rolled=False,continuity='root_2nd').add_filter(A_detectors='squares',state=False)
Unrolled_AB = AndGate(rolled=False,continuity='root_2nd').add_filter(A_detectors='squares',state=False,root_1st='A')
Unrolled_BA = AndGate(rolled=False,continuity='root_2nd').add_filter(A_detectors='squares',state=False,root_1st='B')

####### Bootstrapping #######

chain = bootstrap(chain)
U = bootstrap(Unrolled_state)
UA = bootstrap(Unrolled_stateA)
UB = bootstrap(Unrolled_stateB)
UAA_BB = bootstrap(Unrolled_AA_BB)
UAA = bootstrap(Unrolled_AA)
UBB = bootstrap(Unrolled_BB)
UAB_BA = bootstrap(Unrolled_AB_BA)
UAB = bootstrap(Unrolled_AB)
UBA = bootstrap(Unrolled_BA)

graph([chain],['Chain'])
graph([U,UA,UB],['Unrolled A or B in state condition','Unrolled A in state condition','Unrolled B in state condition'])
graph([UAA_BB,UAA,UBB],['Unrolled AA or BB','Unrolled AA','Unrolled BB'])
graph([UAB_BA,UAB,UBA],['Unrolled AB or BA','Unrolled AB','Unrolled BA'])

# %%
graph2([UAA_BB,UAB_BA,U])
#plt.savefig('results_E2.png',dpi=300,bbox_inches='tight')

# %% [markdown]
# ## Comparison Right *vs* Left

# %%
# Same as the general comparison BUT only for the condition 'right'

chain = Chain(stim='ChainS').add_filter(sampling='right')
Unrolled_state = AndGate(rolled=False,continuity='root_2nd').add_filter(sampling='right',state=True)
Unrolled_stateA = AndGate(rolled=False,continuity='root_2nd').add_filter(sampling='right',state=True,state_branch='A')
Unrolled_stateB = AndGate(rolled=False,continuity='root_2nd').add_filter(sampling='right',state=True,state_branch='B')
Unrolled_AA_BB = AndGate(rolled=False,continuity='root_1st').add_filter(sampling='right')
Unrolled_AA = AndGate(rolled=False,continuity='root_1st').add_filter(sampling='right',root_1st='A')
Unrolled_BB = AndGate(rolled=False,continuity='root_1st').add_filter(sampling='right',root_1st='B')
Unrolled_AB_BA = AndGate(rolled=False,continuity='root_2nd').add_filter(sampling='right',state=False)
Unrolled_AB = AndGate(rolled=False,continuity='root_2nd').add_filter(sampling='right',state=False,root_1st='A')
Unrolled_BA = AndGate(rolled=False,continuity='root_2nd').add_filter(sampling='right',state=False,root_1st='B')

chain = bootstrap(chain)
U = bootstrap(Unrolled_state)
UA = bootstrap(Unrolled_stateA)
UB = bootstrap(Unrolled_stateB)
UAA_BB = bootstrap(Unrolled_AA_BB)
UAA = bootstrap(Unrolled_AA)
UBB = bootstrap(Unrolled_BB)
UAB_BA = bootstrap(Unrolled_AB_BA)
UAB = bootstrap(Unrolled_AB)
UBA = bootstrap(Unrolled_BA)

graph([chain],['Chain'])
graph([U,UA,UB],['Unrolled A or B in state condition','Unrolled A in state condition','Unrolled B in state condition'])
graph([UAA_BB,UAA,UBB],['Unrolled AA or BB','Unrolled AA','Unrolled BB'])
graph([UAB_BA,UAB,UBA],['Unrolled AB or BA','Unrolled AB','Unrolled BA'])

# %%
# Same as the general comparison BUT only for the condition 'left'

chain = Chain(stim='ChainS').add_filter(sampling='left')
Unrolled_state = AndGate(rolled=False,continuity='root_2nd').add_filter(sampling='left',A_detectors='squares',state=True)
Unrolled_stateA = AndGate(rolled=False,continuity='root_2nd').add_filter(sampling='left',A_detectors='squares',state=True,state_branch='A')
Unrolled_stateB = AndGate(rolled=False,continuity='root_2nd').add_filter(sampling='left',A_detectors='squares',state=True,state_branch='B')
Unrolled_AA_BB = AndGate(rolled=False,continuity='root_1st').add_filter(A_detectors='squares',sampling='left')
Unrolled_AA = AndGate(rolled=False,continuity='root_1st').add_filter(sampling='left',A_detectors='squares',root_1st='A')
Unrolled_BB = AndGate(rolled=False,continuity='root_1st').add_filter(sampling='left',A_detectors='squares',root_1st='B')
Unrolled_AB_BA = AndGate(rolled=False,continuity='root_2nd').add_filter(sampling='left',A_detectors='squares',state=False)
Unrolled_AB = AndGate(rolled=False,continuity='root_2nd').add_filter(sampling='left',A_detectors='squares',state=False,root_1st='A')
Unrolled_BA = AndGate(rolled=False,continuity='root_2nd').add_filter(sampling='left',A_detectors='squares',state=False,root_1st='B')

chain = bootstrap(chain)
U = bootstrap(Unrolled_state)
UA = bootstrap(Unrolled_stateA)
UB = bootstrap(Unrolled_stateB)
UAA_BB = bootstrap(Unrolled_AA_BB)
UAA = bootstrap(Unrolled_AA)
UBB = bootstrap(Unrolled_BB)
UAB_BA = bootstrap(Unrolled_AB_BA)
UAB = bootstrap(Unrolled_AB)
UBA = bootstrap(Unrolled_BA)

graph([chain],['Chain'])
graph([U,UA,UB],['Unrolled A or B in state condition','Unrolled A in state condition','Unrolled B in state condition'])
graph([UAA_BB,UAA,UBB],['Unrolled AA or BB','Unrolled AA','Unrolled BB'])
graph([UAB_BA,UAB,UBA],['Unrolled AB or BA','Unrolled AB','Unrolled BA'])

# %%
# Broad comparison between right vs left sampling

chain_Right = Chain(stim='ChainS').add_filter(sampling='right')
chain_Left = Chain(stim='ChainS').add_filter(sampling='left')
Unrolled_state_Right = AndGate(rolled=False,continuity='root_2nd').add_filter(sampling='right',state=True)
Unrolled_state_Left = AndGate(rolled=False,continuity='root_2nd').add_filter(sampling='left',state=True)
Unrolled_AA_BB_Right = AndGate(rolled=False,continuity='root_1st').add_filter(sampling='right')
Unrolled_AA_BB_Left = AndGate(rolled=False,continuity='root_1st').add_filter(sampling='left')
Unrolled_AB_BA_Right = AndGate(rolled=False,continuity='root_2nd').add_filter(sampling='right',state=False)
Unrolled_AB_BA_Left = AndGate(rolled=False,continuity='root_2nd').add_filter(sampling='left',state=False)

chain_R = bootstrap(chain_Right)
chain_L = bootstrap(chain_Left)
U_R = bootstrap(Unrolled_state_Right)
U_L = bootstrap(Unrolled_state_Left)
UAA_BB_R = bootstrap(Unrolled_AA_BB_Right)
UAA_BB_L = bootstrap(Unrolled_AA_BB_Left)
UAB_BA_R = bootstrap(Unrolled_AB_BA_Right)
UAB_BA_L = bootstrap(Unrolled_AB_BA_Left)

graph([chain_R,chain_L],['Chain left','Chain right'])
graph([U_R,U_L],['Unrolled A or B in state condition left','Unrolled A or B in state condition right'])
graph([UAA_BB_R,UAA_BB_L],['Unrolled AA or BB left','Unrolled AA or BB right'])
graph([UAB_BA_R,UAB_BA_L],['Unrolled AB or BA left','Unrolled AB or BA right'])

# %% [markdown]
# ## Comparison Top *vs* Bottom

# %%
# Broad comparison between TOP vs BOTTOM location of branch A

Unrolled_state_Top = AndGate(rolled=False,continuity='root_2nd').add_filter(level='top',state=True)
Unrolled_state_Bottom = AndGate(rolled=False,continuity='root_2nd').add_filter(level='bottom',state=True)
Unrolled_AA_BB_Top = AndGate(rolled=False,continuity='root_1st').add_filter(level='top')
Unrolled_AA_BB_Bottom = AndGate(rolled=False,continuity='root_1st').add_filter(level='bottom')
Unrolled_AB_BA_Top = AndGate(rolled=False,continuity='root_2nd').add_filter(level='top',state=False)
Unrolled_AB_BA_Bottom = AndGate(rolled=False,continuity='root_2nd').add_filter(level='bottom',state=False)

US_T = bootstrap(Unrolled_state_Top)
US_B = bootstrap(Unrolled_state_Bottom)
UAA_BB_T = bootstrap(Unrolled_AA_BB_Top)
UAA_BB_B = bootstrap(Unrolled_AA_BB_Bottom)
UAB_BA_T = bootstrap(Unrolled_AB_BA_Top)
UAB_BA_B = bootstrap(Unrolled_AB_BA_Bottom)

graph([US_T,US_B],['Unrolled A or B in state condition top','Unrolled A or B in state condition bottom'])
graph([UAA_BB_T,UAA_BB_B],['Unrolled AA or BB top','Unrolled AA or BB bottom'])
graph([UAB_BA_T,UAB_BA_B],['Unrolled AB or BA top','Unrolled AB or BA bottom'])
