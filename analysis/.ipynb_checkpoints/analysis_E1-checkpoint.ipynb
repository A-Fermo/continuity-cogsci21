# %%
import os
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator
from collections import defaultdict
from jupyterthemes import jtplot
jtplot.style(theme="chesterish")

# %% [markdown]
# ### Row data.csv

# %%
root_dir = os.path.dirname(os.getcwd())
data_row = pd.read_csv("{}/data/data_E1.csv".format(root_dir))
data_row.head()
# Out:
#    subject_id        rt                          stimulus  button_pressed  \
# 0           1  16775.13                    img/inst_1.png             0.0
# 1           1       NaN                   img/inst_2R.png             NaN
# 2           1       NaN   img/inst_3R.png,img/inst_3R.gif             NaN
# 3           1       NaN                   img/inst_4R.png             NaN
# 4           1       NaN  img/inst_5R.png,img/inst_5RB.gif             NaN
#
#               trial_type  trial_index  time_elapsed internal_node_id gender  \
# 0  image-button-response            0         16783      0.0-0.0-0.0   male
# 1          causal-graph1            1         30108      0.0-0.0-1.0   male
# 2          causal-graph1            2        139781      0.0-0.0-2.0   male
# 3          causal-graph1            3        142755      0.0-0.0-3.0   male
# 4          causal-graph1            4        330315      0.0-0.0-4.0   male
#
#    age  ...    status nb_of_run responses question_order stim_type  length  \
# 0   29  ...       NaN       NaN       NaN            NaN       NaN     NaN
# 1   29  ...  inactive       NaN       NaN            NaN       NaN     NaN
# 2   29  ...  inactive       1.0       NaN            NaN       NaN     NaN
# 3   29  ...  inactive       NaN       NaN            NaN       NaN     NaN
# 4   29  ...  inactive       2.0       NaN            NaN       NaN     NaN
#
#   state_OR_event branch_first time_interval node_selected
# 0            NaN          NaN           NaN           NaN
# 1            NaN          NaN           NaN           NaN
# 2            NaN          NaN           NaN           NaN
# 3            NaN          NaN           NaN           NaN
# 4            NaN          NaN           NaN           NaN
#
# [5 rows x 24 columns]

# %% [markdown]
# ### Demographical data only

# %%
data_demog = data_row[["subject_id","gender","age","language","country","turkcode"]]
data_demog.head()
# Out:
#    subject_id gender  age language                   country  \
# 0           1   male   29  English  United States of America
# 1           1   male   29  English  United States of America
# 2           1   male   29  English  United States of America
# 3           1   male   29  English  United States of America
# 4           1   male   29  English  United States of America
#
#             turkcode
# 0  R568084887600gxrw
# 1  R568084887600gxrw
# 2  R568084887600gxrw
# 3  R568084887600gxrw
# 4  R568084887600gxrw

# %% [markdown]
# ### Target stimuli only (instructions deleted)

# %%
data = data_row[["subject_id","rt","stimulus","trial_type","sampling","status","nb_of_run","stim_type","length","state_OR_event",
                   "branch_first","time_interval","node_selected"]]
data = data[(data["trial_type"]=="causal-graph1") & (data["status"]=="active")].drop(["trial_type","status"],axis=1)
data.reset_index(drop=True,inplace=True)
stimulus = []
for items in data.stimulus.array:
    stimulus.append(items.split(",")[1].split("/")[1].split(".")[0])
stimulus = pd.Series(stimulus)
data.stimulus = stimulus
data.head()
# Out:
#    subject_id         rt      stimulus sampling  nb_of_run stim_type length  \
# 0           1  22620.305      chain_RL    Right        1.0     Chain   Long
# 1           1  23863.120  branch_RTLE1    Right        1.0  AND_Gate   Long
# 2           1  10390.475   branch_RBSS    Right        1.0  AND_Gate  Short
# 3           1  14482.460  branch_RTSE3    Right        1.0  AND_Gate  Short
# 4           1  30929.865  branch_RTLE2    Right        1.0  AND_Gate   Long
#
#   state_OR_event branch_first time_interval node_selected
# 0            NaN          NaN           NaN         node7
# 1          Event          Top         Short        node12
# 2          State       Bottom           NaN        node15
# 3          Event          Top          Long        node14
# 4          Event          Top        Medium        node14

# %% [markdown]
# ### Chain only

# %%
data_chain = data[data["stim_type"]=="Chain"].drop(["stim_type","state_OR_event","branch_first","time_interval"],axis=1)
data_chain.reset_index(drop=True,inplace=True)
data_chain["stimulus"] = data_chain["stimulus"].astype("category")
data_chain["sampling"] = data_chain["sampling"].astype("category")
data_chain["length"] = data_chain["length"].astype("category")
data_chain.head()
# Out:
#    subject_id         rt  stimulus sampling  nb_of_run  length node_selected
# 0           1  22620.305  chain_RL    Right        1.0    Long         node7
# 1           1  30747.455  chain_RM    Right        1.0  Medium         node7
# 2           1  12595.985  chain_RS    Right        1.0   Short         node8
# 3           2  46211.535  chain_LL     Left        1.0    Long         node2
# 4           2  10868.255  chain_LM     Left        1.0  Medium         node2

# %% [markdown]
# ### AND-Gate only

# %%
data_AND_Gate = data[data["stim_type"]=="AND_Gate"].drop(["stim_type"],axis=1)
data_AND_Gate.reset_index(drop=True,inplace=True)
data_AND_Gate["stimulus"] = data_AND_Gate["stimulus"].astype("category")
data_AND_Gate["state_OR_event"] = data_AND_Gate["state_OR_event"].astype("category")
data_AND_Gate["sampling"] = data_AND_Gate["sampling"].astype("category")
data_AND_Gate["length"] = data_AND_Gate["length"].astype("category")
data_AND_Gate["branch_first"] = data_AND_Gate["branch_first"].astype("category")
data_AND_Gate["time_interval"] = data_AND_Gate["time_interval"].astype("category")
data_AND_Gate.head()
# Out:
#    subject_id         rt      stimulus sampling  nb_of_run  length  \
# 0           1  23863.120  branch_RTLE1    Right        1.0    Long
# 1           1  10390.475   branch_RBSS    Right        1.0   Short
# 2           1  14482.460  branch_RTSE3    Right        1.0   Short
# 3           1  30929.865  branch_RTLE2    Right        1.0    Long
# 4           1  15376.405  branch_RBME1    Right        1.0  Medium
#
#   state_OR_event branch_first time_interval node_selected
# 0          Event          Top         Short        node12
# 1          State       Bottom           NaN        node15
# 2          Event          Top          Long        node14
# 3          Event          Top        Medium        node14
# 4          Event       Bottom         Short        node14

# %% [markdown]
# ### General functions

# %%
class AndGate(object):

    def __init__(self,length=None):
        if length == "short":
            data = data_AND_Gate[data_AND_Gate["length"]=="Short"]
        elif length == "medium":
            data = data_AND_Gate[data_AND_Gate["length"]=="Medium"]
        elif length == "long":
            data = data_AND_Gate[data_AND_Gate["length"]=="Long"]
        self.df = data
        self.node_select = self.df["node_selected"].value_counts(normalize=True)*100
        values = {}
        nodes = ["node"+str(i+1) for i in range(15)]
        for item in nodes:
            if item not in self.node_select.keys():
                values[item] = 0
            else:
                values[item] = self.node_select[item]
        self.node_select = pd.Series(values)
        
    def add_filter(self,sampling=None,level=None,delay=None):
        if sampling == "right":
            self.df = self.df[self.df["sampling"]=="Right"]
        elif sampling == "left":
            self.df = self.df[self.df["sampling"]=="Left"]
        if level == "top":
            self.df = self.df[self.df["branch_first"]=="Top"]
        elif level == "bottom":
            self.df = self.df[self.df["branch_first"]=="Bottom"]
        if delay == "short":
            self.df = self.df[self.df["time_interval"]=="Short"]
        elif delay == "medium":
            self.df = self.df[self.df["time_interval"]=="Medium"]
        elif delay == "long":
            self.df = self.df[self.df["time_interval"]=="Long"]
        elif delay == False:
            self.df = self.df[self.df["state_OR_event"]=="State"]
        
        self.node_select = self.df["node_selected"].value_counts(normalize=True)*100
        values = {}
        nodes = ["node"+str(i+1) for i in range(15)]
        for item in nodes:
            if item not in self.node_select.keys():
                values[item] = 0
            else:
                values[item] = self.node_select[item]
        self.node_select = pd.Series(values)
        return self
    
class Chain(object):
    def __init__(self,length=None):
        if length == "short":
            data = data_chain[data_chain["length"]=="Short"]
        elif length == "medium":
            data = data_chain[data_chain["length"]=="Medium"]
        elif length == "long":
            data = data_chain[data_chain["length"]=="Long"]
        self.df = data
        self.node_select = self.df["node_selected"].value_counts(normalize=True)*100
        values = {}
        nodes = ["node"+str(i+1) for i in range(8)]
        for item in nodes:
            if item not in self.node_select.keys():
                values[item] = 0
            else:
                values[item] = self.node_select[item]
        self.node_select = pd.Series(values)
        
    def add_filter(self,sampling=None):
        if sampling == "right":
            self.df = self.df[self.df["sampling"]=="Right"]
        elif sampling == "left":
            self.df = self.df[self.df["sampling"]=="Left"]
        self.node_select = self.df["node_selected"].value_counts(normalize=True)*100
        values = {}
        nodes = ["node"+str(i+1) for i in range(8)]
        for item in nodes:
            if item not in self.node_select.keys():
                values[item] = 0
            else:
                values[item] = self.node_select[item]
        self.node_select = pd.Series(values)
        return self
    
def graph(list_of_data,title):
    fig = plt.figure(figsize=(6.6*len(list_of_data),5))
    a = str(len(list_of_data))
    for i,x in enumerate(list_of_data):
        axis = fig.add_subplot(int("1"+a+str(i+1)))
        axis.set_ylim([0,110])
        axis.set_xlabel("Detectors",labelpad=20)
        axis.set_ylabel("Percentage of responses")
        axis.label_outer()
        axis.spines["top"].set_visible(False)
        axis.spines["right"].set_visible(False)
        axis.set_title(title[i])
        x.node_select.plot.bar(ax=axis)

# %% [markdown]
# ### Comparison Right *vs* Left

# %%
ChainShort_R = Chain("short").add_filter(sampling="right")
ChainMedium_R = Chain("medium").add_filter(sampling="right")
ChainLong_R = Chain("long").add_filter(sampling="right")
ChainShort_L = Chain("short").add_filter(sampling="left")
ChainMedium_L = Chain("medium").add_filter(sampling="left")
ChainLong_L = Chain("long").add_filter(sampling="left")
BranchShort_R = AndGate("short").add_filter(sampling="right")
BranchMedium_R = AndGate("medium").add_filter(sampling="right")
BranchLong_R = AndGate("long").add_filter(sampling="right")
BranchShort_L = AndGate("short").add_filter(sampling="left")
BranchMedium_L = AndGate("medium").add_filter(sampling="left")
BranchLong_L = AndGate("long").add_filter(sampling="left")

graph([ChainShort_L,ChainShort_R],["Short chain left","Short chain right"])
graph([ChainMedium_L,ChainMedium_R],["Medium chain left","Medium chain right"])
graph([ChainLong_L,ChainLong_R],["Long chain left","Long chain right"])
graph([BranchShort_L,BranchShort_R],["Short AND-Gate left","Short AND-Gate right"])
graph([BranchMedium_L,BranchMedium_R],["Medium AND-Gate left","Medium AND-Gate right"])
graph([BranchLong_L,BranchLong_R],["Long AND-Gate left","Long AND-Gate right"])

# %% [markdown]
# ### Comparison Top *vs* Bottom

# %%
BranchShort_T = AndGate("short").add_filter(level="top")
BranchMedium_T = AndGate("medium").add_filter(level="top")
BranchLong_T = AndGate("long").add_filter(level="top")
BranchShort_B = AndGate("short").add_filter(level="bottom")
BranchMedium_B = AndGate("medium").add_filter(level="bottom")
BranchLong_B = AndGate("long").add_filter(level="bottom")

graph([BranchShort_T,BranchShort_B],["Short AND-Gate top","Short AND-Gate bottom"])
graph([BranchMedium_T,BranchMedium_B],["Medium AND-Gate top","Medium AND-Gate bottom"])
graph([BranchLong_T,BranchLong_B],["Long AND-Gate top","Long AND-Gate bottom"])

# %% [markdown]
# ### General comparison

# %%
MediumEvent3.df
# Out:
#      subject_id         rt      stimulus sampling  nb_of_run  length  \
# 18            2  16809.110  branch_LBME3     Left        1.0  Medium
# 57            5  14773.000  branch_RBME3    Right        1.0  Medium
# 81            7  14616.000  branch_LBME3     Left        1.0  Medium
# 91            8  15870.000  branch_LBME3     Left        1.0  Medium
# 98            9  16958.000  branch_LBME3     Left        1.0  Medium
# 115          10  17271.840  branch_LBME3     Left        1.0  Medium
# 121          11  29967.635  branch_LBME3     Left        1.0  Medium
# 136          12  21590.450  branch_RBME3    Right        1.0  Medium
# 165          14  15084.585  branch_RBME3    Right        1.0  Medium
# 187          16  17597.065  branch_LBME3     Left        1.0  Medium
# 196          17  15466.455  branch_RBME3    Right        1.0  Medium
# 222          19  14871.810  branch_RBME3    Right        1.0  Medium
# 237          20  31500.175  branch_LBME3     Left        1.0  Medium
# 279          24  20395.000  branch_RBME3    Right        1.0  Medium
# 339          29  14971.700  branch_RBME3    Right        1.0  Medium
#
#     state_OR_event branch_first time_interval node_selected
# 18           Event       Bottom          Long         node2
# 57           Event       Bottom          Long         node7
# 81           Event       Bottom          Long         node3
# 91           Event       Bottom          Long        node12
# 98           Event       Bottom          Long        node13
# 115          Event       Bottom          Long        node15
# 121          Event       Bottom          Long        node12
# 136          Event       Bottom          Long        node12
# 165          Event       Bottom          Long        node12
# 187          Event       Bottom          Long         node3
# 196          Event       Bottom          Long         node5
# 222          Event       Bottom          Long         node7
# 237          Event       Bottom          Long         node2
# 279          Event       Bottom          Long        node11
# 339          Event       Bottom          Long        node12

# %%
ChainShort = Chain("short").add_filter(sampling="right")
ChainMedium = Chain("medium").add_filter(sampling="right")
ChainLong = Chain("long").add_filter(sampling="right")
ShortState = AndGate("short").add_filter(sampling="right",level="top",delay=False)
MediumState = AndGate("medium").add_filter(sampling="right",level="top",delay=False)
LongState = AndGate("long").add_filter(sampling="right",level="top",delay=False)
ShortEvent1 = AndGate("short").add_filter(sampling="right",level="top",delay="short")
ShortEvent2 = AndGate("short").add_filter(sampling="right",level="top",delay="medium")
ShortEvent3 = AndGate("short").add_filter(sampling="right",level="top",delay="long")
MediumEvent1 = AndGate("medium").add_filter(sampling="right",level="top",delay="short")
MediumEvent2  = AndGate("medium").add_filter(sampling="right",level="top",delay="medium")
MediumEvent3 = AndGate("medium").add_filter(sampling="right",level="top",delay="long")
LongEvent1 = AndGate("long").add_filter(sampling="right",level="top",delay="short")
LongEvent2  = AndGate("long").add_filter(sampling="right",level="top",delay="medium")
LongEvent3 = AndGate("long").add_filter(sampling="right",level="top",delay="long")

graph([ChainShort],["Short chain"])
graph([ChainMedium],["Medium chain"])
graph([ChainLong],["Long chain"])
graph([ShortState,ShortEvent1,ShortEvent2,ShortEvent3],["Short state top AND-Gate","Short event1 top AND-Gate",
                                                        "Short event2 top AND-Gate","Short event3 top AND-Gate"])
graph([MediumState,MediumEvent1,MediumEvent2,MediumEvent3],["Medium state top AND-Gate","Medium event1 top AND-Gate",
                                                        "Medium event2 top AND-Gate","Medium event3 top AND-Gate"])
graph([LongState,LongEvent1,LongEvent2,LongEvent3],["Long state top AND-Gate","Long event1 top AND-Gate",
                                                        "Long event2 top AND-Gate","Long event3 top AND-Gate"])

# %%
ChainShort = Chain("short").add_filter(sampling="left")
ChainMedium = Chain("medium").add_filter(sampling="left")
ChainLong = Chain("long").add_filter(sampling="left")
ShortState = AndGate("short").add_filter(sampling="left",level="top",delay=False)
MediumState = AndGate("medium").add_filter(sampling="left",level="top",delay=False)
LongState = AndGate("long").add_filter(sampling="left",level="top",delay=False)
ShortEvent1 = AndGate("short").add_filter(sampling="left",level="top",delay="short")
ShortEvent2 = AndGate("short").add_filter(sampling="left",level="top",delay="medium")
ShortEvent3 = AndGate("short").add_filter(sampling="left",level="top",delay="long")
MediumEvent1 = AndGate("medium").add_filter(sampling="left",level="top",delay="short")
MediumEvent2  = AndGate("medium").add_filter(sampling="left",level="top",delay="medium")
MediumEvent3 = AndGate("medium").add_filter(sampling="left",level="top",delay="long")
LongEvent1 = AndGate("long").add_filter(sampling="left",level="top",delay="short")
LongEvent2  = AndGate("long").add_filter(sampling="left",level="top",delay="medium")
LongEvent3 = AndGate("long").add_filter(sampling="left",level="top",delay="long")

graph([ChainShort],["Short chain"])
graph([ChainMedium],["Medium chain"])
graph([ChainLong],["Long chain"])
graph([ShortState,ShortEvent1,ShortEvent2,ShortEvent3],["Short state top AND-Gate","Short event1 top AND-Gate",
                                                        "Short event2 top AND-Gate","Short event3 top AND-Gate"])
graph([MediumState,MediumEvent1,MediumEvent2,MediumEvent3],["Medium state top AND-Gate","Medium event1 top AND-Gate",
                                                        "Medium event2 top AND-Gate","Medium event3 top AND-Gate"])
graph([LongState,LongEvent1,LongEvent2,LongEvent3],["Long state top AND-Gate","Long event1 top AND-Gate",
                                                        "Long event2 top AND-Gate","Long event3 top AND-Gate"])

# %%
ChainShort = Chain("short").add_filter(sampling="right")
ChainMedium = Chain("medium").add_filter(sampling="right")
ChainLong = Chain("long").add_filter(sampling="right")
ShortState = AndGate("short").add_filter(sampling="right",level="bottom",delay=False)
MediumState = AndGate("medium").add_filter(sampling="right",level="bottom",delay=False)
LongState = AndGate("long").add_filter(sampling="right",level="bottom",delay=False)
ShortEvent1 = AndGate("short").add_filter(sampling="right",level="bottom",delay="short")
ShortEvent2 = AndGate("short").add_filter(sampling="right",level="bottom",delay="medium")
ShortEvent3 = AndGate("short").add_filter(sampling="right",level="bottom",delay="long")
MediumEvent1 = AndGate("medium").add_filter(sampling="right",level="bottom",delay="short")
MediumEvent2  = AndGate("medium").add_filter(sampling="right",level="bottom",delay="medium")
MediumEvent3 = AndGate("medium").add_filter(sampling="right",level="bottom",delay="long")
LongEvent1 = AndGate("long").add_filter(sampling="right",level="bottom",delay="short")
LongEvent2  = AndGate("long").add_filter(sampling="right",level="bottom",delay="medium")
LongEvent3 = AndGate("long").add_filter(sampling="right",level="bottom",delay="long")

graph([ChainShort],["Short chain"])
graph([ChainMedium],["Medium chain"])
graph([ChainLong],["Long chain"])
graph([ShortState,ShortEvent1,ShortEvent2,ShortEvent3],["Short state top AND-Gate","Short event1 top AND-Gate",
                                                        "Short event2 top AND-Gate","Short event3 top AND-Gate"])
graph([MediumState,MediumEvent1,MediumEvent2,MediumEvent3],["Medium state top AND-Gate","Medium event1 top AND-Gate",
                                                        "Medium event2 top AND-Gate","Medium event3 top AND-Gate"])
graph([LongState,LongEvent1,LongEvent2,LongEvent3],["Long state top AND-Gate","Long event1 top AND-Gate",
                                                        "Long event2 top AND-Gate","Long event3 top AND-Gate"])

# %%
ChainShort = Chain("short").add_filter(sampling="left")
ChainMedium = Chain("medium").add_filter(sampling="left")
ChainLong = Chain("long").add_filter(sampling="left")
ShortState = AndGate("short").add_filter(sampling="left",level="bottom",delay=False)
MediumState = AndGate("medium").add_filter(sampling="left",level="bottom",delay=False)
LongState = AndGate("long").add_filter(sampling="left",level="bottom",delay=False)
ShortEvent1 = AndGate("short").add_filter(sampling="left",level="bottom",delay="short")
ShortEvent2 = AndGate("short").add_filter(sampling="left",level="bottom",delay="medium")
ShortEvent3 = AndGate("short").add_filter(sampling="left",level="bottom",delay="long")
MediumEvent1 = AndGate("medium").add_filter(sampling="left",level="bottom",delay="short")
MediumEvent2  = AndGate("medium").add_filter(sampling="left",level="bottom",delay="medium")
MediumEvent3 = AndGate("medium").add_filter(sampling="left",level="bottom",delay="long")
LongEvent1 = AndGate("long").add_filter(sampling="left",level="bottom",delay="short")
LongEvent2  = AndGate("long").add_filter(sampling="left",level="bottom",delay="medium")
LongEvent3 = AndGate("long").add_filter(sampling="left",level="bottom",delay="long")

graph([ChainShort],["Short chain"])
graph([ChainMedium],["Medium chain"])
graph([ChainLong],["Long chain"])
graph([ShortState,ShortEvent1,ShortEvent2,ShortEvent3],["Short state top AND-Gate","Short event1 top AND-Gate",
                                                        "Short event2 top AND-Gate","Short event3 top AND-Gate"])
graph([MediumState,MediumEvent1,MediumEvent2,MediumEvent3],["Medium state top AND-Gate","Medium event1 top AND-Gate",
                                                        "Medium event2 top AND-Gate","Medium event3 top AND-Gate"])
graph([LongState,LongEvent1,LongEvent2,LongEvent3],["Long state top AND-Gate","Long event1 top AND-Gate",
                                                        "Long event2 top AND-Gate","Long event3 top AND-Gate"])

# %%
ShortEvent3.df
# Out:
#      subject_id         rt      stimulus sampling  nb_of_run length  \
# 23            2  13415.075  branch_LBSE3     Left        1.0  Short
# 95            8  16339.000  branch_LBSE3     Left        1.0  Short
# 105           9  17100.000  branch_LBSE3     Left        1.0  Short
# 184          16  14280.215  branch_LBSE3     Left        1.0  Short
# 236          20  16032.145  branch_LBSE3     Left        1.0  Short
# 326          28  13650.345  branch_LBSE3     Left        1.0  Short
#
#     state_OR_event branch_first time_interval node_selected
# 23           Event       Bottom          Long         node9
# 95           Event       Bottom          Long        node14
# 105          Event       Bottom          Long        node14
# 184          Event       Bottom          Long        node10
# 236          Event       Bottom          Long         node9
# 326          Event       Bottom          Long        node14

# %%
LongEvent2.df
# Out:
#      subject_id         rt      stimulus sampling  nb_of_run length  \
# 38            4  41863.000  branch_LBLE2     Left        1.0   Long
# 72            7  29129.000  branch_LBLE2     Left        1.0   Long
# 126          11  16425.775  branch_LBLE2     Left        1.0   Long
# 186          16  23700.675  branch_LBLE2     Left        1.0   Long
# 318          27  27699.030  branch_LBLE2     Left        1.0   Long
#
#     state_OR_event branch_first time_interval node_selected
# 38           Event       Bottom        Medium         node8
# 72           Event       Bottom        Medium         node8
# 126          Event       Bottom        Medium         node3
# 186          Event       Bottom        Medium         node8
# 318          Event       Bottom        Medium        node15
