# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
#from jupyterthemes import jtplot
#jtplot.style(theme="chesterish")
pd.options.display.max_rows = 200

# %% [markdown]
# ## Data structuring

# %% [markdown]
# #### Importing data.csv

# %%
root_dir = os.path.dirname(os.getcwd())
data_clean = pd.read_csv("{}/data/data_E2_100def.csv".format(root_dir))
data_clean
# Out:
#       subject_id     stimulus     trial_type  time_elapsed  gender  age  \
# 0              1  instruction  causal-graph1          6362  female   31
# 1              1  instruction  causal-graph1         11076  female   31
# 2              1  instruction  causal-graph1         23724  female   31
# 3              1  instruction  causal-graph1         29399  female   31
# 4              1  instruction  causal-graph1         40590  female   31
# ...          ...          ...            ...           ...     ...  ...
# 2471         100       UBS_RT  causal-graph1        521552  female   37
# 2472         100      UABS_RB  causal-graph1        535960  female   37
# 2473         100     chainS_R  causal-graph1        552680  female   37
# 2474         100  instruction  causal-graph1        554990  female   37
# 2475         100      comment    survey-text        558439  female   37
#
#                  language                   country sampling  \
# 0     English, Indonesian  United States of America    Right
# 1     English, Indonesian  United States of America    Right
# 2     English, Indonesian  United States of America    Right
# 3     English, Indonesian  United States of America    Right
# 4     English, Indonesian  United States of America    Right
# ...                   ...                       ...      ...
# 2471              English  United States of America    Right
# 2472              English  United States of America    Right
# 2473              English  United States of America    Right
# 2474              English  United States of America    Right
# 2475              English  United States of America    Right
#
#                turkcode  ...  responses  stim_type rolled_OR_unrolled  \
# 0     R565304137610gxrw  ...        NaN        NaN                NaN
# 1     R565304137610gxrw  ...        NaN        NaN                NaN
# 2     R565304137610gxrw  ...        NaN        NaN                NaN
# 3     R565304137610gxrw  ...        NaN        NaN                NaN
# 4     R565304137610gxrw  ...        NaN        NaN                NaN
# ...                 ...  ...        ...        ...                ...
# 2471  R565986147390gxrw  ...        NaN   AND_Gate           Unrolled
# 2472  R565986147390gxrw  ...        NaN   AND_Gate           Unrolled
# 2473  R565986147390gxrw  ...        NaN     ChainS                NaN
# 2474  R565986147390gxrw  ...        NaN        NaN                NaN
# 2475  R565986147390gxrw  ...  {"Q0":""}        NaN                NaN
#
#      A_branch_loc A_detectors state_OR_event state_branch root_1st imdt_2nd  \
# 0             NaN         NaN            NaN          NaN      NaN      NaN
# 1             NaN         NaN            NaN          NaN      NaN      NaN
# 2             NaN         NaN            NaN          NaN      NaN      NaN
# 3             NaN         NaN            NaN          NaN      NaN      NaN
# 4             NaN         NaN            NaN          NaN      NaN      NaN
# ...           ...         ...            ...          ...      ...      ...
# 2471          Top     Squares          State            B      NaN        A
# 2472       Bottom     Squares          Event          NaN        A        B
# 2473          NaN         NaN            NaN          NaN      NaN      NaN
# 2474          NaN         NaN            NaN          NaN      NaN      NaN
# 2475          NaN         NaN            NaN          NaN      NaN      NaN
#
#      node_selected
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# ...            ...
# 2471       nodeA30
# 2472        nodeB8
# 2473       nodeB19
# 2474           NaN
# 2475           NaN
#
# [2476 rows x 22 columns]

# %%
time = []
for item in data_clean[data_clean['stimulus']=='comment']['time_elapsed']:
    time.append(item)
time = np.array(time)
time.mean()/1000/60
# Out:
# 6.961863333333333

# %%
for idx,item in enumerate(data_clean['stimulus']):
    if item == 'comment':
        print(data_clean['responses'][idx])
# Out:
# {"Q0":""}
# {"Q0":""}
# {"Q0":""}
# {"Q0":"I was a little confused when you asked which detector caused G to activate, as each detector can be activated by the detector before it. "}
# {"Q0":""}
# {"Q0":""}
# {"Q0":""}
# {"Q0":""}
# {"Q0":""}
# {"Q0":""}
# {"Q0":""}
# {"Q0":""}
# {"Q0":""}
# {"Q0":"None"}
# {"Q0":""}
# {"Q0":""}
# {"Q0":""}
# {"Q0":""}
# {"Q0":""}
# {"Q0":""}
# {"Q0":""}
# {"Q0":""}
# {"Q0":""}
# {"Q0":""}
# {"Q0":"Thank you."}
# {"Q0":""}
# {"Q0":""}
# {"Q0":""}
# {"Q0":"THANK YOU."}
# {"Q0":""}
# {"Q0":"Thank you!"}
# {"Q0":""}
# {"Q0":"It was different but I don't know if I really understand this "}
# {"Q0":""}
# {"Q0":"None to add"}
# {"Q0":""}
# {"Q0":""}
# {"Q0":""}
# {"Q0":""}
# {"Q0":""}
# {"Q0":""}
# {"Q0":""}
# {"Q0":"none"}
# {"Q0":""}
# {"Q0":""}
# {"Q0":""}
# {"Q0":""}
# {"Q0":""}
# {"Q0":"The instructions didn't help much with finding the cause of G\"/ activation."}
# {"Q0":""}
# {"Q0":""}
# {"Q0":""}
# {"Q0":""}
# {"Q0":""}
# {"Q0":"I hope I got  the answers right on most, I realized maybe it was the same as my last answers afterall."}
# {"Q0":""}
# {"Q0":""}
# {"Q0":""}
# {"Q0":""}
# {"Q0":""}
# {"Q0":"None thank you"}
# {"Q0":""}
# {"Q0":""}
# {"Q0":"Even after reviewing the instructions carefully it was kind of confusing to know what information you were wanting. Did you want the particle that initiated the the others who in turn activated G? Or the particle itself that was directly responsible for activating G? I went with the particle that I considered directly responsible. "}
# {"Q0":""}
# {"Q0":""}
# {"Q0":""}
# {"Q0":""}
# {"Q0":""}
# {"Q0":"none"}
# {"Q0":""}
# {"Q0":""}
# {"Q0":"N/A"}
# {"Q0":""}
# {"Q0":"None"}
# {"Q0":""}
# {"Q0":""}
# {"Q0":"everything worked as intended"}
# {"Q0":"It ook a while but i learned what to do."}
# {"Q0":""}
# {"Q0":""}
# {"Q0":"Interesting survey. Straight forward and fast paced. Thank you!"}
# {"Q0":"This task is awesome."}
# {"Q0":""}
# {"Q0":""}
# {"Q0":""}
# {"Q0":""}
# {"Q0":"GOOD STUDY."}
# {"Q0":"This was very interesting. The instructions were very clear and easy to follow. Good luck with your research. "}
# {"Q0":"In every instance I though there were at least 2 causes, not one, but I could only select one"}
# {"Q0":""}
# {"Q0":""}
# {"Q0":""}
# {"Q0":""}
# {"Q0":""}
# {"Q0":"Didn't really understand it.  What it supposed to be the last block before the G, or the first one to get radioactive particles?"}
# {"Q0":""}
# {"Q0":""}
# {"Q0":"I'm a little confused as I suspect that the task was so easy I was uncertain about whether or not my answers were correct, especially concerning the connection that the inactivating change of inputs relate to the activated chain of inputs and which chain (and its prior, responsible first input) was responsible for G's activation in the end.\n\neames.chris1900@gmail.com"}
# {"Q0":""}

# %% [markdown]
# #### Demographical data only

# %%
data_demog = data_clean[["subject_id","gender","age","language","country","turkcode"]]
data_demog = data_demog.drop_duplicates()
data_demog
# Out:
#       subject_id  gender  age             language                   country  \
# 0              1  female   31  English, Indonesian  United States of America
# 17             2    male   31              English  United States of America
# 34             3    male   47              english  United States of America
# 51             4    male   25              English  United States of America
# 68             5  female   33              English  United States of America
# 85             6  female   19              english  United States of America
# 110            7  female   64              English  United States of America
# 135            8  female   25              English  United States of America
# 160            9  female   35              english  United States of America
# 209           10  female   32              English  United States of America
# 226           11    male   47              English  United States of America
# 259           12  female   54              English  United States of America
# 276           13  female   41              English  United States of America
# 293           14  female   43              English  United States of America
# 318           15    male   42              English  United States of America
# 335           16    male   36              English  United States of America
# 360           17    male   33              English  United States of America
# 377           18    male   39              English  United States of America
# 394           19    male   27              English  United States of America
# 411           20  female   34              English  United States of America
# 436           21    male   24              English  United States of America
# 453           22    male   32              english  United States of America
# 470           23    male   38              English  United States of America
# 487           24  female   49              English  United States of America
# 504           25  female   40              English  United States of America
# 529           26  female   57              English  United States of America
# 546           27  female   46              English  United States of America
# 563           28    male   35              english  United States of America
# 588           29    male   59              ENGLISH  United States of America
# 637           30  female   29              english  United States of America
# 662           31  female   30              English  United States of America
# 679           32  female   41              English  United States of America
# 704           33  female   58             English   United States of America
# 737           34  female   60                  eng  United States of America
# 770           35    male   26              English  United States of America
# 819           36    male   31              English  United States of America
# 836           37  female   34              English  United States of America
# 861           38    male   32              English  United States of America
# 878           39    male   45              English  United States of America
# 903           40    male   49              English  United States of America
# 920           41  female   40              english  United States of America
# 945           42    male   37              English  United States of America
# 962           43  female   46              English  United States of America
# 987           44    male   38              English  United States of America
# 1004          45    male   44              English  United States of America
# 1021          46    male   33              English  United States of America
# 1046          47    male   62              English  United States of America
# 1071          48    male   37     Russian, English  United States of America
# 1112          49    male   23              English  United States of America
# 1145          50    male   27              English  United States of America
# 1162          51    male   53              English  United States of America
# 1187          52    male   73              english  United States of America
# 1204          53  female   49              English  United States of America
# 1229          54    male   53              English  United States of America
# 1246          55  female   57              English  United States of America
# 1279          56    male   24             English.  United States of America
# 1304          57  female   37              English  United States of America
# 1321          58  female   37              english  United States of America
# 1338          59    male   33              English  United States of America
# 1363          60  female   56              English  United States of America
# 1388          61    male   30              English  United States of America
# 1437          62  female   39              English  United States of America
# 1454          63    male   23              English  United States of America
# 1471          64  female   39              English  United States of America
# 1512          65    male   27              English  United States of America
# 1561          66  female   33              English  United States of America
# 1578          67    male   24              English  United States of America
# 1595          68    male   46              english  United States of America
# 1620          69  female   49              English  United States of America
# 1637          70    male   38              english  United States of America
# 1662          71    male   26              english  United States of America
# 1687          72  female   27              english  United States of America
# 1728          73    male   23              English  United States of America
# 1753          74    male   38              English  United States of America
# 1778          75    male   31              English  United States of America
# 1803          76    male   30              English  United States of America
# 1820          77    male   28              English  United States of America
# 1845          78  female   39              English  United States of America
# 1862          79    male   58              english  United States of America
# 1895          80  female   31              english  United States of America
# 1960          81    male   56              English  United States of America
# 2009          82  female   54              English  United States of America
# 2026          83    male   62              English  United States of America
# 2051          84    male   30              English  United States of America
# 2076          85    male   33              English  United States of America
# 2093          86    male   32              english  United States of America
# 2110          87    male   36              English  United States of America
# 2135          88    male   30              ENGLISH  United States of America
# 2160          89    male   45              English  United States of America
# 2177          90    male   33              English  United States of America
# 2210          91    male   35              English  United States of America
# 2235          92    male   30              English  United States of America
# 2252          93    male   31              English  United States of America
# 2285          94    male   25              English  United States of America
# 2302          95  female   27              English  United States of America
# 2343          96    male   49              english  United States of America
# 2376          97    male   29              English  United States of America
# 2393          98  female   26              English  United States of America
# 2426          99    male   23              English  United States of America
# 2443         100  female   37              English  United States of America
#
#                turkcode
# 0     R565304137610gxrw
# 17    R568037847200gxrw
# 34    R567007587810gxrw
# 51    R562293107890gxrw
# 68    R564425597290gxrw
# 85    R566015437170gxrw
# 110   R565225457430gxrw
# 135   R564891937510gxrw
# 160   R564914717360gxrw
# 209   R567462027230gxrw
# 226   R569839927200gxrw
# 259   R567382397420gxrw
# 276   R561692637360gxrw
# 293   R567209797420gxrw
# 318   R567431727960gxrw
# 335   R569778127550gxrw
# 360   R564283037450gxrw
# 377   R568424107440gxrw
# 394   R562717627310gxrw
# 411   R564385287730gxrw
# 436   R564927097300gxrw
# 453   R567072427720gxrw
# 470   R565616437700gxrw
# 487   R564974807240gxrw
# 504   R565102177690gxrw
# 529   R565390917210gxrw
# 546   R568788967700gxrw
# 563   R565796347770gxrw
# 588   R561817947540gxrw
# 637   R565951837980gxrw
# 662   R567280867770gxrw
# 679   R563892367170gxrw
# 704   R562080497850gxrw
# 737   R567189477500gxrw
# 770   R563103597710gxrw
# 819   R564453527100gxrw
# 836   R562013587380gxrw
# 861   R564488067420gxrw
# 878   R561288177410gxrw
# 903   R564771007790gxrw
# 920   R568381327180gxrw
# 945   R561679417780gxrw
# 962   R563690957290gxrw
# 987   R561290117100gxrw
# 1004  R564577597560gxrw
# 1021  R561773827670gxrw
# 1046  R562332347600gxrw
# 1071  R561288317930gxrw
# 1112  R569984007440gxrw
# 1145  R562140177340gxrw
# 1162  R565269147300gxrw
# 1187  R569663677410gxrw
# 1204  R567164037820gxrw
# 1229  R562549397410gxrw
# 1246  R565373437870gxrw
# 1279  R561206867210gxrw
# 1304  R564112577560gxrw
# 1321  R562367667790gxrw
# 1338  R565051477310gxrw
# 1363  R566806247670gxrw
# 1388  R565233047520gxrw
# 1437  R562605447570gxrw
# 1454  R568649397740gxrw
# 1471  R565892187370gxrw
# 1512  R567334787900gxrw
# 1561  R569209847320gxrw
# 1578  R562461907520gxrw
# 1595  R566212297330gxrw
# 1620  R561437747750gxrw
# 1637  R568923367480gxrw
# 1662  R567462487730gxrw
# 1687  R568523057460gxrw
# 1728  R561188127970gxrw
# 1753  R561745517200gxrw
# 1778  R565359417370gxrw
# 1803  R567969477950gxrw
# 1820  R567539147580gxrw
# 1845  R563957057110gxrw
# 1862  R561875557360gxrw
# 1895  R567911377750gxrw
# 1960  R566247267790gxrw
# 2009  R568907077360gxrw
# 2026  R561555167480gxrw
# 2051  R562670387250gxrw
# 2076  R561829147980gxrw
# 2093  R567427357190gxrw
# 2110  R565226487920gxrw
# 2135  R564241567170gxrw
# 2160  R567211767700gxrw
# 2177  R563398467940gxrw
# 2210  R563541877780gxrw
# 2235  R563317837530gxrw
# 2252  R562054327460gxrw
# 2285  R563852317500gxrw
# 2302  R565981247860gxrw
# 2343  R568353977340gxrw
# 2376  R562207107830gxrw
# 2393  R566849427520gxrw
# 2426  R565987507110gxrw
# 2443  R565986147390gxrw

# %%
data_demog['gender'].value_counts()
# Out:
# male      61
# female    39
# Name: gender, dtype: int64

# %%
data_demog['language'].value_counts()
# Out:
# English                76
# english                17
# ENGLISH                 2
# English, Indonesian     1
# English.                1
# eng                     1
# Russian, English        1
# English                 1
# Name: language, dtype: int64

# %%
data_demog[data_demog['gender'] == 'male']['age'].mean()
# Out:
# 36.65573770491803

# %% [markdown]
# #### Target stimuli only (instructions deleted)

# %%
data = data_clean[["subject_id","rt","stimulus","trial_type","sampling","nb_of_run","stim_type","rolled_OR_unrolled",
                   "A_branch_loc","A_detectors","state_OR_event","state_branch","root_1st","imdt_2nd","node_selected"]]
data = data[data["stimulus"] != "instruction"].drop(['trial_type'],axis=1)
data.reset_index(drop=True,inplace=True)

data
# Out:
#      subject_id         rt  stimulus sampling  nb_of_run stim_type  \
# 0             1  19950.760   UAAS_RT    Right        1.0  AND_Gate
# 1             1  14289.955   UABS_RB    Right        1.0  AND_Gate
# 2             1  12181.330   UBBS_RT    Right        2.0  AND_Gate
# 3             1  13457.560    UAS_RB    Right        1.0  AND_Gate
# 4             1  10690.350  chainS_R    Right        1.0    ChainS
# ..          ...        ...       ...      ...        ...       ...
# 795         100  14898.000    UAS_RT    Right        1.0  AND_Gate
# 796         100  11452.000    UBS_RT    Right        1.0  AND_Gate
# 797         100  12388.000   UABS_RB    Right        1.0  AND_Gate
# 798         100  14964.000  chainS_R    Right        1.0    ChainS
# 799         100   3178.000   comment    Right        NaN       NaN
#
#     rolled_OR_unrolled A_branch_loc A_detectors state_OR_event state_branch  \
# 0             Unrolled          Top     Squares          Event          NaN
# 1             Unrolled       Bottom     Squares          Event          NaN
# 2             Unrolled          Top     Squares          Event          NaN
# 3             Unrolled       Bottom     Squares          State            A
# 4                  NaN          NaN         NaN            NaN          NaN
# ..                 ...          ...         ...            ...          ...
# 795           Unrolled          Top     Squares          State            A
# 796           Unrolled          Top     Squares          State            B
# 797           Unrolled       Bottom     Squares          Event          NaN
# 798                NaN          NaN         NaN            NaN          NaN
# 799                NaN          NaN         NaN            NaN          NaN
#
#     root_1st imdt_2nd node_selected
# 0          A        A        nodeA7
# 1          A        B       nodeA41
# 2          B        B        nodeB6
# 3        NaN        B       nodeA41
# 4        NaN      NaN        nodeB9
# ..       ...      ...           ...
# 795      NaN        B        nodeB8
# 796      NaN        A       nodeA30
# 797        A        B        nodeB8
# 798      NaN      NaN       nodeB19
# 799      NaN      NaN           NaN
#
# [800 rows x 14 columns]

# %%
data["nb_of_run"].value_counts()
# Out:
# 1.0    633
# 2.0     60
# 3.0      7
# Name: nb_of_run, dtype: int64

# %% [markdown]
# #### Chain only

# %%
data_chain = data[(data["stim_type"]=="ChainS")|(data["stim_type"]=="ChainC")].drop(["rolled_OR_unrolled","A_detectors",
                                                    "state_OR_event","state_branch","root_1st","imdt_2nd",],axis=1)
data_chain.reset_index(drop=True,inplace=True)
data_chain["stimulus"] = data_chain["stimulus"].astype("category")
data_chain["sampling"] = data_chain["sampling"].astype("category")
data_chain["stim_type"] = data_chain["stim_type"].astype("category")
data_chain.head()
# Out:
#    subject_id         rt  stimulus sampling  nb_of_run stim_type A_branch_loc  \
# 0           1  10690.350  chainS_R    Right        1.0    ChainS          NaN
# 1           2   8851.390  chainS_L     Left        1.0    ChainS          NaN
# 2           3  18117.000  chainS_R    Right        1.0    ChainS          NaN
# 3           4  13172.380  chainS_L     Left        2.0    ChainS          NaN
# 4           5   8726.075  chainS_R    Right        1.0    ChainS          NaN
#
#   node_selected
# 0        nodeB9
# 1        nodeB9
# 2        nodeB9
# 3       nodeB19
# 4        nodeB9

# %% [markdown]
# #### AND-Gate only

# %%
data_AND_Gate = data[data["stim_type"]=="AND_Gate"].drop(["stim_type"],axis=1)
data_AND_Gate.reset_index(drop=True,inplace=True)
data_AND_Gate["stimulus"] = data_AND_Gate["stimulus"].astype("category")
data_AND_Gate["state_OR_event"] = data_AND_Gate["state_OR_event"].astype("category")
data_AND_Gate["rolled_OR_unrolled"] = data_AND_Gate["rolled_OR_unrolled"].astype("category")
data_AND_Gate["A_branch_loc"] = data_AND_Gate["A_branch_loc"].astype("category")
data_AND_Gate["A_detectors"] = data_AND_Gate["A_detectors"].astype("category")
data_AND_Gate["root_1st"] = data_AND_Gate["root_1st"].astype("category")
data_AND_Gate["imdt_2nd"] = data_AND_Gate["imdt_2nd"].astype("category")
data_AND_Gate
# Out:
#      subject_id         rt stimulus sampling  nb_of_run rolled_OR_unrolled  \
# 0             1  19950.760  UAAS_RT    Right        1.0           Unrolled
# 1             1  14289.955  UABS_RB    Right        1.0           Unrolled
# 2             1  12181.330  UBBS_RT    Right        2.0           Unrolled
# 3             1  13457.560   UAS_RB    Right        1.0           Unrolled
# 4             1  12429.980   UBS_RB    Right        1.0           Unrolled
# ..          ...        ...      ...      ...        ...                ...
# 595         100  23013.000  UBAS_RT    Right        1.0           Unrolled
# 596         100  11951.000  UBBS_RB    Right        2.0           Unrolled
# 597         100  14898.000   UAS_RT    Right        1.0           Unrolled
# 598         100  11452.000   UBS_RT    Right        1.0           Unrolled
# 599         100  12388.000  UABS_RB    Right        1.0           Unrolled
#
#     A_branch_loc A_detectors state_OR_event state_branch root_1st imdt_2nd  \
# 0            Top     Squares          Event          NaN        A        A
# 1         Bottom     Squares          Event          NaN        A        B
# 2            Top     Squares          Event          NaN        B        B
# 3         Bottom     Squares          State            A      NaN        B
# 4         Bottom     Squares          State            B      NaN        A
# ..           ...         ...            ...          ...      ...      ...
# 595          Top     Squares          Event          NaN        B        A
# 596       Bottom     Squares          Event          NaN        B        B
# 597          Top     Squares          State            A      NaN        B
# 598          Top     Squares          State            B      NaN        A
# 599       Bottom     Squares          Event          NaN        A        B
#
#     node_selected
# 0          nodeA7
# 1         nodeA41
# 2          nodeB6
# 3         nodeA41
# 4         nodeB19
# ..            ...
# 595       nodeA25
# 596       nodeB16
# 597        nodeB8
# 598       nodeA30
# 599        nodeB8
#
# [600 rows x 13 columns]

# %% [markdown]
# ## Functions

# %%
def nb(letter,lower_bound,upper_bound):
    return [letter+str(i) for i in range(lower_bound,upper_bound+1)]

def chain_node_cat(stim,node):
    stim = stim.split('_')[0]
    node = node[4:]
    if stim == 'chainS':
        categories = {'INACT':nb('B',1,7),'ROOT':['B8','B9','B10'],'INBTW':nb('B',11,18),'IMDT':['B19'],'EFFECT':['B20']}
    elif stim == 'chainC':
        categories = {'INACT':nb('A',1,24),'ROOT':['A25','A26','A27'],'INBTW':nb('A',28,40),'IMDT':['A41'],'EFFECT':['B20']}
        
    category = [cat for cat,nd in categories.items() if node in nd][0]
    
    return category

def branch_node_cat(stim,node):
    node = node[4:]
    stim = stim.split('_')[0]
    if stim == 'UAAS': 
        categories = {'UNKNOWN':[],'INACT_1st':nb('A',1,6),'INACT_2nd':nb('B',1,6),'ROOT_1st':['A6','A7','A8'],
                      'ROOT_2nd':['B6','B7','B8'],'INBTW_1st':nb('A',9,40),'INBTW_2nd':nb('B',9,18),'IMDT_1st':['B19'],
                      'IMDT_2nd':['A41'],'EFFECT':['B20']}
    elif stim == 'UABS': 
        categories = {'UNKNOWN':[],'INACT_1st':nb('A',1,5),'INACT_2nd':nb('B',1,5),'ROOT_1st':['A6','A7','A8'],
                      'ROOT_2nd':['B6','B7','B8'],'INBTW_1st':nb('A',9,40),'INBTW_2nd':nb('B',9,18),'IMDT_1st':['A41'],
                      'IMDT_2nd':['B19'],'EFFECT':['B20']}
    elif stim == 'UAS': 
        categories = {'UNKNOWN':[],'INACT_1st':nb('A',1,25),'INACT_2nd':nb('B',1,6),'ROOT_1st':['A26','A27','A28'],
                      'ROOT_2nd':['B7','B8','B9'],'INBTW_1st':nb('A',29,40),'INBTW_2nd':nb('B',10,18),'IMDT_1st':['A41'],
                      'IMDT_2nd':['B19'],'EFFECT':['B20']}
    elif stim == 'UBAS': 
        categories = {'UNKNOWN':[],'INACT_1st':nb('B',1,2),'INACT_2nd':nb('A',1,23),'ROOT_1st':['B3','B4','B5'],
                      'ROOT_2nd':['A24','A25','A26'],'INBTW_1st':nb('B',6,18),'INBTW_2nd':nb('A',27,40),'IMDT_1st':['B19'],
                      'IMDT_2nd':['A41'],'EFFECT':['B20']}
    elif stim == 'UBBS': 
        categories = {'UNKNOWN':[],'INACT_1st':[],'INACT_2nd':nb('A',1,35),'ROOT_1st':['B1','B2','B3'],
                      'ROOT_2nd':['A36','A37','A38'],'INBTW_1st':nb('B',4,18),'INBTW_2nd':nb('A',39,40),'IMDT_1st':['A41'],
                      'IMDT_2nd':['B19'],'EFFECT':['B20']}
    elif stim == 'UBS': 
        categories = {'UNKNOWN':[],'INACT_1st':nb('B',1,6),'INACT_2nd':nb('A',1,28),'ROOT_1st':['B7','B8','B9'],
                      'ROOT_2nd':['A29','A30','A31'],'INBTW_1st':nb('B',10,18),'INBTW_2nd':nb('A',32,40),'IMDT_1st':['B19'],
                      'IMDT_2nd':['A41'],'EFFECT':['B20']}

    category = [cat for cat,nd in categories.items() if node in nd][0]

    return category

class AndGate(object):

    def __init__(self,rolled=False,continuity='root_1st'):
        if rolled == False:
            data = data_AND_Gate[data_AND_Gate["rolled_OR_unrolled"]=="Unrolled"]
        elif rolled == True:
            data = data_AND_Gate[data_AND_Gate["rolled_OR_unrolled"]=="Rolled"]
        if continuity == 'root_1st':
            data = data[data['root_1st']==data['imdt_2nd']]
        elif continuity == 'root_2nd':
            data = data[(data['root_1st']!=data['imdt_2nd'])|(data['state_OR_event']=='State')]
            
        self.df = data
        
        self.node_select = self.df["node_selected"].value_counts(normalize=True)*100
        values = {}
        nodes = ["nodeA"+str(i+1) for i in range(41)]+["nodeB"+str(i+1) for i in range(20)]
        for item in nodes:
            if item not in self.node_select.keys():
                values[item] = 0
            else:
                values[item] = self.node_select[item]
        self.node_select = pd.Series(values)
        
        self.node_category = self.df["node_category"].value_counts(normalize=True)*100
        values = {}
        cats = ['UNKNOWN','INACT_1st','INACT_2nd','ROOT_1st','ROOT_2nd','INBTW_1st','INBTW_2nd','IMDT_1st','IMDT_2nd','EFFECT']
        for item in cats:
            if item not in self.node_category.keys():
                values[item] = 0
            else:
                values[item] = self.node_category[item]
        self.node_category = pd.Series(values)
        
    def add_filter(self,sampling=None,level=None,state=None,root_1st=None,state_branch=None,A_detectors=None):
        if sampling == "right":
            self.df = self.df[self.df["sampling"]=="Right"]
        elif sampling == "left":
            self.df = self.df[self.df["sampling"]=="Left"]
        if level == "top":
            self.df = self.df[self.df["A_branch_loc"]=="Top"]
        elif level == "bottom":
            self.df = self.df[self.df["A_branch_loc"]=="Bottom"]
        if A_detectors == "squares":
            self.df = self.df[self.df["A_detectors"]=="Squares"]
        elif A_detectors == "circles":
            self.df = self.df[self.df["A_detectors"]=="Circles"]
        if state == False:
            self.df = self.df[self.df["state_OR_event"]=="Event"]
        elif state == True:
            self.df = self.df[self.df["state_OR_event"]=="State"]
        if root_1st == 'A':
            self.df = self.df[self.df["root_1st"]=="A"]
        elif root_1st == 'B':
            self.df = self.df[self.df["root_1st"]=="B"]
        if state_branch == 'A':
            self.df = self.df[self.df["state_branch"]=="A"]
        if state_branch == 'B':
            self.df = self.df[self.df["state_branch"]=="B"]
        
        self.node_select = self.df["node_selected"].value_counts(normalize=True)*100
        values = {}
        nodes = ["nodeA"+str(i+1) for i in range(41)]+["nodeB"+str(i+1) for i in range(20)]
        for item in nodes:
            if item not in self.node_select.keys():
                values[item] = 0
            else:
                values[item] = self.node_select[item]
        self.node_select = pd.Series(values)
        
        self.node_category = self.df["node_category"].value_counts(normalize=True)*100
        values = {}
        cats = ['UNKNOWN','INACT_1st','INACT_2nd','ROOT_1st','ROOT_2nd','INBTW_1st','INBTW_2nd','IMDT_1st','IMDT_2nd','EFFECT']
        for item in cats:
            if item not in self.node_category.keys():
                values[item] = 0
            else:
                values[item] = self.node_category[item]
        self.node_category = pd.Series(values)
        
        return self
    
class Chain(object):
    def __init__(self,stim=None):
        data = data_chain[data_chain["stim_type"] == stim]
            
        self.df = data
        
        self.node_select = self.df["node_selected"].value_counts(normalize=True)*100
        values = {}
        if stim == 'ChainS':
            nodes = ["nodeB"+str(i+1) for i in range(20)]
        elif stim == 'ChainC':
            nodes = ["nodeA"+str(i+1) for i in range(41)]+['nodesB20']
            
        for item in nodes:
            if item not in self.node_select.keys():
                values[item] = 0
            else:
                values[item] = self.node_select[item]
        self.node_select = pd.Series(values)
        
        self.node_category = self.df["node_category"].value_counts(normalize=True)*100
        values = {}
        cats = ['INACT','ROOT','INBTW','IMDT','EFFECT']
        for item in cats:
            if item not in self.node_category.keys():
                values[item] = 0
            else:
                values[item] = self.node_category[item]
        self.node_category = pd.Series(values)
        
    def add_filter(self,sampling=None,level=None):
        if sampling == "right":
            self.df = self.df[self.df["sampling"]=="Right"]
        elif sampling == "left":
            self.df = self.df[self.df["sampling"]=="Left"]
        if level == 'top':
            self.df = self.df[self.df['A_branch_loc']=='Top']
        elif level == 'bottom':
            self.df = self.df[self.df['A_branch_loc']=='Bottom']
            
        self.node_select = self.df["node_selected"].value_counts(normalize=True)*100
        values = {}
        stim = self.df['stim_type'].cat.remove_unused_categories().cat.categories[0]
        if stim == 'ChainS':
            nodes = ["nodeB"+str(i+1) for i in range(20)]
        elif stim == 'ChainC':
            nodes = ["nodeA"+str(i+1) for i in range(41)]+['nodesB20']
        for item in nodes:
            if item not in self.node_select.keys():
                values[item] = 0
            else:
                values[item] = self.node_select[item]
        self.node_select = pd.Series(values)
        
        self.node_category = self.df["node_category"].value_counts(normalize=True)*100
        values = {}
        cats = ['INACT','ROOT','INBTW','IMDT','EFFECT']
        for item in cats:
            if item not in self.node_category.keys():
                values[item] = 0
            else:
                values[item] = self.node_category[item]
        self.node_category = pd.Series(values)
        
        return self
    
def bootstrap(stim):
    df_mean_std = {}
    data = stim.df.node_category.to_numpy()
    labels = stim.df.node_category.cat.categories.to_list()
    if len(labels) == 9:
        labels = ['INACT_1st','INACT_2nd','ROOT_1st','ROOT_2nd','INBTW_1st','INBTW_2nd','IMDT_1st','IMDT_2nd','EFFECT']
    else:
        labels = ['INACT','ROOT','INBTW','IMDT','EFFECT']

    mean_per_cat = []
    std_per_cat = []    

    sample_mean = {}
    for category in labels:
            sample_mean[category] = []
    for _ in range(100):
        sample_n = np.random.choice(data, size=98)
        series = pd.Series(sample_n).value_counts(normalize=True)*100
        
        for category in sample_mean.keys():
            if category in series.index:
                mean = series[category]
                sample_mean[category].append(mean)

    for category in sample_mean.keys():
        sample_mean[category] = np.array(sample_mean[category])
        if len(sample_mean[category]) != 0:
            mean = np.mean(sample_mean[category])
            std = np.std(sample_mean[category])
        else:
            mean = 0
            std = 0

        mean_per_cat.append(mean)
        std_per_cat.append(std)

    df_mean_std["mean"] = mean_per_cat
    df_mean_std["std"] = std_per_cat

    df_mean_std = pd.DataFrame(df_mean_std,columns=['mean','std'],index=labels)
        
    return df_mean_std
    
def graph(list_of_df,title,x_axis='node_category'):
    plt.rcParams['axes.grid'] = False
    fig = plt.figure(figsize=(6.6*len(list_of_df),5))
    #fig = plt.figure(figsize=(6,5))
    a = str(len(list_of_df))
    for i,x in enumerate(list_of_df):
        axis = fig.add_subplot(int("1"+a+str(i+1)))
        #axis = fig.add_subplot(111)
        axis.set_ylim([0,80])
        axis.set_ylabel("Percentage of responses")
        axis.label_outer()
        axis.spines["top"].set_visible(False)
        axis.spines["right"].set_visible(False)
        axis.set_title(title[i])
        
        labels = x.index.to_list()
        mean_per_cat = x['mean'].values
        std_per_cat = x['std'].values
        axis.bar(labels, mean_per_cat, yerr=std_per_cat,capsize=3,ecolor='black',error_kw={'markeredgewidth':1})
        plt.xticks(rotation=90)
            
def graph2(x,x_axis='node_category'):
    plt.rcParams['axes.grid'] = False
    fig = plt.figure(figsize=(8,4))
    #fig.suptitle("Experiment 1", fontweight="bold",y=1.05)
    axis = fig.add_subplot(111)
    axis.spines["top"].set_visible(False)
    axis.spines["right"].set_visible(False)
    axis.set_ylim([0,80])
    kwargs={'fontsize':14}
    axis.set_ylabel("Number of responses (%)",**kwargs)
    axis.set_title('Summary of the results',**kwargs)
    axis.label_outer()
    categories = ['$RC','I1','R2','I2','other']
    event_R1c_mean = [x[0].loc["ROOT_1st","mean"],x[0].loc["IMDT_1st","mean"],x[0].loc["ROOT_2nd",'mean'],
                 x[0].loc['IMDT_2nd','mean'],x[0].loc['INACT_1st','mean']+x[0].loc['INACT_2nd','mean']+
                 x[0].loc['INBTW_1st','mean']+x[0].loc['INBTW_2nd','mean']+x[0].loc['EFFECT','mean']]
    event_R2c_mean = [x[1].loc["ROOT_1st","mean"],x[1].loc["IMDT_1st","mean"],x[1].loc["ROOT_2nd",'mean'],
                 x[1].loc['IMDT_2nd','mean'],x[1].loc['INACT_1st','mean']+x[1].loc['INACT_2nd','mean']+
                 x[1].loc['INBTW_1st','mean']+x[1].loc['INBTW_2nd','mean']+x[1].loc['EFFECT','mean']]
    state_R2c_mean = [x[2].loc["ROOT_1st","mean"],x[2].loc["IMDT_1st","mean"],x[2].loc["ROOT_2nd",'mean'],
                 x[2].loc['IMDT_2nd','mean'],x[2].loc['INACT_1st','mean']+x[2].loc['INACT_2nd','mean']+
                 x[2].loc['INBTW_1st','mean']+x[2].loc['INBTW_2nd','mean']+x[2].loc['EFFECT','mean']]
                      
    event_R1c_std = [x[0].loc["ROOT_1st","std"],x[0].loc["IMDT_1st","std"],x[0].loc["ROOT_2nd",'std'],
                 x[0].loc['IMDT_2nd','std'],x[0].loc['INACT_1st','std']+x[0].loc['INACT_2nd','std']+
                 x[0].loc['INBTW_1st','std']+x[0].loc['INBTW_2nd','std']+x[0].loc['EFFECT','std']]
    event_R2c_std = [x[1].loc["ROOT_1st","std"],x[1].loc["IMDT_1st","std"],x[1].loc["ROOT_2nd",'std'],
                 x[1].loc['IMDT_2nd','std'],x[1].loc['INACT_1st','std']+x[1].loc['INACT_2nd','std']+
                 x[1].loc['INBTW_1st','std']+x[1].loc['INBTW_2nd','std']+x[1].loc['EFFECT','std']]
    state_R2c_std = [x[2].loc["ROOT_1st","std"],x[2].loc["IMDT_1st","std"],x[2].loc["ROOT_2nd",'std'],
                 x[2].loc['IMDT_2nd','std'],x[2].loc['INACT_1st','std']+x[2].loc['INACT_2nd','std']+
                 x[2].loc['INBTW_1st','std']+x[2].loc['INBTW_2nd','std']+x[2].loc['EFFECT','std']]
    
    df_mean = pd.DataFrame({'$R_C$,$R_D$,$I_D$,$I_C$':event_R1c_mean,'$R_D$,$R_C$,$I_D$,$I_C$':event_R2c_mean,'$R_D$,$I_D$,$R_C$,$I_C$':state_R2c_mean}, 
                          index=categories)
    df_std = pd.DataFrame({'$R_C$,$R_D$,$I_D$,$I_C$':event_R1c_std,'$R_D$,$R_C$,$I_D$,$I_C$':event_R2c_std,'$R_D$,$I_D$,$R_C$,$I_C$':state_R2c_std}, 
                          index=categories)
    
    df_mean.plot.bar(ax=axis,yerr=df_std,capsize=3,ecolor='black',rot=0,error_kw={'markeredgewidth':1},fontsize=14)
    axis.legend(fontsize=14)

# %%
data_chain['node_category'] = data_chain.apply(lambda x: chain_node_cat(x['stimulus'],x['node_selected']),axis=1)
data_chain['node_category'] = data_chain['node_category'].astype('category')
data_AND_Gate['node_category'] = data_AND_Gate.apply(lambda x: branch_node_cat(x['stimulus'],x['node_selected']),axis=1)
data_AND_Gate['node_category'] = data_AND_Gate['node_category'].astype('category')

# %%
data_chain
# Out:
#     subject_id          rt  stimulus sampling  nb_of_run stim_type  \
# 0            1   10690.350  chainS_R    Right        1.0    ChainS
# 1            2    8851.390  chainS_L     Left        1.0    ChainS
# 2            3   18117.000  chainS_R    Right        1.0    ChainS
# 3            4   13172.380  chainS_L     Left        2.0    ChainS
# 4            5    8726.075  chainS_R    Right        1.0    ChainS
# 5            6    8505.340  chainS_R    Right        1.0    ChainS
# 6            7   12404.190  chainS_L     Left        1.0    ChainS
# 7            8   13427.315  chainS_L     Left        1.0    ChainS
# 8            9   15379.935  chainS_R    Right        1.0    ChainS
# 9           10    8439.875  chainS_R    Right        1.0    ChainS
# 10          11    9523.385  chainS_R    Right        1.0    ChainS
# 11          12   10375.785  chainS_L     Left        1.0    ChainS
# 12          13   21004.165  chainS_R    Right        1.0    ChainS
# 13          14   10241.805  chainS_L     Left        1.0    ChainS
# 14          15   10988.320  chainS_L     Left        1.0    ChainS
# 15          16    8575.000  chainS_R    Right        1.0    ChainS
# 16          17    8417.960  chainS_L     Left        1.0    ChainS
# 17          18   12207.000  chainS_R    Right        1.0    ChainS
# 18          19    8948.425  chainS_R    Right        1.0    ChainS
# 19          20    8669.350  chainS_R    Right        1.0    ChainS
# 20          21   10190.380  chainS_L     Left        1.0    ChainS
# 21          22   23526.000  chainS_R    Right        1.0    ChainS
# 22          23   20741.985  chainS_R    Right        1.0    ChainS
# 23          24    9046.895  chainS_R    Right        2.0    ChainS
# 24          25   11037.710  chainS_L     Left        1.0    ChainS
# 25          26   13049.000  chainS_R    Right        1.0    ChainS
# 26          27   12091.355  chainS_R    Right        1.0    ChainS
# 27          28    9447.650  chainS_R    Right        1.0    ChainS
# 28          29    9806.295  chainS_R    Right        1.0    ChainS
# 29          30   11662.000  chainS_L     Left        1.0    ChainS
# 30          31   19400.325  chainS_R    Right        1.0    ChainS
# 31          32    8452.700  chainS_L     Left        1.0    ChainS
# 32          33   17933.975  chainS_L     Left        1.0    ChainS
# 33          34   16157.695  chainS_R    Right        1.0    ChainS
# 34          35   14035.540  chainS_L     Left        1.0    ChainS
# 35          36    9775.965  chainS_R    Right        1.0    ChainS
# 36          37   14949.535  chainS_L     Left        1.0    ChainS
# 37          38   15195.440  chainS_L     Left        1.0    ChainS
# 38          39   14397.480  chainS_L     Left        1.0    ChainS
# 39          40    9042.515  chainS_L     Left        1.0    ChainS
# 40          41   15420.255  chainS_R    Right        2.0    ChainS
# 41          42   15876.585  chainS_L     Left        1.0    ChainS
# 42          43   10675.925  chainS_R    Right        1.0    ChainS
# 43          44    8686.675  chainS_R    Right        1.0    ChainS
# 44          45   12339.435  chainS_L     Left        1.0    ChainS
# 45          46   13496.000  chainS_R    Right        1.0    ChainS
# 46          47   12435.215  chainS_R    Right        1.0    ChainS
# 47          48   16580.185  chainS_R    Right        1.0    ChainS
# 48          49   18811.000  chainS_R    Right        1.0    ChainS
# 49          50    9362.000  chainS_L     Left        1.0    ChainS
# 50          51   14400.270  chainS_L     Left        1.0    ChainS
# 51          52   39882.000  chainS_R    Right        1.0    ChainS
# 52          53   12399.005  chainS_R    Right        1.0    ChainS
# 53          54    9426.640  chainS_L     Left        1.0    ChainS
# 54          55   13496.280  chainS_R    Right        1.0    ChainS
# 55          56   42417.000  chainS_L     Left        1.0    ChainS
# 56          57    8203.025  chainS_L     Left        1.0    ChainS
# 57          58    8678.645  chainS_L     Left        1.0    ChainS
# 58          59   10590.000  chainS_L     Left        1.0    ChainS
# 59          60   11886.030  chainS_R    Right        1.0    ChainS
# 60          61   27544.140  chainS_R    Right        1.0    ChainS
# 61          62   10101.310  chainS_L     Left        1.0    ChainS
# 62          63   17833.050  chainS_R    Right        1.0    ChainS
# 63          64   13328.700  chainS_R    Right        1.0    ChainS
# 64          65    8326.835  chainS_R    Right        1.0    ChainS
# 65          66    9585.970  chainS_R    Right        1.0    ChainS
# 66          67    8073.260  chainS_R    Right        1.0    ChainS
# 67          68   23340.725  chainS_L     Left        1.0    ChainS
# 68          69   12116.310  chainS_L     Left        1.0    ChainS
# 69          70   12998.270  chainS_R    Right        1.0    ChainS
# 70          71    8856.505  chainS_L     Left        1.0    ChainS
# 71          72    9244.755  chainS_L     Left        1.0    ChainS
# 72          73   18796.160  chainS_R    Right        1.0    ChainS
# 73          74   19678.000  chainS_L     Left        1.0    ChainS
# 74          75   11839.455  chainS_L     Left        1.0    ChainS
# 75          76    8776.000  chainS_L     Left        1.0    ChainS
# 76          77   10715.000  chainS_R    Right        1.0    ChainS
# 77          78    8951.025  chainS_L     Left        1.0    ChainS
# 78          79  118256.700  chainS_R    Right        1.0    ChainS
# 79          80    8892.990  chainS_L     Left        1.0    ChainS
# 80          81   13784.000  chainS_R    Right        1.0    ChainS
# 81          82   12514.810  chainS_L     Left        1.0    ChainS
# 82          83   15936.000  chainS_R    Right        1.0    ChainS
# 83          84   14772.000  chainS_R    Right        1.0    ChainS
# 84          85    9409.000  chainS_L     Left        1.0    ChainS
# 85          86   14320.570  chainS_L     Left        1.0    ChainS
# 86          87    8983.545  chainS_L     Left        1.0    ChainS
# 87          88   11751.000  chainS_L     Left        1.0    ChainS
# 88          89   11133.860  chainS_R    Right        1.0    ChainS
# 89          90   10045.635  chainS_L     Left        1.0    ChainS
# 90          91   10157.510  chainS_R    Right        1.0    ChainS
# 91          92    9137.635  chainS_R    Right        1.0    ChainS
# 92          93    8343.835  chainS_R    Right        1.0    ChainS
# 93          94   12891.510  chainS_L     Left        1.0    ChainS
# 94          95   16905.000  chainS_L     Left        2.0    ChainS
# 95          96   15509.650  chainS_R    Right        1.0    ChainS
# 96          97    8712.725  chainS_L     Left        1.0    ChainS
# 97          98   12263.975  chainS_R    Right        1.0    ChainS
# 98          99   15934.585  chainS_R    Right        1.0    ChainS
# 99         100   14964.000  chainS_R    Right        1.0    ChainS
#
#    A_branch_loc node_selected node_category
# 0           NaN        nodeB9          ROOT
# 1           NaN        nodeB9          ROOT
# 2           NaN        nodeB9          ROOT
# 3           NaN       nodeB19          IMDT
# 4           NaN        nodeB9          ROOT
# 5           NaN        nodeB9          ROOT
# 6           NaN        nodeB9          ROOT
# 7           NaN        nodeB9          ROOT
# 8           NaN        nodeB9          ROOT
# 9           NaN        nodeB9          ROOT
# 10          NaN        nodeB9          ROOT
# 11          NaN        nodeB9          ROOT
# 12          NaN        nodeB9          ROOT
# 13          NaN        nodeB9          ROOT
# 14          NaN        nodeB9          ROOT
# 15          NaN        nodeB9          ROOT
# 16          NaN        nodeB9          ROOT
# 17          NaN       nodeB20        EFFECT
# 18          NaN       nodeB19          IMDT
# 19          NaN        nodeB9          ROOT
# 20          NaN       nodeB19          IMDT
# 21          NaN        nodeB9          ROOT
# 22          NaN       nodeB19          IMDT
# 23          NaN       nodeB19          IMDT
# 24          NaN        nodeB9          ROOT
# 25          NaN        nodeB9          ROOT
# 26          NaN        nodeB9          ROOT
# 27          NaN        nodeB9          ROOT
# 28          NaN        nodeB9          ROOT
# 29          NaN        nodeB9          ROOT
# 30          NaN       nodeB19          IMDT
# 31          NaN       nodeB19          IMDT
# 32          NaN        nodeB9          ROOT
# 33          NaN        nodeB9          ROOT
# 34          NaN        nodeB9          ROOT
# 35          NaN        nodeB9          ROOT
# 36          NaN        nodeB9          ROOT
# 37          NaN        nodeB9          ROOT
# 38          NaN       nodeB19          IMDT
# 39          NaN        nodeB9          ROOT
# 40          NaN        nodeB9          ROOT
# 41          NaN        nodeB9          ROOT
# 42          NaN       nodeB19          IMDT
# 43          NaN        nodeB9          ROOT
# 44          NaN       nodeB19          IMDT
# 45          NaN       nodeB19          IMDT
# 46          NaN        nodeB8          ROOT
# 47          NaN       nodeB19          IMDT
# 48          NaN        nodeB9          ROOT
# 49          NaN       nodeB19          IMDT
# 50          NaN        nodeB9          ROOT
# 51          NaN        nodeB9          ROOT
# 52          NaN       nodeB20        EFFECT
# 53          NaN        nodeB9          ROOT
# 54          NaN       nodeB20        EFFECT
# 55          NaN        nodeB9          ROOT
# 56          NaN        nodeB9          ROOT
# 57          NaN        nodeB9          ROOT
# 58          NaN        nodeB9          ROOT
# 59          NaN       nodeB19          IMDT
# 60          NaN       nodeB11         INBTW
# 61          NaN       nodeB19          IMDT
# 62          NaN       nodeB19          IMDT
# 63          NaN       nodeB19          IMDT
# 64          NaN        nodeB9          ROOT
# 65          NaN       nodeB19          IMDT
# 66          NaN       nodeB20        EFFECT
# 67          NaN        nodeB9          ROOT
# 68          NaN        nodeB9          ROOT
# 69          NaN       nodeB19          IMDT
# 70          NaN        nodeB9          ROOT
# 71          NaN        nodeB9          ROOT
# 72          NaN       nodeB19          IMDT
# 73          NaN       nodeB20        EFFECT
# 74          NaN       nodeB13         INBTW
# 75          NaN        nodeB9          ROOT
# 76          NaN        nodeB9          ROOT
# 77          NaN        nodeB9          ROOT
# 78          NaN        nodeB9          ROOT
# 79          NaN        nodeB1         INACT
# 80          NaN       nodeB20        EFFECT
# 81          NaN        nodeB9          ROOT
# 82          NaN        nodeB9          ROOT
# 83          NaN        nodeB9          ROOT
# 84          NaN        nodeB9          ROOT
# 85          NaN        nodeB9          ROOT
# 86          NaN        nodeB9          ROOT
# 87          NaN        nodeB8          ROOT
# 88          NaN       nodeB19          IMDT
# 89          NaN        nodeB9          ROOT
# 90          NaN        nodeB9          ROOT
# 91          NaN        nodeB9          ROOT
# 92          NaN        nodeB9          ROOT
# 93          NaN        nodeB9          ROOT
# 94          NaN        nodeB8          ROOT
# 95          NaN       nodeB19          IMDT
# 96          NaN        nodeB9          ROOT
# 97          NaN       nodeB19          IMDT
# 98          NaN        nodeB9          ROOT
# 99          NaN       nodeB19          IMDT

# %% [markdown]
# ## General comparison

# %%
# For Unrolled: only graphs with SQUARES for branch A

chain = Chain(stim='ChainS')
Unrolled_state = AndGate(rolled=False,continuity='root_2nd').add_filter(A_detectors='squares',state=True)
Unrolled_stateA = AndGate(rolled=False,continuity='root_2nd').add_filter(A_detectors='squares',state=True,state_branch='A')
Unrolled_stateB = AndGate(rolled=False,continuity='root_2nd').add_filter(A_detectors='squares',state=True,state_branch='B')
Unrolled_AA_BB = AndGate(rolled=False,continuity='root_1st').add_filter(A_detectors='squares')
Unrolled_AA = AndGate(rolled=False,continuity='root_1st').add_filter(A_detectors='squares',root_1st='A')
Unrolled_BB = AndGate(rolled=False,continuity='root_1st').add_filter(A_detectors='squares',root_1st='B')
Unrolled_AB_BA = AndGate(rolled=False,continuity='root_2nd').add_filter(A_detectors='squares',state=False)
Unrolled_AB = AndGate(rolled=False,continuity='root_2nd').add_filter(A_detectors='squares',state=False,root_1st='A')
Unrolled_BA = AndGate(rolled=False,continuity='root_2nd').add_filter(A_detectors='squares',state=False,root_1st='B')

####### Bootstrapping #######

chain = bootstrap(chain)
U = bootstrap(Unrolled_state)
UA = bootstrap(Unrolled_stateA)
UB = bootstrap(Unrolled_stateB)
UAA_BB = bootstrap(Unrolled_AA_BB)
UAA = bootstrap(Unrolled_AA)
UBB = bootstrap(Unrolled_BB)
UAB_BA = bootstrap(Unrolled_AB_BA)
UAB = bootstrap(Unrolled_AB)
UBA = bootstrap(Unrolled_BA)

graph([chain],['Chain'])
graph([U,UA,UB],['Unrolled A or B in state condition','Unrolled A in state condition','Unrolled B in state condition'])
graph([UAA_BB,UAA,UBB],['Unrolled AA or BB','Unrolled AA','Unrolled BB'])
graph([UAB_BA,UAB,UBA],['Unrolled AB or BA','Unrolled AB','Unrolled BA'])

# %%
graph2([UAA_BB,UAB_BA,U])
#plt.savefig('results_E2.jpg',dpi=300,bbox_inches='tight')

# %%
UAA_BB
# Out:
#                 mean       std
# INACT_1st   1.320528  0.581954
# INACT_2nd   2.557023  1.287148
# ROOT_1st   45.153061  4.620940
# ROOT_2nd   19.112245  4.182068
# INBTW_1st   3.582058  1.857140
# INBTW_2nd   1.308784  0.549220
# IMDT_1st    0.000000  0.000000
# IMDT_2nd   26.193878  3.946896
# EFFECT      3.029001  1.664911

# %%
UAB_BA
# Out:
#                 mean       std
# INACT_1st   1.414657  0.660437
# INACT_2nd   1.884921  0.926203
# ROOT_1st   23.357143  4.283029
# ROOT_2nd   42.357143  5.440785
# INBTW_1st   2.527829  1.499193
# INBTW_2nd   1.654298  0.883970
# IMDT_1st    1.439037  0.552557
# IMDT_2nd   25.265306  4.431721
# EFFECT      3.329753  1.954179

# %%
U
# Out:
#                 mean       std
# INACT_1st   1.587302  0.801708
# INACT_2nd   1.195335  0.384575
# ROOT_1st   21.928571  4.289345
# ROOT_2nd   44.275510  4.229207
# INBTW_1st   1.388424  0.555309
# INBTW_2nd   1.557465  0.742875
# IMDT_1st    2.713358  1.331217
# IMDT_2nd   25.214286  4.504371
# EFFECT      3.723964  1.859395

# %% [markdown]
# ## Comparison Right *vs* Left

# %%
# Same as the general comparison BUT only for the condition 'right'

chain = Chain(stim='ChainS').add_filter(sampling='right')
Unrolled_state = AndGate(rolled=False,continuity='root_2nd').add_filter(sampling='right',state=True)
Unrolled_stateA = AndGate(rolled=False,continuity='root_2nd').add_filter(sampling='right',state=True,state_branch='A')
Unrolled_stateB = AndGate(rolled=False,continuity='root_2nd').add_filter(sampling='right',state=True,state_branch='B')
Unrolled_AA_BB = AndGate(rolled=False,continuity='root_1st').add_filter(sampling='right')
Unrolled_AA = AndGate(rolled=False,continuity='root_1st').add_filter(sampling='right',root_1st='A')
Unrolled_BB = AndGate(rolled=False,continuity='root_1st').add_filter(sampling='right',root_1st='B')
Unrolled_AB_BA = AndGate(rolled=False,continuity='root_2nd').add_filter(sampling='right',state=False)
Unrolled_AB = AndGate(rolled=False,continuity='root_2nd').add_filter(sampling='right',state=False,root_1st='A')
Unrolled_BA = AndGate(rolled=False,continuity='root_2nd').add_filter(sampling='right',state=False,root_1st='B')

chain = bootstrap(chain)
U = bootstrap(Unrolled_state)
UA = bootstrap(Unrolled_stateA)
UB = bootstrap(Unrolled_stateB)
UAA_BB = bootstrap(Unrolled_AA_BB)
UAA = bootstrap(Unrolled_AA)
UBB = bootstrap(Unrolled_BB)
UAB_BA = bootstrap(Unrolled_AB_BA)
UAB = bootstrap(Unrolled_AB)
UBA = bootstrap(Unrolled_BA)

graph([chain],['Chain'])
graph([U,UA,UB],['Unrolled A or B in state condition','Unrolled A in state condition','Unrolled B in state condition'])
graph([UAA_BB,UAA,UBB],['Unrolled AA or BB','Unrolled AA','Unrolled BB'])
graph([UAB_BA,UAB,UBA],['Unrolled AB or BA','Unrolled AB','Unrolled BA'])

# %%
# Same as the general comparison BUT only for the condition 'left'

chain = Chain(stim='ChainS').add_filter(sampling='left')
Unrolled_state = AndGate(rolled=False,continuity='root_2nd').add_filter(sampling='left',A_detectors='squares',state=True)
Unrolled_stateA = AndGate(rolled=False,continuity='root_2nd').add_filter(sampling='left',A_detectors='squares',state=True,state_branch='A')
Unrolled_stateB = AndGate(rolled=False,continuity='root_2nd').add_filter(sampling='left',A_detectors='squares',state=True,state_branch='B')
Unrolled_AA_BB = AndGate(rolled=False,continuity='root_1st').add_filter(A_detectors='squares',sampling='left')
Unrolled_AA = AndGate(rolled=False,continuity='root_1st').add_filter(sampling='left',A_detectors='squares',root_1st='A')
Unrolled_BB = AndGate(rolled=False,continuity='root_1st').add_filter(sampling='left',A_detectors='squares',root_1st='B')
Unrolled_AB_BA = AndGate(rolled=False,continuity='root_2nd').add_filter(sampling='left',A_detectors='squares',state=False)
Unrolled_AB = AndGate(rolled=False,continuity='root_2nd').add_filter(sampling='left',A_detectors='squares',state=False,root_1st='A')
Unrolled_BA = AndGate(rolled=False,continuity='root_2nd').add_filter(sampling='left',A_detectors='squares',state=False,root_1st='B')

chain = bootstrap(chain)
U = bootstrap(Unrolled_state)
UA = bootstrap(Unrolled_stateA)
UB = bootstrap(Unrolled_stateB)
UAA_BB = bootstrap(Unrolled_AA_BB)
UAA = bootstrap(Unrolled_AA)
UBB = bootstrap(Unrolled_BB)
UAB_BA = bootstrap(Unrolled_AB_BA)
UAB = bootstrap(Unrolled_AB)
UBA = bootstrap(Unrolled_BA)

graph([chain],['Chain'])
graph([U,UA,UB],['Unrolled A or B in state condition','Unrolled A in state condition','Unrolled B in state condition'])
graph([UAA_BB,UAA,UBB],['Unrolled AA or BB','Unrolled AA','Unrolled BB'])
graph([UAB_BA,UAB,UBA],['Unrolled AB or BA','Unrolled AB','Unrolled BA'])

# %%
# Broad comparison between right vs left sampling

chain_Right = Chain(stim='ChainS').add_filter(sampling='right')
chain_Left = Chain(stim='ChainS').add_filter(sampling='left')
Unrolled_state_Right = AndGate(rolled=False,continuity='root_2nd').add_filter(sampling='right',state=True)
Unrolled_state_Left = AndGate(rolled=False,continuity='root_2nd').add_filter(sampling='left',state=True)
Unrolled_AA_BB_Right = AndGate(rolled=False,continuity='root_1st').add_filter(sampling='right')
Unrolled_AA_BB_Left = AndGate(rolled=False,continuity='root_1st').add_filter(sampling='left')
Unrolled_AB_BA_Right = AndGate(rolled=False,continuity='root_2nd').add_filter(sampling='right',state=False)
Unrolled_AB_BA_Left = AndGate(rolled=False,continuity='root_2nd').add_filter(sampling='left',state=False)

chain_R = bootstrap(chain_Right)
chain_L = bootstrap(chain_Left)
U_R = bootstrap(Unrolled_state_Right)
U_L = bootstrap(Unrolled_state_Left)
UAA_BB_R = bootstrap(Unrolled_AA_BB_Right)
UAA_BB_L = bootstrap(Unrolled_AA_BB_Left)
UAB_BA_R = bootstrap(Unrolled_AB_BA_Right)
UAB_BA_L = bootstrap(Unrolled_AB_BA_Left)

graph([chain_R,chain_L],['Chain left','Chain right'])
graph([U_R,U_L],['Unrolled A or B in state condition left','Unrolled A or B in state condition right'])
graph([UAA_BB_R,UAA_BB_L],['Unrolled AA or BB left','Unrolled AA or BB right'])
graph([UAB_BA_R,UAB_BA_L],['Unrolled AB or BA left','Unrolled AB or BA right'])

# %% [markdown]
# ## Comparison Top *vs* Bottom

# %%
# Broad comparison between TOP vs BOTTOM location of branch A

Unrolled_state_Top = AndGate(rolled=False,continuity='root_2nd').add_filter(level='top',state=True)
Unrolled_state_Bottom = AndGate(rolled=False,continuity='root_2nd').add_filter(level='bottom',state=True)
Unrolled_AA_BB_Top = AndGate(rolled=False,continuity='root_1st').add_filter(level='top')
Unrolled_AA_BB_Bottom = AndGate(rolled=False,continuity='root_1st').add_filter(level='bottom')
Unrolled_AB_BA_Top = AndGate(rolled=False,continuity='root_2nd').add_filter(level='top',state=False)
Unrolled_AB_BA_Bottom = AndGate(rolled=False,continuity='root_2nd').add_filter(level='bottom',state=False)

US_T = bootstrap(Unrolled_state_Top)
US_B = bootstrap(Unrolled_state_Bottom)
UAA_BB_T = bootstrap(Unrolled_AA_BB_Top)
UAA_BB_B = bootstrap(Unrolled_AA_BB_Bottom)
UAB_BA_T = bootstrap(Unrolled_AB_BA_Top)
UAB_BA_B = bootstrap(Unrolled_AB_BA_Bottom)

graph([US_T,US_B],['Unrolled A or B in state condition top','Unrolled A or B in state condition bottom'])
graph([UAA_BB_T,UAA_BB_B],['Unrolled AA or BB top','Unrolled AA or BB bottom'])
graph([UAB_BA_T,UAB_BA_B],['Unrolled AB or BA top','Unrolled AB or BA bottom'])
